# %%
# !pwd
# %matplotlib widget
# Out:
# /panda/eedy/Kyushu/notebook

# %%
## 只有一个点的GNSS，所以就不用了
#from mintpy.cli import view, tsview, plot_network, plot_transection
#opt = '--show-gps  --gps-comp enu2los  -v -2 2 --lalo-label --lalo-step 0.5 --ylabel-rot 90 --figsize 10 8 --mask-gps '
#view.main(f'../mintpy_ion_split_deramp/geo/geo_velocity.h5 velocity {opt} -m ../mintpy_ion_split_deramp/geo/geo_maskTempCoh.h5 --title geo_velocity_SET_ion-split_ERA5_ramp_demErr'.split())
# Out:
# run view.py in MintPy version 1.6.0, date 2024-05-09
# input file is velocity file: /panda/eedy/Kyushu/mintpy_ion_split_deramp/geo/geo_velocity.h5 in float32 format
# file size in y/x: (510, 367)
# input dataset: "['velocity']"
# turning glob search OFF for velocity file
# num of datasets in file geo_velocity.h5: 5
# datasets to exclude (0):
# []
# datasets to display (1):
# ['velocity']
# data   coverage in y/x: (0, 0, 367, 510)
# subset coverage in y/x: (0, 0, 367, 510)
# data   coverage in lat/lon: (130.4245844837754, 32.41639027296167, 131.1350116250617, 31.715188072759656)
# subset coverage in lat/lon: (130.4245844837754, 32.41639027296167, 131.1350116250617, 31.715188072759656)
# ------------------------------------------------------------------------
# colormap: jet
# initiate cartopy map projection: PlateCarree
# figure title: geo_velocity_SET_ion-split_ERA5_ramp_demErr
# read mask from file: geo_maskTempCoh.h5
# reading data ...
# masking data
# ...

# %%
## 做了ramp
from mintpy.cli import view, tsview, plot_network, plot_transection
opt = '-v -2 2 --ref-yx 180 190 --noverbos '
view.main(f'../mintpy_no_ion_deramp/geo/geo_velocity.h5 velocity  {opt} --title geo_velocity_SET_ERA5_ramp_demErr '.split())
view.main(f'../mintpy_ion_split_deramp/geo/geo_velocity.h5 velocity {opt} --title geo_velocity_SET_ion-split_ERA5_ramp_demErr'.split())
view.main(f'../mintpy_ion_GIM_deramp/geo/geo_velocity.h5 velocity {opt} --title geo_velocity_SET_ion-GIM_ERA5_ramp_demErr'.split())
# Out:
# view.py ../mintpy_no_ion_deramp/geo/geo_velocity.h5 velocity -v -2 2 --ref-yx 180 190 --noverbos --title geo_velocity_SET_ERA5_ramp_demErr
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# view.py ../mintpy_ion_split_deramp/geo/geo_velocity.h5 velocity -v -2 2 --ref-yx 180 190 --noverbos --title geo_velocity_SET_ion-split_ERA5_ramp_demErr
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# view.py ../mintpy_ion_GIM_deramp/geo/geo_velocity.h5 velocity -v -2 2 --ref-yx 180 190 --noverbos --title geo_velocity_SET_ion-GIM_ERA5_ramp_demErr
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
## 没有做ramp
from mintpy.cli import view, tsview, plot_network, plot_transection
opt = '-v -2 2 --ref-yx 180 190 --noverbos '
view.main(f'../mintpy_no_ion/geo/geo_velocity.h5 velocity  {opt} --title geo_velocity_SET_ERA5_demErr '.split())
view.main(f'../mintpy_ion_split/geo/geo_velocity.h5 velocity {opt} --title geo_velocity_SET_ion-split_ERA5_demErr'.split())
view.main(f'../mintpy_ion_GIM/geo/geo_velocity.h5 velocity {opt} --title geo_velocity_SET_ion-GIM_ERA5_demErr'.split())
# Out:
# view.py ../mintpy_no_ion/geo/geo_velocity.h5 velocity -v -2 2 --ref-yx 180 190 --noverbos --title geo_velocity_SET_ERA5_demErr
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# view.py ../mintpy_ion_split/geo/geo_velocity.h5 velocity -v -2 2 --ref-yx 180 190 --noverbos --title geo_velocity_SET_ion-split_ERA5_demErr
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# view.py ../mintpy_ion_GIM/geo/geo_velocity.h5 velocity -v -2 2 --ref-yx 180 190 --noverbos --title geo_velocity_SET_ion-GIM_ERA5_demErr
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
