# %%
# !pwd
# Out:
# /panda/eedy/ion_los-angle/s1_a166/mintpy_gim_ion_upsample/geo

# %%
from mintpy.cli import view, tsview, plot_network, plot_transection
opt = '--show-gnss  --gnss-comp enu2los  -v -2 2 --lalo-label --lalo-step 1 --ylabel-rot 90 --ref-gnss P623 --figsize 20 16 --save --noverbose '
view.main(f' geo_velocity.h5 velocity {opt} -m geo_maskTempCoh.h5 --title geo_velocity_SET_ERA5_demErr'.split())
# Out:
# view.py geo_velocity.h5 velocity --show-gnss --gnss-comp enu2los -v -2 2 --lalo-label --lalo-step 1 --ylabel-rot 90 --ref-gnss P623 --figsize 20 16 --save --noverbose -m geo_maskTempCoh.h5 --title geo_velocity_SET_ERA5_demErr
# load 21962 GNSS sites with fields: site lat lon start_date end_date num_solution
# keep sites within SNWE of (31.746136327112016, 40.24959559776317, -118.25408627841469, -113.5850835591817): [745]
# keep sites with end_date >= 20150403: [666]
# keep sites with start_date <= 20211221: [636]
# keep sites with # of solutions >= 50: [634]
# ['7OAK' '7ODM' 'ACSB' 'ACSX' 'AERO' 'AGMT' 'AIAH' 'ALAM' 'ANTB' 'ANTE'
#  'AQUA' 'AR27' 'AR53' 'ASHM' 'AST1' 'AST2' 'AVRY' 'AZBH' 'AZDS' 'AZFM'
#  'AZGV' 'AZKG' 'AZLH' 'AZPK' 'AZQZ' 'AZRY' 'AZU1' 'AZYC' 'AZYU' 'AZYW'
#  'BBRY' 'BDSP' 'BEAT' 'BEER' 'BEES' 'BEMT' 'BEPK' 'BGIS' 'BIGS' 'BILL'
#  'BIRD' 'BKAP' 'BKMS' 'BLSA' 'BLYT' 'BMHL' 'BNSL' 'BOBS' 'BOMG' 'BONI'
#  'BOUL' 'BRAW' 'BROK' 'BSRY' 'BTDM' 'CA29' 'CAB5' 'CABD' 'CABS' 'CABY'
#  'CAC1' 'CAC2' 'CACJ' 'CACL' 'CACM' 'CACT' 'CACX' 'CAE1' 'CAE2' 'CAEC'
#  'CAES' 'CAGD' 'CAGW' 'CAHV' 'CAIB' 'CAIV' 'CAL5' 'CALA' 'CALK' 'CALL'
#  'CALS' 'CANC' 'CANI' 'CAOR' 'CAOS' 'CARA' 'CAS4' 'CAS6' 'CASD' 'CASE'
#  'CASJ' 'CATE' 'CAVI' 'CAWS' 'CBAD' 'CCCC' 'CCCS' 'CCWR' 'CDMT' 'CERB'
#  'CERR' 'CGDM' 'CHIA' 'CHIL' 'CHMS' 'CHNA' 'CIT1' 'CJMG' 'CJMS' 'CJVG'
#  'CLAR' 'CLBD' 'CLV1' 'CLV2' 'CLV3' 'CMPO' 'CMRP' 'CNPP' 'COAG' 'COKG'
#  'COLD' 'COLU' 'COPP' 'CORX' 'COSJ' 'COSO' 'COTD' 'COYA' 'CPBN' 'CRAM'
#  'CRFP' 'CRPL' 'CRRS' 'CTMS' 'CVHS' 'DAEX' 'DEEP' 'DESC' 'DETR' 'DEVL'
#  'DHLG' 'DLUZ' 'DMAR' 'DRYC' 'DS13' 'DSME' 'DSSC' 'DTPG' 'DUNF' 'DVNW'
#  'DVPB' 'DVSE' 'DYH2' 'EAGL' 'ECFS' 'ECHO' 'EGAN' 'ELGI' 'ELLY' 'ELSC'
#  'ELSG' 'EPAS' 'ERRG' 'ESC1' 'ESCN' 'EWPP' 'FHOG' 'FISH' 'FOOT' 'FOXG'
#  'FSHB' 'FVPK' 'GALE' 'GARD' 'GEMF' 'GEND' 'GEOR' 'GHRP' 'GISA' 'GLRS'
#  'GMAG' 'GMPK' 'GMRC' 'GNPS' 'GOAT' 'GOL2' 'GOLD' 'GRES' 'GUNL' 'GVRS'
#  'HANN' 'HAR7' 'HCMN' 'HFVV' 'HIGH' 'HIKO' 'HIVI' 'HMTG' 'HNA1' 'HNPS'
#  'HNTS' 'HOL3' 'HOLP' 'HOME' 'HOOT' 'HUAL' 'HW50' 'HW95' 'I40A' 'ICKY'
#  'ICOR' 'IDOG' 'IDQG' 'IID2' 'IMIE' 'IMPS' 'INDE' 'INKH' 'IRVI' 'IVAN'
#  'IXLC' 'JAS1' 'JEAN' 'JNHG' 'JONE' 'JPL3' 'JPL4' 'JPLF' 'JPLM' 'JPLQ'
#  'JPLT' 'JPLV' 'KDMM' 'KEMP' 'KENN' 'KGMN' 'KING' 'KITT' 'KYVW' 'LAVA'
#  'LBC1' 'LBC2' 'LBCH' 'LBNO' 'LBRF' 'LBSE' 'LBSW' 'LDES' 'LDSW' 'LGWD'
#  'LINJ' 'LITT' 'LKHG' 'LL01' 'LLAS' 'LMHG' 'LMSG' 'LNMT' 'LONG' 'LONP'
#  'LORS' 'LPCG' 'LPHS' 'LRRG' 'MANH' 'MAT2' 'MCKI' 'MCOY' 'MEAD' 'MERC'
#  'MESQ' 'MEXI' 'MHMS' 'MILK' 'MILR' 'MINA' 'MINE' 'MISE' 'MJPK' 'MLFP'
#  'MOHO' 'MONP' 'MONT' 'MRDM' 'MSC1' 'MSOB' 'MTA1' 'MTGG' 'MUDD' 'MVFD'
#  'MXGE' 'MXGM' 'MXGW' 'MXS1' 'NAYX' 'NDAP' 'NELS' 'NEVA' 'NEWS' 'NOCO'
#  'NOPE' 'NPAS' 'NSSS' 'NVAG' 'NVAL' 'NVB1' 'NVBC' 'NVBM' 'NVC1' 'NVC2'
#  'NVCA' 'NVCO' 'NVDB' 'NVFW' 'NVH1' 'NVH2' 'NVIS' 'NVKP' 'NVL1' 'NVLA'
#  'NVLM' 'NVLV' 'NVLX' 'NVM1' 'NVMQ' 'NVMV' 'NVNL' 'NVOV' 'NVPI' 'NVPO'
#  'NVRM' 'NVSL' 'NVSV' 'NVTP' 'NVWS' 'NYOR' 'OAES' 'OASI' 'OBRC' 'OCSD'
#  'OEOC' 'OLNC' 'OMRE' 'OPBL' 'OPCL' 'OPCP' 'OPCX' 'OPRD' 'ORMT' 'OTAY'
#  'OTHQ' 'OWEN' 'OXYC' 'P002' 'P003' 'P005' 'P006' 'P010' 'P066' 'P068'
#  'P069' 'P071' 'P072' 'P073' 'P074' 'P075' 'P076' 'P077' 'P079' 'P080'
#  'P081' 'P091' 'P092' 'P093' 'P094' 'P099' 'P102' 'P132' 'P462' 'P463'
#  'P464' 'P465' 'P466' 'P467' 'P468' 'P469' 'P470' 'P471' 'P472' 'P473'
#  'P474' 'P475' 'P476' 'P477' 'P478' 'P479' 'P480' 'P481' 'P482' 'P483'
#  'P484' 'P485' 'P486' 'P487' 'P488' 'P489' 'P490' 'P491' 'P492' 'P493'
#  'P494' 'P495' 'P496' 'P497' 'P498' 'P499' 'P500' 'P501' 'P502' 'P503'
#  'P504' 'P505' 'P506' 'P507' 'P508' 'P509' 'P510' 'P511' 'P517' 'P562'
#  'P568' 'P569' 'P574' 'P575' 'P577' 'P579' 'P580' 'P581' 'P582' 'P583'
#  'P584' 'P585' 'P586' 'P587' 'P588' 'P589' 'P590' 'P591' 'P592' 'P593'
#  'P594' 'P595' 'P596' 'P597' 'P598' 'P599' 'P600' 'P601' 'P603' 'P604'
#  'P605' 'P606' 'P607' 'P608' 'P609' 'P610' 'P611' 'P612' 'P613' 'P614'
#  'P615' 'P616' 'P617' 'P618' 'P619' 'P620' 'P621' 'P622' 'P623' 'P625'
#  'P626' 'P652' 'P726' 'P740' 'P741' 'P742' 'P744' 'P795' 'P796' 'P797'
#  'P811' 'P812' 'PACT' 'PAHR' 'PALG' 'PALO' 'PANA' 'PB1Y' 'PB2Y' 'PBPP'
#  'PEAR' 'PHIL' 'PHIN' 'PHJX' 'PHLB' 'PHON' 'PILO' 'PIN1' 'PIN2' 'PIUT'
#  'PJZX' 'PKRD' 'PLO5' 'PLO6' 'PLTX' 'PMOB' 'POBG' 'POSD' 'POTR' 'PPBF'
#  'PSAP' 'PSDM' 'PTAX' 'PTEX' 'QHTP' 'QUEX' 'RAAP' 'RAGG' 'RAMT' 'RBFT'
#  'RCSC' 'RDMT' 'REES' 'REP3' 'REP4' 'REPO' 'RHCG' 'RHCL' 'RHIL' 'RICO'
#  'RIDG' 'RKMG' 'RMVJ' 'ROJO' 'ROXY' 'ROYS' 'RP02' 'RPAS' 'RSTP' 'RTHS'
#  'RUNG' 'RVSD' 'RYAN' 'SA63' 'SACY' 'SALO' 'SANA' 'SBCC' 'SCIA' 'SDHL'
#  'SGDM' 'SGLG' 'SGPS' 'SHOS' 'SIO5' 'SKUL' 'SLAT' 'SLHG' 'SLMS' 'SMTN'
#  'SNHS' 'SNOG' 'SNTE' 'SNTF' 'SONG' 'SPMS' 'STIR' 'STRK' 'SVAL' 'SYLV'
#  'TABL' 'TABV' 'TCGC' 'THM2' 'THMG' 'THMS' 'THOM' 'THUM' 'TIVA' 'TLCC'
#  'TMAP' 'TOIY' 'TONI' 'TONO' 'TOQU' 'TOWG' 'TOYA' 'TPLM' 'TPOG' 'TRAK'
#  'TRAM' 'TWMS' 'UFOS' 'UNR1' 'UNR2' 'USGC' 'UTBE' 'UTGN' 'UTSG' 'VDCY'
#  'VFSP' 'VIGU' 'VNPS' 'VTOR' 'WCHS' 'WEEP' 'WHC1' 'WHYT' 'WIDC' 'WLSN'
#  'WMDG' 'WNRA' 'WOLF' 'WOMT' 'WOND' 'WORG' 'WWFG' 'WWMT' 'YOMB' 'YUCI'
#  'YUHG' 'YUMX' 'ZLA1' 'ZUMA']
# nearest GNSS site (potential --ref-gnss choice): NELS at [35.7140007019043, -114.7958984375]

# %%
from mintpy.cli import view, tsview, plot_network, plot_transection
opt = '--show-gnss  --gnss-comp enu2los  -v -2 2 --lalo-label --lalo-step 1 --ylabel-rot 90 --ref-gnss P623 --figsize 20 16 --save --noverbose --ex-gnss AZYW BEAT CAEC IDQG TMAP MESQ SVAL NAYX'
view.main(f' geo_velocity.h5 velocity {opt} -m geo_maskTempCoh.h5 --title geo_velocity_SET_ERA5_demErr_ion-GIM'.split())
# Out:
# view.py geo_velocity.h5 velocity --show-gnss --gnss-comp enu2los -v -2 2 --lalo-label --lalo-step 1 --ylabel-rot 90 --ref-gnss P623 --figsize 20 16 --save --noverbose --ex-gnss AZYW BEAT CAEC IDQG TMAP MESQ SVAL NAYX -m geo_maskTempCoh.h5 --title geo_velocity_SET_ERA5_demErr_ion-GIM
# load 21962 GNSS sites with fields: site lat lon start_date end_date num_solution
# keep sites within SNWE of (31.746136327112016, 40.24959559776317, -118.25408627841469, -113.5850835591817): [745]
# keep sites with end_date >= 20150403: [666]
# keep sites with start_date <= 20211221: [636]
# keep sites with # of solutions >= 50: [634]
# ['7OAK' '7ODM' 'ACSB' 'ACSX' 'AERO' 'AGMT' 'AIAH' 'ALAM' 'ANTB' 'ANTE'
#  'AQUA' 'AR27' 'AR53' 'ASHM' 'AST1' 'AST2' 'AVRY' 'AZBH' 'AZDS' 'AZFM'
#  'AZGV' 'AZKG' 'AZLH' 'AZPK' 'AZQZ' 'AZRY' 'AZU1' 'AZYC' 'AZYU' 'AZYW'
#  'BBRY' 'BDSP' 'BEAT' 'BEER' 'BEES' 'BEMT' 'BEPK' 'BGIS' 'BIGS' 'BILL'
#  'BIRD' 'BKAP' 'BKMS' 'BLSA' 'BLYT' 'BMHL' 'BNSL' 'BOBS' 'BOMG' 'BONI'
#  'BOUL' 'BRAW' 'BROK' 'BSRY' 'BTDM' 'CA29' 'CAB5' 'CABD' 'CABS' 'CABY'
#  'CAC1' 'CAC2' 'CACJ' 'CACL' 'CACM' 'CACT' 'CACX' 'CAE1' 'CAE2' 'CAEC'
#  'CAES' 'CAGD' 'CAGW' 'CAHV' 'CAIB' 'CAIV' 'CAL5' 'CALA' 'CALK' 'CALL'
#  'CALS' 'CANC' 'CANI' 'CAOR' 'CAOS' 'CARA' 'CAS4' 'CAS6' 'CASD' 'CASE'
#  'CASJ' 'CATE' 'CAVI' 'CAWS' 'CBAD' 'CCCC' 'CCCS' 'CCWR' 'CDMT' 'CERB'
#  'CERR' 'CGDM' 'CHIA' 'CHIL' 'CHMS' 'CHNA' 'CIT1' 'CJMG' 'CJMS' 'CJVG'
#  'CLAR' 'CLBD' 'CLV1' 'CLV2' 'CLV3' 'CMPO' 'CMRP' 'CNPP' 'COAG' 'COKG'
#  'COLD' 'COLU' 'COPP' 'CORX' 'COSJ' 'COSO' 'COTD' 'COYA' 'CPBN' 'CRAM'
#  'CRFP' 'CRPL' 'CRRS' 'CTMS' 'CVHS' 'DAEX' 'DEEP' 'DESC' 'DETR' 'DEVL'
#  'DHLG' 'DLUZ' 'DMAR' 'DRYC' 'DS13' 'DSME' 'DSSC' 'DTPG' 'DUNF' 'DVNW'
#  'DVPB' 'DVSE' 'DYH2' 'EAGL' 'ECFS' 'ECHO' 'EGAN' 'ELGI' 'ELLY' 'ELSC'
#  'ELSG' 'EPAS' 'ERRG' 'ESC1' 'ESCN' 'EWPP' 'FHOG' 'FISH' 'FOOT' 'FOXG'
#  'FSHB' 'FVPK' 'GALE' 'GARD' 'GEMF' 'GEND' 'GEOR' 'GHRP' 'GISA' 'GLRS'
#  'GMAG' 'GMPK' 'GMRC' 'GNPS' 'GOAT' 'GOL2' 'GOLD' 'GRES' 'GUNL' 'GVRS'
#  'HANN' 'HAR7' 'HCMN' 'HFVV' 'HIGH' 'HIKO' 'HIVI' 'HMTG' 'HNA1' 'HNPS'
#  'HNTS' 'HOL3' 'HOLP' 'HOME' 'HOOT' 'HUAL' 'HW50' 'HW95' 'I40A' 'ICKY'
#  'ICOR' 'IDOG' 'IDQG' 'IID2' 'IMIE' 'IMPS' 'INDE' 'INKH' 'IRVI' 'IVAN'
#  'IXLC' 'JAS1' 'JEAN' 'JNHG' 'JONE' 'JPL3' 'JPL4' 'JPLF' 'JPLM' 'JPLQ'
#  'JPLT' 'JPLV' 'KDMM' 'KEMP' 'KENN' 'KGMN' 'KING' 'KITT' 'KYVW' 'LAVA'
#  'LBC1' 'LBC2' 'LBCH' 'LBNO' 'LBRF' 'LBSE' 'LBSW' 'LDES' 'LDSW' 'LGWD'
#  'LINJ' 'LITT' 'LKHG' 'LL01' 'LLAS' 'LMHG' 'LMSG' 'LNMT' 'LONG' 'LONP'
#  'LORS' 'LPCG' 'LPHS' 'LRRG' 'MANH' 'MAT2' 'MCKI' 'MCOY' 'MEAD' 'MERC'
#  'MESQ' 'MEXI' 'MHMS' 'MILK' 'MILR' 'MINA' 'MINE' 'MISE' 'MJPK' 'MLFP'
#  'MOHO' 'MONP' 'MONT' 'MRDM' 'MSC1' 'MSOB' 'MTA1' 'MTGG' 'MUDD' 'MVFD'
#  'MXGE' 'MXGM' 'MXGW' 'MXS1' 'NAYX' 'NDAP' 'NELS' 'NEVA' 'NEWS' 'NOCO'
#  'NOPE' 'NPAS' 'NSSS' 'NVAG' 'NVAL' 'NVB1' 'NVBC' 'NVBM' 'NVC1' 'NVC2'
#  'NVCA' 'NVCO' 'NVDB' 'NVFW' 'NVH1' 'NVH2' 'NVIS' 'NVKP' 'NVL1' 'NVLA'
#  'NVLM' 'NVLV' 'NVLX' 'NVM1' 'NVMQ' 'NVMV' 'NVNL' 'NVOV' 'NVPI' 'NVPO'
#  'NVRM' 'NVSL' 'NVSV' 'NVTP' 'NVWS' 'NYOR' 'OAES' 'OASI' 'OBRC' 'OCSD'
#  'OEOC' 'OLNC' 'OMRE' 'OPBL' 'OPCL' 'OPCP' 'OPCX' 'OPRD' 'ORMT' 'OTAY'
#  'OTHQ' 'OWEN' 'OXYC' 'P002' 'P003' 'P005' 'P006' 'P010' 'P066' 'P068'
#  'P069' 'P071' 'P072' 'P073' 'P074' 'P075' 'P076' 'P077' 'P079' 'P080'
#  'P081' 'P091' 'P092' 'P093' 'P094' 'P099' 'P102' 'P132' 'P462' 'P463'
#  'P464' 'P465' 'P466' 'P467' 'P468' 'P469' 'P470' 'P471' 'P472' 'P473'
#  'P474' 'P475' 'P476' 'P477' 'P478' 'P479' 'P480' 'P481' 'P482' 'P483'
#  'P484' 'P485' 'P486' 'P487' 'P488' 'P489' 'P490' 'P491' 'P492' 'P493'
#  'P494' 'P495' 'P496' 'P497' 'P498' 'P499' 'P500' 'P501' 'P502' 'P503'
#  'P504' 'P505' 'P506' 'P507' 'P508' 'P509' 'P510' 'P511' 'P517' 'P562'
#  'P568' 'P569' 'P574' 'P575' 'P577' 'P579' 'P580' 'P581' 'P582' 'P583'
#  'P584' 'P585' 'P586' 'P587' 'P588' 'P589' 'P590' 'P591' 'P592' 'P593'
#  'P594' 'P595' 'P596' 'P597' 'P598' 'P599' 'P600' 'P601' 'P603' 'P604'
#  'P605' 'P606' 'P607' 'P608' 'P609' 'P610' 'P611' 'P612' 'P613' 'P614'
#  'P615' 'P616' 'P617' 'P618' 'P619' 'P620' 'P621' 'P622' 'P623' 'P625'
#  'P626' 'P652' 'P726' 'P740' 'P741' 'P742' 'P744' 'P795' 'P796' 'P797'
#  'P811' 'P812' 'PACT' 'PAHR' 'PALG' 'PALO' 'PANA' 'PB1Y' 'PB2Y' 'PBPP'
#  'PEAR' 'PHIL' 'PHIN' 'PHJX' 'PHLB' 'PHON' 'PILO' 'PIN1' 'PIN2' 'PIUT'
#  'PJZX' 'PKRD' 'PLO5' 'PLO6' 'PLTX' 'PMOB' 'POBG' 'POSD' 'POTR' 'PPBF'
#  'PSAP' 'PSDM' 'PTAX' 'PTEX' 'QHTP' 'QUEX' 'RAAP' 'RAGG' 'RAMT' 'RBFT'
#  'RCSC' 'RDMT' 'REES' 'REP3' 'REP4' 'REPO' 'RHCG' 'RHCL' 'RHIL' 'RICO'
#  'RIDG' 'RKMG' 'RMVJ' 'ROJO' 'ROXY' 'ROYS' 'RP02' 'RPAS' 'RSTP' 'RTHS'
#  'RUNG' 'RVSD' 'RYAN' 'SA63' 'SACY' 'SALO' 'SANA' 'SBCC' 'SCIA' 'SDHL'
#  'SGDM' 'SGLG' 'SGPS' 'SHOS' 'SIO5' 'SKUL' 'SLAT' 'SLHG' 'SLMS' 'SMTN'
#  'SNHS' 'SNOG' 'SNTE' 'SNTF' 'SONG' 'SPMS' 'STIR' 'STRK' 'SVAL' 'SYLV'
#  'TABL' 'TABV' 'TCGC' 'THM2' 'THMG' 'THMS' 'THOM' 'THUM' 'TIVA' 'TLCC'
#  'TMAP' 'TOIY' 'TONI' 'TONO' 'TOQU' 'TOWG' 'TOYA' 'TPLM' 'TPOG' 'TRAK'
#  'TRAM' 'TWMS' 'UFOS' 'UNR1' 'UNR2' 'USGC' 'UTBE' 'UTGN' 'UTSG' 'VDCY'
#  'VFSP' 'VIGU' 'VNPS' 'VTOR' 'WCHS' 'WEEP' 'WHC1' 'WHYT' 'WIDC' 'WLSN'
#  'WMDG' 'WNRA' 'WOLF' 'WOMT' 'WOND' 'WORG' 'WWFG' 'WWMT' 'YOMB' 'YUCI'
#  'YUHG' 'YUMX' 'ZLA1' 'ZUMA']
# nearest GNSS site (potential --ref-gnss choice): NELS at [35.7140007019043, -114.7958984375]

# %%
from mintpy.utils import readfile, utils as ut, plot as pp
kwargs = dict(ref_gnss_site='TIVA', csv_file='gnss_enu2los_UNR.csv',msk_file='geo_maskTempCoh.h5' , fig_size = (8,8) , vlim=[-2, 2])
kwargs['ex_gnss_sites'] = ['AZYW','BEAT', 'CAEC', 'IDQG', 'TMAP' , 'MESQ' , 'SVAL','NAYX']
sites, insar_obs, gnss_obs = pp.plot_insar_vs_gnss_scatter(vel_file='geo_velocity.h5', **kwargs)
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read GNSS velocity from file: gnss_enu2los_UNR.csv
# read InSAR velocity from file: geo_velocity.h5
# [==================================================] 626/626 ZUMA    7s /     0s
# median offset between InSAR and GNSS [before common referencing]: -0.94 cm/year
# referencing both InSAR and GNSS data to site: TIVA
# removing sites with NaN values in GNSS or InSAR
# pruning sites with value range: [-2, 2] cm/yr
# GNSS   min/max: -1.24 / 1.21
# InSAR min/max: -1.46 / 1.47
# RMSE = 0.17 cm/yr
# R^2 = 0.91
# Preliminary outliers detection: abs(InSAR - GNSS) > med abs dev (0.13) * 5
# Site:  InSAR  GNSS
# CAGW:  -0.5,   0.1  cm/yr
# save figure to file insar_vs_gnss_scatter.pdf
