# %%
# !pwd
# Out:
# /panda/eedy/ion_los-angle/s1_d173/notebook

# %%
from mintpy.objects import ramp
from mintpy.utils import ptime, readfile, writefile
import h5py
import numpy as np
from matplotlib import pyplot as plt, colorbar, ticker, colors
from mintpy.utils import ptime, readfile, writefile
from scipy.optimize import curve_fit
from mpl_toolkits.mplot3d import Axes3D

# %%
######### split

# %%
path_split = '../mintpy_split_ion_upsample/geo/geo_ion-split.h5'

# %%
# !reference_point.py ../mintpy_split_ion_upsample/geo/geo_ion-split.h5 -y 180 -x 190
# !reference_date.py ../mintpy_split_ion_upsample/geo/geo_ion-split.h5 --ref-date 20190112
# Out:
# WARNING: auto turn ON --write-data for file tpye timeseries
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# --------------------------------------------------
# input reference point in y/x: (180, 190)
# --------------------------------------------------
# calculating the temporal average of timeseries file: ../mintpy_split_ion_upsample/geo/geo_ion-split.h5
# reading timeseries data from file: ../mintpy_split_ion_upsample/geo/geo_ion-split.h5 ...
# /home/eedy/tools/MintPy/src/mintpy/objects/stack.py:455: RuntimeWarning: Mean of empty slice
#   dmean = np.nanmean(data, axis=0)
# updating dataset values without re-writing to a new file
# update metadata
# input reference date: 20190112
# --------------------------------------------------
# change reference date for file: /panda/eedy/ion_los-angle/s1_d173/mintpy_split_ion_upsample/geo/geo_ion-split.h5
# reading data ...
# referencing in time ...
# --------------------------------------------------
# open  HDF5 file /panda/eedy/ion_los-angle/s1_d173/mintpy_split_ion_upsample/geo/geo_ion-split.h5 in r+ mode
# writing dataset /timeseries                block: (0, 284, 0, 784, 0, 301)
# close HDF5 file /panda/eedy/ion_los-angle/s1_d173/mintpy_split_ion_upsample/geo/geo_ion-split.h5.
# update "REF_DATE" attribute value to 20190112
# time used: 00 mins 1.9 secs.

# %%
timeseries_split = readfile.read(path_split, datasetName='timeseries')[0]
timeseries_split = np.squeeze(timeseries_split)

mask_path_split = '../mintpy_split_ion_upsample/geo/geo_maskTempCoh.h5'
mask_split = readfile.read(mask_path_split, datasetName='mask')[0]
mask_split = np.squeeze(mask_split)

data_out, ramp = ramp.deramp(timeseries_split, mask_in=mask_split, ramp_type='linear', metadata=None, max_num_sample=1e3, coeff_file=None,ignore_zero_value=True)

# %%
def function(data, a, b, c):
    '''
    拟合曲面使用的函数
    '''
    x = data[0]
    y = data[1]
    return a*x+b*y + c



slope_ion_split = np.zeros(timeseries_split.shape[0])
slope_ion_split_dongxifangxiang = np.zeros(timeseries_split.shape[0])
slope_ion_split_nanbeifangxiang = np.zeros(timeseries_split.shape[0])
angle_deg_ion_split = np.zeros(timeseries_split.shape[0])
meta = readfile.read_attribute(path_split)
AZIMUTH_PIXEL_SIZE =  float(meta['AZIMUTH_PIXEL_SIZE'])
RANGE_PIXEL_SIZE = float(meta['RANGE_PIXEL_SIZE'])

for i in range(timeseries_split.shape[0]):
    x_data = ramp.shape[2]
    y_data = ramp.shape[1]
    X_data, Y_data = np.meshgrid(range(x_data), range(y_data))
    Z_data = ramp[i, :,:]
    
    x_data = X_data.flatten()
    y_data = Y_data.flatten()
    z_data = Z_data.flatten()
    
    parameters, covariance = curve_fit(function, [x_data, y_data], z_data)
    print("The equation of the fit plane is: Z = {0} * X + {1} * Y + {2}".format(parameters[0],parameters[1],parameters[2]))
    
    Z_fit = function([X_data, Y_data], *parameters)
    
    # 计算梯度，考虑到横纵坐标的实际长度
    dx = parameters[1]/RANGE_PIXEL_SIZE
    dy = parameters[0]/AZIMUTH_PIXEL_SIZE
    # 计算梯度的大小和方向
    magnitude = np.hypot(dx, dy)  # 梯度的大小
    direction = np.degrees(np.arctan2(dy, dx)) + 90  # 梯度的方向，以x轴正半轴为0°，逆时针旋转为正方向
    direction = (direction + 360) % 360  # 将角度值限制在0°到360°之间

    print('The magnitude of the gradient is( cm(ion)/ 100km(juli)):', magnitude*1e7)
    print('The direction of the gradient is:', direction)

    slope_ion_split[i] = magnitude*1e7
    angle_deg_ion_split[i] = direction
    slope_ion_split_dongxifangxiang[i] = dy*1e7
    slope_ion_split_nanbeifangxiang[i] = dx*1e7

    print(i)
# Out:
# The equation of the fit plane is: Z = -0.00015885500403405888 * X + -2.061276033233611e-05 * Y + 0.035677944499317306
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0596088465313438
# The direction of the gradient is: 343.8381023889998
# 0
# The equation of the fit plane is: Z = -7.4880872835054e-05 * X + -1.828900378138774e-05 * Y + 0.018750281814623366
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5464721582025625
# The direction of the gradient is: 331.38773867610234
# 1
# The equation of the fit plane is: Z = -5.0141961361136e-05 * X + -1.5751431859419877e-05 * Y + 0.012752452638506766
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.39242252130680855
# The direction of the gradient is: 324.9464359246495
# 2
# The equation of the fit plane is: Z = -5.156234447659377e-05 * X + 1.2942537518962008e-05 * Y + 0.008168755269816098
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3787121425097855
# The direction of the gradient is: 29.275304166555657
# 3
# The equation of the fit plane is: Z = 2.9219555599205287e-06 * X + -7.595911362076878e-06 * Y + 0.002144579731934283
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11028902660668927
# The direction of the gradient is: 260.22753256885574
# 4
# The equation of the fit plane is: Z = -3.4330246513058974e-05 * X + -1.0715934285591366e-05 * Y + 0.009473690329018528
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.26811501125468995
# The direction of the gradient is: 325.1177943099706
# 5
# The equation of the fit plane is: Z = -2.4605792096179506e-05 * X + 1.0703812799402423e-05 * Y + -0.0009625040234246777
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21979193228548063
# The direction of the gradient is: 44.1737844932386
# 6
# The equation of the fit plane is: Z = -1.6344111768894197e-05 * X + -1.638989916012317e-05 * Y + 0.006428467425997477
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.256835195247367
# The direction of the gradient is: 294.0603532053643
# 7
# The equation of the fit plane is: Z = -4.651195561605436e-05 * X + -1.1698664296944303e-05 * Y + 0.013050960860385805
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.34178508482375686
# The direction of the gradient is: 330.6748722684545
# 8
# The equation of the fit plane is: Z = -7.000973464858873e-05 * X + -4.396164510513653e-05 * Y + 0.01850920024561481
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7725737719500422
# The direction of the gradient is: 305.4903078246245
# 9
# The equation of the fit plane is: Z = -6.167953875006387e-05 * X + -1.5398232727232692e-05 * Y + 0.015222216897834697
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4524352014861743
# The direction of the gradient is: 330.85714675102184
# 10
# The equation of the fit plane is: Z = -4.350843055908794e-05 * X + -2.763003538413013e-05 * Y + 0.01360210598267799
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4837385493706929
# The direction of the gradient is: 305.1857602483952
# 11
# The equation of the fit plane is: Z = -3.805798834602584e-05 * X + -1.170856721490436e-05 * Y + 0.010340842139783653
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2958360870339882
# The direction of the gradient is: 325.5064344407747
# 12
# The equation of the fit plane is: Z = -5.237526880059991e-05 * X + -2.36874092665777e-05 * Y + 0.014108940776997769
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.47694288244870076
# The direction of the gradient is: 314.7121900045373
# 13
# The equation of the fit plane is: Z = -2.2833829016056042e-05 * X + -2.0643473935529577e-05 * Y + 0.008072793344862612
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3296244061480406
# The direction of the gradient is: 296.34689170439765
# 14
# The equation of the fit plane is: Z = -3.371919946536538e-05 * X + -1.0358561297291267e-05 * Y + 0.008916077808201748
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2619864861252019
# The direction of the gradient is: 325.54557146613575
# 15
# The equation of the fit plane is: Z = -3.06096438362818e-05 * X + 2.0357631534385295e-07 * Y + 0.005913660754322884
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19612760913743787
# The direction of the gradient is: 0.8510039312926665
# 16
# The equation of the fit plane is: Z = -2.6441655429061695e-05 * X + -1.8363984119438115e-05 * Y + 0.007910381509245723
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3126404579413316
# The direction of the gradient is: 302.80940491512695
# 17
# The equation of the fit plane is: Z = 3.6044998548739843e-06 * X + -8.626495262466544e-06 * Y + -0.001420728568181627
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1255767307663487
# The direction of the gradient is: 259.40332243340185
# 18
# The equation of the fit plane is: Z = -2.9463648930892335e-06 * X + -5.164099756947216e-06 * Y + 0.002256912774156874
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0762652446029309
# The direction of the gradient is: 284.3302043180537
# 19
# The equation of the fit plane is: Z = -1.8959792987473364e-05 * X + -1.1362961224140787e-05 * Y + 0.005440037433948112
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20295451156465188
# The direction of the gradient is: 306.7628665696284
# 20
# The equation of the fit plane is: Z = 9.517129129881013e-06 * X + -2.3899004886488227e-05 * Y + 0.002531992254105288
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3473603169943475
# The direction of the gradient is: 259.89033401245274
# 21
# The equation of the fit plane is: Z = -2.0800263683433833e-06 * X + -2.8128259114141787e-05 * Y + 0.0063948223719641
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4027033301597055
# The direction of the gradient is: 271.89634826151257
# 22
# The equation of the fit plane is: Z = -1.0771725249523572e-05 * X + -2.1998013454640453e-05 * Y + 0.006131859468307614
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3222424349726251
# The direction of the gradient is: 282.36615646620237
# 23
# The equation of the fit plane is: Z = 1.4432734093351186e-06 * X + -1.9064903437100662e-05 * Y + 0.0036243802185633
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.27295333110475073
# The direction of the gradient is: 268.05867388816705
# 24
# The equation of the fit plane is: Z = -6.527704925319555e-06 * X + -3.998952554130863e-05 * Y + 0.007395276561013714
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.573730006236142
# The direction of the gradient is: 274.18016554932115
# 25
# The equation of the fit plane is: Z = 4.211558363792496e-07 * X + -3.698918945494036e-05 * Y + 0.006634442291542183
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5292792992743011
# The direction of the gradient is: 269.7079111488505
# 26
# The equation of the fit plane is: Z = -9.694678346963235e-07 * X + -3.228754087231875e-05 * Y + 0.0075708884885748165
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.46203902947396064
# The direction of the gradient is: 270.7702345699302
# 27
# The equation of the fit plane is: Z = -2.5336610288327592e-06 * X + -1.4683140848250386e-05 * Y + 0.003691670293932381
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21072485068411542
# The direction of the gradient is: 274.41792540961745
# 28
# The equation of the fit plane is: Z = 2.188802812990518e-05 * X + -2.184090070206886e-05 * Y + -0.00038273841165587983
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.34253726314664135
# The direction of the gradient is: 245.8338257803282
# 29
# The equation of the fit plane is: Z = 6.523028736756015e-06 * X + 1.452858516859699e-05 * Y + -0.004356796705126641
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21204615779135824
# The direction of the gradient is: 101.36649266201033
# 30
# The equation of the fit plane is: Z = -5.734150981584915e-06 * X + -2.234528106143865e-05 * Y + 0.004600831210635585
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3218386375419158
# The direction of the gradient is: 276.55441250685413
# 31
# The equation of the fit plane is: Z = -8.492342436107733e-06 * X + -3.367277608900499e-05 * Y + 0.008046376453425524
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4848805577788544
# The direction of the gradient is: 276.44263451921876
# 32
# The equation of the fit plane is: Z = -1.7985944343510228e-05 * X + -4.913425182466285e-06 * Y + 0.004581376153140072
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.13498451452598265
# The direction of the gradient is: 328.6113443332186
# 33
# The equation of the fit plane is: Z = -1.3270882182256938e-05 * X + -8.456571083485473e-06 * Y + 0.0038644924283132223
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.14788737999163618
# The direction of the gradient is: 305.09345647852524
# 34
# The equation of the fit plane is: Z = -3.0211256549786622e-05 * X + -2.2538346197855143e-05 * Y + 0.009709346797539953
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.37612194496407775
# The direction of the gradient is: 300.9709506744656
# 35
# The equation of the fit plane is: Z = -4.217285700615713e-05 * X + -2.594990824998785e-05 * Y + 0.011652899501397973
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4592110793371269
# The direction of the gradient is: 306.04168248907604
# 36
# The equation of the fit plane is: Z = -4.531530634547698e-05 * X + -4.318114289585389e-05 * Y + 0.014682864886069973
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6826798897645823
# The direction of the gradient is: 295.1674829316915
# 37
# The equation of the fit plane is: Z = -6.193780139103196e-05 * X + -2.590117895191716e-05 * Y + 0.015004433531798651
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5429718546140382
# The direction of the gradient is: 316.95526571165965
# 38
# The equation of the fit plane is: Z = -5.126097623664344e-05 * X + -5.4972004626340565e-05 * Y + 0.018477826925308104
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8523917203978144
# The direction of the gradient is: 292.66132994547525
# 39
# The equation of the fit plane is: Z = -3.690552268291397e-05 * X + -1.4104564276295022e-05 * Y + 0.009684786095875995
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.31086320797025063
# The direction of the gradient is: 319.5168533032545
# 40
# The equation of the fit plane is: Z = -5.690515692002902e-05 * X + -9.572955669060505e-06 * Y + 0.013415574749074946
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3894563110409193
# The direction of the gradient is: 339.40770917763234
# 41
# The equation of the fit plane is: Z = -2.6662410589405726e-05 * X + -2.7915633134013776e-05 * Y + 0.009298970518913144
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4344319940383407
# The direction of the gradient is: 293.1535710491579
# 42
# The equation of the fit plane is: Z = -4.0209185613888084e-05 * X + -3.179231571678976e-06 * Y + 0.008662555614166623
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.26159292800623224
# The direction of the gradient is: 349.98532468690894
# 43
# The equation of the fit plane is: Z = -1.8956965539232595e-05 * X + -1.275709573612567e-05 * Y + 0.005737535498989803
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21925086673588867
# The direction of the gradient is: 303.63750098923174
# 44
# The equation of the fit plane is: Z = -1.8445038285708446e-05 * X + -4.2508292565200785e-05 * Y + 0.01043099165813755
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6196173815549628
# The direction of the gradient is: 280.9946077462061
# 45
# The equation of the fit plane is: Z = -1.8009457784591375e-07 * X + -8.728066372904775e-06 * Y + 0.0012818107784326805
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1248938415705157
# The direction of the gradient is: 270.5293232564662
# 46
# The equation of the fit plane is: Z = -3.3002522027769825e-06 * X + -1.5698741937904642e-05 * Y + 0.0027619579108779206
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.22562368888116455
# The direction of the gradient is: 275.377189384868
# 47
# The equation of the fit plane is: Z = -1.3527273918711872e-05 * X + -1.247828183161977e-05 * Y + 0.0014682452945308762
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19847116492942246
# The direction of the gradient is: 295.8910979066137
# 48
# The equation of the fit plane is: Z = 1.065846737657917e-05 * X + -1.6555363472114623e-05 * Y + 0.0005259177187667158
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2465336425743255
# The direction of the gradient is: 253.91985293193943
# 49
# The equation of the fit plane is: Z = 1.1475486457441125e-05 * X + -5.822855375975023e-06 * Y + -0.0012467835783451062
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11111743965833423
# The direction of the gradient is: 228.57496872832655
# 50
# The equation of the fit plane is: Z = -1.975221907032663e-05 * X + -1.5150004136250852e-05 * Y + 0.0073849456912747375
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.25101200220505676
# The direction of the gradient is: 300.2744959729356
# 51
# The equation of the fit plane is: Z = -1.663968073477066e-05 * X + -3.0573972205445415e-05 * Y + 0.008355714916663351
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.45027959304954296
# The direction of the gradient is: 283.69497178574835
# 52
# The equation of the fit plane is: Z = -4.946252814003357e-06 * X + -2.0535501304331358e-05 * Y + 0.0037204848398512866
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2955430261244779
# The direction of the gradient is: 276.15526101743893
# 53
# The equation of the fit plane is: Z = 1.3839644808608328e-05 * X + -1.4270909155015426e-05 * Y + 0.0007240784042015858
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.22261936421995218
# The direction of the gradient is: 246.52895595388247
# 54
# The equation of the fit plane is: Z = 2.469030865772002e-06 * X + -1.375571207080527e-05 * Y + 0.0017161502296897688
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19746289498773947
# The direction of the gradient is: 265.40525097101613
# 55
# The equation of the fit plane is: Z = 0.0 * X + 0.0 * Y + 6.4e-323
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0
# The direction of the gradient is: 90.0
# 56
# The equation of the fit plane is: Z = -5.62450979182972e-06 * X + -1.6300264157982228e-05 * Y + 0.0046282017727070435
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23600505966086452
# The direction of the gradient is: 278.7825491058046
# 57
# The equation of the fit plane is: Z = 5.2613652074211395e-06 * X + -1.5925370859471443e-05 * Y + 0.0019334759404994253
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2303531950355129
# The direction of the gradient is: 261.5856297576429
# 58
# The equation of the fit plane is: Z = -1.7976269167895846e-05 * X + -2.202245637121299e-05 * Y + 0.006021553629484123
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.33550211137215985
# The direction of the gradient is: 290.0762744018481
# 59
# The equation of the fit plane is: Z = 3.864180133074441e-06 * X + -2.468679303611567e-05 * Y + 0.003891810019821175
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3541058501124349
# The direction of the gradient is: 265.99102015570963
# 60
# The equation of the fit plane is: Z = 1.2361903350988535e-05 * X + -2.332142596618023e-05 * Y + 0.00012691898681496954
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.34297206157636073
# The direction of the gradient is: 256.6488330166926
# 61
# The equation of the fit plane is: Z = -1.338457761438791e-05 * X + -2.8274920895054966e-05 * Y + 0.006836285176511401
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.41356889190234275
# The direction of the gradient is: 281.9666899836765
# 62
# The equation of the fit plane is: Z = -1.3859691256073277e-05 * X + -1.4546577588545103e-05 * Y + 0.004670044251560872
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.22629331670030964
# The direction of the gradient is: 293.1030943110858
# 63
# The equation of the fit plane is: Z = -5.5276120055550195e-05 * X + -3.905184865831499e-05 * Y + 0.014882080680376324
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6615548951876336
# The direction of the gradient is: 302.36484194833156
# 64
# The equation of the fit plane is: Z = -1.5817820761088767e-05 * X + 1.18323365125674e-05 * Y + -0.0001759595799833773
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19731847851773532
# The direction of the gradient is: 59.09714880678433
# 65
# The equation of the fit plane is: Z = -3.1946998873281196e-05 * X + -1.0124351702332745e-05 * Y + 0.00792280281541979
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.25075505172506757
# The direction of the gradient is: 324.70923346252545
# 66
# The equation of the fit plane is: Z = -8.126014420986592e-05 * X + 3.8098109029948913e-06 * Y + 0.01481206204282065
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.52345352592943
# The direction of the gradient is: 5.9777886455416365
# 67
# The equation of the fit plane is: Z = -3.9999608088981086e-05 * X + -2.4651134886586013e-05 * Y + 0.010507025461725552
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.43599232614009736
# The direction of the gradient is: 305.9991141131842
# 68
# The equation of the fit plane is: Z = -4.073139000576544e-05 * X + -2.2810265593198046e-05 * Y + 0.010584144348200007
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.41788243984667117
# The direction of the gradient is: 308.642884168129
# 69
# The equation of the fit plane is: Z = -3.0027470699669196e-05 * X + 2.3157477590871207e-05 * Y + 0.001766441874363332
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3831524911059975
# The direction of the gradient is: 59.86177727625068
# 70
# The equation of the fit plane is: Z = -1.3292932122170095e-05 * X + -2.7461999970048016e-05 * Y + 0.006517051605403064
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.40207217641162707
# The direction of the gradient is: 282.22852571339297
# 71
# The equation of the fit plane is: Z = -2.6377878088009664e-05 * X + -2.7769686214489648e-05 * Y + 0.010900374114811198
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4317959540086216
# The direction of the gradient is: 293.0401256224106
# 72
# The equation of the fit plane is: Z = -2.5225110030480563e-05 * X + -2.3919558276740943e-05 * Y + 0.008036205367366447
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.37849725673280055
# The direction of the gradient is: 295.27576593300535
# 73
# The equation of the fit plane is: Z = -8.643331420603812e-05 * X + -3.2471232450578596e-05 * Y + 0.020727335259055183
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7228527293458821
# The direction of the gradient is: 320.00156071129743
# 74
# The equation of the fit plane is: Z = -1.0448310210033703e-05 * X + -2.9932464494088362e-05 * Y + 0.0057751119625339305
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.43349825535384756
# The direction of the gradient is: 278.8829062657318
# 75
# The equation of the fit plane is: Z = -6.496854629924623e-05 * X + -2.1029628502475726e-05 * Y + 0.014512547662406632
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5136106077669389
# The direction of the gradient is: 324.13544777336404
# 76
# The equation of the fit plane is: Z = -1.0386748427486e-05 * X + -1.2580803731290321e-05 * Y + 0.002655745247769682
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19192235128149437
# The direction of the gradient is: 290.2872026328729
# 77
# The equation of the fit plane is: Z = -4.9432723680999434e-05 * X + -2.6441786468003823e-05 * Y + 0.013441866159364543
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.49340465812870615
# The direction of the gradient is: 309.9310456446333
# 78
# The equation of the fit plane is: Z = -6.602821007127735e-06 * X + -2.6997715752648288e-05 * Y + 0.0052608447863760335
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3886152422525544
# The direction of the gradient is: 276.24922690440746
# 79
# The equation of the fit plane is: Z = -7.061689794681391e-05 * X + -2.8260772925743676e-05 * Y + 0.01608938539211242
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6067994547006824
# The direction of the gradient is: 318.20920001560785
# 80
# The equation of the fit plane is: Z = -7.474343399200507e-06 * X + -2.1253991680046093e-05 * Y + 0.0036575717802125904
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.30786685663429275
# The direction of the gradient is: 278.94812759403555
# 81
# The equation of the fit plane is: Z = -5.411882954216751e-05 * X + -2.7610233194336493e-05 * Y + 0.013567114223308481
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5256391726886801
# The direction of the gradient is: 311.27082984941273
# 82
# The equation of the fit plane is: Z = 4.1843925894982775e-06 * X + -1.7620838036325445e-05 * Y + 0.0013095482501741657
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2535549376605337
# The direction of the gradient is: 263.930848137501
# 83
# The equation of the fit plane is: Z = -8.549529753252987e-05 * X + -3.571189681644744e-05 * Y + 0.021122882931872117
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7490903194062326
# The direction of the gradient is: 316.9877128543112
# 84
# The equation of the fit plane is: Z = 8.659928156444427e-06 * X + 2.3616760561493727e-06 * Y + -0.00303026223153883
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.06496255955574984
# The direction of the gradient is: 148.65503095491465
# 85
# The equation of the fit plane is: Z = -5.2068294257934456e-05 * X + -2.0325016878577474e-05 * Y + 0.012701485352793246
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4425598636791513
# The direction of the gradient is: 318.91725865635874
# 86
# The equation of the fit plane is: Z = 3.412055292687377e-06 * X + -1.5249468169430789e-05 * Y + 0.000819937878345441
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21929446271193712
# The direction of the gradient is: 264.2790855167335
# 87
# The equation of the fit plane is: Z = -9.09943487054304e-05 * X + -2.164903300187937e-05 * Y + 0.018611912929552315
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6601623006992847
# The direction of the gradient is: 332.01522120474544
# 88
# The equation of the fit plane is: Z = 7.016709855133495e-06 * X + -1.5467009679476993e-05 * Y + 0.0001524014041665822
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.22583436560905096
# The direction of the gradient is: 258.51821750384704
# 89
# The equation of the fit plane is: Z = -6.578673502381849e-05 * X + -2.8703129670116807e-05 * Y + 0.01637501893393067
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5884912003620512
# The direction of the gradient is: 315.74116904394657
# 90
# The equation of the fit plane is: Z = 3.247000893961518e-06 * X + -1.2885030885669472e-05 * Y + 0.0003124021421921388
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.18553971633260574
# The direction of the gradient is: 263.56253592817245
# 91
# The equation of the fit plane is: Z = -5.2635582740742915e-05 * X + -3.320523259059483e-05 * Y + 0.013516689090240003
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5826350582706397
# The direction of the gradient is: 305.3649540453142
# 92
# The equation of the fit plane is: Z = -2.989966090517436e-06 * X + -2.019610486406375e-05 * Y + 0.0038589057970724993
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2896170382626585
# The direction of the gradient is: 273.7924031689495
# 93
# The equation of the fit plane is: Z = -4.5281676255246465e-05 * X + -2.6374148677121174e-05 * Y + 0.010173837035464761
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4760033063399085
# The direction of the gradient is: 307.5504545721941
# 94
# The equation of the fit plane is: Z = -3.9509684702978745e-06 * X + -3.857461663590215e-05 * Y + 0.007927089070489775
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5525381535770466
# The direction of the gradient is: 272.62572053922213
# 95
# The equation of the fit plane is: Z = -7.417610237551992e-05 * X + -2.060818079755948e-05 * Y + 0.015494047803279183
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5592760526854061
# The direction of the gradient is: 328.18005805951236
# 96
# The equation of the fit plane is: Z = -3.378720492113417e-05 * X + -2.5868772946061672e-05 * Y + 0.009482656800908968
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.42879959597836187
# The direction of the gradient is: 300.3189335031685
# 97
# The equation of the fit plane is: Z = -5.670349847380081e-05 * X + -4.050220353288599e-05 * Y + 0.01578987841690967
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6839876035230056
# The direction of the gradient is: 302.0812857226608
# 98
# The equation of the fit plane is: Z = 2.0036912849555548e-05 * X + -1.9336805151100447e-05 * Y + -0.0011630631636053432
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3050158786407761
# The direction of the gradient is: 245.11090555660314
# 99
# The equation of the fit plane is: Z = -7.010387879677575e-05 * X + -3.7334733140281074e-05 * Y + 0.017691572622426408
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6979309771551365
# The direction of the gradient is: 310.0548091097285
# 100
# The equation of the fit plane is: Z = -2.681582189695029e-05 * X + -3.6221665955240854e-05 * Y + 0.011048511311639362
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5460218719908724
# The direction of the gradient is: 288.3390688083422
# 101
# The equation of the fit plane is: Z = -5.538983944933426e-05 * X + -3.294700296744378e-05 * Y + 0.014788157517915637
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5900663873343607
# The direction of the gradient is: 306.97006818494395
# 102
# The equation of the fit plane is: Z = -1.567285977723286e-06 * X + -1.184978723562573e-05 * Y + 0.0016215387942403727
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16985377319835596
# The direction of the gradient is: 273.38907760705524
# 103
# The equation of the fit plane is: Z = -6.626431277847613e-05 * X + -3.322816329597893e-05 * Y + 0.01753567772134367
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6374070985310349
# The direction of the gradient is: 311.7615769061452
# 104
# The equation of the fit plane is: Z = -2.776791028513153e-05 * X + -2.5311795219855204e-05 * Y + 0.009356667235006815
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4035151868722224
# The direction of the gradient is: 296.1597483273916
# 105
# The equation of the fit plane is: Z = -8.88166268408897e-05 * X + -4.868814756682236e-05 * Y + 0.023124837175894034
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8995182729886633
# The direction of the gradient is: 309.2408765176989
# 106
# The equation of the fit plane is: Z = -6.898314722006458e-06 * X + -2.8741167542148576e-05 * Y + 0.005968879223379967
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.41362069178890004
# The direction of the gradient is: 276.1337460761903
# 107
# The equation of the fit plane is: Z = -4.950763112935201e-05 * X + -3.7482346902944926e-05 * Y + 0.013491544440993616
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6230982016597783
# The direction of the gradient is: 300.59961633389173
# 108
# The equation of the fit plane is: Z = 2.880899484838545e-06 * X + -2.3761771887239654e-05 * Y + 0.001619577653577328
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3405040072841897
# The direction of the gradient is: 266.89276597192986
# 109
# The equation of the fit plane is: Z = -5.653064277314004e-05 * X + -3.316485236899759e-05 * Y + 0.015211221228001172
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5969654850226368
# The direction of the gradient is: 307.35059328583503
# 110
# The equation of the fit plane is: Z = -8.550296386233465e-06 * X + 2.541009519567514e-06 * Y + 0.00016794912056784805
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.06574726809174238
# The direction of the gradient is: 33.57376164658899
# 111
# The equation of the fit plane is: Z = -7.824488049661951e-05 * X + -2.988107472007382e-05 * Y + 0.017485252475929643
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6588638702251073
# The direction of the gradient is: 319.5382219966659
# 112
# The equation of the fit plane is: Z = -1.1346511934493572e-05 * X + -3.623190585318851e-05 * Y + 0.0077023370715268245
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5235081731786314
# The direction of the gradient is: 277.98177927683196
# 113
# The equation of the fit plane is: Z = -8.795513282125852e-05 * X + -7.709445616826915e-06 * Y + 0.015962894733961296
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5741959561490065
# The direction of the gradient is: 348.92360102667783
# 114
# The equation of the fit plane is: Z = -7.0276390363283e-05 * X + -2.8712016328958556e-05 * Y + 0.01707566900953531
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6095080522756199
# The direction of the gradient is: 317.6199908103302
# 115
# The equation of the fit plane is: Z = -2.7677846708859143e-05 * X + -1.5310487391983324e-05 * Y + 0.006216639254268717
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.28184643542140886
# The direction of the gradient is: 308.9872364431025
# 116
# The equation of the fit plane is: Z = -8.074512410469374e-05 * X + -1.329742188531838e-05 * Y + 0.016229559185042812
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5511897030846821
# The direction of the gradient is: 339.8059942694388
# 117
# The equation of the fit plane is: Z = -4.148601282737451e-05 * X + -4.197406848528209e-05 * Y + 0.015552049097863604
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6567827427745807
# The direction of the gradient is: 293.8711210985719
# 118
# The equation of the fit plane is: Z = -0.00010985268031180161 * X + -3.1585218330490666e-05 * Y + 0.02474752534984664
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8364074970207868
# The direction of the gradient is: 327.2929334470372
# 119
# The equation of the fit plane is: Z = -2.3266083349563952e-05 * X + -6.220332333885172e-06 * Y + 0.004696325861433981
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17360980796466102
# The direction of the gradient is: 329.1576956537543
# 120
# The equation of the fit plane is: Z = -0.00013169394871058947 * X + -4.4950741859290803e-05 * Y + 0.030028408006572874
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.060924490261438
# The direction of the gradient is: 322.68064363918467
# 121
# The equation of the fit plane is: Z = -2.6638951085582626e-05 * X + -4.118945768025421e-05 * Y + 0.011035624821589249
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6135863708696855
# The direction of the gradient is: 286.14962721820837
# 122
# The equation of the fit plane is: Z = -9.597570107101202e-05 * X + -4.1173767936227934e-05 * Y + 0.02270524238409484
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8515749428847887
# The direction of the gradient is: 316.2245019182401
# 123
# The equation of the fit plane is: Z = -4.23996435597948e-05 * X + -2.9380683915153958e-05 * Y + 0.013248607200458468
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5005274892720798
# The direction of the gradient is: 302.86822624961474
# 124
# The equation of the fit plane is: Z = -9.191203899635982e-05 * X + -2.4120501178304752e-05 * Y + 0.018711745400698112
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6825422336571053
# The direction of the gradient is: 329.62462079386773
# 125
# The equation of the fit plane is: Z = -1.3334756977949192e-05 * X + -2.719653403936341e-05 * Y + 0.005753395336291032
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.39841803661111946
# The direction of the gradient is: 282.38188957170144
# 126
# The equation of the fit plane is: Z = -0.00010151060107905648 * X + -3.573722780266942e-05 * Y + 0.022730118394831612
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8273066032261168
# The direction of the gradient is: 321.82247327130153
# 127
# The equation of the fit plane is: Z = -2.4401794144486542e-05 * X + -3.058986836110864e-05 * Y + 0.009107592123895536
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.46478658610156504
# The direction of the gradient is: 289.6550895750992
# 128
# The equation of the fit plane is: Z = -8.58316381749576e-05 * X + -4.689056396596211e-05 * Y + 0.02265215606252585
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8675010941846529
# The direction of the gradient is: 309.33727622203605
# 129
# The equation of the fit plane is: Z = -4.389864998047561e-05 * X + -1.0095187388930776e-05 * Y + 0.010162147659166742
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.31617127954827173
# The direction of the gradient is: 332.8144260550096
# 130
# The equation of the fit plane is: Z = -9.629888743160387e-05 * X + -2.324798536307192e-05 * Y + 0.019662143082815813
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7009216957885526
# The direction of the gradient is: 331.6672216043987
# 131
# The equation of the fit plane is: Z = -2.7311253383710406e-05 * X + -3.3813460431226636e-05 * Y + 0.009990349188508777
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5144986277158352
# The direction of the gradient is: 289.88217140701255
# 132
# The equation of the fit plane is: Z = -6.678341013438629e-05 * X + -2.8357071114017432e-05 * Y + 0.015846805771552324
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5896628820106795
# The direction of the gradient is: 316.51879461830003
# 133
# The equation of the fit plane is: Z = -3.26794088892448e-05 * X + -3.055036569934957e-05 * Y + 0.009514927156421417
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4846915496189246
# The direction of the gradient is: 295.5918698197696
# 134
# The equation of the fit plane is: Z = -8.656156919102165e-05 * X + -3.716550159024035e-05 * Y + 0.020373840728995736
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7683462163915293
# The direction of the gradient is: 316.20106879993943
# 135
# The equation of the fit plane is: Z = -2.2284700552513727e-05 * X + -2.20531343892513e-05 * Y + 0.007739689775763115
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3463499993855942
# The direction of the gradient is: 294.3440760156343
# 136
# The equation of the fit plane is: Z = -5.877753736095568e-05 * X + -3.615842979302612e-05 * Y + 0.01460400215027507
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6399150428268361
# The direction of the gradient is: 306.04824966764716
# 137
# The equation of the fit plane is: Z = -4.480853786068244e-06 * X + -2.4814708872193302e-05 * Y + 0.0032925594205849037
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3562283217255699
# The direction of the gradient is: 274.62230614214536
# 138
# The equation of the fit plane is: Z = -6.0166640062774964e-05 * X + -3.490018634764961e-05 * Y + 0.014978178467355562
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6308463820827138
# The direction of the gradient is: 307.66423608336015
# 139
# The equation of the fit plane is: Z = 8.443353150133145e-07 * X + -1.975488455754389e-05 * Y + 0.0026266273925166614
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2827212515948187
# The direction of the gradient is: 268.9036778579541
# 140
# The equation of the fit plane is: Z = -7.928923242163662e-05 * X + -8.650241404140081e-06 * Y + 0.015009153145842273
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5228423217215138
# The direction of the gradient is: 346.3060997685009
# 141
# The equation of the fit plane is: Z = 1.2520225161238548e-05 * X + -1.6149112959770194e-05 * Y + 2.623987763255337e-05
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.24460134624459376
# The direction of the gradient is: 250.856601811799
# 142
# The equation of the fit plane is: Z = -3.67269921369311e-05 * X + -6.292232791632528e-05 * Y + 0.015018352529461109
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9305843393270822
# The direction of the gradient is: 284.646197806902
# 143
# The equation of the fit plane is: Z = 2.229565385969528e-05 * X + -2.7848188698689773e-05 * Y + -0.00028318417202246096
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.42330379518474043
# The direction of the gradient is: 250.2788273315108
# 144
# The equation of the fit plane is: Z = -5.2374536634709194e-05 * X + -2.5408491476909925e-05 * Y + 0.011425445619850191
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4947441251847046
# The direction of the gradient is: 312.70488720101565
# 145
# The equation of the fit plane is: Z = -1.0731624608246114e-05 * X + -3.9347448538680876e-05 * Y + 0.008004620789870943
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5671988651362541
# The direction of the gradient is: 276.9623304466964
# 146
# The equation of the fit plane is: Z = -6.143215503391141e-05 * X + -3.847524341345604e-05 * Y + 0.014498711042153155
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6767509747945014
# The direction of the gradient is: 305.56080039462177
# 147
# The equation of the fit plane is: Z = 9.784372636511288e-06 * X + -2.7520693330364865e-05 * Y + 0.0022695167932523077
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3987472786616238
# The direction of the gradient is: 260.95526807881174
# 148
# The equation of the fit plane is: Z = -6.690892531307436e-05 * X + -3.0523731449497887e-05 * Y + 0.01583329743784054
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6119731132178797
# The direction of the gradient is: 314.464041238422
# 149
# The equation of the fit plane is: Z = 2.2110205071706968e-05 * X + -5.5651514160370136e-05 * Y + 0.005236431231525494
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.808809620936749
# The direction of the gradient is: 259.9133432428821
# 150
# The equation of the fit plane is: Z = -6.02598775286045e-05 * X + -2.328741169885054e-05 * Y + 0.013239427238110443
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5099796548560436
# The direction of the gradient is: 319.202277896144
# 151
# The equation of the fit plane is: Z = -1.0948616857213807e-05 * X + -2.5111002227394796e-05 * Y + 0.00551093285038477
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3660920730290844
# The direction of the gradient is: 281.04632712866294
# 152
# The equation of the fit plane is: Z = -6.354485116117061e-05 * X + -3.375374277057239e-05 * Y + 0.01582965556098399
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6316693311658629
# The direction of the gradient is: 310.1282204003479
# 153
# The equation of the fit plane is: Z = -5.560552354204512e-06 * X + -2.2596436049024886e-05 * Y + 0.004102057888002836
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3252854610892375
# The direction of the gradient is: 276.28753592459395
# 154
# The equation of the fit plane is: Z = -5.3341734125108085e-05 * X + -5.587856362110627e-05 * Y + 0.01861032575284436
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8695288684835728
# The direction of the gradient is: 293.14260146880997
# 155
# The equation of the fit plane is: Z = 1.6655360360691268e-06 * X + -1.622596681017982e-05 * Y + 0.0014919751414046057
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23241985020549902
# The direction of the gradient is: 267.3685889993533
# 156
# The equation of the fit plane is: Z = -4.3593447134906406e-05 * X + -1.547772611784376e-05 * Y + 0.009206014165079029
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3564414923712627
# The direction of the gradient is: 321.58656882273067
# 157
# The equation of the fit plane is: Z = -1.1611880919374965e-05 * X + -2.54343188475084e-05 * Y + 0.005571320704065314
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3714613444490734
# The direction of the gradient is: 281.5528993955172
# 158
# The equation of the fit plane is: Z = -0.00010496821275777444 * X + -3.862223657124449e-05 * Y + 0.02407814689419922
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8704381453887433
# The direction of the gradient is: 320.58758068467665
# 159
# The equation of the fit plane is: Z = 4.776172523235469e-07 * X + -5.045955547287624e-05 * Y + 0.0062417036311227065
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7220242279718133
# The direction of the gradient is: 269.7571798519907
# 160
# The equation of the fit plane is: Z = -5.75707873760272e-05 * X + -3.7543642364658796e-05 * Y + 0.016483577024165964
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6516372991017307
# The direction of the gradient is: 304.47288104543713
# 161
# The equation of the fit plane is: Z = 5.586927672219635e-06 * X + -9.144432157020011e-06 * Y + 0.00017389292655797123
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.135653666813216
# The direction of the gradient is: 254.7007569388536
# 162
# The equation of the fit plane is: Z = -6.684537393851301e-05 * X + -4.120854835529847e-05 * Y + 0.017929798111367887
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7287569178603124
# The direction of the gradient is: 305.99065927673314
# 163
# The equation of the fit plane is: Z = 1.4089071487747796e-05 * X + -6.714770805612664e-05 * Y + 0.007014782943675073
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9650365313552283
# The direction of the gradient is: 264.63303089982514
# 164
# The equation of the fit plane is: Z = -6.142441569561759e-05 * X + -2.347424040185697e-05 * Y + 0.013400493077720408
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5173822147106507
# The direction of the gradient is: 319.5180128848932
# 165
# The equation of the fit plane is: Z = 4.363151272141226e-05 * X + -1.4754244628049515e-05 * Y + -0.006752560587330308
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3502979113447129
# The direction of the gradient is: 217.06179193515368
# 166
# The equation of the fit plane is: Z = -6.1878289022518e-05 * X + -5.149409897123969e-05 * Y + 0.017876751821966356
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.836698790513714
# The direction of the gradient is: 298.28171897232517
# 167
# The equation of the fit plane is: Z = 9.865062730800036e-06 * X + -2.19079936876562e-05 * Y + 0.0016523388673548012
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.31978582518008125
# The direction of the gradient is: 258.6010574461461
# 168
# The equation of the fit plane is: Z = -5.8813564024338615e-05 * X + -2.0478437790636055e-05 * Y + 0.01233863444909901
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.47732587804564386
# The direction of the gradient is: 322.1291277042101
# 169
# The equation of the fit plane is: Z = -1.590503646601798e-05 * X + -5.656628787407361e-06 * Y + 0.0036645539225722496
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.13013273365261002
# The direction of the gradient is: 321.53921918533666
# 170
# The equation of the fit plane is: Z = -6.809969841931964e-05 * X + -1.9707849683931863e-05 * Y + 0.014309253587571923
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5194931722113764
# The direction of the gradient is: 327.1235016549202
# 171
# The equation of the fit plane is: Z = -4.302269072764121e-05 * X + -1.9008133653056162e-06 * Y + 0.007573222572658002
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.27697097998225995
# The direction of the gradient is: 354.3644959203872
# 172
# The equation of the fit plane is: Z = -8.767376914904864e-05 * X + -2.5164178714443358e-05 * Y + 0.018946301727005708
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6671988230272874
# The direction of the gradient is: 327.33851305053554
# 173
# The equation of the fit plane is: Z = -3.6528456280606675e-05 * X + -1.0540912998894871e-05 * Y + 0.007662632612840864
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2784192309092388
# The direction of the gradient is: 327.198466846805
# 174
# The equation of the fit plane is: Z = -9.362373091985388e-05 * X + -1.6764331954859394e-05 * Y + 0.018731861555933406
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6460042636097907
# The direction of the gradient is: 338.2025837822573
# 175
# The equation of the fit plane is: Z = -3.890282335792141e-05 * X + -1.4946334779873583e-05 * Y + 0.008891977241381552
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3284167075009585
# The direction of the gradient is: 319.36791622733085
# 176
# The equation of the fit plane is: Z = -0.00013159351213798675 * X + -2.7232835018619695e-05 * Y + 0.029447471525823048
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9287739652943331
# The direction of the gradient is: 335.1936033439721
# 177
# The equation of the fit plane is: Z = -5.2864101793029213e-05 * X + -2.0203802633154262e-05 * Y + 0.013787360033552604
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4452874803015949
# The direction of the gradient is: 319.516596239661
# 178
# The equation of the fit plane is: Z = -0.0001291058365157395 * X + -3.634585112327457e-05 * Y + 0.030134362821597857
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9770508602010298
# The direction of the gradient is: 327.8402011741415
# 179
# The equation of the fit plane is: Z = -5.6597799942829723e-05 * X + -4.373126655175146e-05 * Y + 0.0177798447778284
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7232126792577864
# The direction of the gradient is: 300.0912706018573
# 180
# The equation of the fit plane is: Z = -0.00013734937629425624 * X + -4.363968104166641e-05 * Y + 0.030966533628089578
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0789964469004605
# The direction of the gradient is: 324.6396683793665
# 181
# The equation of the fit plane is: Z = -5.4514065700574945e-05 * X + -2.8727028799228906e-05 * Y + 0.014712020809746922
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5393891971814737
# The direction of the gradient is: 310.3532767547889
# 182
# The equation of the fit plane is: Z = -0.00012103678821193925 * X + -3.8326865940978806e-05 * Y + 0.02746501579560705
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9497730586163201
# The direction of the gradient is: 324.73108183083264
# 183
# The equation of the fit plane is: Z = -4.698026960501737e-05 * X + -2.122987452623877e-05 * Y + 0.012128263832667161
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.42763593534523053
# The direction of the gradient is: 314.7358948719844
# 184
# The equation of the fit plane is: Z = -0.00011014624371733558 * X + -5.745908447178462e-05 * Y + 0.028180701308753418
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.083485006326421
# The direction of the gradient is: 310.63949104275616
# 185
# The equation of the fit plane is: Z = -7.260426557446097e-05 * X + -1.2256547028584478e-05 * Y + 0.015119140326095798
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.49711494138489165
# The direction of the gradient is: 339.3419654599765
# 186
# The equation of the fit plane is: Z = -0.00010877696563539545 * X + -2.2674022375547487e-05 * Y + 0.02290601398971975
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7687184683096494
# The direction of the gradient is: 335.0358089756708
# 187
# The equation of the fit plane is: Z = -3.941394252635665e-05 * X + -2.5464343040029253e-05 * Y + 0.011590151110958713
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4433107835720193
# The direction of the gradient is: 304.72271710342
# 188
# The equation of the fit plane is: Z = -0.00010410822335811335 * X + -4.342588494710847e-05 * Y + 0.02606381168495443
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9115798607060355
# The direction of the gradient is: 317.0276579822797
# 189
# The equation of the fit plane is: Z = -4.1055337160693515e-05 * X + -2.0110912694628244e-05 * Y + 0.011607120219567781
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.38986128539986875
# The direction of the gradient is: 312.42860931169594
# 190
# The equation of the fit plane is: Z = -0.0001092157276895404 * X + -3.761019447297751e-05 * Y + 0.024706955371079264
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8827273897196793
# The direction of the gradient is: 322.4355109249269
# 191
# ...
# 219
# The equation of the fit plane is: Z = -4.072379303180387e-06 * X + -2.144154640542948e-05 * Y + 0.003529241079910472
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3079110308425968
# The direction of the gradient is: 274.8607045235319
# 220
# The equation of the fit plane is: Z = -2.0864781963584727e-05 * X + -1.0941288428148743e-05 * Y + 0.00505792420413035
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20586120603973662
# The direction of the gradient is: 310.4918291256846
# 221
# The equation of the fit plane is: Z = -6.5228643436020335e-06 * X + 1.5862056834455855e-05 * Y + -0.0012035345793938342
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2307828075953043
# The direction of the gradient is: 79.56740077330102
# 222
# The equation of the fit plane is: Z = -5.107146137324854e-05 * X + -2.0395879179750327e-05 * Y + 0.012630047439991037
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.43844044467243976
# The direction of the gradient is: 318.26892634246906
# 223
# The equation of the fit plane is: Z = -6.592929861877212e-05 * X + -1.864723479601965e-05 * Y + 0.015493958472707493
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.49960408211668744
# The direction of the gradient is: 327.7195762819291
# 224
# The equation of the fit plane is: Z = -4.828565515307322e-05 * X + -2.6249305955466026e-05 * Y + 0.012395860222416219
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.48659108097791376
# The direction of the gradient is: 309.47565097350326
# 225
# The equation of the fit plane is: Z = -0.00013070215292739558 * X + -7.990395079951832e-05 * Y + 0.036976820393843486
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.417177427287547
# The direction of the gradient is: 306.2186860014759
# 226
# The equation of the fit plane is: Z = -0.0001349010990844314 * X + -5.090592613275382e-05 * Y + 0.03345616450066417
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1302793292640958
# The direction of the gradient is: 319.87579594491433
# 227
# The equation of the fit plane is: Z = -0.00021805962815271397 * X + -4.84762009421957e-05 * Y + 0.048567974169965604
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5597581817384198
# The direction of the gradient is: 333.5952885476769
# 228
# The equation of the fit plane is: Z = -0.00011197151842190212 * X + -8.459872672265014e-06 * Y + 0.022569732649346815
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.727506514645578
# The direction of the gradient is: 350.4219152819818
# 229
# The equation of the fit plane is: Z = -0.00010582165155703763 * X + -1.0601430738960483e-05 * Y + 0.019760095223953368
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6947281998747575
# The direction of the gradient is: 347.38783716181956
# 230
# The equation of the fit plane is: Z = -0.00013028441699089365 * X + 6.63671707600597e-06 * Y + 0.02223875648113117
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8400743500518475
# The direction of the gradient is: 6.490706416680609
# 231
# The equation of the fit plane is: Z = -0.0001261525460125894 * X + -3.4610740923876704e-05 * Y + 0.030816136736769563
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.947881183610645
# The direction of the gradient is: 328.50191250101307
# 232
# The equation of the fit plane is: Z = -7.419303315158582e-05 * X + -3.675598257555089e-06 * Y + 0.014055325488848433
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.47823128482311916
# The direction of the gradient is: 353.6861177810058
# 233
# The equation of the fit plane is: Z = -6.173631571670008e-05 * X + -5.334051237917139e-05 * Y + 0.019586278566891848
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8596372514946805
# The direction of the gradient is: 297.3939570397662
# 234
# The equation of the fit plane is: Z = -0.0001323080553768837 * X + 4.565999965378474e-05 * Y + 0.01777938464661277
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.07022117824943
# The direction of the gradient is: 37.62374767654137
# 235
# The equation of the fit plane is: Z = -7.164469610524474e-05 * X + -3.138337675246374e-05 * Y + 0.01927985981891945
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6421366251523614
# The direction of the gradient is: 315.6274327384374
# 236
# The equation of the fit plane is: Z = -7.668287392038668e-05 * X + 3.767299312178033e-06 * Y + 0.013548352610910638
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4942306305269373
# The direction of the gradient is: 6.261702225632121
# 237
# The equation of the fit plane is: Z = -8.335628970578613e-05 * X + 6.385079896898768e-06 * Y + 0.015732645377190272
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.541795330429103
# The direction of the gradient is: 9.708189459954724
# 238
# The equation of the fit plane is: Z = -4.161919921291276e-05 * X + -3.8008713315822946e-05 * Y + 0.012917374987990176
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6057075105416101
# The direction of the gradient is: 296.1175012310453
# 239
# The equation of the fit plane is: Z = -5.06622317985167e-05 * X + -3.4776358352811835e-05 * Y + 0.014298816341830743
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5941084872936077
# The direction of the gradient is: 303.11525940051155
# 240
# The equation of the fit plane is: Z = -4.853683172802282e-05 * X + -2.0812816413503558e-06 * Y + 0.008902053124689975
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3123824062744467
# The direction of the gradient is: 354.5294444899648
# 241
# The equation of the fit plane is: Z = -4.714307410241806e-05 * X + -9.77213257149312e-06 * Y + 0.010643913958395836
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.33282745374413925
# The direction of the gradient is: 335.1577567014094
# 242
# The equation of the fit plane is: Z = 3.4342643178312336e-06 * X + -2.7874208269523102e-05 * Y + 0.0034388904972807686
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3994540162042085
# The direction of the gradient is: 266.84251021280284
# 243
# The equation of the fit plane is: Z = -1.4869305676693531e-05 * X + -2.8325508315462415e-05 * Y + 0.006689954755220258
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4163499635583425
# The direction of the gradient is: 283.22670250638794
# 244
# The equation of the fit plane is: Z = -2.5436122545471754e-05 * X + -2.8757088673328367e-05 * Y + 0.009626824571305101
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.44257490527706095
# The direction of the gradient is: 291.6053229226588
# 245
# The equation of the fit plane is: Z = 2.203849228211841e-06 * X + -2.0880988580571736e-05 * Y + 0.0017830895343669546
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.29911616771101074
# The direction of the gradient is: 267.2944311579953
# 246
# The equation of the fit plane is: Z = -1.493620654933078e-05 * X + -3.376720310960703e-05 * Y + 0.007280575305927528
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4925541989104713
# The direction of the gradient is: 281.20242438232174
# 247
# The equation of the fit plane is: Z = 4.758498241409437e-06 * X + -4.489347931945616e-05 * Y + 0.005612676074086668
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6430966542505012
# The direction of the gradient is: 267.2828623304986
# 248
# The equation of the fit plane is: Z = -6.4087291641725e-05 * X + -3.9583091703111607e-05 * Y + 0.022961858346723537
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6995546193923489
# The direction of the gradient is: 305.93912146522507
# 249
# The equation of the fit plane is: Z = -3.624488134451745e-05 * X + -2.0736719965622127e-05 * Y + 0.010477978892189403
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3767796291504407
# The direction of the gradient is: 308.0464055517255
# 250
# The equation of the fit plane is: Z = -4.4535687493867465e-05 * X + -2.751801874489162e-05 * Y + 0.013845711330809543
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4862617580561403
# The direction of the gradient is: 305.9283887577443
# 251
# The equation of the fit plane is: Z = -3.944695888198931e-05 * X + -6.055851765597896e-05 * Y + 0.017028256594134275
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9026239519069247
# The direction of the gradient is: 286.2594811018115
# 252
# The equation of the fit plane is: Z = -3.173983683295398e-05 * X + -2.8847221403089296e-05 * Y + 0.011049059634298317
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4601404353938886
# The direction of the gradient is: 296.22665605486077
# 253
# The equation of the fit plane is: Z = -0.00010133285276320707 * X + -4.02335348285274e-05 * Y + 0.028192697034050796
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8676946573527275
# The direction of the gradient is: 318.4344273071224
# 254
# The equation of the fit plane is: Z = -0.0001511492163967096 * X + 1.6129511642746252e-06 * Y + 0.029763140652319085
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9686385832591266
# The direction of the gradient is: 1.3652985784142402
# 255
# The equation of the fit plane is: Z = -0.0001953805539059538 * X + -6.396981624858722e-05 * Y + 0.04048804525631242
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.550705470211736
# The direction of the gradient is: 323.82387539253426
# 256
# The equation of the fit plane is: Z = -0.0001829824957931626 * X + -6.322557863048137e-05 * Y + 0.04640765273649072
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.480798049114708
# The direction of the gradient is: 322.342205752796
# 257
# The equation of the fit plane is: Z = -0.00029928241798064207 * X + -7.82573462803401e-05 * Y + 0.07437216056692733
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.220434500406914
# The direction of the gradient is: 329.7149013555625
# 258
# The equation of the fit plane is: Z = -0.00018488578323492982 * X + -7.150129060125055e-05 * Y + 0.04818254192703496
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5651777978635544
# The direction of the gradient is: 319.18156545024533
# 259
# The equation of the fit plane is: Z = -0.00015264604964995243 * X + 2.1389506070970145e-05 * Y + 0.026226158355115648
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.024726701755765
# The direction of the gradient is: 17.377966955527313
# 260
# The equation of the fit plane is: Z = -0.00019314298464622747 * X + 2.128498720001371e-05 * Y + 0.034057097629200936
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2743341014456504
# The direction of the gradient is: 13.827417901432455
# 261
# The equation of the fit plane is: Z = -0.00017651657523499455 * X + -5.088598340048671e-06 * Y + 0.03684261459825174
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1332255348929823
# The direction of the gradient is: 356.3160971095143
# 262
# The equation of the fit plane is: Z = -0.00020871242767487414 * X + -1.7301659385922124e-05 * Y + 0.04070770097484411
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.359876988519038
# The direction of the gradient is: 349.5107642521916
# 263
# The equation of the fit plane is: Z = -0.00013886074771623583 * X + -4.3158684155752276e-05 * Y + 0.03669560971899305
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.08296816395702
# The direction of the gradient is: 325.23310276013774
# 264
# The equation of the fit plane is: Z = -0.00014623136603185432 * X + -1.9921679355804045e-05 * Y + 0.03198943927669844
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9792635818327161
# The direction of the gradient is: 343.07663524696767
# 265
# The equation of the fit plane is: Z = -0.00014219659080208733 * X + -1.3506767741392584e-05 * Y + 0.03224445210827747
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9312817289673151
# The direction of the gradient is: 348.0225272614328
# 266
# The equation of the fit plane is: Z = -7.41880910294452e-05 * X + -8.043610004561165e-05 * Y + 0.02769535980795652
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2452263953728018
# The direction of the gradient is: 292.4388211898743
# 267
# The equation of the fit plane is: Z = -0.00010900603084929466 * X + -4.809115840722857e-05 * Y + 0.028333981107425018
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9804265372092376
# The direction of the gradient is: 315.42303875918697
# 268
# The equation of the fit plane is: Z = -7.94280842347497e-05 * X + -2.1509485084311183e-05 * Y + 0.019537204172360035
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5947052795216126
# The direction of the gradient is: 328.8335140261505
# 269
# The equation of the fit plane is: Z = -2.1590842957067594e-05 * X + -1.1228502801720501e-05 * Y + 0.006727499879364849
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.212008902485712
# The direction of the gradient is: 310.7266699118693
# 270
# The equation of the fit plane is: Z = -3.0507704763865876e-05 * X + 2.6667010224949523e-05 * Y + 0.004002080366519757
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.42871966381774984
# The direction of the gradient is: 62.87720463609287
# 271
# The equation of the fit plane is: Z = -1.976408523284466e-05 * X + -2.7953335108694803e-05 * Y + 0.009254460333565986
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.41954379428871424
# The direction of the gradient is: 287.56627920624675
# 272
# The equation of the fit plane is: Z = -1.3533805647925687e-05 * X + -3.380228462178019e-05 * Y + 0.008604755078030256
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.49138190185836184
# The direction of the gradient is: 280.16332614617363
# 273
# The equation of the fit plane is: Z = -2.419125612838757e-05 * X + -4.788390778948545e-05 * Y + 0.012651211842181946
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7024735729674136
# The direction of the gradient is: 282.7459316520727
# 274
# The equation of the fit plane is: Z = -6.465475189550473e-05 * X + -3.2193132140494335e-05 * Y + 0.015634712072846873
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6194956384764595
# The direction of the gradient is: 311.96247001667905
# 275
# The equation of the fit plane is: Z = -2.8604049110984606e-05 * X + -3.63507988900288e-05 * Y + 0.011483286825801561
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5514765391731479
# The direction of the gradient is: 289.40856049095487
# 276
# The equation of the fit plane is: Z = -2.8168334832389444e-05 * X + -6.418944151033368e-05 * Y + 0.01746209652767123
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9360378211362138
# The direction of the gradient is: 281.11606060961
# 277
# The equation of the fit plane is: Z = -1.1912026798282383e-05 * X + -3.595943478749771e-05 * Y + 0.009948449169421215
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5201666814188066
# The direction of the gradient is: 278.4366264799618
# 278
# The equation of the fit plane is: Z = -1.3967031092184593e-05 * X + -9.846204696225826e-06 * Y + 0.004553176406755102
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16690245425971745
# The direction of the gradient is: 302.4208977682176
# 279
# The equation of the fit plane is: Z = -3.459775833185616e-05 * X + -2.408707819102589e-05 * Y + 0.011296717256162471
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4097814842798926
# The direction of the gradient is: 302.745877053919
# 280
# The equation of the fit plane is: Z = -2.1529605557924676e-06 * X + -4.417045377260885e-05 * Y + 0.007709477838852287
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6321784832222219
# The direction of the gradient is: 271.2502187607157
# 281
# The equation of the fit plane is: Z = -3.0254381492079546e-05 * X + -5.280026205715075e-05 * Y + 0.01680488800499101
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.779978345217003
# The direction of the gradient is: 284.38917017037693
# 282
# The equation of the fit plane is: Z = -8.656578354660902e-05 * X + -4.128278762598244e-05 * Y + 0.02507434609021445
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8102571203845959
# The direction of the gradient is: 313.1941309240674
# 283

# %%
######### GIM

# %%
path_GIM = '../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5'

# %%
# !reference_point.py ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 -y 180 -x 190
# !reference_date.py ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 --ref-date 20190112
# Out:
# WARNING: auto turn ON --write-data for file tpye timeseries
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# --------------------------------------------------
# input reference point in y/x: (180, 190)
# --------------------------------------------------
# calculating the temporal average of timeseries file: ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5
# reading timeseries data from file: ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 ...
# /home/eedy/tools/MintPy/src/mintpy/objects/stack.py:455: RuntimeWarning: Mean of empty slice
#   dmean = np.nanmean(data, axis=0)
# updating dataset values without re-writing to a new file
# update metadata
# input reference date: 20190112
# --------------------------------------------------
# change reference date for file: /panda/eedy/ion_los-angle/s1_d173/mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5
# reading data ...
# referencing in time ...
# --------------------------------------------------
# open  HDF5 file /panda/eedy/ion_los-angle/s1_d173/mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 in r+ mode
# writing dataset /timeseries                block: (0, 284, 0, 784, 0, 301)
# close HDF5 file /panda/eedy/ion_los-angle/s1_d173/mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5.
# update "REF_DATE" attribute value to 20190112
# time used: 00 mins 2.7 secs.

# %%
timeseries_GIM = readfile.read(path_GIM, datasetName='timeseries')[0]
timeseries_GIM = np.squeeze(timeseries_GIM)

mask_path_gim = '../mintpy_gim_ion_upsample/geo/geo_maskTempCoh.h5'
mask_gim = readfile.read(mask_path_gim, datasetName='mask')[0]
mask_gim = np.squeeze(mask_gim)

from mintpy.objects import ramp
data_out, ramp = ramp.deramp(timeseries_GIM, mask_in=mask_gim, ramp_type='linear', metadata=None, max_num_sample=1e3, coeff_file=None,ignore_zero_value=True)

# %%
def function(data, a, b, c):
    '''
    拟合曲面使用的函数
    '''
    x = data[0]
    y = data[1]
    return a*x+b*y + c



slope_ion_GIM = np.zeros(timeseries_GIM.shape[0])
slope_ion_GIM_dongxifangxiang = np.zeros(timeseries_GIM.shape[0])
slope_ion_GIM_nanbeifangxiang = np.zeros(timeseries_GIM.shape[0])
angle_deg_ion_GIM = np.zeros(timeseries_GIM.shape[0])
meta = readfile.read_attribute(path_GIM)
AZIMUTH_PIXEL_SIZE =  float(meta['AZIMUTH_PIXEL_SIZE'])
RANGE_PIXEL_SIZE = float(meta['RANGE_PIXEL_SIZE'])

for i in range(timeseries_GIM.shape[0]):
    x_data = ramp.shape[2]
    y_data = ramp.shape[1]
    X_data, Y_data = np.meshgrid(range(x_data), range(y_data))
    Z_data = ramp[i, :,:]
    
    x_data = X_data.flatten()
    y_data = Y_data.flatten()
    z_data = Z_data.flatten()
    
    parameters, covariance = curve_fit(function, [x_data, y_data], z_data)
    print("The equation of the fit plane is: Z = {0} * X + {1} * Y + {2}".format(parameters[0],parameters[1],parameters[2]))
    
    Z_fit = function([X_data, Y_data], *parameters)
    
    # 计算梯度，考虑到横纵坐标的实际长度
    dx = parameters[1]/RANGE_PIXEL_SIZE
    dy = parameters[0]/AZIMUTH_PIXEL_SIZE
    # 计算梯度的大小和方向
    magnitude = np.hypot(dx, dy)  # 梯度的大小
    direction = np.degrees(np.arctan2(dy, dx)) + 90  # 梯度的方向，以x轴正半轴为0°，逆时针旋转为正方向
    direction = (direction + 360) % 360  # 将角度值限制在0°到360°之间

    print('The magnitude of the gradient is( cm(ion)/ 100km(juli)):', magnitude*1e7)
    print('The direction of the gradient is:', direction)

    slope_ion_GIM[i] = magnitude*1e7
    angle_deg_ion_GIM[i] = direction
    slope_ion_GIM_dongxifangxiang[i] = dy*1e7
    slope_ion_GIM_nanbeifangxiang[i] = dx*1e7

    print(i)
# Out:
# The equation of the fit plane is: Z = -5.400822730915332e-05 * X + 7.791057670156033e-06 * Y + 0.008937117041310137
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.363528599743461
# The direction of the gradient is: 17.858280486497677
# 0
# The equation of the fit plane is: Z = -4.0734442240019304e-05 * X + 1.991067886899447e-05 * Y + 0.004516500987886008
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3863596799895814
# The direction of the gradient is: 47.509768377349246
# 1
# The equation of the fit plane is: Z = -2.2142709606510957e-05 * X + 6.986704272612054e-06 * Y + 0.0030581172094845933
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17354797509782108
# The direction of the gradient is: 35.172926050699346
# 2
# The equation of the fit plane is: Z = -3.5623481102359544e-05 * X + 4.9408646206108865e-05 * Y + -0.001837700389222162
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7429060328166296
# The direction of the gradient is: 72.10884153110607
# 3
# The equation of the fit plane is: Z = -8.841292076231091e-07 * X + 1.3460244350314814e-06 * Y + -0.0001268882949632181
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.020075709084405622
# The direction of the gradient is: 73.61153771855822
# 4
# The equation of the fit plane is: Z = -8.179055950174504e-06 * X + -2.1854456516252026e-06 * Y + 0.002028117903101371
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.06102215792309122
# The direction of the gradient is: 329.17241343021755
# 5
# The equation of the fit plane is: Z = -6.530710946538178e-07 * X + 3.290424845560022e-05 * Y + -0.0056482906347469514
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4708402418829921
# The direction of the gradient is: 89.49084760821273
# 6
# The equation of the fit plane is: Z = -1.3898916204467901e-05 * X + 2.474025809895155e-05 * Y + -0.0015440534221895822
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3650318903872807
# The direction of the gradient is: 75.88081154317001
# 7
# The equation of the fit plane is: Z = -2.742033214259279e-05 * X + 9.819968333998171e-06 * Y + 0.0037521163516452097
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.22495502212003798
# The direction of the gradient is: 38.6546140914582
# 8
# The equation of the fit plane is: Z = -2.4202752881559684e-05 * X + -1.905692470876987e-05 * Y + 0.008118551467860705
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3136862723178547
# The direction of the gradient is: 299.6244419544321
# 9
# The equation of the fit plane is: Z = -1.636457234946234e-05 * X + -6.608405511335831e-06 * Y + 0.004444024335385608
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.14118525043518754
# The direction of the gradient is: 317.9523363327581
# 10
# The equation of the fit plane is: Z = -1.3154018230309308e-05 * X + 4.931660849789818e-06 * Y + 0.0018948298210497267
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.10991647384711112
# The direction of the gradient is: 39.94109866390869
# 11
# The equation of the fit plane is: Z = -1.4000412892301642e-05 * X + 5.490192046206352e-06 * Y + 0.0019056938459460283
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11923417381315765
# The direction of the gradient is: 41.21276799390017
# 12
# The equation of the fit plane is: Z = -1.6382391650883593e-05 * X + -7.583664948042612e-06 * Y + 0.004652287206905002
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1509670918380713
# The direction of the gradient is: 314.04542852054055
# 13
# The equation of the fit plane is: Z = -1.5432983920798797e-05 * X + 1.4434074161039535e-05 * Y + 0.0006453675914402389
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.22898195490780876
# The direction of the gradient is: 64.41824400452651
# 14
# The equation of the fit plane is: Z = -1.4138104473038375e-05 * X + 1.139384202045761e-05 * Y + 0.0009206304500424124
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.18650486359018045
# The direction of the gradient is: 60.944186142247474
# 15
# The equation of the fit plane is: Z = -1.0833998418049033e-05 * X + 7.485965090896914e-06 * Y + 0.0010424053172840906
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.12763799824095795
# The direction of the gradient is: 57.05711980664387
# 16
# The equation of the fit plane is: Z = -1.5558966583250181e-06 * X + -9.870636290161137e-07 * Y + 0.0006175090419684903
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.01728708658049829
# The direction of the gradient is: 305.21332768093976
# 17
# The equation of the fit plane is: Z = -4.748986090937564e-06 * X + 3.101085587830916e-05 * Y + -0.004439468489865214
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4447712579817713
# The direction of the gradient is: 86.07753877553546
# 18
# The equation of the fit plane is: Z = -1.4125827058554078e-05 * X + 1.7902645945132658e-05 * Y + -0.00044492676626478513
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2716822502342278
# The direction of the gradient is: 70.54246754801079
# 19
# The equation of the fit plane is: Z = -1.2190783617392122e-05 * X + 4.622032917653854e-06 * Y + 0.0015557602188135265
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.10234227263837542
# The direction of the gradient is: 40.25743572049737
# 20
# The equation of the fit plane is: Z = -5.4727217534588205e-06 * X + 2.9875870103564412e-05 * Y + -0.0041017578720961385
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4289245185276172
# The direction of the gradient is: 85.31119109864733
# 21
# The equation of the fit plane is: Z = -1.8022609529339505e-05 * X + 1.0794843262267675e-05 * Y + 0.001673040363401847
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19284857442418604
# The direction of the gradient is: 53.22073185548385
# 22
# The equation of the fit plane is: Z = -1.3680000355983988e-05 * X + 5.685100208149329e-06 * Y + 0.0015125017644645443
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11957722101446457
# The direction of the gradient is: 42.86631267036728
# 23
# The equation of the fit plane is: Z = -1.2779462787400376e-05 * X + 2.0890507970090197e-05 * Y + -0.0012173066465761466
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3099288065918553
# The direction of the gradient is: 74.68237059079462
# 24
# The equation of the fit plane is: Z = -6.3483786133971664e-06 * X + 1.4914696993794113e-05 * Y + -0.0012309556400196225
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21725308391942566
# The direction of the gradient is: 79.20998291184782
# 25
# The equation of the fit plane is: Z = 2.2110437855370274e-06 * X + -8.21255034022196e-06 * Y + 0.0011168101335967645
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11836277838583233
# The direction of the gradient is: 263.12647388566427
# 26
# The equation of the fit plane is: Z = -1.1460089039059287e-05 * X + -9.497717700648327e-06 * Y + 0.0037425393171001456
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.15446624532520617
# The direction of the gradient is: 298.3802489188124
# 27
# The equation of the fit plane is: Z = -5.151592961141394e-06 * X + 1.0118272102514557e-05 * Y + -0.000640064143658577
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.14849500199886484
# The direction of the gradient is: 77.15816309762408
# 28
# The equation of the fit plane is: Z = -8.036123523902767e-06 * X + -7.659748936078286e-06 * Y + 0.0029566079163289003
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.12109216562934448
# The direction of the gradient is: 295.16145509363446
# 29
# The equation of the fit plane is: Z = -6.695361152999761e-06 * X + 1.3712331940384207e-05 * Y + -0.0009607516522438606
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20084170938284998
# The direction of the gradient is: 77.66799639528017
# 30
# The equation of the fit plane is: Z = -5.879123152323027e-06 * X + 1.8548248867142483e-05 * Y + -0.001970896869167393
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.26806333186100934
# The direction of the gradient is: 81.9226324868643
# 31
# The equation of the fit plane is: Z = -1.1393975692641262e-05 * X + 5.28071157131915e-06 * Y + 0.001488049612009613
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.10506224407316504
# The direction of the gradient is: 45.9885449793851
# 32
# The equation of the fit plane is: Z = -7.67573168541483e-06 * X + 1.0774256055666833e-05 * Y + -0.0003681849973912949
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16182017321233544
# The direction of the gradient is: 72.30846643638267
# 33
# The equation of the fit plane is: Z = -4.377767869369287e-06 * X + -1.735626097084608e-07 * Y + 0.0010929534620844946
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.028156664862005774
# The direction of the gradient is: 354.939810696132
# 34
# The equation of the fit plane is: Z = -1.5890898300653503e-05 * X + -6.8780490085279446e-06 * Y + 0.0043164868923392585
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.14160054171747033
# The direction of the gradient is: 315.9702325961633
# 35
# The equation of the fit plane is: Z = -2.8120296801585257e-05 * X + 9.132626998098393e-06 * Y + 0.003832351549663072
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.22256077539990632
# The direction of the gradient is: 35.95526060851648
# 36
# The equation of the fit plane is: Z = -2.5561946164872614e-05 * X + -1.803496208729405e-05 * Y + 0.008388121276160362
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3056375201347957
# The direction of the gradient is: 302.39961262238717
# 37
# The equation of the fit plane is: Z = -2.4279237534365494e-05 * X + -1.1564822162646714e-05 * Y + 0.006775844213120446
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.22710988117249564
# The direction of the gradient is: 313.2282888445996
# 38
# The equation of the fit plane is: Z = -3.101146311723167e-05 * X + -3.81718778550452e-06 * Y + 0.0067815815243389
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20605134117196816
# The direction of the gradient is: 344.6284542675828
# 39
# The equation of the fit plane is: Z = -2.1234125853679505e-05 * X + -6.6002778541176195e-06 * Y + 0.005513855491605401
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16560875951128065
# The direction of the gradient is: 325.23068411649103
# 40
# The equation of the fit plane is: Z = -1.610514356480698e-05 * X + -6.012674039221367e-06 * Y + 0.004167120711918232
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1343432523529417
# The direction of the gradient is: 320.1778047677505
# 41
# The equation of the fit plane is: Z = -1.1512951637958008e-05 * X + -1.2883241225926245e-05 * Y + 0.0046040727967323865
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19855300821151484
# The direction of the gradient is: 291.807308324711
# 42
# The equation of the fit plane is: Z = -2.5445048651771577e-05 * X + 9.522264722612337e-06 * Y + 0.0033175732161779326
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21246097273175607
# The direction of the gradient is: 39.889299358076755
# 43
# The equation of the fit plane is: Z = -8.971593593545022e-06 * X + 2.1466678958009783e-06 * Y + 0.0015005553382491186
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.06517070587653508
# The direction of the gradient is: 28.12008651191809
# 44
# The equation of the fit plane is: Z = -1.0661078143611279e-05 * X + -2.1695019095492936e-05 * Y + 0.005943411872422517
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.31785580014312503
# The direction of the gradient is: 282.40870620757187
# 45
# The equation of the fit plane is: Z = -8.27827671107501e-06 * X + 2.34536399997776e-05 * Y + -0.0024205908167628637
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3397593868626278
# The direction of the gradient is: 81.01944090699669
# 46
# The equation of the fit plane is: Z = -1.0335957811418376e-05 * X + 1.1809588373327061e-05 * Y + 3.0313651287347774e-06
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.18149303910101858
# The direction of the gradient is: 68.6011852233429
# 47
# The equation of the fit plane is: Z = -1.0263481757447049e-05 * X + 1.2691905943338516e-05 * Y + -0.0003820073383987782
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19314397880058157
# The direction of the gradient is: 70.09605323654
# 48
# The equation of the fit plane is: Z = -2.7221723545028926e-06 * X + 5.7121508692556766e-06 * Y + -0.0003747798105381813
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.08357418718065726
# The direction of the gradient is: 77.95512755033167
# 49
# The equation of the fit plane is: Z = -1.2184018588671496e-05 * X + 6.462235704070034e-06 * Y + 0.001403198609134952
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.12100981686318513
# The direction of the gradient is: 49.82955971861401
# 50
# The equation of the fit plane is: Z = -5.454030191741919e-06 * X + 2.811589053053512e-06 * Y + 0.0007335943975533643
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.05328654649121828
# The direction of the gradient is: 49.02411935158949
# 51
# The equation of the fit plane is: Z = -4.240412566276544e-06 * X + -1.2131614531765566e-05 * Y + 0.0029253042615462986
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17570230946556958
# The direction of the gradient is: 278.8947070900699
# 52
# The equation of the fit plane is: Z = 6.445622967371379e-06 * X + -1.2838411630987319e-06 * Y + -0.0009695184518084951
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0451967256287873
# The direction of the gradient is: 203.9821201713629
# 53
# The equation of the fit plane is: Z = 2.757931839009049e-07 * X + -3.1690447007292446e-07 * Y + 0.00016415556267658586
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.004866621804044653
# The direction of the gradient is: 248.71124137876996
# 54
# The equation of the fit plane is: Z = 1.0801877171849713e-05 * X + 3.5021679724310313e-06 * Y + -0.002583548493779401
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.08544246911724952
# The direction of the gradient is: 144.0910077246209
# 55
# The equation of the fit plane is: Z = 0.0 * X + 0.0 * Y + 6.4e-323
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0
# The direction of the gradient is: 90.0
# 56
# The equation of the fit plane is: Z = -5.08375088008212e-06 * X + 7.760599003549334e-06 * Y + -0.0002745879632495654
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11572307998509938
# The direction of the gradient is: 73.653406887026
# 57
# The equation of the fit plane is: Z = 1.0667943816858707e-05 * X + -7.799291931031874e-06 * Y + -0.0004838149463481544
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.13086434727135524
# The direction of the gradient is: 238.51561247863333
# 58
# The equation of the fit plane is: Z = 4.5394072869844595e-06 * X + -7.3739127529148095e-06 * Y + 0.00048431517513668383
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.10944680929454807
# The direction of the gradient is: 254.5901019897492
# 59
# The equation of the fit plane is: Z = -1.3983521300901245e-06 * X + -1.3567599956818344e-05 * Y + 0.002659842738828191
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19434322694447867
# The direction of the gradient is: 272.64214261535926
# 60
# The equation of the fit plane is: Z = -9.598497838673484e-06 * X + 3.96382876824105e-06 * Y + 0.0012307201985097122
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.08365688196699725
# The direction of the gradient is: 42.686088914210586
# 61
# The equation of the fit plane is: Z = -2.4304262043645663e-05 * X + -1.0715247751937585e-05 * Y + 0.006572846608880406
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2185253029902038
# The direction of the gradient is: 315.44249163049267
# 62
# The equation of the fit plane is: Z = -5.454765395839127e-06 * X + -1.2906573994298255e-06 * Y + 0.0013691495803552602
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.03952651907253151
# The direction of the gradient is: 332.1456298302437
# 63
# The equation of the fit plane is: Z = -2.6303858824205002e-05 * X + -2.3480170140363855e-06 * Y + 0.005445879687537258
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17183669539723856
# The direction of the gradient is: 348.72493496610474
# 64
# The equation of the fit plane is: Z = -5.6255014090746466e-06 * X + 3.868764760543684e-06 * Y + 0.0006241611343613501
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.06605598074213509
# The direction of the gradient is: 56.933699360859464
# 65
# The equation of the fit plane is: Z = -1.8768456550034673e-05 * X + -1.3873780755082702e-05 * Y + 0.006152871300991492
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23209427204891453
# The direction of the gradient is: 301.20353855073665
# 66
# The equation of the fit plane is: Z = -3.1081168825615694e-05 * X + 1.9532932089914135e-05 * Y + 0.0024905993287092777
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3431737111344086
# The direction of the gradient is: 54.53180278274982
# 67
# The equation of the fit plane is: Z = -1.5669941684159742e-05 * X + -1.5674719215631928e-05 * Y + 0.006003166832529408
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.24573009137903534
# The direction of the gradient is: 294.1135665178216
# 68
# The equation of the fit plane is: Z = -1.1384472810788385e-05 * X + -9.565702817798573e-06 * Y + 0.004016552499377503
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.15509439370289904
# The direction of the gradient is: 298.05197203606133
# 69
# The equation of the fit plane is: Z = 1.415775391238403e-06 * X + -3.4290825718088926e-06 * Y + 0.0005099078932446661
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.049897534710678586
# The direction of the gradient is: 259.5265010074844
# 70
# The equation of the fit plane is: Z = -4.755802382872851e-06 * X + -1.3535310958825326e-05 * Y + 0.003505144373079734
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19605664046638047
# The direction of the gradient is: 278.94048923531705
# 71
# The equation of the fit plane is: Z = -7.4982692948497905e-06 * X + -1.9740341521460818e-05 * Y + 0.005145121531938264
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.28651733966375115
# The direction of the gradient is: 279.65209076928556
# 72
# The equation of the fit plane is: Z = 2.9460250040872807e-06 * X + -1.1281201373837838e-05 * Y + 0.0015842418320330613
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1625206067136842
# The direction of the gradient is: 263.33094534605107
# 73
# The equation of the fit plane is: Z = -2.063388950344021e-05 * X + -3.443165792759919e-06 * Y + 0.004679110691962604
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1410769810726809
# The direction of the gradient is: 339.56003566979956
# 74
# The equation of the fit plane is: Z = -5.017874754423568e-06 * X + -1.2515325371271998e-05 * Y + 0.00328689502805338
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.18194246425920152
# The direction of the gradient is: 280.17717050478586
# 75
# The equation of the fit plane is: Z = 1.1761642500454529e-05 * X + -5.172533227870926e-06 * Y + -0.00116958467626695
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.10562192702819588
# The direction of the gradient is: 224.48598258509764
# 76
# The equation of the fit plane is: Z = 2.5563922634073794e-06 * X + 9.220618900133633e-07 * Y + -0.00046245072676325813
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.021031165483254757
# The direction of the gradient is: 141.146046934712
# 77
# The equation of the fit plane is: Z = 1.1540371873328649e-06 * X + -6.480687208051237e-06 * Y + 0.0012277234497321636
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0930254011836237
# The direction of the gradient is: 265.44139745004213
# 78
# The equation of the fit plane is: Z = -1.673390803672999e-06 * X + -5.619384018500243e-06 * Y + 0.001541194421519925
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0811184437511142
# The direction of the gradient is: 277.5946093365989
# 79
# The equation of the fit plane is: Z = -7.571999257840904e-06 * X + 1.121250717552403e-06 * Y + 0.0014487547970453932
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0510955171031965
# The direction of the gradient is: 18.30022565962065
# 80
# The equation of the fit plane is: Z = 4.091779682593805e-06 * X + -1.4910204613762455e-06 * Y + -0.00042264344280378333
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.03379915355518566
# The direction of the gradient is: 219.14034815233458
# 81
# The equation of the fit plane is: Z = -6.835825707934258e-06 * X + -7.400548119792201e-07 * Y + 0.0014933369801770513
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.045056931191252765
# The direction of the gradient is: 346.40713747343574
# 82
# The equation of the fit plane is: Z = -8.805388274826275e-06 * X + -3.213690266339366e-06 * Y + 0.0023843959278012335
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.07278048470156946
# The direction of the gradient is: 320.8154564820345
# 83
# The equation of the fit plane is: Z = -1.4716494533267502e-05 * X + -1.4225630487157554e-05 * Y + 0.0053494373027200975
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.22432779570954958
# The direction of the gradient is: 294.8531898275528
# 84
# The equation of the fit plane is: Z = 2.7997742990942298e-06 * X + 1.5704754858368525e-05 * Y + -0.0030252285435371415
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.22543158845614425
# The direction of the gradient is: 94.5637596704085
# 85
# The equation of the fit plane is: Z = -2.065240527115845e-06 * X + -1.2153182150202387e-05 * Y + 0.002623586350064593
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17440058540526793
# The direction of the gradient is: 274.3510631871679
# 86
# The equation of the fit plane is: Z = 2.800185191729575e-06 * X + -1.1500079734816585e-05 * Y + 0.0016344360498960016
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16552784089588554
# The direction of the gradient is: 263.77807472308075
# 87
# The equation of the fit plane is: Z = -5.73844596130406e-06 * X + 5.5869473636565435e-06 * Y + 8.046670481937296e-05
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.08799124309280473
# The direction of the gradient is: 65.3030797189731
# 88
# The equation of the fit plane is: Z = 1.0488255478570196e-05 * X + -9.46771369587193e-06 * Y + -0.00021394000209400764
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1512210599971843
# The direction of the gradient is: 243.61834870464668
# 89
# The equation of the fit plane is: Z = 5.286440242766873e-06 * X + -4.834235200759606e-06 * Y + -0.00017452834890003784
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.07701871312209575
# The direction of the gradient is: 243.9124709692951
# 90
# The equation of the fit plane is: Z = -1.2491616775808604e-05 * X + 7.4534576199635554e-06 * Y + 0.0012304592898911553
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.13333809646525596
# The direction of the gradient is: 53.11568179399143
# 91
# The equation of the fit plane is: Z = 1.1414651888943771e-06 * X + -7.968062010605995e-06 * Y + 0.001445891588532459
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11424802236612375
# The direction of the gradient is: 266.32999901763685
# 92
# The equation of the fit plane is: Z = 5.355195692108319e-06 * X + -9.826197667199265e-06 * Y + 0.0009420692521324751
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.14472694202591246
# The direction of the gradient is: 256.2869086429728
# 93
# The equation of the fit plane is: Z = 7.187287839537381e-06 * X + -1.0305277344834888e-05 * Y + 0.0005275278197380163
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1544788993822698
# The direction of the gradient is: 252.6578619397851
# 94
# The equation of the fit plane is: Z = -6.8568199197074005e-06 * X + -2.2160210785612707e-05 * Y + 0.005320554377110293
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3201154664318996
# The direction of the gradient is: 277.88758205144245
# 95
# The equation of the fit plane is: Z = 2.8495659977199216e-07 * X + -1.0740262083481701e-05 * Y + 0.0019799574902394637
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.15369154305323765
# The direction of the gradient is: 269.3193965486414
# 96
# The equation of the fit plane is: Z = -4.966509704875062e-06 * X + -9.280952085262694e-06 * Y + 0.0026227422944655426
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.13655836621751669
# The direction of the gradient is: 283.4740625697587
# 97
# The equation of the fit plane is: Z = 9.502283412917809e-06 * X + -1.0673224027940295e-05 * Y + 0.00028685405364178027
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16440796448996806
# The direction of the gradient is: 248.26672293949036
# 98
# The equation of the fit plane is: Z = 1.396335005983383e-05 * X + -6.572887746001312e-06 * Y + -0.0013410539251166175
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.12980108855784284
# The direction of the gradient is: 226.43336362689138
# 99
# The equation of the fit plane is: Z = -3.2679742553837464e-06 * X + -1.3895642731219214e-05 * Y + 0.0032041111688916333
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19992982424204922
# The direction of the gradient is: 276.0110898316417
# 100
# The equation of the fit plane is: Z = -1.161485294864441e-05 * X + -1.7810428748069217e-05 * Y + 0.005219231221843298
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2654882548373945
# The direction of the gradient is: 286.2772574568852
# 101
# The equation of the fit plane is: Z = 1.3830027652602543e-05 * X + -1.7087273075337093e-05 * Y + 0.0004777417177072097
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2600587354859112
# The direction of the gradient is: 250.07989773243116
# 102
# The equation of the fit plane is: Z = -4.922462889232223e-06 * X + -1.3881122927620955e-05 * Y + 0.00348180727904169
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20111082887598863
# The direction of the gradient is: 279.0219067547623
# 103
# The equation of the fit plane is: Z = -6.910063487129783e-06 * X + -2.570693442487435e-05 * Y + 0.005912358823553271
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.370490915728761
# The direction of the gradient is: 276.86275672283637
# 104
# The equation of the fit plane is: Z = -1.1015305430232333e-05 * X + 8.787253644986891e-07 * Y + 0.001870080163790114
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.07168280656074388
# The direction of the gradient is: 10.102242580921313
# 105
# The equation of the fit plane is: Z = -2.038551249184289e-05 * X + -1.8381584762965947e-05 * Y + 0.007047307145818274
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.29366019163667495
# The direction of the gradient is: 296.4068963028359
# 106
# The equation of the fit plane is: Z = -2.115282146037568e-05 * X + -9.035203687089143e-06 * Y + 0.005775890696899237
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.18729555543494128
# The direction of the gradient is: 316.34902703194774
# 107
# The equation of the fit plane is: Z = -2.259655138086711e-05 * X + -1.4789961229011455e-06 * Y + 0.004680752287161821
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1463073517386452
# The direction of the gradient is: 351.6832406781458
# 108
# The equation of the fit plane is: Z = -1.0834222936422853e-06 * X + 2.56352174838519e-06 * Y + -7.781165107419108e-05
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.03733198191395202
# The direction of the gradient is: 79.28464665105435
# 109
# The equation of the fit plane is: Z = 4.629449246720831e-06 * X + -2.107840681373352e-05 * Y + 0.0029149220185236465
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3030623735034343
# The direction of the gradient is: 264.38372721347673
# 110
# The equation of the fit plane is: Z = -3.6556104632146468e-06 * X + 1.926981615078958e-06 * Y + 0.00039667656566425176
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.036176978959236404
# The direction of the gradient is: 49.65554534444942
# 111
# The equation of the fit plane is: Z = -7.350496566747649e-06 * X + -1.42888430950789e-06 * Y + 0.0018338121084704238
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.05133910418238571
# The direction of the gradient is: 336.531323217017
# 112
# The equation of the fit plane is: Z = -1.6007191127422094e-05 * X + -1.0443591597538862e-05 * Y + 0.004952477515335266
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.18124047484006048
# The direction of the gradient is: 304.46053828981917
# 113
# The equation of the fit plane is: Z = -7.6087791148041055e-06 * X + -4.670932070355119e-06 * Y + 0.002467432243411915
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.08272403848565232
# The direction of the gradient is: 306.1053636453712
# 114
# The equation of the fit plane is: Z = -1.1044654818302022e-06 * X + -1.3280643191888525e-05 * Y + 0.0029669382048806365
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1901623024016895
# The direction of the gradient is: 272.13247120465036
# 115
# The equation of the fit plane is: Z = -1.3066025627562458e-05 * X + 1.6760237181573334e-06 * Y + 0.002465874245074775
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.08707730413543098
# The direction of the gradient is: 15.98644633805128
# 116
# The equation of the fit plane is: Z = -1.8728440190445273e-05 * X + -5.263767467156048e-06 * Y + 0.004737119737090592
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.141667712758615
# The direction of the gradient is: 327.88262523189496
# 117
# The equation of the fit plane is: Z = -2.0972766194626284e-05 * X + -2.7293040554130222e-05 * Y + 0.008822367195684896
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.413000233587712
# The direction of the gradient is: 288.9861981004261
# 118
# The equation of the fit plane is: Z = -2.3350257853907038e-05 * X + 5.31184470379416e-07 * Y + 0.004665893322040203
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.14979042367141818
# The direction of the gradient is: 2.908539355322148
# 119
# The equation of the fit plane is: Z = -9.671153025039667e-06 * X + -3.9249063350377515e-06 * Y + 0.0027956954772062658
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.08362459640765307
# The direction of the gradient is: 317.81063840050297
# 120
# The equation of the fit plane is: Z = -2.5220588424644292e-05 * X + -1.9129564144588702e-05 * Y + 0.008328215421619371
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.31785497871870955
# The direction of the gradient is: 300.5536687503541
# 121
# The equation of the fit plane is: Z = -1.2137752787728608e-05 * X + -2.2762481924432947e-05 * Y + 0.006564553227537778
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.33485906644575086
# The direction of the gradient is: 283.4280961709022
# 122
# The equation of the fit plane is: Z = -1.9869688911914462e-05 * X + -2.1368658050225035e-05 * Y + 0.007621654309359541
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3312016818846338
# The direction of the gradient is: 292.6036241298817
# 123
# The equation of the fit plane is: Z = -1.8922234874288668e-05 * X + -9.02255620090776e-06 * Y + 0.005351495840068382
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17709820749188834
# The direction of the gradient is: 313.1984485484438
# 124
# The equation of the fit plane is: Z = -1.7790360291460733e-05 * X + 2.130338495300476e-06 * Y + 0.003240728958998072
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11798285630302063
# The direction of the gradient is: 14.973086021948745
# 125
# The equation of the fit plane is: Z = -1.0343802150666392e-05 * X + 3.349402482334672e-06 * Y + 0.0015950357275896112
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.08178346751609561
# The direction of the gradient is: 35.874492376568696
# 126
# The equation of the fit plane is: Z = -1.3467045297263087e-05 * X + -1.1892241677493187e-05 * Y + 0.0048581903662604006
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19078760530364183
# The direction of the gradient is: 296.88653743872635
# 127
# The equation of the fit plane is: Z = -8.506987931888221e-06 * X + -1.8053820456834235e-05 * Y + 0.004995230514451208
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.26401592675333024
# The direction of the gradient is: 281.91337383694895
# 128
# The equation of the fit plane is: Z = -1.2685872800786542e-05 * X + -1.6036576531406698e-05 * Y + 0.00548570271026906
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2434329584654992
# The direction of the gradient is: 289.50365705150546
# 129
# The equation of the fit plane is: Z = -1.9097241522310903e-05 * X + 5.365474229646469e-06 * Y + 0.0029215482928747843
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.144442625912097
# The direction of the gradient is: 32.108012224562515
# 130
# The equation of the fit plane is: Z = -5.4784599591832914e-06 * X + -3.0656977054834976e-06 * Y + 0.0016780380056707663
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0561800291822676
# The direction of the gradient is: 308.66413800007933
# 131
# The equation of the fit plane is: Z = -1.0913729615854132e-05 * X + -8.804959561787559e-06 * Y + 0.003750647025260321
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.14409050083882358
# The direction of the gradient is: 299.029207916382
# 132
# The equation of the fit plane is: Z = -2.7264160021953094e-06 * X + -1.143933971184139e-05 * Y + 0.0027159289620149025
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16461304774496469
# The direction of the gradient is: 276.09117994467545
# 133
# The equation of the fit plane is: Z = -4.209122458538582e-06 * X + -6.893332964231546e-06 * Y + 0.0023436062461568807
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.10225542949540856
# The direction of the gradient is: 285.29071657350124
# 134
# The equation of the fit plane is: Z = -6.6582454024086724e-06 * X + -1.4128594679057043e-05 * Y + 0.0040015346170580585
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2066152060846883
# The direction of the gradient is: 281.91481646738185
# 135
# The equation of the fit plane is: Z = 1.1358843326554766e-06 * X + -1.9493582931323423e-06 * Y + 0.00040228214059220276
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.028826738697433327
# The direction of the gradient is: 255.37760737075416
# 136
# The equation of the fit plane is: Z = 4.320784609020785e-06 * X + -9.480109813098951e-06 * Y + 0.0009902465421279213
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.138445078548475
# The direction of the gradient is: 258.46606607586193
# 137
# The equation of the fit plane is: Z = 2.010624430746827e-08 * X + 3.610322446588067e-06 * Y + -0.00041233765285223606
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.051659689570298706
# The direction of the gradient is: 90.14286794491778
# 138
# The equation of the fit plane is: Z = 4.213306042722785e-06 * X + -8.165245680520796e-06 * Y + 0.0008936823031139953
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11991288849553418
# The direction of the gradient is: 256.9908086347
# 139
# The equation of the fit plane is: Z = 1.939038486432152e-06 * X + 1.1915870476373427e-05 * Y + -0.002313218061871389
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17095425574730452
# The direction of the gradient is: 94.16720300133358
# 140
# The equation of the fit plane is: Z = -9.026437371969704e-06 * X + 2.0964402832791658e-05 * Y + -0.0018262518830843533
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3054996313699136
# The direction of the gradient is: 79.08837902118802
# 141
# The equation of the fit plane is: Z = -1.5125283947634848e-06 * X + 3.3732747674314545e-06 * Y + -0.00016613815699379326
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.049230758706656684
# The direction of the gradient is: 78.64813407057409
# 142
# The equation of the fit plane is: Z = -4.349684294596817e-06 * X + -1.6701394476901436e-05 * Y + 0.0038875023718203806
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.24059688354781347
# The direction of the gradient is: 276.65118101644316
# 143
# The equation of the fit plane is: Z = -8.695067354475875e-07 * X + -7.546092552168891e-06 * Y + 0.0017688601601226017
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.10811944040076954
# The direction of the gradient is: 272.9533619909646
# 144
# The equation of the fit plane is: Z = 4.94452300549225e-06 * X + 4.05324882184148e-06 * Y + -0.001567452457573662
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0660846264795403
# The direction of the gradient is: 118.6432306602436
# 145
# The equation of the fit plane is: Z = -2.528013455776579e-06 * X + -8.047169198001058e-06 * Y + 0.001853860341943942
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11627914285499652
# The direction of the gradient is: 278.00658134415323
# 146
# The equation of the fit plane is: Z = -1.1891134575838536e-05 * X + -1.6175499605097405e-05 * Y + 0.005071923925886167
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.24366804942108525
# The direction of the gradient is: 288.21895362448123
# 147
# The equation of the fit plane is: Z = 5.167034341692405e-07 * X + -1.3593348043905703e-05 * Y + 0.0023356327790776455
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19453322048159483
# The direction of the gradient is: 269.02495711349684
# 148
# The equation of the fit plane is: Z = -4.937554642720529e-06 * X + 1.243826942252233e-05 * Y + -0.0010925494934447483
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.18076657626755677
# The direction of the gradient is: 79.92161658046433
# 149
# The equation of the fit plane is: Z = -1.561065194752254e-05 * X + -3.6569724826387046e-06 * Y + 0.003593823230383204
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11287420937161477
# The direction of the gradient is: 332.3811746927019
# 150
# The equation of the fit plane is: Z = 1.6334225569561832e-05 * X + -3.6643158383831323e-06 * Y + -0.002320805584988942
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11704844609163281
# The direction of the gradient is: 206.6123765237743
# 151
# The equation of the fit plane is: Z = 3.3829004637244198e-06 * X + -1.655109169684452e-05 * Y + 0.002429794432081101
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23781657261555222
# The direction of the gradient is: 264.7711607499714
# 152
# The equation of the fit plane is: Z = 1.5287789575754985e-05 * X + -9.616817997864327e-06 * Y + -0.0010285619177059068
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16890316620443568
# The direction of the gradient is: 234.55777243325872
# 153
# The equation of the fit plane is: Z = 6.321760879075135e-06 * X + -8.72270971660742e-06 * Y + 0.00038752882701524583
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.13121878395531708
# The direction of the gradient is: 252.0217514852044
# 154
# The equation of the fit plane is: Z = -7.795782934945623e-06 * X + -1.957613816964628e-05 * Y + 0.0049249517344911046
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.28452970169088365
# The direction of the gradient is: 280.10981583320233
# 155
# The equation of the fit plane is: Z = 2.661760001734552e-06 * X + 1.4743958569504203e-05 * Y + -0.003059902996082178
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21165704757091597
# The direction of the gradient is: 94.62128049929288
# 156
# The equation of the fit plane is: Z = 1.2255094973501879e-05 * X + 3.55045339008647e-08 * Y + -0.0021302780443112398
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.07851602860088548
# The direction of the gradient is: 179.6292718155214
# 157
# The equation of the fit plane is: Z = 3.1752700320585653e-07 * X + -3.921957450581315e-06 * Y + 0.000667720886558728
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.05615552386788348
# The direction of the gradient is: 267.92394717000957
# 158
# The equation of the fit plane is: Z = -3.2880697336292706e-06 * X + -8.371239323806102e-06 * Y + 0.0019775279989597528
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.12162097465540864
# The direction of the gradient is: 279.9743253825629
# 159
# The equation of the fit plane is: Z = -7.528092456514213e-06 * X + -6.295847396702965e-06 * Y + 0.002586180370456759
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.10218450403100507
# The direction of the gradient is: 298.1635252766167
# 160
# The equation of the fit plane is: Z = 5.436233900769499e-06 * X + -8.046310015403964e-06 * Y + 0.0005034928515140978
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.12028588522754682
# The direction of the gradient is: 253.1692842670609
# 161
# The equation of the fit plane is: Z = 8.336923663198965e-06 * X + -8.678296607083142e-06 * Y + 7.911785949822497e-05
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1351762001266349
# The direction of the gradient is: 246.72602356266225
# 162
# The equation of the fit plane is: Z = 3.987995734033364e-06 * X + -6.145294969221802e-06 * Y + 0.00038760796024523065
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.09156875223463827
# The direction of the gradient is: 253.79809945860768
# 163
# The equation of the fit plane is: Z = -4.182047898672644e-06 * X + -3.276335618301202e-05 * Y + 0.00658069884874193
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.469570654471475
# The direction of the gradient is: 273.27098968442453
# 164
# The equation of the fit plane is: Z = -2.129789749825359e-06 * X + -1.2642907611238683e-07 * Y + 0.0004806101637234085
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.013764267179628765
# The direction of the gradient is: 352.4476989529399
# 165
# The equation of the fit plane is: Z = 1.4609372752083122e-06 * X + -6.934602523542889e-06 * Y + 0.0010751605335347478
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0996665861705451
# The direction of the gradient is: 264.61137947687314
# 166
# The equation of the fit plane is: Z = -1.2538797038262953e-05 * X + -5.258523892910625e-06 * Y + 0.0032943846056567297
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11006721585038273
# The direction of the gradient is: 316.8733741674265
# 167
# The equation of the fit plane is: Z = 5.301075856258482e-06 * X + -6.056821130779938e-06 * Y + 0.00012124859456188652
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.09308300615645111
# The direction of the gradient is: 248.60103719498977
# 168
# The equation of the fit plane is: Z = -5.357330832242502e-08 * X + 2.5850139604928183e-07 * Y + 0.00010724892854414903
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.003714745638440213
# The direction of the gradient is: 84.6985528130109
# 169
# The equation of the fit plane is: Z = -7.062061119440344e-06 * X + 7.685815301101227e-06 * Y + 0.00013876343912075267
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11891834304465147
# The direction of the gradient is: 67.63748603952718
# 170
# The equation of the fit plane is: Z = -4.911273921351614e-06 * X + 1.2813675472800029e-06 * Y + 0.0008701654852364079
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.036417159707180013
# The direction of the gradient is: 30.229725019376247
# 171
# The equation of the fit plane is: Z = -3.194098239547521e-05 * X + 1.6979710947707645e-05 * Y + 0.0030506819050171202
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.31765580394530163
# The direction of the gradient is: 49.89391194035227
# 172
# The equation of the fit plane is: Z = -1.4791574667131743e-05 * X + -7.5011906919437316e-06 * Y + 0.004296536902957069
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.143181039994007
# The direction of the gradient is: 311.4413359484839
# 173
# The equation of the fit plane is: Z = -9.980434596179283e-06 * X + 1.512421311099683e-06 * Y + 0.001660049614889917
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.06750431667355411
# The direction of the gradient is: 18.69841830128854
# 174
# The equation of the fit plane is: Z = -7.90188689191223e-06 * X + 5.165670945953784e-06 * Y + 0.0007154597431482311
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.08958941364359359
# The direction of the gradient is: 55.59244861608943
# 175
# The equation of the fit plane is: Z = -1.9283409877362555e-05 * X + 7.2646118506783974e-06 * Y + 0.0025746777544878737
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16145579006633137
# The direction of the gradient is: 40.07712496033014
# 176
# The equation of the fit plane is: Z = -3.7620687986069965e-05 * X + 6.313051039737604e-06 * Y + 0.006169019917036143
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.25739512428896644
# The direction of the gradient is: 20.545342780131136
# 177
# The equation of the fit plane is: Z = -2.629479958191854e-05 * X + 1.3591825426015039e-05 * Y + 0.0027146869065689735
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2572999160044169
# The direction of the gradient is: 49.10075894810757
# 178
# The equation of the fit plane is: Z = -3.5447461235179236e-05 * X + -8.70982152508422e-06 * Y + 0.008457115592225412
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.25904930553242744
# The direction of the gradient is: 331.2430261853531
# 179
# The equation of the fit plane is: Z = -2.0589900882698358e-05 * X + -3.1935124280784914e-05 * Y + 0.00963491222129867
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4756138034123484
# The direction of the gradient is: 286.1022673784938
# 180
# The equation of the fit plane is: Z = -3.1824219462938544e-05 * X + -4.25896212329175e-06 * Y + 0.006949643479845712
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21279999988875395
# The direction of the gradient is: 343.35888426493216
# 181
# The equation of the fit plane is: Z = -1.8839872235791776e-05 * X + -1.853434941861008e-05 * Y + 0.006962812450919068
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2913802119486441
# The direction of the gradient is: 294.47136975066894
# 182
# The equation of the fit plane is: Z = -1.8389084303761203e-05 * X + -6.646289807667258e-06 * Y + 0.004772450605410623
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.15140677276327225
# The direction of the gradient is: 321.08889189872906
# 183
# The equation of the fit plane is: Z = -2.4397446285738373e-05 * X + 9.620414875896374e-06 * Y + 0.0030606383934313054
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20828143045191716
# The direction of the gradient is: 41.36993625835515
# 184
# The equation of the fit plane is: Z = -2.8323548567044935e-05 * X + -2.521209689181053e-05 * Y + 0.010041178198137069
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.40382227713944446
# The direction of the gradient is: 296.7023330989375
# 185
# The equation of the fit plane is: Z = -3.5045824405934436e-05 * X + 1.456799664296358e-05 * Y + 0.0041550740727551595
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.30637283390797365
# The direction of the gradient is: 42.87364976602794
# 186
# The equation of the fit plane is: Z = -2.9872890894053314e-05 * X + 1.689887894706569e-06 * Y + 0.005619877873917627
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19290730622173496
# The direction of the gradient is: 7.200790438942818
# 187
# The equation of the fit plane is: Z = -1.316829961361381e-05 * X + -1.2192885350119802e-05 * Y + 0.0048407170028274705
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19379333210557062
# The direction of the gradient is: 295.8066019229528
# 188
# The equation of the fit plane is: Z = -1.5911295544071008e-05 * X + -2.124674584299917e-05 * Y + 0.006946699866524057
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3206514670161756
# The direction of the gradient is: 288.5366073660949
# 189
# The equation of the fit plane is: Z = -1.3897530205664649e-05 * X + -6.556258652627411e-06 * Y + 0.003944481233278572
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.12933813360824026
# The direction of the gradient is: 313.50392957548576
# 190
# The equation of the fit plane is: Z = -1.533868461568095e-05 * X + -7.077922198614951e-06 * Y + 0.004435046069485263
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.14111691208281793
# ...
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.04188457339043397
# The direction of the gradient is: 23.1533116942951
# 220
# The equation of the fit plane is: Z = -1.7340647907940688e-05 * X + 1.1426245294309513e-05 * Y + 0.0012219334852720297
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19766977013114637
# The direction of the gradient is: 55.803866448489146
# 221
# The equation of the fit plane is: Z = -1.7372635981743034e-05 * X + 1.1422513598740968e-05 * Y + 0.0013742229719775983
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19774088608354756
# The direction of the gradient is: 55.74605589766355
# 222
# The equation of the fit plane is: Z = -2.7555352125660457e-05 * X + 1.339189907227055e-05 * Y + 0.0030715367312813945
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.26054733315713574
# The direction of the gradient is: 47.34623274748208
# 223
# The equation of the fit plane is: Z = -2.106575557384227e-05 * X + 5.038619744330623e-06 * Y + 0.0032251015547806825
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.15301153769913295
# The direction of the gradient is: 28.111273065869227
# 224
# The equation of the fit plane is: Z = -1.8674451421618386e-05 * X + 6.772047087203239e-06 * Y + 0.002471042833103826
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.15395983597788832
# The direction of the gradient is: 39.004826729034676
# 225
# The equation of the fit plane is: Z = -4.3656463220929445e-05 * X + 6.465634416507031e-06 * Y + 0.007168492014395556
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.29459659938367583
# The direction of the gradient is: 18.30299563635822
# 226
# The equation of the fit plane is: Z = -5.306043391796415e-05 * X + -4.738882981642319e-06 * Y + 0.01093738803175232
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3466376958727352
# The direction of the gradient is: 348.7192820105688
# 227
# The equation of the fit plane is: Z = -4.298835671484299e-05 * X + -1.2819239582284372e-05 * Y + 0.009748685193465691
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.33090475435908984
# The direction of the gradient is: 326.33583156648837
# 228
# The equation of the fit plane is: Z = -3.7707881673907903e-05 * X + 3.609865044137667e-06 * Y + 0.0066103713650941575
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2470423536000842
# The direction of the gradient is: 12.068767984252418
# 229
# The equation of the fit plane is: Z = -4.955174705766476e-05 * X + 2.2063715853742296e-05 * Y + 0.0058085489812806255
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.44771913038990185
# The direction of the gradient is: 44.84113151246402
# 230
# The equation of the fit plane is: Z = -5.5478773438436635e-05 * X + 2.3367968044986475e-05 * Y + 0.0066756705564735815
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.48799169766012257
# The direction of the gradient is: 43.25079356566687
# 231
# The equation of the fit plane is: Z = -3.5449266408994446e-05 * X + -3.675919971726235e-05 * Y + 0.013376653000993827
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5729191652518355
# The direction of the gradient is: 293.35404671578374
# 232
# The equation of the fit plane is: Z = -3.456986812140893e-05 * X + 2.7354475308992397e-05 * Y + 0.0019683099626124257
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4497275523769053
# The direction of the gradient is: 60.496868148812155
# 233
# The equation of the fit plane is: Z = -3.3249429271100294e-05 * X + -1.98124674738229e-05 * Y + 0.009969615645178195
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3546058274460139
# The direction of the gradient is: 306.92136106138787
# 234
# The equation of the fit plane is: Z = -4.3045817510700186e-05 * X + 2.88678997243254e-05 * Y + 0.0031779936175082304
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4966674325009406
# The direction of the gradient is: 56.27124835020368
# 235
# The equation of the fit plane is: Z = -2.4467760971429927e-05 * X + -3.7732318048099167e-06 * Y + 0.005315467813971924
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16579421181735546
# The direction of the gradient is: 340.9951543694068
# 236
# The equation of the fit plane is: Z = -1.9684557185828936e-05 * X + 2.8095956230817904e-05 * Y + -0.0010671348414542678
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4213370398027465
# The direction of the gradient is: 72.58353159379618
# 237
# The equation of the fit plane is: Z = -3.3304697164224704e-05 * X + 1.8558571777030095e-05 * Y + 0.003070309327723314
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3406543949530935
# The direction of the gradient is: 51.217919297065976
# 238
# The equation of the fit plane is: Z = -1.5789589222366717e-05 * X + -1.8040294675223394e-05 * Y + 0.006142270047131122
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2772492216656555
# The direction of the gradient is: 291.3993183856377
# 239
# The equation of the fit plane is: Z = -2.4993213219433343e-05 * X + -1.089031802149037e-06 * Y + 0.004886007389817089
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16087979305615502
# The direction of the gradient is: 354.44162846028604
# 240
# The equation of the fit plane is: Z = -2.8299209127391725e-05 * X + 2.4179228879343206e-05 * Y + 0.000978234701811929
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3906033295078711
# The direction of the gradient is: 62.34390666099995
# 241
# The equation of the fit plane is: Z = -3.482699228415211e-05 * X + 3.2353629101235474e-05 * Y + 0.0007906244120003934
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5139075647663295
# The direction of the gradient is: 64.26727331565968
# 242
# The equation of the fit plane is: Z = -6.353954067645367e-06 * X + -1.2504413123228292e-05 * Y + 0.0034461305068080937
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.18349602722506445
# The direction of the gradient is: 282.8174312353114
# 243
# The equation of the fit plane is: Z = -6.2887067545816314e-06 * X + 5.781851090655285e-06 * Y + 0.00019742365054454535
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.09202051025477727
# The direction of the gradient is: 64.03425117130632
# 244
# The equation of the fit plane is: Z = -9.370849118250318e-06 * X + -2.3146004722139201e-07 * Y + 0.0018938184020136503
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.060127248121021916
# The direction of the gradient is: 356.8424397445699
# 245
# The equation of the fit plane is: Z = 1.1353658371738963e-06 * X + -7.959114129873689e-07 * Y + -0.00019155211079639414
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.013513304393188352
# The direction of the gradient is: 237.43349282794998
# 246
# The equation of the fit plane is: Z = -1.2114377649650956e-05 * X + -5.229173824418725e-06 * Y + 0.003247158103130306
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.10780676601133143
# The direction of the gradient is: 316.0483415792146
# 247
# The equation of the fit plane is: Z = -1.559978272035765e-05 * X + -4.126497721947491e-06 * Y + 0.0035651975057839663
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11608145192719216
# The direction of the gradient is: 329.42572553084403
# 248
# The equation of the fit plane is: Z = -4.528281523221682e-05 * X + 7.83953205915793e-07 * Y + 0.008377049778829691
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.29032897165049104
# The direction of the gradient is: 2.214292356205931
# 249
# The equation of the fit plane is: Z = -4.027434388481357e-05 * X + 1.508448706641268e-05 * Y + 0.004827032256592627
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3363989158673127
# The direction of the gradient is: 39.91300293611289
# 250
# The equation of the fit plane is: Z = -3.1012856505570285e-05 * X + -2.196364542224185e-06 * Y + 0.00613941785853573
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2011593711532255
# The direction of the gradient is: 351.01177375277973
# 251
# The equation of the fit plane is: Z = -2.7843520652540718e-05 * X + 5.82592327084085e-06 * Y + 0.004026919863466484
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19690156631163383
# The direction of the gradient is: 25.047530763963323
# 252
# The equation of the fit plane is: Z = -3.167493769712458e-05 * X + 2.1528565998820835e-07 * Y + 0.0059109396005851056
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20295434489670178
# The direction of the gradient is: 0.8696820554452529
# 253
# The equation of the fit plane is: Z = -3.040731384531434e-05 * X + -1.8340642540667863e-05 * Y + 0.008882483110355603
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.32683647163160573
# The direction of the gradient is: 306.587266129907
# 254
# The equation of the fit plane is: Z = -4.784026714055352e-05 * X + 1.045702498205721e-05 * Y + 0.007287968258106517
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.34107020757513
# The direction of the gradient is: 26.021041153772046
# 255
# The equation of the fit plane is: Z = -5.007939269060276e-05 * X + -6.92259912105767e-06 * Y + 0.010541198610484687
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.33578496407221253
# The direction of the gradient is: 342.8428547803054
# 256
# The equation of the fit plane is: Z = -4.653763063864421e-05 * X + -2.146922147284622e-05 * Y + 0.012463834146635364
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.42809564585683363
# The direction of the gradient is: 314.143653205089
# 257
# The equation of the fit plane is: Z = -5.427739589008902e-05 * X + -2.4602241861313616e-05 * Y + 0.013951917559389083
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4948193570348171
# The direction of the gradient is: 314.6485793006266
# 258
# The equation of the fit plane is: Z = -6.090999877718359e-05 * X + -4.333481193487992e-06 * Y + 0.012510995092517867
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.395126151063791
# The direction of the gradient is: 350.97126089565654
# 259
# The equation of the fit plane is: Z = -6.703331477218346e-05 * X + 5.3385825649577656e-05 * Y + 0.003363433324026627
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8763350779695398
# The direction of the gradient is: 60.655193175040836
# 260
# The equation of the fit plane is: Z = -7.213174535640258e-05 * X + 2.5298899079433344e-05 * Y + 0.009343740903626009
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5870277212660289
# The direction of the gradient is: 38.07281214178272
# 261
# The equation of the fit plane is: Z = -4.9684335202873224e-05 * X + 3.3406502969990145e-05 * Y + 0.0037607943923087315
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5742943832349446
# The direction of the gradient is: 56.339894295188344
# 262
# The equation of the fit plane is: Z = -5.577925660622001e-05 * X + 3.4764656343914386e-05 * Y + 0.004522709194493129
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6124983702363286
# The direction of the gradient is: 54.30674855954646
# 263
# The equation of the fit plane is: Z = -4.4718467323030236e-05 * X + -5.459319196689433e-06 * Y + 0.009430376258306047
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2969553671625336
# The direction of the gradient is: 344.74840047223756
# 264
# The equation of the fit plane is: Z = -3.19459157949017e-05 * X + -8.473761612578981e-06 * Y + 0.007832897853318154
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23788670760240316
# The direction of the gradient is: 329.3564727929045
# 265
# The equation of the fit plane is: Z = -4.525338137355344e-05 * X + 2.1782179343875335e-05 * Y + 0.004961761311742929
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4256744202285004
# The direction of the gradient is: 47.07093384669491
# 266
# The equation of the fit plane is: Z = -3.06085473551679e-05 * X + -2.072531401861999e-05 * Y + 0.009454464314168803
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.35552748974544723
# The direction of the gradient is: 303.4749146399222
# 267
# The equation of the fit plane is: Z = -1.9948573304830034e-05 * X + -8.04116511667499e-06 * Y + 0.004845577058535947
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17196687101114205
# The direction of the gradient is: 318.00383115436387
# 268
# The equation of the fit plane is: Z = -2.6283307029059026e-05 * X + 8.428724975220926e-06 * Y + 0.0032234372041487934
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20712396909985245
# The direction of the gradient is: 35.61145345767693
# 269
# The equation of the fit plane is: Z = -1.9895105738765832e-05 * X + -4.729987096443781e-07 * Y + 0.003869094157474652
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.12764099694792463
# The direction of the gradient is: 356.96051104660506
# 270
# The equation of the fit plane is: Z = -3.066657627872197e-05 * X + 3.8003298741903416e-05 * Y + -0.0009416624937943684
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5781875641930403
# The direction of the gradient is: 70.1350377197952
# 271
# The equation of the fit plane is: Z = -2.3505443353269976e-05 * X + 1.5569140139376316e-05 * Y + 0.001594453756024718
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.26889990152426135
# The direction of the gradient is: 55.942211018668786
# 272
# The equation of the fit plane is: Z = -2.7601596420531854e-05 * X + 5.654696054779898e-06 * Y + 0.004074082020554078
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1944663990105287
# The direction of the gradient is: 24.586883053078168
# 273
# The equation of the fit plane is: Z = -2.0484794059309976e-05 * X + -7.635284115707742e-06 * Y + 0.005156828344427272
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1707623706160216
# The direction of the gradient is: 320.22383463637607
# 274
# The equation of the fit plane is: Z = -1.5608080732603715e-05 * X + 2.490001720125909e-05 * Y + -0.0011668003965856503
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.370056764846827
# The direction of the gradient is: 74.32278150987497
# 275
# The equation of the fit plane is: Z = -2.960602839181885e-05 * X + 3.4166501986185973e-06 * Y + 0.0050293811030524375
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1958752265518153
# The direction of the gradient is: 14.453193176118475
# 276
# The equation of the fit plane is: Z = -3.581418199503704e-05 * X + 4.394623542291331e-07 * Y + 0.006464015848991528
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2295358992679774
# The direction of the gradient is: 1.5698294790316254
# 277
# The equation of the fit plane is: Z = -2.427833720231432e-05 * X + -2.0191418977460372e-05 * Y + 0.008249873261712545
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3281250939796603
# The direction of the gradient is: 298.29665384660507
# 278
# The equation of the fit plane is: Z = -2.5618501539677516e-05 * X + 7.494339864410241e-06 * Y + 0.0036128540213730266
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19605575663634056
# The direction of the gradient is: 33.15893526706759
# 279
# The equation of the fit plane is: Z = -4.273854183057626e-05 * X + 1.7665745768590248e-05 * Y + 0.005090651340383954
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.37265106111503293
# The direction of the gradient is: 42.71243304877157
# 280
# The equation of the fit plane is: Z = -1.701512472004903e-05 * X + -1.78144853184862e-05 * Y + 0.0064383068788943475
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.27723568702631435
# The direction of the gradient is: 293.1540445438291
# 281
# The equation of the fit plane is: Z = -3.037406732595074e-05 * X + -1.4736523537796853e-05 * Y + 0.008268854850085872
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2869336231558428
# The direction of the gradient is: 312.70269086040184
# 282
# The equation of the fit plane is: Z = -3.5162531552909524e-05 * X + 1.9232342483075304e-05 * Y + 0.0032235884486509696
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3556398166605912
# The direction of the gradient is: 50.69596493543645
# 283

# %%
with h5py.File(path_GIM, 'r') as file:
    date_GIM = file['date']
    date_GIM = date_GIM[()]
date_GIM = np.char.decode(date_GIM)

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

slope_ion_GIM_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_GIM_correct[i] = slope_ion_GIM[j[0]]
slope_ion_GIM = slope_ion_GIM_correct

angle_deg_ion_GIM_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_GIM == date_split[i])[0]
    if len(j) > 0:
        angle_deg_ion_GIM_correct[i] = angle_deg_ion_GIM[j[0]]
angle_deg_ion_GIM = angle_deg_ion_GIM_correct

slope_ion_GIM_dongxifangxiang_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_GIM_dongxifangxiang_correct[i] = slope_ion_GIM_dongxifangxiang[j[0]]
slope_ion_GIM_dongxifangxiang = slope_ion_GIM_dongxifangxiang_correct

slope_ion_GIM_nanbeifangxiang_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_GIM_nanbeifangxiang_correct[i] = slope_ion_GIM_nanbeifangxiang[j[0]]
slope_ion_GIM_nanbeifangxiang = slope_ion_GIM_nanbeifangxiang_correct

# %%
######### hight_GIM

# %%
path_hight_GIM = '../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5'

# %%
# !reference_point.py ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 -y 180 -x 190
# !reference_date.py ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 --ref-date 20190112
# Out:
# WARNING: auto turn ON --write-data for file tpye timeseries
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# --------------------------------------------------
# input reference point in y/x: (180, 190)
# --------------------------------------------------
# calculating the temporal average of timeseries file: ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5
# reading timeseries data from file: ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 ...
# /home/eedy/tools/MintPy/src/mintpy/objects/stack.py:455: RuntimeWarning: Mean of empty slice
#   dmean = np.nanmean(data, axis=0)
# updating dataset values without re-writing to a new file
# update metadata
# input reference date: 20190112
# --------------------------------------------------
# change reference date for file: /panda/eedy/ion_los-angle/s1_d173/mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5
# reading data ...
# referencing in time ...
# --------------------------------------------------
# open  HDF5 file /panda/eedy/ion_los-angle/s1_d173/mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 in r+ mode
# writing dataset /timeseries                block: (0, 284, 0, 784, 0, 301)
# close HDF5 file /panda/eedy/ion_los-angle/s1_d173/mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5.
# update "REF_DATE" attribute value to 20190112
# time used: 00 mins 3.5 secs.

# %%
timeseries_hight_GIM = readfile.read(path_hight_GIM, datasetName='timeseries')[0]
timeseries_hight_GIM = np.squeeze(timeseries_hight_GIM)

mask_path_hight_gim = '../mintpy_hight_gim_ion_upsample/geo/geo_maskTempCoh.h5'
mask_hight_gim = readfile.read(mask_path_hight_gim, datasetName='mask')[0]
mask_hight_gim = np.squeeze(mask_hight_gim)

from mintpy.objects import ramp
data_out, ramp = ramp.deramp(timeseries_hight_GIM, mask_in=mask_hight_gim, ramp_type='linear', metadata=None, max_num_sample=1e3, coeff_file=None,ignore_zero_value=True)

# %%
def function(data, a, b, c):
    '''
    拟合曲面使用的函数
    '''
    x = data[0]
    y = data[1]
    return a*x+b*y + c



slope_ion_hight_GIM = np.zeros(timeseries_hight_GIM.shape[0])
slope_ion_hight_GIM_dongxifangxiang = np.zeros(timeseries_hight_GIM.shape[0])
slope_ion_hight_GIM_nanbeifangxiang = np.zeros(timeseries_hight_GIM.shape[0])
angle_deg_ion_hight_GIM = np.zeros(timeseries_hight_GIM.shape[0])
meta = readfile.read_attribute(path_hight_GIM)
AZIMUTH_PIXEL_SIZE =  float(meta['AZIMUTH_PIXEL_SIZE'])
RANGE_PIXEL_SIZE = float(meta['RANGE_PIXEL_SIZE'])

for i in range(timeseries_hight_GIM.shape[0]):
    x_data = ramp.shape[2]
    y_data = ramp.shape[1]
    X_data, Y_data = np.meshgrid(range(x_data), range(y_data))
    Z_data = ramp[i, :,:]
    
    x_data = X_data.flatten()
    y_data = Y_data.flatten()
    z_data = Z_data.flatten()
    
    parameters, covariance = curve_fit(function, [x_data, y_data], z_data)
    print("The equation of the fit plane is: Z = {0} * X + {1} * Y + {2}".format(parameters[0],parameters[1],parameters[2]))
    
    Z_fit = function([X_data, Y_data], *parameters)
    
    # 计算梯度，考虑到横纵坐标的实际长度
    dx = parameters[1]/RANGE_PIXEL_SIZE
    dy = parameters[0]/AZIMUTH_PIXEL_SIZE
    # 计算梯度的大小和方向
    magnitude = np.hypot(dx, dy)  # 梯度的大小
    direction = np.degrees(np.arctan2(dy, dx)) + 90  # 梯度的方向，以x轴正半轴为0°，逆时针旋转为正方向
    direction = (direction + 360) % 360  # 将角度值限制在0°到360°之间

    print('The magnitude of the gradient is( cm(ion)/ 100km(juli)):', magnitude*1e7)
    print('The direction of the gradient is:', direction)

    slope_ion_hight_GIM[i] = magnitude*1e7
    angle_deg_ion_hight_GIM[i] = direction
    slope_ion_hight_GIM_dongxifangxiang[i] = dy*1e7
    slope_ion_hight_GIM_nanbeifangxiang[i] = dx*1e7
    

    print(i)
# Out:
# The equation of the fit plane is: Z = -5.899284695093925e-05 * X + -1.4002705115834255e-05 * Y + 0.013776312219537117
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4277729752941449
# The direction of the gradient is: 332.0704806886467
# 0
# The equation of the fit plane is: Z = -3.823983436661124e-05 * X + -8.691046708071152e-06 * Y + 0.009094339616962804
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.27474582158493455
# The direction of the gradient is: 333.0873115394709
# 1
# The equation of the fit plane is: Z = -2.3371722843588947e-05 * X + -1.8599486711882758e-05 * Y + 0.007584540824022255
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.30536784029360736
# The direction of the gradient is: 299.3631286251209
# 2
# The equation of the fit plane is: Z = -3.281882961700572e-05 * X + 3.368173730291872e-05 * Y + 0.0007352775479577897
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5258151769970363
# The direction of the gradient is: 66.42973516642962
# 3
# The equation of the fit plane is: Z = -7.626348440768725e-06 * X + -1.9810269742488096e-06 * Y + 0.0015742879275534001
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.05648681013689386
# The direction of the gradient is: 329.8795300902331
# 4
# The equation of the fit plane is: Z = -4.512983394001952e-06 * X + -9.559280302264016e-06 * Y + 0.002907234125511847
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.13980468240381488
# The direction of the gradient is: 281.9355599427762
# 5
# The equation of the fit plane is: Z = 8.030500304679867e-06 * X + 2.8201712946039905e-05 * Y + -0.0061656872953673066
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4068003459277155
# The direction of the gradient is: 97.26576070322324
# 6
# The equation of the fit plane is: Z = -9.173382135323139e-06 * X + -1.1545154372620837e-05 * Y + 0.003845534909916649
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17534057961055136
# The direction of the gradient is: 289.58355455615566
# 7
# The equation of the fit plane is: Z = -2.1841992963787244e-05 * X + -1.1344548841570431e-05 * Y + 0.006485262019853539
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21431712912044418
# The direction of the gradient is: 310.76302612401787
# 8
# The equation of the fit plane is: Z = -2.2207581649656986e-05 * X + -2.6419387958422402e-05 * Y + 0.009065420602550356
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4039182590148142
# The direction of the gradient is: 290.6244673622782
# 9
# The equation of the fit plane is: Z = -1.4744224290819354e-05 * X + -2.667024323859548e-05 * Y + 0.007884515139952879
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.39313736250739373
# The direction of the gradient is: 283.9028230866423
# 10
# The equation of the fit plane is: Z = 4.7398277364779117e-07 * X + -1.237875219161223e-05 * Y + 0.0023633692919916567
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17715162225340744
# The direction of the gradient is: 269.0178136835192
# 11
# The equation of the fit plane is: Z = -3.4272026704512527e-06 * X + -9.486973415802723e-06 * Y + 0.002383227528356558
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.13751187977109322
# The direction of the gradient is: 279.18793005297425
# 12
# The equation of the fit plane is: Z = -1.7257972909996216e-05 * X + -1.5935008489242345e-05 * Y + 0.0063943987633885094
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2534050620694458
# The direction of the gradient is: 295.86944066375133
# 13
# The equation of the fit plane is: Z = -5.191988032692354e-06 * X + -1.4244435048983254e-05 * Y + 0.003938627220330403
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20651778513527685
# The direction of the gradient is: 279.268881637674
# 14
# The equation of the fit plane is: Z = -4.631071796301547e-06 * X + -7.209446805983683e-06 * Y + 0.002156116983534925
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.10734075755958063
# The direction of the gradient is: 286.0458938758361
# 15
# The equation of the fit plane is: Z = 1.6767459623977138e-06 * X + -5.013617203844537e-06 * Y + 0.001039322377879337
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.07253888394003327
# The direction of the gradient is: 261.48368096139495
# 16
# The equation of the fit plane is: Z = 4.4880813900805375e-06 * X + -1.5033974814203747e-05 * Y + 0.0020868934171322097
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21703191189857843
# The direction of the gradient is: 262.38673297107437
# 17
# The equation of the fit plane is: Z = 3.910144977091046e-06 * X + 1.6019386248214273e-05 * Y + -0.003432502825972052
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2305836797154689
# The direction of the gradient is: 96.23702568905833
# 18
# The equation of the fit plane is: Z = -3.7132558617862727e-06 * X + 1.498068320182681e-06 * Y + 0.0004052646439504904
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.03202236197903939
# The direction of the gradient is: 42.02041676919089
# 19
# The equation of the fit plane is: Z = -4.053379392752543e-06 * X + -4.398929482832835e-06 * Y + 0.0016337387773953374
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.06809013570044259
# The direction of the gradient is: 292.41960799110404
# 20
# The equation of the fit plane is: Z = 8.228304665191063e-06 * X + -4.99168466508486e-07 * Y + -0.0017026493797486612
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.05319772784025392
# The direction of the gradient is: 187.71604357510614
# 21
# The equation of the fit plane is: Z = -1.576773139460039e-06 * X + -1.2063100988554815e-05 * Y + 0.002525433298516098
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17290434226831644
# The direction of the gradient is: 273.34939123823534
# 22
# The equation of the fit plane is: Z = -2.9193973335544304e-06 * X + -1.3387716412052629e-05 * Y + 0.002873921313039155
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1924736200994092
# The direction of the gradient is: 275.5765173975442
# 23
# The equation of the fit plane is: Z = -7.052973398495203e-06 * X + 6.244930604402579e-06 * Y + 0.00011851563069869066
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.10013283549643479
# The direction of the gradient is: 63.17535062004134
# 24
# The equation of the fit plane is: Z = -5.538950591950228e-06 * X + -1.4349086879467775e-05 * Y + 0.003901927535464894
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20836286342989452
# The direction of the gradient is: 279.8058339542048
# 25
# The equation of the fit plane is: Z = 6.043467417818901e-06 * X + -1.9672696386828808e-05 * Y + 0.002678267801457709
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2841438067586671
# The direction of the gradient is: 262.1682934912935
# 26
# The equation of the fit plane is: Z = -9.462607962148193e-06 * X + -3.213259549804574e-05 * Y + 0.00761544985079968
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4637597161313884
# The direction of the gradient is: 277.51134538684585
# 27
# The equation of the fit plane is: Z = 5.851343716248057e-06 * X + -2.42027832041618e-05 * Y + 0.003146063448326363
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.34833683606420446
# The direction of the gradient is: 263.82192329607165
# 28
# The equation of the fit plane is: Z = 2.489743036024019e-06 * X + -1.815780051739944e-05 * Y + 0.0026494699536635836
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2603062551218572
# The direction of the gradient is: 266.4868452987947
# 29
# The equation of the fit plane is: Z = -1.0632734282726928e-05 * X + 2.0260968971695176e-06 * Y + 0.001707230912172918
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.07403296266900188
# The direction of the gradient is: 23.053915867343107
# 30
# The equation of the fit plane is: Z = -4.687340881154395e-06 * X + -1.4164993757511409e-05 * Y + 0.0036296215645680104
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20489724205052534
# The direction of the gradient is: 278.42777279806415
# 31
# The equation of the fit plane is: Z = -1.0161544753458531e-06 * X + -1.727789574071485e-05 * Y + 0.0035278162380392177
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.24731235940155455
# The direction of the gradient is: 271.50840952822045
# 32
# The equation of the fit plane is: Z = -3.7318571228433567e-06 * X + -1.8109387449977434e-06 * Y + 0.0010996759343215895
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.035257401820763735
# The direction of the gradient is: 312.6969927122973
# 33
# The equation of the fit plane is: Z = -3.756662255216487e-06 * X + -2.322662770405502e-05 * Y + 0.005113699983005027
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.33321644027130753
# The direction of the gradient is: 274.1419919929586
# 34
# The equation of the fit plane is: Z = -1.628492222886235e-05 * X + -3.4098853607069934e-05 * Y + 0.00912759532760331
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4989452010122065
# The direction of the gradient is: 282.0699355882592
# 35
# The equation of the fit plane is: Z = -1.818914735791289e-05 * X + -1.700287811056626e-05 * Y + 0.0064941417130189895
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2697599484591468
# The direction of the gradient is: 295.5935207619009
# 36
# The equation of the fit plane is: Z = -1.7007890433997916e-05 * X + -3.032787596738842e-05 * Y + 0.008986100127833517
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4474277709481231
# The direction of the gradient is: 284.0952295692263
# 37
# The equation of the fit plane is: Z = -2.303714903174993e-05 * X + -2.174228382336707e-05 * Y + 0.00850528312255518
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.34434101331923206
# The direction of the gradient is: 295.38001989413016
# 38
# The equation of the fit plane is: Z = -2.490985996149448e-05 * X + -3.740824479572499e-05 * Y + 0.011202392494813397
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.55855281385678
# The direction of the gradient is: 286.6018500460667
# 39
# The equation of the fit plane is: Z = -8.535405617400462e-06 * X + -2.8596837997646307e-05 * Y + 0.006879262713981709
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4128253671013975
# The direction of the gradient is: 277.6118680824486
# 40
# The equation of the fit plane is: Z = -1.268906291074534e-05 * X + -2.3142814224601346e-05 * Y + 0.006854743129930437
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3409795539170785
# The direction of the gradient is: 283.7930173538149
# 41
# The equation of the fit plane is: Z = -9.804207532873966e-06 * X + -2.335745080764082e-05 * Y + 0.006236282736388837
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3400692465057269
# The direction of the gradient is: 280.6439098583015
# 42
# The equation of the fit plane is: Z = -1.966229395289281e-05 * X + -1.639998368398247e-05 * Y + 0.006232748536098514
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.26633805476439143
# The direction of the gradient is: 298.22725323731663
# 43
# The equation of the fit plane is: Z = -5.803571781552868e-06 * X + -1.6030928153863944e-05 * Y + 0.004096277151387417
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23237790116805324
# The direction of the gradient is: 279.20717646184255
# 44
# The equation of the fit plane is: Z = -1.1004990872985672e-05 * X + -1.3867930157175735e-05 * Y + 0.004563673119879398
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21058742179775938
# The direction of the gradient is: 289.56058097161684
# 45
# The equation of the fit plane is: Z = -1.10916791898062e-06 * X + 2.451167219454047e-06 * Y + 0.00027094793770856586
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.03578598884709524
# The direction of the gradient is: 78.54656565898131
# 46
# The equation of the fit plane is: Z = 1.5900332297584439e-06 * X + -1.4281311897094475e-05 * Y + 0.0021183750788970027
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20460276735660304
# The direction of the gradient is: 267.14616097904513
# 47
# The equation of the fit plane is: Z = -7.710196632104429e-06 * X + 1.129730086032944e-05 * Y + -0.0008980080218838338
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1690300883100321
# The direction of the gradient is: 73.00811940076562
# 48
# The equation of the fit plane is: Z = 1.5357688461535324e-06 * X + -5.930590531328849e-06 * Y + 0.0011267758359737189
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.08542837767042107
# The direction of the gradient is: 263.38631132134833
# 49
# The equation of the fit plane is: Z = -8.346450280005588e-06 * X + 4.919824694199095e-06 * Y + 0.0011918369446254256
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.08840302707226833
# The direction of the gradient is: 52.77999302818938
# 50
# The equation of the fit plane is: Z = 2.0962760304151785e-06 * X + -4.598193053470402e-06 * Y + 0.0006003657258811442
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.06715151799079706
# The direction of the gradient is: 258.4631704901044
# 51
# The equation of the fit plane is: Z = -1.2456314838938595e-05 * X + -2.140979356920981e-05 * Y + 0.00567892488897151
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.31657307880608665
# The direction of the gradient is: 284.6009654462169
# 52
# The equation of the fit plane is: Z = 1.5028392887444686e-05 * X + -6.269531512483837e-06 * Y + -0.0015898542780084172
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.13159809410947176
# The direction of the gradient is: 222.97621806451582
# 53
# The equation of the fit plane is: Z = 5.173046517234467e-06 * X + -1.1119902470688003e-05 * Y + 0.000993043364607502
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16252788250979724
# The direction of the gradient is: 258.2339566480615
# 54
# The equation of the fit plane is: Z = 1.6875616720461727e-05 * X + 8.039032800581381e-07 * Y + -0.003626954474356907
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.10872675410295479
# The direction of the gradient is: 173.92693433010254
# 55
# The equation of the fit plane is: Z = 0.0 * X + 0.0 * Y + 6.4e-323
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0
# The direction of the gradient is: 90.0
# 56
# The equation of the fit plane is: Z = 1.5243096816365508e-05 * X + -1.459715293221665e-05 * Y + -3.576745397785274e-05
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2305709790078996
# The direction of the gradient is: 244.94130258400776
# 57
# The equation of the fit plane is: Z = 1.5119583855235384e-05 * X + -1.625879425729652e-05 * Y + 8.210791480436969e-05
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.252005017034738
# The direction of the gradient is: 247.3946117345041
# 58
# The equation of the fit plane is: Z = 1.9884752943507317e-07 * X + -1.0598697340139952e-05 * Y + 0.0020342233716836838
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.15166042317694722
# The direction of the gradient is: 269.5187084598799
# 59
# The equation of the fit plane is: Z = 6.067566099010908e-06 * X + -1.237498393023893e-05 * Y + 0.0012028470024243387
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.18128839213855985
# The direction of the gradient is: 257.6181566319111
# 60
# The equation of the fit plane is: Z = -1.3907551031609953e-06 * X + -9.259601941459642e-07 * Y + 0.0006115670666324937
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.01596675184423984
# The direction of the gradient is: 303.92047487482284
# 61
# The equation of the fit plane is: Z = -2.2249715971156555e-05 * X + -1.2448306530616878e-05 * Y + 0.006687057378017856
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2281371963072013
# The direction of the gradient is: 308.6696107187063
# 62
# The equation of the fit plane is: Z = 4.487473672740793e-06 * X + -5.73369354281804e-06 * Y + 0.00040080821370334224
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.08693401357730879
# The direction of the gradient is: 250.68824458494157
# 63
# The equation of the fit plane is: Z = -2.039913854359369e-05 * X + -1.68751770094042e-05 * Y + 0.006649886093097244
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2745632985873183
# The direction of the gradient is: 298.42411882132205
# 64
# The equation of the fit plane is: Z = -5.728403628978407e-06 * X + 2.8590745643823375e-06 * Y + 0.0013392948584736726
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.054959277687891536
# The direction of the gradient is: 48.105023202123334
# 65
# The equation of the fit plane is: Z = -1.750816675903422e-05 * X + -1.2354065839242325e-05 * Y + 0.005911686000530042
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2093570491476872
# The direction of the gradient is: 302.3967525914273
# 66
# The equation of the fit plane is: Z = -3.1115849682549224e-05 * X + 1.2831139304258598e-05 * Y + 0.0037103311712352958
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2710139213092643
# The direction of the gradient is: 42.64479701600595
# 67
# The equation of the fit plane is: Z = -1.6579448439876214e-05 * X + -1.2344902624392378e-05 * Y + 0.005789286974739397
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2061179943980668
# The direction of the gradient is: 301.01961807692396
# 68
# The equation of the fit plane is: Z = -1.7190463003282022e-05 * X + -1.8803575911718735e-05 * Y + 0.0065084048732422005
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.29072546543560013
# The direction of the gradient is: 292.26083408925535
# 69
# The equation of the fit plane is: Z = -4.769687702847498e-06 * X + 1.5517418142241331e-06 * Y + 0.0009565647813167799
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.037772767230333675
# The direction of the gradient is: 36.002533077061685
# 70
# The equation of the fit plane is: Z = -8.710050424768657e-06 * X + -2.176924665741831e-05 * Y + 0.005450474433135243
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3164515837319749
# The direction of the gradient is: 280.156531718397
# 71
# The equation of the fit plane is: Z = -1.5692812614888206e-05 * X + -2.402013523159018e-05 * Y + 0.0074738300610602635
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.35810322961445457
# The direction of the gradient is: 286.3051781519854
# 72
# The equation of the fit plane is: Z = 1.981402465366518e-06 * X + -2.0661819556521275e-05 * Y + 0.003312535490373838
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2959190860136752
# The direction of the gradient is: 267.54139820429054
# 73
# The equation of the fit plane is: Z = -2.7569311205356162e-05 * X + -5.5823929817452534e-06 * Y + 0.006584959158999494
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19384973886725926
# The direction of the gradient is: 335.66574240753977
# 74
# The equation of the fit plane is: Z = -6.897530535573207e-06 * X + -1.1863834040727138e-05 * Y + 0.0036294269182390497
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17541509777639758
# The direction of the gradient is: 284.59103910620604
# 75
# The equation of the fit plane is: Z = 1.1836009163022647e-05 * X + -1.2437428765284258e-05 * Y + 7.3045023168991615e-06
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1934469226261296
# The direction of the gradient is: 246.92156220690936
# 76
# The equation of the fit plane is: Z = 4.204047010547921e-06 * X + -1.7071869123769413e-05 * Y + 0.0026347503850660844
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.245759028343238
# The direction of the gradient is: 263.7080319204782
# 77
# The equation of the fit plane is: Z = 6.559046452661676e-07 * X + -2.4666440507421705e-05 * Y + 0.004514488712684573
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3529731836724665
# The direction of the gradient is: 269.31787425935204
# 78
# The equation of the fit plane is: Z = -2.3284658761606547e-06 * X + -2.577302729904257e-05 * Y + 0.004707963304234291
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.36908374073714445
# The direction of the gradient is: 272.3164261865418
# 79
# The equation of the fit plane is: Z = -2.241539573493238e-06 * X + -1.6101249842542624e-05 * Y + 0.003396567666150216
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2308373590970317
# The direction of the gradient is: 273.5667776669565
# 80
# The equation of the fit plane is: Z = 3.0013543083717547e-06 * X + -9.171278331552216e-06 * Y + 0.001499906816320205
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.13263163431763259
# The direction of the gradient is: 261.66398331040534
# 81
# The equation of the fit plane is: Z = -1.0068422052188109e-05 * X + -7.939570957368312e-06 * Y + 0.003130241945937418
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.13064165608117506
# The direction of the gradient is: 299.58774556272556
# 82
# The equation of the fit plane is: Z = -1.179160623763708e-05 * X + -4.936454113138027e-06 * Y + 0.0033786398653929037
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.10342309116219206
# The direction of the gradient is: 316.923781464414
# 83
# The equation of the fit plane is: Z = -3.252634029521833e-05 * X + -1.5022421237706931e-05 * Y + 0.009101220592636476
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2993819408186034
# The direction of the gradient is: 314.11116728432097
# 84
# The equation of the fit plane is: Z = 5.8644528059152175e-06 * X + 8.921035091562248e-06 * Y + -0.0023968025788139733
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.13306414180368717
# The direction of the gradient is: 106.4009458590474
# 85
# The equation of the fit plane is: Z = -9.594876335137784e-06 * X + -1.555145296465933e-05 * Y + 0.00434292509494867
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23085778235983456
# The direction of the gradient is: 285.4426186995507
# 86
# The equation of the fit plane is: Z = 4.716115328140319e-06 * X + -1.631900320388883e-05 * Y + 0.002234673187109775
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23545271940075393
# The direction of the gradient is: 262.6271549307336
# 87
# The equation of the fit plane is: Z = -1.0718267795728736e-05 * X + -5.125051811672224e-06 * Y + 0.0031644735011900726
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.10046473853556288
# The direction of the gradient is: 313.1183695548335
# 88
# The equation of the fit plane is: Z = 8.044336642726358e-06 * X + -1.9748274160756148e-05 * Y + 0.002282346485342447
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.287236291128152
# The direction of the gradient is: 259.6637179192736
# 89
# The equation of the fit plane is: Z = -4.787302565585103e-06 * X + -7.597401971455585e-06 * Y + 0.002209227360561571
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11295378732357798
# The direction of the gradient is: 285.755510158571
# 90
# The equation of the fit plane is: Z = -3.4491321689593905e-06 * X + 3.5712711045285285e-06 * Y + -1.411176667153435e-05
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.05567391143091664
# The direction of the gradient is: 66.61492987050718
# 91
# The equation of the fit plane is: Z = 5.461294123450081e-06 * X + -1.2006525202474772e-05 * Y + 0.0014326990914604303
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17532616567355874
# The direction of the gradient is: 258.48855783865076
# 92
# The equation of the fit plane is: Z = 6.8494999335716895e-06 * X + -2.1213507585245155e-05 * Y + 0.0025034957702271274
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3066963189193454
# The direction of the gradient is: 261.77381317213815
# 93
# The equation of the fit plane is: Z = 1.4908608082677592e-05 * X + -2.7697189492246183e-05 * Y + 0.0022178396388870644
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4076620596374958
# The direction of the gradient is: 256.44972947556323
# 94
# The equation of the fit plane is: Z = 3.5588969276507207e-06 * X + -4.282776409500594e-05 * Y + 0.0070043580150170575
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6132396759437182
# The direction of the gradient is: 267.8692109231449
# 95
# The equation of the fit plane is: Z = -3.7378766820593814e-06 * X + -8.370053806488476e-06 * Y + 0.002139692097016404
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.12213645928106982
# The direction of the gradient is: 281.3072644025693
# 96
# The equation of the fit plane is: Z = -2.0592015709290014e-05 * X + -7.352285782473831e-06 * Y + 0.00493934141823221
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16873694413640922
# The direction of the gradient is: 321.4299079615937
# 97
# The equation of the fit plane is: Z = 1.6351247623933375e-05 * X + -1.8785005098475275e-05 * Y + 0.0004028942627758352
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2884839653667276
# The direction of the gradient is: 248.7074736301838
# 98
# The equation of the fit plane is: Z = 1.7772745808479748e-05 * X + -1.7522442842231322e-05 * Y + -0.00038776567352725164
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2753697478331153
# The direction of the gradient is: 245.57538935086086
# 99
# The equation of the fit plane is: Z = -8.527803967482091e-06 * X + -1.681055508324967e-05 * Y + 0.004403484213196904
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.24666626193722496
# The direction of the gradient is: 282.7967392872664
# 100
# The equation of the fit plane is: Z = -3.0031679094977857e-05 * X + -1.7751723484706236e-05 * Y + 0.00867289294613683
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.31865077306626677
# The direction of the gradient is: 307.1429480152385
# 101
# The equation of the fit plane is: Z = 2.1450916713838502e-05 * X + -2.2177738694630812e-05 * Y + -0.0002472404116827787
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.34581782445861736
# The direction of the gradient is: 246.5840785712486
# 102
# The equation of the fit plane is: Z = -1.5468006379775015e-06 * X + -1.9217086016252276e-05 * Y + 0.0034661478168240382
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.275152737038483
# The direction of the gradient is: 272.0639996741171
# 103
# The equation of the fit plane is: Z = -4.342402103722791e-06 * X + -3.842693619432932e-05 * Y + 0.0074202206813032846
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.550548270174086
# The direction of the gradient is: 272.89650858176776
# 104
# The equation of the fit plane is: Z = -2.5260099868486577e-05 * X + -9.84911047069772e-06 * Y + 0.006165925050998099
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21459512221091745
# The direction of the gradient is: 318.9496440800566
# 105
# The equation of the fit plane is: Z = -3.447370110845949e-05 * X + -2.4454653396702852e-05 * Y + 0.010759389587727682
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4137901981961279
# The direction of the gradient is: 302.25937707773005
# 106
# The equation of the fit plane is: Z = -6.746332021866394e-06 * X + -2.2508799371155334e-05 * Y + 0.005223156476698972
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3249619903689595
# The direction of the gradient is: 277.6432697014383
# 107
# The equation of the fit plane is: Z = -8.374249565207463e-06 * X + -1.8928037244892557e-05 * Y + 0.005151824771404466
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2761010812647938
# The direction of the gradient is: 281.20481556638345
# 108
# The equation of the fit plane is: Z = 1.3492023565950088e-05 * X + -1.0422625894855678e-05 * Y + -0.0009661047979406202
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17237503554895153
# The direction of the gradient is: 239.90343822229602
# 109
# The equation of the fit plane is: Z = 3.418443918309205e-06 * X + -3.143604741664942e-05 * Y + 0.005026753852346487
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.45034624347115343
# The direction of the gradient is: 267.2125413632175
# 110
# The equation of the fit plane is: Z = -7.681926800536562e-06 * X + 3.52017311863347e-06 * Y + 0.0006963135810914833
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0704220902239825
# The direction of the gradient is: 45.66392014483159
# 111
# The equation of the fit plane is: Z = -3.472189528348702e-06 * X + -1.6244154076939703e-05 * Y + 0.003489875346144239
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23349707459745084
# The direction of the gradient is: 275.4668395266203
# 112
# The equation of the fit plane is: Z = -1.9025198199280032e-05 * X + -2.2192459338571767e-05 * Y + 0.007554077978954113
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.34013777184991384
# The direction of the gradient is: 290.99887159562286
# 113
# The equation of the fit plane is: Z = -8.31801190872555e-06 * X + -1.410510474764142e-05 * Y + 0.004395557758893961
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2087446453436696
# The direction of the gradient is: 284.79087219102234
# 114
# The equation of the fit plane is: Z = 2.0074621059705773e-06 * X + -2.8442700340262528e-05 * Y + 0.005060373197629047
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.40718523359309416
# The direction of the gradient is: 268.18998256296095
# 115
# The equation of the fit plane is: Z = -1.6144372338528072e-05 * X + -8.297438703817674e-06 * Y + 0.0050115666946684715
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1574615999211656
# The direction of the gradient is: 311.0615532537365
# 116
# The equation of the fit plane is: Z = -1.7983305579588354e-05 * X + -7.910657956661985e-06 * Y + 0.005391654029485162
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16151340021916977
# The direction of the gradient is: 315.5069096982129
# 117
# The equation of the fit plane is: Z = -2.581746219122447e-05 * X + -4.583487162915869e-05 * Y + 0.012829026861392012
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6763798407681595
# The direction of the gradient is: 284.1548350816419
# 118
# The equation of the fit plane is: Z = -1.9804722110906646e-05 * X + -9.515118229374205e-06 * Y + 0.005728520828164115
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.18610761630371056
# The direction of the gradient is: 312.9820228172123
# 119
# The equation of the fit plane is: Z = -5.6722770882554454e-06 * X + -6.406025085998214e-06 * Y + 0.0025392001905856893
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.09860372207155471
# The direction of the gradient is: 291.6262336718713
# 120
# The equation of the fit plane is: Z = -3.24040417488814e-05 * X + -2.9104446699385412e-05 * Y + 0.011421360830357552
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.46532781659023115
# The direction of the gradient is: 296.496401152399
# 121
# The equation of the fit plane is: Z = -9.055297320630207e-06 * X + -3.768929778878794e-05 * Y + 0.008860777161601179
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5424016401763757
# The direction of the gradient is: 276.1400012551834
# 122
# The equation of the fit plane is: Z = -2.301345837720467e-05 * X + -4.363300451936425e-05 * Y + 0.012028919187974302
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6415107525699036
# The direction of the gradient is: 283.287181194538
# 123
# The equation of the fit plane is: Z = -2.1622348303324226e-05 * X + -2.7975722186398735e-05 * Y + 0.00936094876607319
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.42359181962991455
# The direction of the gradient is: 289.0886188861049
# 124
# The equation of the fit plane is: Z = -1.4212542488913578e-05 * X + -1.318499347052965e-05 * Y + 0.005507511460831343
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20948597303583955
# The direction of the gradient is: 295.76364228151033
# 125
# The equation of the fit plane is: Z = -1.2279225517430938e-06 * X + -1.92748904320747e-05 * Y + 0.004007153657818503
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.27591351184920493
# The direction of the gradient is: 271.63384950746274
# 126
# The equation of the fit plane is: Z = -1.2875044725514106e-05 * X + -2.665756177575105e-05 * Y + 0.00755509056198665
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3902557319051482
# The direction of the gradient is: 282.20232631430565
# 127
# The equation of the fit plane is: Z = -1.1761772026294928e-05 * X + -2.453860631242567e-05 * Y + 0.006871714694906271
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3591138515887876
# The direction of the gradient is: 282.1125477580703
# 128
# The equation of the fit plane is: Z = -1.2350844648868731e-05 * X + -3.840110894825172e-05 * Y + 0.009177000994863538
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.555143563026551
# The direction of the gradient is: 278.1946077056903
# 129
# The equation of the fit plane is: Z = -2.046641477707476e-05 * X + -7.642524099000138e-06 * Y + 0.005588916869459741
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17073822370145558
# The direction of the gradient is: 320.17183573216505
# 130
# The equation of the fit plane is: Z = -8.358887126226668e-06 * X + -1.4757397753761113e-05 * Y + 0.00443017060231916
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21784618958446755
# The direction of the gradient is: 284.2307610876255
# 131
# The equation of the fit plane is: Z = -1.0328781221387792e-05 * X + -3.126175005096976e-05 * Y + 0.007136177693997663
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.45218749510795964
# The direction of the gradient is: 278.4148839449125
# 132
# The equation of the fit plane is: Z = -3.4568574551148236e-06 * X + -3.0518774117361475e-05 * Y + 0.006202053800129951
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4372495175386343
# The direction of the gradient is: 272.9033085160536
# 133
# The equation of the fit plane is: Z = -7.944126933770298e-07 * X + -2.60958879898636e-05 * Y + 0.0051034551069792725
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3734365897894325
# The direction of the gradient is: 270.7809045201028
# 134
# The equation of the fit plane is: Z = -7.167945381326969e-07 * X + -3.706958609746435e-05 * Y + 0.0067588467244778785
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5304426833845878
# The direction of the gradient is: 270.49604015411717
# 135
# The equation of the fit plane is: Z = 5.233773975048342e-06 * X + -1.6933244463919453e-05 * Y + 0.0021765061345795614
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.24460426808143676
# The direction of the gradient is: 262.120915123529
# 136
# The equation of the fit plane is: Z = 9.918004377163297e-06 * X + -2.7408050812902113e-05 * Y + 0.0031235556875270297
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.39729164470297573
# The direction of the gradient is: 260.79679319772583
# 137
# The equation of the fit plane is: Z = 7.813751318810378e-06 * X + -1.2880972960602507e-05 * Y + 0.0011764315965651865
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19098914830808236
# The direction of the gradient is: 254.80470621285372
# 138
# The equation of the fit plane is: Z = 8.559107298970335e-06 * X + -2.4105900673768952e-05 * Y + 0.0028373825003044292
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.34925906908991994
# The direction of the gradient is: 260.9669049608391
# 139
# The equation of the fit plane is: Z = 6.630698965020735e-07 * X + -9.060341564209406e-06 * Y + 0.0017178021233477429
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.12971256524943336
# The direction of the gradient is: 268.1232340640129
# 140
# The equation of the fit plane is: Z = -6.251254315559173e-06 * X + 1.3905172523581553e-05 * Y + -0.0012719619487612888
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20295765283207723
# The direction of the gradient is: 78.61910092548027
# 141
# The equation of the fit plane is: Z = 5.246905310060615e-06 * X + -2.3214226544002363e-05 * Y + 0.00305956271472061
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3338652542907852
# The direction of the gradient is: 264.221385756195
# 142
# The equation of the fit plane is: Z = -7.457041699239062e-06 * X + -4.35186059066454e-05 * Y + 0.00893779971648391
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6245308021041986
# The direction of the gradient is: 274.3872499075009
# 143
# The equation of the fit plane is: Z = 5.272892013798883e-06 * X + -2.6713692933531836e-05 * Y + 0.0037038781169688195
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3837318501160741
# The direction of the gradient is: 264.94944870966026
# 144
# The equation of the fit plane is: Z = 8.80447886772059e-06 * X + -1.283603585495582e-05 * Y + 0.0005695842969506365
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19213542654467844
# The direction of the gradient is: 252.92749963896608
# 145
# The equation of the fit plane is: Z = -3.7465288108503547e-06 * X + -2.6754868595218542e-05 * Y + 0.005427999573649896
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3835828806172561
# The direction of the gradient is: 273.5876401651308
# 146
# The equation of the fit plane is: Z = -1.2671051520333158e-05 * X + -1.9958706362754666e-05 * Y + 0.005995796400474674
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2968996654778667
# The direction of the gradient is: 285.868074400905
# 147
# The equation of the fit plane is: Z = 1.0197334225776501e-05 * X + -3.4339257820494023e-05 * Y + 0.00413045315461229
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4956791764643186
# The direction of the gradient is: 262.42632542012984
# 148
# The equation of the fit plane is: Z = 8.248329162026682e-07 * X + -1.0294867082810952e-05 * Y + 0.0018580998915196515
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1474023687233488
# The direction of the gradient is: 267.9454828108803
# 149
# The equation of the fit plane is: Z = -7.372382540111263e-06 * X + -3.219032674409627e-05 * Y + 0.006905917828494214
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4630216299797987
# The direction of the gradient is: 275.854878122779
# 150
# The equation of the fit plane is: Z = 2.6909826726133508e-05 * X + -7.724550780207798e-06 * Y + -0.003535381333042222
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20479098733841813
# The direction of the gradient is: 212.6644389402985
# 151
# The equation of the fit plane is: Z = 3.5912430315161094e-06 * X + -2.0962281686459406e-05 * Y + 0.0033548767754568603
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3008270892285121
# The direction of the gradient is: 265.6136088845939
# 152
# The equation of the fit plane is: Z = 2.7565741656016187e-05 * X + -1.5256420462324679e-05 * Y + -0.0026314913644320016
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2807932423120284
# The direction of the gradient is: 231.02735971673007
# 153
# The equation of the fit plane is: Z = 1.0723187600112864e-05 * X + -1.1855438711299577e-05 * Y + -0.0002582534451492195
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.18302074748195885
# The direction of the gradient is: 247.95300027486235
# 154
# The equation of the fit plane is: Z = -3.5396317310884e-08 * X + -4.123659118187253e-05 * Y + 0.007050808735121774
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5900478601664682
# The direction of the gradient is: 270.02202044215824
# 155
# The equation of the fit plane is: Z = 1.5124442776797631e-05 * X + -3.958843293400561e-06 * Y + -0.0017834151011059884
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1122404525790183
# The direction of the gradient is: 210.3106721174969
# 156
# The equation of the fit plane is: Z = 1.9508350384929397e-05 * X + -1.6012670672984246e-06 * Y + -0.00334084419775488
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.12706643000083478
# The direction of the gradient is: 190.38824212581721
# 157
# The equation of the fit plane is: Z = 6.631996935648145e-06 * X + -1.8368464028015893e-05 * Y + 0.0017029671037420244
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.26624364214578156
# The direction of the gradient is: 260.8170725546032
# 158
# The equation of the fit plane is: Z = -1.946572471596415e-05 * X + -4.85948953097244e-06 * Y + 0.004356910045001343
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.14278531696730326
# The direction of the gradient is: 330.8576904039887
# 159
# The equation of the fit plane is: Z = 2.963000637879368e-06 * X + -2.7917363286761043e-05 * Y + 0.004646830092864009
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3999158961465745
# The direction of the gradient is: 267.27929480375315
# 160
# The equation of the fit plane is: Z = 1.5022052011202638e-05 * X + -1.875495946038533e-05 * Y + 0.00019061230726096921
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.28509721016700446
# The direction of the gradient is: 250.27086902253927
# 161
# The equation of the fit plane is: Z = 1.0837651818809866e-05 * X + -1.391066995300853e-05 * Y + 0.0007542458962215646
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2108082475502508
# The direction of the gradient is: 250.7696375602917
# 162
# The equation of the fit plane is: Z = 1.182063050343524e-05 * X + -2.8934947140095206e-05 * Y + 0.003031162755990215
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4208946757300215
# The direction of the gradient is: 259.63440959884986
# 163
# The equation of the fit plane is: Z = 1.7293787976740034e-06 * X + -4.169966052919064e-05 * Y + 0.006723692972407795
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5967766608239432
# The direction of the gradient is: 268.9362037947234
# 164
# The equation of the fit plane is: Z = 9.891370170201956e-06 * X + -1.2732789845079868e-05 * Y + 0.00037846376090452374
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19289785857920355
# The direction of the gradient is: 250.8210396834495
# 165
# The equation of the fit plane is: Z = 1.6573668941115403e-05 * X + -1.906785789002553e-05 * Y + 3.0892674185804115e-06
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.29277247407971263
# The direction of the gradient is: 248.73525995192983
# 166
# The equation of the fit plane is: Z = -5.470031989136032e-06 * X + -2.1821184072104093e-05 * Y + 0.004675666257120228
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3141963656566974
# The direction of the gradient is: 276.4039585538683
# 167
# The equation of the fit plane is: Z = 9.701168932153404e-06 * X + -1.5702157208973337e-05 * Y + 0.0010498669174035915
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.233117675789822
# The direction of the gradient is: 254.53717702512165
# 168
# The equation of the fit plane is: Z = 8.956519337476395e-06 * X + -1.3666552297692846e-05 * Y + 0.0012364212913854602
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20379750651087034
# The direction of the gradient is: 253.6465902127801
# 169
# The equation of the fit plane is: Z = -3.3758194118300734e-06 * X + -3.903842266838322e-06 * Y + 0.0018396376506039898
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0599002457686109
# The direction of the gradient is: 291.16550140905184
# 170
# The equation of the fit plane is: Z = 3.625968772145362e-06 * X + -1.1890095123633433e-05 * Y + 0.0018654756664225251
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1717121181878995
# The direction of the gradient is: 262.2247911828978
# 171
# The equation of the fit plane is: Z = -3.283942752005893e-05 * X + 1.1830768508337751e-05 * Y + 0.004449963276101896
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.27004044305807506
# The direction of the gradient is: 38.820751683147364
# 172
# The equation of the fit plane is: Z = -1.471075324569835e-05 * X + -1.4496013482689442e-05 * Y + 0.005698238566183131
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2278289422341475
# The direction of the gradient is: 294.4358602469238
# 173
# The equation of the fit plane is: Z = -1.3817116175933169e-05 * X + -5.138508315823517e-06 * Y + 0.0034646645278906536
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11507469801305771
# The direction of the gradient is: 320.28700214826557
# 174
# The equation of the fit plane is: Z = -1.506910784670054e-07 * X + -6.496938765432028e-06 * Y + 0.001390904661448962
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.09296867505979936
# The direction of the gradient is: 270.5949957856425
# 175
# The equation of the fit plane is: Z = -2.15221450285318e-05 * X + -1.0755884741062059e-05 * Y + 0.006166558629116614
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20663708202910452
# The direction of the gradient is: 311.8576847239308
# 176
# The equation of the fit plane is: Z = -3.828676928351877e-05 * X + -8.467382822887977e-06 * Y + 0.008960893056186876
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.27358169911860936
# The direction of the gradient is: 333.71348711696504
# 177
# The equation of the fit plane is: Z = -2.4885959417330077e-05 * X + 8.006536804475362e-07 * Y + 0.004979101686660704
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.15984727786767966
# The direction of the gradient is: 4.109973810882536
# 178
# The equation of the fit plane is: Z = -3.229417153131605e-05 * X + -2.0216273507388196e-05 * Y + 0.01030595563296424
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3556470549686937
# The direction of the gradient is: 305.57382563058286
# 179
# The equation of the fit plane is: Z = -2.3063713152909166e-05 * X + -4.0017937991797197e-05 * Y + 0.011371440983824983
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5913679634285858
# The direction of the gradient is: 284.46947471328065
# 180
# The equation of the fit plane is: Z = -4.296866078502328e-05 * X + -8.716384793126066e-06 * Y + 0.00965856445525381
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.30222158321097947
# The direction of the gradient is: 335.6265838853927
# 181
# The equation of the fit plane is: Z = -1.9516455116617008e-05 * X + -3.0031460757875336e-05 * Y + 0.009412242592798423
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.44753681802442663
# The direction of the gradient is: 286.223565752754
# 182
# The equation of the fit plane is: Z = -1.7887956119064208e-05 * X + -1.9231610890217284e-05 * Y + 0.006766692532639331
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.29809201327962953
# The direction of the gradient is: 292.6097683695186
# 183
# The equation of the fit plane is: Z = -2.407247880159197e-05 * X + -6.55583153520695e-06 * Y + 0.006091139004827178
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.18051267808490976
# The direction of the gradient is: 328.69013202596733
# 184
# The equation of the fit plane is: Z = -2.9103422156114027e-05 * X + -4.023911308432625e-05 * Y + 0.012735469557565247
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6052130210659825
# The direction of the gradient is: 287.9437672782073
# 185
# The equation of the fit plane is: Z = -4.0486947864544095e-05 * X + 4.92525362924446e-06 * Y + 0.0070467572692437174
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2687900743435187
# The direction of the gradient is: 15.200181361333307
# 186
# The equation of the fit plane is: Z = -2.2053375938837054e-05 * X + -1.207698079864831e-05 * Y + 0.006414878272476914
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.22321509892776692
# The direction of the gradient is: 309.2696864097845
# 187
# The equation of the fit plane is: Z = -9.839398293832593e-06 * X + -3.2851987101527945e-05 * Y + 0.00789628090346771
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4742817636997899
# The direction of the gradient is: 277.6379066274079
# 188
# The equation of the fit plane is: Z = -2.0863640893534806e-05 * X + -3.811182851484349e-05 * Y + 0.011081580702166796
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5614785705329546
# The direction of the gradient is: 283.7721664124228
# 189
# The equation of the fit plane is: Z = -1.4033508084496489e-05 * X + -2.558376326126515e-05 * Y + 0.006942824882342108
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.37695309413506045
# The direction of the gradient is: 283.7987746832581
# 190
# The equation of the fit plane is: Z = -1.7908109541688764e-05 * X + -2.334761197796514e-05 * Y + 0.007874049971902358
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3532292613971569
# The direction of the gradient is: 288.9538934666362
# 191
# ...
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20207144220276102
# The direction of the gradient is: 241.88396409818188
# 220
# The equation of the fit plane is: Z = -6.427745657642149e-07 * X + -4.455900581903613e-06 * Y + 0.0012340366637275746
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.06389162147535686
# The direction of the gradient is: 273.69548218663465
# 221
# The equation of the fit plane is: Z = -5.9587437917092244e-06 * X + 2.4050152520194285e-06 * Y + 0.0007633944917926889
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.05139687728489526
# The direction of the gradient is: 42.03264486272366
# 222
# The equation of the fit plane is: Z = -3.101004396319179e-05 * X + -2.2247102899318714e-06 * Y + 0.006612941476455183
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20120534451351338
# The direction of the gradient is: 350.89689202120127
# 223
# The equation of the fit plane is: Z = -2.571297872991666e-05 * X + -2.308392498873695e-06 * Y + 0.005345688787544498
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1680134272506799
# The direction of the gradient is: 348.6621481422636
# 224
# The equation of the fit plane is: Z = -2.2775250394391376e-05 * X + -1.2580273168634453e-05 * Y + 0.006409114481020092
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23171978338681534
# The direction of the gradient is: 309.02787547569824
# 225
# The equation of the fit plane is: Z = -5.004934431286691e-05 * X + -3.0539551454484677e-05 * Y + 0.014566922898614929
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.54200800393999
# The direction of the gradient is: 306.2703486824049
# 226
# The equation of the fit plane is: Z = -6.681607463766166e-05 * X + -1.558860814471398e-05 * Y + 0.015297824224122875
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4826969400355016
# The direction of the gradient is: 332.4772123547608
# 227
# The equation of the fit plane is: Z = -7.677925843157042e-05 * X + -3.5838743466908613e-05 * Y + 0.0200434422627149
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7105914462692456
# The direction of the gradient is: 313.8076614647824
# 228
# The equation of the fit plane is: Z = -4.051433956759669e-05 * X + -2.0142654853182305e-05 * Y + 0.011464087120418017
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.38786870732356227
# The direction of the gradient is: 312.00542653978704
# 229
# The equation of the fit plane is: Z = -5.699764378754244e-05 * X + 3.6040981827967682e-06 * Y + 0.010796565923660524
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.36878880214105
# The direction of the gradient is: 8.03843735633535
# 230
# The equation of the fit plane is: Z = -5.954235667822751e-05 * X + 6.827272362657163e-06 * Y + 0.010820646614054427
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3937785521160613
# The direction of the gradient is: 14.364191340462071
# 231
# The equation of the fit plane is: Z = -4.26478738248662e-05 * X + -5.127131266231525e-05 * Y + 0.016890061712538873
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7828618121400353
# The direction of the gradient is: 290.4271160851173
# 232
# The equation of the fit plane is: Z = -3.4185584112308935e-05 * X + -7.810315837573555e-07 * Y + 0.007090901236954084
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21930079883373108
# The direction of the gradient is: 357.07891886936335
# 233
# The equation of the fit plane is: Z = -2.926212162806439e-05 * X + -3.444213952359172e-05 * Y + 0.01212960379262333
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5272803873764446
# The direction of the gradient is: 290.82695876001696
# 234
# The equation of the fit plane is: Z = -5.554727779999677e-05 * X + 3.456337624785981e-05 * Y + 0.0051560701270983444
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6092923627226228
# The direction of the gradient is: 54.262237084197295
# 235
# The equation of the fit plane is: Z = -3.5715029696330294e-05 * X + -2.0881939413247765e-05 * Y + 0.01063826213145166
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3763447060332491
# The direction of the gradient is: 307.44444172024026
# 236
# The equation of the fit plane is: Z = -2.665002509677344e-05 * X + 1.3467797796585811e-05 * Y + 0.003225415609880853
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.25746467149659036
# The direction of the gradient is: 48.459357206842185
# 237
# The equation of the fit plane is: Z = -3.873986271438611e-05 * X + 1.250955206158832e-06 * Y + 0.007358685275107969
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.24883825562842854
# The direction of the gradient is: 4.125028372757981
# 238
# The equation of the fit plane is: Z = -1.890655707877726e-05 * X + -3.8306935777858646e-05 * Y + 0.010441002952158735
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5613520788954881
# The direction of the gradient is: 282.4612478333245
# 239
# The equation of the fit plane is: Z = -3.603560352715036e-05 * X + -2.1530880618229778e-05 * Y + 0.01011949776895664
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3849865797191534
# The direction of the gradient is: 306.84690333929325
# 240
# The equation of the fit plane is: Z = -3.92156719405541e-05 * X + 2.7984907551420874e-05 * Y + 0.002664222568587303
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4727240093206848
# The direction of the gradient is: 57.89468939028842
# 241
# The equation of the fit plane is: Z = -3.652058482762584e-05 * X + 3.364211764108813e-05 * Y + 0.0008953737984360162
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5352297887307562
# The direction of the gradient is: 64.07785018886182
# 242
# The equation of the fit plane is: Z = 2.6003327575165186e-06 * X + -1.901577185457611e-05 * Y + 0.00283475974050246
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.27260317940582224
# The direction of the gradient is: 266.4963243440882
# 243
# The equation of the fit plane is: Z = 6.515826929650815e-06 * X + -8.890669371585674e-06 * Y + 0.0005101267419666955
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.13388923046472492
# The direction of the gradient is: 251.83311092343206
# 244
# The equation of the fit plane is: Z = 1.0339227504086285e-05 * X + -1.8508884873211166e-05 * Y + 0.0015750018823359989
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2729987786670618
# The direction of the gradient is: 255.95767325198096
# 245
# The equation of the fit plane is: Z = 2.3563868521566608e-05 * X + -1.2269991413703858e-05 * Y + -0.0026424654565618023
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23154984431291808
# The direction of the gradient is: 229.308905084426
# 246
# The equation of the fit plane is: Z = 1.790818709746664e-06 * X + -2.76738597779316e-05 * Y + 0.004673655222417882
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3961470305148245
# The direction of the gradient is: 268.34037054014607
# 247
# The equation of the fit plane is: Z = 5.38091810118031e-06 * X + -3.139945782054333e-05 * Y + 0.004162108411047102
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.45061047881767335
# The direction of the gradient is: 265.612321045453
# 248
# The equation of the fit plane is: Z = -2.7621970228621523e-05 * X + -2.5533339573961738e-05 * Y + 0.009336070349720586
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.40595446521666273
# The direction of the gradient is: 295.8440466458702
# 249
# The equation of the fit plane is: Z = -2.9540984960084842e-05 * X + -6.398134572595403e-06 * Y + 0.005823289327064046
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2102391811234152
# The direction of the gradient is: 334.18569388625855
# 250
# The equation of the fit plane is: Z = -1.8970300275554716e-05 * X + -2.4757756051520655e-05 * Y + 0.008130249962877983
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3745231346956786
# The direction of the gradient is: 288.9358921869008
# 251
# The equation of the fit plane is: Z = -1.2327213102697127e-05 * X + -4.19916535402958e-05 * Y + 0.00889258864188861
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6060200172818286
# The direction of the gradient is: 277.4880741334696
# 252
# The equation of the fit plane is: Z = -2.3072009429733092e-05 * X + -7.406261728587747e-06 * Y + 0.005176432872612459
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1818788750133846
# The direction of the gradient is: 324.3615773300463
# 253
# The equation of the fit plane is: Z = -2.248193246915117e-05 * X + -6.508372481369271e-05 * Y + 0.015248588725039492
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9423452983916285
# The direction of the gradient is: 278.79193435403397
# 254
# The equation of the fit plane is: Z = -5.7390982810841436e-05 * X + 5.602162741733854e-06 * Y + 0.010419479254401958
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.37632186388954136
# The direction of the gradient is: 12.29882544740326
# 255
# The equation of the fit plane is: Z = -5.513927484749783e-05 * X + -2.3897698027742007e-05 * Y + 0.014526547952719474
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.49165110587944844
# The direction of the gradient is: 315.93211304878866
# 256
# The equation of the fit plane is: Z = -6.721605887198639e-05 * X + -4.019718272280942e-05 * Y + 0.019288243685552833
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7185191019144043
# The direction of the gradient is: 306.8220520384044
# 257
# The equation of the fit plane is: Z = -8.577189867418309e-05 * X + -5.43660144396933e-05 * Y + 0.024781620860694988
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9524259444809205
# The direction of the gradient is: 305.2370689724472
# 258
# The equation of the fit plane is: Z = -7.229858785041164e-05 * X + -2.8738407078389543e-05 * Y + 0.01897437267717395
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6193904263009705
# The direction of the gradient is: 318.4020100369905
# 259
# The equation of the fit plane is: Z = -7.775388327393937e-05 * X + 4.319391190995003e-05 * Y + 0.007436560809007373
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7938128799746405
# The direction of the gradient is: 51.13166205986596
# 260
# The equation of the fit plane is: Z = -7.989502341622628e-05 * X + 1.0712210068595496e-05 * Y + 0.01338350578246668
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5343187426048056
# The direction of the gradient is: 16.670580513338336
# 261
# The equation of the fit plane is: Z = -5.7365408652016845e-05 * X + 1.2753252227995744e-06 * Y + 0.011392935183937006
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.36797417255039766
# The direction of the gradient is: 2.842554939174363
# 262
# The equation of the fit plane is: Z = -7.966829799502439e-05 * X + 1.691743920373015e-05 * Y + 0.012254409170320411
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.564902152443856
# The direction of the gradient is: 25.373343690921388
# 263
# The equation of the fit plane is: Z = -5.03299102986834e-05 * X + -3.046088740917916e-05 * Y + 0.015389984863333782
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5421680296514972
# The direction of the gradient is: 306.49387065506755
# 264
# The equation of the fit plane is: Z = -5.016847509599347e-05 * X + -2.407602139771324e-05 * Y + 0.014104074810600642
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.47115447908652486
# The direction of the gradient is: 313.0143727274346
# 265
# The equation of the fit plane is: Z = -4.902707894872966e-05 * X + 3.4164207885193617e-06 * Y + 0.008837037594830203
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.31788180734408206
# The direction of the gradient is: 8.846258108089842
# 266
# The equation of the fit plane is: Z = -3.3008239441656755e-05 * X + -4.9274086570674616e-05 * Y + 0.01504347377201438
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7360865859939855
# The direction of the gradient is: 286.6959992804866
# 267
# The equation of the fit plane is: Z = -3.718671750033292e-05 * X + -4.0564904970100796e-05 * Y + 0.013353129714269843
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6274285859936716
# The direction of the gradient is: 292.3159404151986
# 268
# The equation of the fit plane is: Z = -3.073378711863692e-05 * X + -3.0046102536368156e-05 * Y + 0.010775233558099659
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4728694820721632
# The direction of the gradient is: 294.60730811581846
# 269
# The equation of the fit plane is: Z = -7.673878398806047e-06 * X + -2.656129080934662e-05 * Y + 0.005969895927786177
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.38322797218738996
# The direction of the gradient is: 277.37074574668225
# 270
# The equation of the fit plane is: Z = -2.1267597254271598e-05 * X + 4.134040119582262e-05 * Y + -0.0032233015626207807
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6070229377292906
# The direction of the gradient is: 77.02866348925113
# 271
# The equation of the fit plane is: Z = -7.0076631544068805e-06 * X + -1.0061135643909291e-05 * Y + 0.003005535932385438
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.15080130238890282
# The direction of the gradient is: 287.3204106954255
# 272
# The equation of the fit plane is: Z = -1.674084458672909e-05 * X + -1.0414722916531085e-05 * Y + 0.004903539211357892
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.18360547270406324
# The direction of the gradient is: 305.74295588315806
# 273
# The equation of the fit plane is: Z = -7.089303945869582e-06 * X + -1.6235607533991285e-05 * Y + 0.004044009681398958
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23671094873641366
# The direction of the gradient is: 281.06221209299224
# 274
# The equation of the fit plane is: Z = -2.0226032543129808e-05 * X + 2.5972343442709705e-05 * Y + -0.0006896794938410189
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.39357757615212385
# The direction of the gradient is: 70.77733247383361
# 275
# The equation of the fit plane is: Z = -3.777307104147615e-06 * X + -1.82322703520139e-05 * Y + 0.003934240929001402
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.26200266657877425
# The direction of the gradient is: 275.2996993108307
# 276
# The equation of the fit plane is: Z = -1.2019134540294248e-05 * X + -3.969234812525665e-05 * Y + 0.009007342308254214
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5731477153588175
# The direction of the gradient is: 277.72106227862594
# 277
# The equation of the fit plane is: Z = 6.880554924289453e-06 * X + -4.5587962272579235e-05 * Y + 0.006811094774587721
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6537986510769747
# The direction of the gradient is: 266.1339788429657
# 278
# The equation of the fit plane is: Z = -8.965106908107756e-08 * X + -3.803142128421512e-06 * Y + 0.0010007384916265675
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.05442158609946012
# The direction of the gradient is: 270.60471052151996
# 279
# The equation of the fit plane is: Z = -1.3785841815687395e-05 * X + -1.9380765145465203e-05 * Y + 0.006000272857143317
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2910412108834444
# The direction of the gradient is: 287.66595378918055
# 280
# The equation of the fit plane is: Z = 7.788242592607382e-06 * X + -4.9784453758032846e-05 * Y + 0.007031251645234929
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7141031774883855
# The direction of the gradient is: 265.9932918011408
# 281
# The equation of the fit plane is: Z = -1.654855245770691e-05 * X + -3.953150810543344e-05 * Y + 0.009827178700880464
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5755001919779058
# The direction of the gradient is: 280.6159150978175
# 282
# The equation of the fit plane is: Z = -2.777896610688017e-05 * X + -3.186779952403288e-05 * Y + 0.010383643391966887
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4894911897628157
# The direction of the gradient is: 291.32041344855213
# 283

# %%
with h5py.File(path_hight_GIM, 'r') as file:
    date_hight_GIM = file['date']
    date_hight_GIM = date_hight_GIM[()]
date_hight_GIM = np.char.decode(date_hight_GIM)

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

slope_ion_hight_GIM_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_hight_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_hight_GIM_correct[i] = slope_ion_hight_GIM[j[0]]
slope_ion_hight_GIM = slope_ion_hight_GIM_correct

angle_deg_ion_hight_GIM_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_hight_GIM == date_split[i])[0]
    if len(j) > 0:
        angle_deg_ion_hight_GIM_correct[i] = angle_deg_ion_hight_GIM[j[0]]
angle_deg_ion_hight_GIM = angle_deg_ion_hight_GIM_correct

slope_ion_hight_GIM_dongxifangxiang_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_hight_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_hight_GIM_dongxifangxiang_correct[i] = slope_ion_hight_GIM_dongxifangxiang[j[0]]
slope_ion_hight_GIM_dongxifangxiang = slope_ion_hight_GIM_dongxifangxiang_correct

slope_ion_hight_GIM_nanbeifangxiang_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_hight_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_hight_GIM_nanbeifangxiang_correct[i] = slope_ion_hight_GIM_nanbeifangxiang[j[0]]
slope_ion_hight_GIM_nanbeifangxiang = slope_ion_hight_GIM_nanbeifangxiang_correct

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi
from scipy.stats import binned_statistic

# 假设 angle_deg_ion_split 和 slope_ion_split 是已经定义好的 numpy 数组
# 转换为弧度
ion_split_angle_deg_rad = np.deg2rad(angle_deg_ion_split)

# 计算每个bin中的均值
bin_means, bin_edges, _ = binned_statistic(ion_split_angle_deg_rad, slope_ion_split, statistic='mean', bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12))

# 从蓝色颜色图中取颜色，bin_means / bin_means.max() 使均值在 0-1 之间，以便映射到颜色的深浅
#colors = plt.get_cmap('Blues')(bin_means / np.nanmax(bin_means))
colors = plt.get_cmap('Blues')(bin_means)

fig = plt.figure()
ax = fig.add_subplot(111, polar=True)

# 绘制直方图，颜色由均值决定
n, bins, patches = ax.hist(ion_split_angle_deg_rad, bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12), alpha=0.7)

# 清除常规极坐标图的细节
#ax.set_yticklabels([])  # 删除y轴标签
#ax.set_yticks([])  # 删除y轴刻度

# 设置x轴标签为0-360度
ax.set_xticks(np.arange(0, 2*np.pi, np.pi/12))
ax.set_xticklabels(['270°','285°', '300°','315°', '330°','345°' ,'0°','15°', '30°','45°', '60°','75°', '90°','105°', '120°','135°', '150°','165°', '180°','195°', '210°','225°', '240°','255°'])

# 设置直方图的颜色
for i in range(len(patches)):
    patches[i].set_facecolor(colors[i])

ax.grid(True)  # 显示网格线
ax.set_title('ion_split_angle')

# 添加颜色条
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=0, vmax=1))
sm.set_array([])
cax = fig.add_axes([0.85, 0.1, 0.03, 0.8])  # 定义颜色条的位置和大小
cbar = fig.colorbar(sm, cax=cax)
cbar.set_label('Mean Slpoe (cm/100km)')

# 在径向上添加长度刻度
#ax.set_yticks(np.linspace(0, max(n), 5))  # 设置刻度范围和数量
ax.set_yticks(np.linspace(0, 100, 6))

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi
from scipy.stats import binned_statistic

# 假设 angle_deg_ion_GIM 和 slope_ion_GIM 是已经定义好的 numpy 数组
# 转换为弧度
ion_GIM_angle_deg_rad = np.deg2rad(angle_deg_ion_GIM)

# 计算每个bin中的均值
bin_means, bin_edges, _ = binned_statistic(ion_GIM_angle_deg_rad, slope_ion_GIM, statistic='mean', bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12))

# 从蓝色颜色图中取颜色，bin_means / bin_means.max() 使均值在 0-1 之间，以便映射到颜色的深浅
#colors = plt.get_cmap('Blues')(bin_means / np.nanmax(bin_means))
colors = plt.get_cmap('Blues')(bin_means)

fig = plt.figure()
ax = fig.add_subplot(111, polar=True)

# 绘制直方图，颜色由均值决定
n, bins, patches = ax.hist(ion_GIM_angle_deg_rad, bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12), alpha=0.7)

# 清除常规极坐标图的细节
#ax.set_yticklabels([])  # 删除y轴标签
#ax.set_yticks([])  # 删除y轴刻度

# 设置x轴标签为0-360度
ax.set_xticks(np.arange(0, 2*np.pi, np.pi/12))
ax.set_xticklabels(['270°','285°', '300°','315°', '330°','345°' ,'0°','15°', '30°','45°', '60°','75°', '90°','105°', '120°','135°', '150°','165°', '180°','195°', '210°','225°', '240°','255°'])

# 设置直方图的颜色
for i in range(len(patches)):
    patches[i].set_facecolor(colors[i])

ax.grid(True)  # 显示网格线
ax.set_title('ion_GIM_angle')

# 添加颜色条
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=0, vmax=1))
sm.set_array([])
cax = fig.add_axes([0.85, 0.1, 0.03, 0.8])  # 定义颜色条的位置和大小
cbar = fig.colorbar(sm, cax=cax)
cbar.set_label('Mean Slpoe (cm/100km)')

# 在径向上添加长度刻度
#ax.set_yticks(np.linspace(0, max(n), 5))  # 设置刻度范围和数量
ax.set_yticks(np.linspace(0, 100, 6))

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi
from scipy.stats import binned_statistic

# 假设 angle_deg_ion_GIM 和 slope_ion_GIM 是已经定义好的 numpy 数组
# 转换为弧度
ion_hight_GIM_angle_deg_rad = np.deg2rad(angle_deg_ion_hight_GIM)

# 计算每个bin中的均值
bin_means, bin_edges, _ = binned_statistic(ion_hight_GIM_angle_deg_rad, slope_ion_hight_GIM, statistic='mean', bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12))

# 从蓝色颜色图中取颜色，bin_means / bin_means.max() 使均值在 0-1 之间，以便映射到颜色的深浅
#colors = plt.get_cmap('Blues')(bin_means / np.nanmax(bin_means))
colors = plt.get_cmap('Blues')(bin_means)

fig = plt.figure()
ax = fig.add_subplot(111, polar=True)

# 绘制直方图，颜色由均值决定
n, bins, patches = ax.hist(ion_hight_GIM_angle_deg_rad, bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12), alpha=0.7)

# 清除常规极坐标图的细节
#ax.set_yticklabels([])  # 删除y轴标签
#ax.set_yticks([])  # 删除y轴刻度

# 设置x轴标签为0-360度
ax.set_xticks(np.arange(0, 2*np.pi, np.pi/12))
ax.set_xticklabels(['270°','285°', '300°','315°', '330°','345°' ,'0°','15°', '30°','45°', '60°','75°', '90°','105°', '120°','135°', '150°','165°', '180°','195°', '210°','225°', '240°','255°'])

# 设置直方图的颜色
for i in range(len(patches)):
    patches[i].set_facecolor(colors[i])

ax.grid(True)  # 显示网格线
ax.set_title('ion_hight_GIM_angle')

# 添加颜色条
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=0, vmax=1))
sm.set_array([])
cax = fig.add_axes([0.85, 0.1, 0.03, 0.8])  # 定义颜色条的位置和大小
cbar = fig.colorbar(sm, cax=cax)
cbar.set_label('Mean Slpoe (cm/100km)')

# 在径向上添加长度刻度
#ax.set_yticks(np.linspace(0, max(n), 5))  # 设置刻度范围和数量
ax.set_yticks(np.linspace(0, 100, 6))

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split, slope_ion_GIM)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope')
plt.ylabel('ion_GIM_slope')

# 添加标题
plt.title('ion_split_slope vs ion_GIM_slope')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-0.5,2]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=1))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_GIM, slope_ion_hight_GIM)

# 为x轴和y轴添加标签
plt.xlabel('ion_GIM_slope')
plt.ylabel('ion_hight_GIM_slope')

# 添加标题
plt.title('ion_GIM_slope vs ion_hight_GIM_slope')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-0.5,2]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=1))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split, slope_ion_hight_GIM)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope')
plt.ylabel('ion_hight_GIM_slope')

# 添加标题
plt.title('ion_split_slope vs ion_hight_GIM_slope')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-0.5,2]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=1))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split_dongxifangxiang, slope_ion_GIM_dongxifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope W-E')
plt.ylabel('ion_GIM_slope W-E')

# 添加标题
plt.title('ion_split_slope vs ion_GIM_slope in W-E direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-2.5, 1]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=1))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split_dongxifangxiang, slope_ion_hight_GIM_dongxifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope W-E')
plt.ylabel('ion_hight_GIM_slope W-E')

# 添加标题
plt.title('ion_split_slope vs ion_hight_GIM_slope in W-E direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-2.5, 1]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=1))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_GIM_dongxifangxiang, slope_ion_hight_GIM_dongxifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_GIM_slope W-E')
plt.ylabel('ion_hight_GIM_slope W-E')

# 添加标题
plt.title('ion_GIM_slope vs ion_hight_GIM_slope in W-E direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-1, 1]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=1))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split_nanbeifangxiang, slope_ion_GIM_nanbeifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope N-S')
plt.ylabel('ion_GIM_slope N-S')

# 添加标题
plt.title('ion_split_slope vs ion_GIM_slope in N-S direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-1.5, 1.5]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=1))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split_nanbeifangxiang, slope_ion_hight_GIM_nanbeifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope N-S')
plt.ylabel('ion_hight_GIM_slope N-S')

# 添加标题
plt.title('ion_split_slope vs ion_hight_GIM_slope in N-S direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-1.5, 1.5]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=1))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_GIM_nanbeifangxiang, slope_ion_hight_GIM_nanbeifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_GIM_slope N-S')
plt.ylabel('ion_hight_GIM_slope N-S')

# 添加标题
plt.title('ion_GIM_slope vs ion_hight_GIM_slope in N-S direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-1.5, 1.5]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=1))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split, width, label='Ion-Split slope', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM, width, label='Ion-GIM slope', alpha=1)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope(cm(ion)/ 100km(distance))')
ax.set_title('Ion-GIM Slope vs Ion-Split Slope')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split, width, label='Ion-Split slope', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM, width, label='Ion-hight-GIM slope', alpha=1)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope(cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-Split Slope')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]


ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM, width, label='Ion-hight-GIM slope', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM, width, label='Ion-GIM slope', alpha=1)


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope(cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-GIM Slope')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split_dongxifangxiang, width, label='Ion-Split slope W-E', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM_dongxifangxiang, width, label='Ion-GIM slope W-E', alpha=1) 

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope W-E (cm(ion)/ 100km(distance))')
ax.set_title('Ion-GIM Slope vs Ion-Split Slope in W-E direction')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split_dongxifangxiang, width, label='Ion-Split slope W-E', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM_dongxifangxiang, width, label='Ion-hight-GIM slope W-E', alpha=1) 

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope W-E (cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-Split Slope in W-E direction')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM_dongxifangxiang, width, label='Ion-hight-GIM slope W-E', alpha=1) 
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM_dongxifangxiang, width, label='Ion-GIM slope W-E', alpha=1) 

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope W-E (cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-GIM Slope in W-E direction')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split_nanbeifangxiang, width, label='Ion-Split slope N-S', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM_nanbeifangxiang, width, label='Ion-GIM slope N-S', alpha=1)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope N-S (cm(ion)/ 100km(distance))')
ax.set_title('Ion-GIM Slope vs Ion-Split Slope in N-S direction')

ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split_nanbeifangxiang, width, label='Ion-Split slope N-S', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM_nanbeifangxiang, width, label='Ion-hight-GIM slope N-S', alpha=1)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope N-S (cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-Split Slope in N-S direction')

ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM_nanbeifangxiang, width, label='Ion-hight-GIM slope N-S', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM_nanbeifangxiang, width, label='Ion-GIM slope N-S', alpha=1)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope N-S (cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-GIM Slope in N-S direction')

ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, angle_deg_ion_split, width, label='Ion-Split angle', alpha=1)
ax.bar(date_GIM_numeric, angle_deg_ion_GIM, width, label='Ion-GIM angle', alpha=1) 
ax.bar(date_GIM_numeric, angle_deg_ion_hight_GIM, width, label='Ion-hight-GIM angle', alpha=1) 

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('degree')
ax.set_title('Ion-GIM angle , Ion-hight-GIM angle vs Ion-Split angle')
ax.legend()

plt.show()
