: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5 with w mode
# create dataset  : intercept    of float32                   in size of (824, 314)           with compression = None
# create dataset  : interceptStd of float32                   in size of (824, 314)           with compression = None
# create dataset  : residue      of float32                   in size of (824, 314)           with compression = None
# create dataset  : velocity     of float32                   in size of (824, 314)           with compression = None
# create dataset  : velocityStd  of float32                   in size of (824, 314)           with compression = None
# add /intercept    attribute: UNIT = m
# add /interceptStd attribute: UNIT = m
# add /residue      attribute: UNIT = m
# add /velocity     attribute: UNIT = m/year
# add /velocityStd  attribute: UNIT = m/year
# close  HDF5 file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# --------------------------------------------------1/1
# reading velocity     in block (0, 0, 229, 690) from velocity_ion-split.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 824, 0, 314] to file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# --------------------------------------------------1/1
# reading velocityStd  in block (0, 0, 229, 690) from velocity_ion-split.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 824, 0, 314] to file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# --------------------------------------------------1/1
# reading intercept    in block (0, 0, 229, 690) from velocity_ion-split.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 824, 0, 314] to file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# --------------------------------------------------1/1
# reading interceptStd in block (0, 0, 229, 690) from velocity_ion-split.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 824, 0, 314] to file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# --------------------------------------------------1/1
# reading residue      in block (0, 0, 229, 690) from velocity_ion-split.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 824, 0, 314] to file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# time used: 00 mins 0.7 secs.
#
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read input option from template file: ../mintpy_gim_ion_upsample/smallbaselineApp.cfg
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: ../mintpy_gim_ion_upsample/inputs/geometryRadar.h5
# calculate output pixel size using approach 1 (same pixel area before/after resampling)
# output pixel size in (lat, lon) in degree: (-0.010288760016465424, 0.014927009482304732)
# output area extent in (S, N, W, E) in degree: (31.84453171848174, 40.32246997204925, -120.33380322642084, -115.64672224897716)
# output file row / column number: (824, 314)
# [1/1] preparing geometry for dest_box: (0, 0, 314, 824) --> full src_box: (0, 0, 229, 690)
# --------------------------------------------------
# resampling file: ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5
# create HDF5 file: ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5 with w mode
# create dataset  : intercept    of float32                   in size of (824, 314)           with compression = None
# create dataset  : interceptStd of float32                   in size of (824, 314)           with compression = None
# create dataset  : residue      of float32                   in size of (824, 314)           with compression = None
# create dataset  : velocity     of float32                   in size of (824, 314)           with compression = None
# create dataset  : velocityStd  of float32                   in size of (824, 314)           with compression = None
# add /intercept    attribute: UNIT = m
# add /interceptStd attribute: UNIT = m
# add /residue      attribute: UNIT = m
# add /velocity     attribute: UNIT = m/year
# add /velocityStd  attribute: UNIT = m/year
# close  HDF5 file: ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5
# --------------------------------------------------1/1
# reading velocity     in block (0, 0, 229, 690) from velocity_ion-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 824, 0, 314] to file: ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5
# --------------------------------------------------1/1
# reading velocityStd  in block (0, 0, 229, 690) from velocity_ion-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 824, 0, 314] to file: ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5
# --------------------------------------------------1/1
# reading intercept    in block (0, 0, 229, 690) from velocity_ion-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 824, 0, 314] to file: ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5
# --------------------------------------------------1/1
# reading interceptStd in block (0, 0, 229, 690) from velocity_ion-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 824, 0, 314] to file: ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5
# --------------------------------------------------1/1
# reading residue      in block (0, 0, 229, 690) from velocity_ion-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 824, 0, 314] to file: ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5
# time used: 00 mins 1.1 secs.

# %%
## 计算高分辨率的电离层的速度以及地理编码的电离层速度
# !timeseries2velocity.py ../mintpy_hight_gim_ion_upsample/ion.h5 -t ../mintpy_hight_gim_ion_upsample/smallbaselineApp.cfg -o ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5
# !geocode.py ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5 -l ../mintpy_hight_gim_ion_upsample/inputs/geometryRadar.h5  -o ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5 -t ../mintpy_hight_gim_ion_upsample/smallbaselineApp.cfg
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read options from template file: smallbaselineApp.cfg
# open timeseries file: ion.h5
# exclude date: []
# --------------------------------------------------
# dates from input file: 293
# ['20150327', '20150502', '20150619', '20150713', '20150806', '20151017', '20160214', '20160309', '20160426', '20160520', '20160613', '20160707', '20160731', '20161216', '20170109', '20170115', '20170202', '20170208', '20170226', '20170310', '20170403', '20170415', '20170427', '20170509', '20170521', '20170602', '20170614', '20170626', '20170708', '20170720', '20170801', '20170813', '20170825', '20170906', '20170918', '20170930', '20171012', '20171024', '20171105', '20171117', '20171129', '20171211', '20171223', '20180104', '20180116', '20180128', '20180209', '20180221', '20180305', '20180317', '20180410', '20180422', '20180504', '20180516', '20180528', '20180609', '20180621', '20180703', '20180715', '20180925', '20181230', '20190111', '20190117', '20190123', '20190210', '20190222', '20190306', '20190312', '20190318', '20190324', '20190330', '20190405', '20190411', '20190417', '20190423', '20190429', '20190511', '20190517', '20190523', '20190529', '20190610', '20190616', '20190622', '20190628', '20190704', '20190710', '20190716', '20190722', '20190728', '20190803', '20190809', '20190815', '20190827', '20190902', '20190908', '20190926', '20191002', '20191008', '20191014', '20191020', '20191026', '20191101', '20191107', '20191113', '20191119', '20191125', '20191201', '20191207', '20191213', '20191225', '20191231', '20200106', '20200118', '20200130', '20200205', '20200211', '20200217', '20200223', '20200229', '20200306', '20200312', '20200318', '20200324', '20200411', '20200417', '20200423', '20200429', '20200505', '20200511', '20200517', '20200523', '20200529', '20200604', '20200610', '20
: ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5
# create HDF5 file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5 with w mode
# create dataset  : intercept    of float32                   in size of (824, 314)           with compression = None
# create dataset  : interceptStd of float32                   in size of (824, 314)           with compression = None
# create dataset  : residue      of float32                   in size of (824, 314)           with compression = None
# create dataset  : velocity     of float32                   in size of (824, 314)           with compression = None
# create dataset  : velocityStd  of float32                   in size of (824, 314)           with compression = None
# add /intercept    attribute: UNIT = m
# add /interceptStd attribute: UNIT = m
# add /residue      attribute: UNIT = m
# add /velocity     attribute: UNIT = m/year
# add /velocityStd  attribute: UNIT = m/year
# close  HDF5 file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading velocity     in block (0, 0, 229, 690) from velocity_ion-hight-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 824, 0, 314] to file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading velocityStd  in block (0, 0, 229, 690) from velocity_ion-hight-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 824, 0, 314] to file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading intercept    in block (0, 0, 229, 690) from velocity_ion-hight-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 824, 0, 314] to file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading interceptStd in block (0, 0, 229, 690) from velocity_ion-hight-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 824, 0, 314] to file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading residue      in block (0, 0, 229, 690) from velocity_ion-hight-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 824, 0, 314] to file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# time used: 00 mins 0.8 secs.

# %%
## 电离层速度的图像展示
from mintpy.cli import view, tsview, plot_network, plot_transection
view.main('../mintpy_split_ion_upsample/geo_velocity_ion-split.h5  velocity --noverbos --title geo_velocity_ion-split --ref-lalo 37 -118 -m ../mintpy_split_ion_upsample/geo/geo_maskTempCoh.h5 -c cmy --wrap --wrap-range -0.1 0.1 '.split())
view.main('../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5  velocity --noverbos --title geo_velocity_ion-GIM --ref-lalo 37 -118 -m ../mintpy_gim_ion_upsample/geo/geo_maskTempCoh.h5 -c cmy --wrap --wrap-range -0.1 0.1 '.split())
view.main('../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5  velocity --noverbos --title geo_velocity_ion-hight-GIM --ref-lalo 37 -118 -m ../mintpy_hight_gim_ion_upsample/geo/geo_maskTempCoh.h5 -c cmy --wrap --wrap-range -0.1 0.1 '.split())
# Out:
# view.py ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5 velocity --noverbos --title geo_velocity_ion-split --ref-lalo 37 -118 -m ../mintpy_split_ion_upsample/geo/geo_maskTempCoh.h5 -c cmy --wrap --wrap-range -0.1 0.1
# view.py ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5 velocity --noverbos --title geo_velocity_ion-GIM --ref-lalo 37 -118 -m ../mintpy_gim_ion_upsample/geo/geo_maskTempCoh.h5 -c cmy --wrap --wrap-range -0.1 0.1
# view.py ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5 velocity --noverbos --title geo_velocity_ion-hight-GIM --ref-lalo 37 -118 -m ../mintpy_hight_gim_ion_upsample/geo/geo_maskTempCoh.h5 -c cmy --wrap --wrap-range -0.1 0.1

# %%
## 将电离层时间序列变为地理坐标的
# !geocode.py ../mintpy_split_ion_upsample/ion.h5 -l ../mintpy_split_ion_upsample/inputs/geometryRadar.h5  -o ../mintpy_split_ion_upsample/geo/geo_ion-split.h5 -t ../mintpy_split_ion_upsample/smallbaselineApp.cfg
# !geocode.py ../mintpy_gim_ion_upsample/ion.h5 -l ../mintpy_gim_ion_upsample/inputs/geometryRadar.h5  -o ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 -t ../mintpy_gim_ion_upsample/smallbaselineApp.cfg
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read input option from template file: ../mintpy_split_ion_upsample/smallbaselineApp.cfg
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: ../mintpy_split_ion_upsample/inputs/geometryRadar.h5
# calculate output pixel size using approach 1 (same pixel area before/after resampling)
# output pixel size in (lat, lon) in degree: (-0.010288760016465424, 0.014927009482304732)
# output area extent in (S, N, W, E) in degree: (31.84453171848174, 40.32246997204925, -120.33380322642084, -115.64672224897716)
# output file row / column number: (824, 314)
# [1/1] preparing geometry for dest_box: (0, 0, 314, 824) --> full src_box: (0, 0, 229, 690)
# --------------------------------------------------
# resampling file: ../mintpy_split_ion_upsample/ion.h5
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: ../mintpy_split_ion_upsample/ion.h5
# create HDF5 file: ../mintpy_split_ion_upsample/geo/geo_ion-split.h5 with w mode
# create dataset  : bperp      of float32                   in size of (291,)               with compression = None
# create dataset  : date       of |S8                       in size of (291,)               with compression = None
# create dataset  : timeseries of float32                   in size of (291, 824, 314)      with compression = None
# close  HDF5 file: ../mintpy_split_ion_upsample/geo/geo_ion-split.h5
# --------------------------------------------------1/1
# reading timeseries in block (0, 0, 229, 690) from ion.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 291, 0, 824, 0, 314] to file: ../mintpy_split_ion_upsample/geo/geo_ion-split.h5
# time used: 00 mins 2.4 secs.
#
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read input option from template file: ../mintpy_gim_ion_upsample/smallbaselineApp.cfg
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: ../mintpy_gim_ion_upsample/inputs/geometryRadar.h5
# calculate output pixel size using approach 1 (same pixel area before/after resampling)
# output pixel size in (lat, lon) in degree: (-0.010288760016465424, 0.014927009482304732)
# output area extent in (S, N, W, E) in degree: (31.84453171848174, 40.32246997204925, -120.33380322642084, -115.64672224897716)
# output file row / column number: (824, 314)
# [1/1] preparing geometry for dest_box: (0, 0, 314, 824) --> full src_box: (0, 0, 229, 690)
# --------------------------------------------------
# resampling file: ../mintpy_gim_ion_upsample/ion.h5
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: ../mintpy_gim_ion_upsample/ion.h5
# create HDF5 file: ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 with w mode
# create dataset  : date       of |S8                       in size of (293,)               with compression = None
# create dataset  : timeseries of float32                   in size of (293, 824, 314)      with compression = None
# close  HDF5 file: ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5
# --------------------------------------------------1/1
# reading timeseries in block (0, 0, 229, 690) from ion.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 293, 0, 824, 0, 314] to file: ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5
# time used: 00 mins 2.9 secs.

# %%
## 将高分辨率的电离层时间序列变为地理坐标的
# !geocode.py ../mintpy_hight_gim_ion_upsample/ion.h5 -l ../mintpy_hight_gim_ion_upsample/inputs/geometryRadar.h5  -o ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 -t ../mintpy_hight_gim_ion_upsample/smallbaselineApp.cfg
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read input option from template file: ../mintpy_hight_gim_ion_upsample/smallbaselineApp.cfg
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: ../mintpy_hight_gim_ion_upsample/inputs/geometryRadar.h5
# calculate output pixel size using approach 1 (same pixel area before/after resampling)
# output pixel size in (lat, lon) in degree: (-0.010288760016465424, 0.014927009482304732)
# output area extent in (S, N, W, E) in degree: (31.84453171848174, 40.32246997204925, -120.33380322642084, -115.64672224897716)
# output file row / column number: (824, 314)
# [1/1] preparing geometry for dest_box: (0, 0, 314, 824) --> full src_box: (0, 0, 229, 690)
# --------------------------------------------------
# resampling file: ../mintpy_hight_gim_ion_upsample/ion.h5
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: ../mintpy_hight_gim_ion_upsample/ion.h5
# create HDF5 file: ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 with w mode
# create dataset  : date       of |S8                       in size of (293,)               with compression = None
# create dataset  : timeseries of float32                   in size of (293, 824, 314)      with compression = None
# close  HDF5 file: ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading timeseries in block (0, 0, 229, 690) from ion.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 293, 0, 824, 0, 314] to file: ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5
# time used: 00 mins 2.7 secs.

# %%
## 电离层的时间序列展示
from mintpy.cli import view, tsview, plot_network, plot_transection
view.main('../mintpy_split_ion_upsample/geo/geo_ion-split.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20190123 --notitle'.split())
view.main('../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20190123 --notitle'.split())
view.main('../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20190123 --notitle'.split())
# Out:
# view.py ../mintpy_split_ion_upsample/geo/geo_ion-split.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20190123 --notitle
# view.py ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20190123 --notitle
# view.py ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20190123 --notitle
