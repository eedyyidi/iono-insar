'20220718', '20220730', '20220811', '20220823', '20220904', '20220916', '20220928', '20221010', '20221022', '20221103', '20221115', '20221127', '20221209', '20221221', '20230102', '20230114', '20230126', '20230207', '20230219', '20230303', '20230315', '20230327', '20230408', '20230420', '20230502', '20230514', '20230526', '20230607', '20230619', '20230701', '20230713', '20230725', '20230806', '20230818', '20230830', '20230911', '20230923', '20231005', '20231017', '20231110', '20231122', '20231204', '20231216', '20231228', '20240109', '20240121', '20240202', '20240214', '20240226', '20240309', '20240321']
# --------------------------------------------------
# using all dates to calculate the time function
# --------------------------------------------------
# estimate deformation model with the following assumed time functions:
#     polynomial : 1
#     periodic   : []
#     stepDate   : []
#     polyline   : []
#     exp        : {}
#     log        : {}
# add/update the following configuration metadata:
# ['startDate', 'endDate', 'excludeDate', 'polynomial', 'periodic', 'stepDate', 'exp', 'log', 'uncertaintyQuantification', 'timeSeriesCovFile', 'bootstrapCount']
# --------------------------------------------------
# create HDF5 file: ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5 with w mode
# create dataset  : intercept    of <class 'numpy.float32'>   in size of (722, 234)           with compression = None
# create dataset  : interceptStd of <class 'numpy.float32'>   in size of (722, 234)           with compression = None
# create dataset  : velocity     of <class 'numpy.float32'>   in size of (722, 234)           with compression = None
# create dataset  : velocityStd  of <class 'numpy.float32'>   in size of (722, 234)           with compression = None
# create dataset  : residue      of <class 'numpy.float32'>   in size of (722, 234)           with compression = None
# add /intercept    attribute: UNIT = m
# add /interceptStd attribute: UNIT = m
# add /velocity     attribute: UNIT = m/year
# add /velocityStd  attribute: UNIT = m/year
# add /residue      attribute: UNIT = m
# close  HDF5 file: ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5
# reading data from file ../mintpy_gim_ion_upsample/ion.h5 ...
# skip pixels with zero/nan value in all acquisitions
# /home/eedy/tools/MintPy/src/mintpy/timeseries2velocity.py:276: RuntimeWarning: Mean of empty slice
#   ts_stack = np.nanmean(ts_data, axis=0)
# number of pixels to invert: 161046 out of 168948 (95.3%)
# estimating time functions via linalg.lstsq ...
# estimating time functions STD from time-series fitting residual ...
# --------------------------------------------------
# open  HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5 in a mode
# writing dataset /intercept                 block: [0, 722, 0, 234]
# close HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5.
# --------------------------------------------------
# open  HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5 in a mode
# writing dataset /interceptStd              block: [0, 722, 0, 234]
# close HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5.
# --------------------------------------------------
# open  HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5 in a mode
# writing dataset /velocity                  block: [0, 722, 0, 234]
# close HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5.
# --------------------------------------------------
# open  HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5 in a mode
# writing dataset /velocityStd               block: [0, 722, 0, 234]
# close HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5.
# --------------------------------------------------
# open  HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5 in a mode
# writing dataset /residue                   block: [0, 722, 0, 234]
# close HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5.
# time used: 00 mins 3.8 secs.
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read input option from template file: ../mintpy_split_ion_upsample/smallbaselineApp.cfg
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: ../mintpy_split_ion_upsample/inputs/geometryRadar.h5
# calculate output pixel size using approach 1 (same pixel area before/after resampling)
# output pixel size in (lat, lon) in degree: (-0.010319281143236688, 0.0132217199261775)
# output area extent in (S, N, W, E) in degree: (-28.33527897357439, -19.605167126396154, -71.32044600400606, -66.4151879113942)
# output file row / column number: (846, 371)
# [1/1] preparing geometry for dest_box: (0, 0, 371, 846) --> full src_box: (0, 0, 234, 722)
# --------------------------------------------------
# resampling file: ../mintpy_split_ion_upsample/velocity_ion-split.h5
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: ../mintpy_split_ion_upsample/velocity_ion-split.h5
# create HDF5 file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5 with w mode
# create dataset  : intercept    of float32                   in size of (846, 371)           with compression = None
# create dataset  : interceptStd of float32                   in size of (846, 371)           with compression = None
# create dataset  : residue      of float32                   in size of (846, 371)           with compression = None
# create dataset  : velocity     of float32                   in size of (846, 371)           with compression = None
# create dataset  : velocityStd  of float32                   in size of (846, 371)           with compression = None
# add /intercept    attribute: UNIT = m
# add /interceptStd attribute: UNIT = m
# add /residue      attribute: UNIT = m
# add /velocity     attribute: UNIT = m/year
# add /velocityStd  attribute: UNIT = m/year
# close  HDF5 file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# --------------------------------------------------1/1
# reading velocity     in block (0, 0, 234, 722) from velocity_ion-split.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 846, 0, 371] to file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# --------------------------------------------------1/1
# reading velocityStd  in block (0, 0, 234, 722) from velocity_ion-split.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 846, 0, 371] to file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# --------------------------------------------------1/1
# reading intercept    in block (0, 0, 234, 722) from velocity_ion-split.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 846, 0, 371] to file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# --------------------------------------------------1/1
# reading interceptStd in block (0, 0, 234, 722) from velocity_ion-split.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 846, 0, 371] to file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# --------------------------------------------------1/1
# reading residue      in block (0, 0, 234, 722) from velocity_ion-split.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 846, 0, 371] to file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# time used: 00 mins 0.9 secs.
#
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read input option from template file: ../mintpy_gim_ion_upsample/smallbaselineApp.cfg
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: ../mintpy_gim_ion_upsample/inputs/geometryRadar.h5
# calculate output pixel size using approach 1 (same pixel area before/after resampling)
# output pixel size in (lat, lon) in degree: (-0.010319281143236688, 0.013221719926177497)
# output area extent in (S, N, W, E) in degree: (-28.33527897357439, -19.605167126396154, -71.32044600400606, -66.41518791139421)
# output file row / column number: (846, 371)
# [1/1] preparing geometry for dest_box: (0, 0, 371, 846) --> full src_box: (0, 0, 234, 722)
# --------------------------------------------------
# resampling file: ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5
# create HDF5 file: ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h
# --------------------------------------------------
# using all dates to calculate the time function
# --------------------------------------------------
# estimate deformation model with the following assumed time functions:
#     polynomial : 1
#     periodic   : []
#     stepDate   : []
#     polyline   : []
#     exp        : {}
#     log        : {}
# add/update the following configuration metadata:
# ['startDate', 'endDate', 'excludeDate', 'polynomial', 'periodic', 'stepDate', 'exp', 'log', 'uncertaintyQuantification', 'timeSeriesCovFile', 'bootstrapCount']
# --------------------------------------------------
# create HDF5 file: ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5 with w mode
# create dataset  : intercept    of <class 'numpy.float32'>   in size of (722, 234)           with compression = None
# create dataset  : interceptStd of <class 'numpy.float32'>   in size of (722, 234)           with compression = None
# create dataset  : velocity     of <class 'numpy.float32'>   in size of (722, 234)           with compression = None
# create dataset  : velocityStd  of <class 'numpy.float32'>   in size of (722, 234)           with compression = None
# create dataset  : residue      of <class 'numpy.float32'>   in size of (722, 234)           with compression = None
# add /intercept    attribute: UNIT = m
# add /interceptStd attribute: UNIT = m
# add /velocity     attribute: UNIT = m/year
# add /velocityStd  attribute: UNIT = m/year
# add /residue      attribute: UNIT = m
# close  HDF5 file: ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5
# reading data from file ../mintpy_hight_gim_ion_upsample/ion.h5 ...
# skip pixels with zero/nan value in all acquisitions
# /home/eedy/tools/MintPy/src/mintpy/timeseries2velocity.py:276: RuntimeWarning: Mean of empty slice
#   ts_stack = np.nanmean(ts_data, axis=0)
# number of pixels to invert: 161046 out of 168948 (95.3%)
# estimating time functions via linalg.lstsq ...
# estimating time functions STD from time-series fitting residual ...
# --------------------------------------------------
# open  HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5 in a mode
# writing dataset /intercept                 block: [0, 722, 0, 234]
# close HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5.
# --------------------------------------------------
# open  HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5 in a mode
# writing dataset /interceptStd              block: [0, 722, 0, 234]
# close HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5.
# --------------------------------------------------
# open  HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5 in a mode
# writing dataset /velocity                  block: [0, 722, 0, 234]
# close HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5.
# --------------------------------------------------
# open  HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5 in a mode
# writing dataset /velocityStd               block: [0, 722, 0, 234]
# close HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5.
# --------------------------------------------------
# open  HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5 in a mode
# writing dataset /residue                   block: [0, 722, 0, 234]
# close HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5.
# time used: 00 mins 2.5 secs.
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read input option from template file: ../mintpy_hight_gim_ion_upsample/smallbaselineApp.cfg
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: ../mintpy_hight_gim_ion_upsample/inputs/geometryRadar.h5
# calculate output pixel size using approach 1 (same pixel area before/after resampling)
# output pixel size in (lat, lon) in degree: (-0.010319281143236688, 0.013221719926177497)
# output area extent in (S, N, W, E) in degree: (-28.33527897357439, -19.605167126396154, -71.32044600400606, -66.41518791139421)
# output file row / column number: (846, 371)
# [1/1] preparing geometry for dest_box: (0, 0, 371, 846) --> full src_box: (0, 0, 234, 722)
# --------------------------------------------------
# resampling file: ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5
# create HDF5 file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5 with w mode
# create dataset  : intercept    of float32                   in size of (846, 371)           with compression = None
# create dataset  : interceptStd of float32                   in size of (846, 371)           with compression = None
# create dataset  : residue      of float32                   in size of (846, 371)           with compression = None
# create dataset  : velocity     of float32                   in size of (846, 371)           with compression = None
# create dataset  : velocityStd  of float32                   in size of (846, 371)           with compression = None
# add /intercept    attribute: UNIT = m
# add /interceptStd attribute: UNIT = m
# add /residue      attribute: UNIT = m
# add /velocity     attribute: UNIT = m/year
# add /velocityStd  attribute: UNIT = m/year
# close  HDF5 file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading velocity     in block (0, 0, 234, 722) from velocity_ion-hight-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 846, 0, 371] to file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading velocityStd  in block (0, 0, 234, 722) from velocity_ion-hight-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 846, 0, 371] to file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading intercept    in block (0, 0, 234, 722) from velocity_ion-hight-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 846, 0, 371] to file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading interceptStd in block (0, 0, 234, 722) from velocity_ion-hight-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 846, 0, 371] to file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading residue      in block (0, 0, 234, 722) from velocity_ion-hight-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 846, 0, 371] to file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# time used: 00 mins 0.8 secs.

# %%
## 电离层速度的图像展示
from mintpy.cli import view, tsview, plot_network, plot_transection
view.main('../mintpy_split_ion_upsample/geo_velocity_ion-split.h5  velocity --noverbos --title geo_velocity_ion-split --ref-lalo -25 -69'.split())
view.main('../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5  velocity --noverbos --title geo_velocity_ion-GIM --ref-lalo -25 -69'.split())
view.main('../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5  velocity --noverbos --title geo_velocity_ion-hight-GIM --ref-lalo -25 -69'.split())
# Out:
# view.py ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5 velocity --noverbos --title geo_velocity_ion-split --ref-lalo -25 -69
# view.py ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5 velocity --noverbos --title geo_velocity_ion-GIM --ref-lalo -25 -69
# view.py ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5 velocity --noverbos --title geo_velocity_ion-hight-GIM --ref-lalo -25 -69

# %%
## 将电离层时间序列变为地理坐标的
# !geocode.py ../mintpy_split_ion_upsample/ion.h5 -l ../mintpy_split_ion_upsample/inputs/geometryRadar.h5  -o ../mintpy_split_ion_upsample/geo/geo_ion-split.h5 -t ../mintpy_split_ion_upsample/smallbaselineApp.cfg
# !geocode.py ../mintpy_gim_ion_upsample/ion.h5 -l ../mintpy_gim_ion_upsample/inputs/geometryRadar.h5  -o ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 -t ../mintpy_gim_ion_upsample/smallbaselineApp.cfg
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read input option from template file: ../mintpy_split_ion_upsample/smallbaselineApp.cfg
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: ../mintpy_split_ion_upsample/inputs/geometryRadar.h5
# calculate output pixel size using approach 1 (same pixel area before/after resampling)
# output pixel size in (lat, lon) in degree: (-0.010319281143236688, 0.0132217199261775)
# output area extent in (S, N, W, E) in degree: (-28.33527897357439, -19.605167126396154, -71.32044600400606, -66.4151879113942)
# output file row / column number: (846, 371)
# [1/1] preparing geometry for dest_box: (0, 0, 371, 846) --> full src_box: (0, 0, 234, 722)
# --------------------------------------------------
# resampling file: ../mintpy_split_ion_upsample/ion.h5
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: ../mintpy_split_ion_upsample/ion.h5
# create HDF5 file: ../mintpy_split_ion_upsample/geo/geo_ion-split.h5 with w mode
# create dataset  : bperp      of float32                   in size of (229,)               with compression = None
# create dataset  : date       of |S8                       in size of (229,)               with compression = None
# create dataset  : timeseries of float32                   in size of (229, 846, 371)      with compression = None
# close  HDF5 file: ../mintpy_split_ion_upsample/geo/geo_ion-split.h5
# --------------------------------------------------1/1
# reading timeseries in block (0, 0, 234, 722) from ion.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 229, 0, 846, 0, 371] to file: ../mintpy_split_ion_upsample/geo/geo_ion-split.h5
# time used: 00 mins 2.1 secs.
#
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read input option from template file: ../mintpy_gim_ion_upsample/smallbaselineApp.cfg
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: ../mintpy_gim_ion_upsample/inputs/geometryRadar.h5
# calculate output pixel size using approach 1 (same pixel area before/after resampling)
# output pixel size in (lat, lon) in degree: (-0.010319281143236688, 0.013221719926177497)
# output area extent in (S, N, W, E) in degree: (-28.33527897357439, -19.605167126396154, -71.32044600400606, -66.41518791139421)
# output file row / column number: (846, 371)
# [1/1] preparing geometry for dest_box: (0, 0, 371, 846) --> full src_box: (0, 0, 234, 722)
# --------------------------------------------------
# resampling file: ../mintpy_gim_ion_upsample/ion.h5
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: ../mintpy_gim_ion_upsample/ion.h5
# create HDF5 file: ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 with w mode
# create dataset  : date       of |S8                       in size of (230,)               with compression = None
# create dataset  : timeseries of float32                   in size of (230, 846, 371)      with compression = None
# close  HDF5 file: ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5
# --------------------------------------------------1/1
# reading timeseries in block (0, 0, 234, 722) from ion.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 230, 0, 846, 0, 371] to file: ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5
# time used: 00 mins 2.0 secs.

# %%
## 将高分辨率的电离层时间序列变为地理坐标的
# !geocode.py ../mintpy_hight_gim_ion_upsample/ion.h5 -l ../mintpy_hight_gim_ion_upsample/inputs/geometryRadar.h5  -o ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 -t ../mintpy_hight_gim_ion_upsample/smallbaselineApp.cfg
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read input option from template file: ../mintpy_hight_gim_ion_upsample/smallbaselineApp.cfg
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: ../mintpy_hight_gim_ion_upsample/inputs/geometryRadar.h5
# calculate output pixel size using approach 1 (same pixel area before/after resampling)
# output pixel size in (lat, lon) in degree: (-0.010319281143236688, 0.013221719926177497)
# output area extent in (S, N, W, E) in degree: (-28.33527897357439, -19.605167126396154, -71.32044600400606, -66.41518791139421)
# output file row / column number: (846, 371)
# [1/1] preparing geometry for dest_box: (0, 0, 371, 846) --> full src_box: (0, 0, 234, 722)
# --------------------------------------------------
# resampling file: ../mintpy_hight_gim_ion_upsample/ion.h5
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: ../mintpy_hight_gim_ion_upsample/ion.h5
# create HDF5 file: ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 with w mode
# create dataset  : date       of |S8                       in size of (230,)               with compression = None
# create dataset  : timeseries of float32                   in size of (230, 846, 371)      with compression = None
# close  HDF5 file: ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading timeseries in block (0, 0, 234, 722) from ion.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 230, 0, 846, 0, 371] to file: ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5
# time used: 00 mins 2.0 secs.

# %%
## 电离层的时间序列展示
from mintpy.cli import view, tsview, plot_network, plot_transection
view.main('../mintpy_split_ion_upsample/geo/geo_ion-split.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20190306 --notitle'.split())
view.main('../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20190306 --notitle'.split())
view.main('../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20190306 --notitle'.split())
# Out:
# view.py ../mintpy_split_ion_upsample/geo/geo_ion-split.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20190306 --notitle
# view.py ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20190306 --notitle
# view.py ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20190306 --notitle
