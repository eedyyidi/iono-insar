# %%
# !pwd
# Out:
# /panda/eedy/chile/s1_a149/notebook

# %%
from mintpy.objects import ramp
from mintpy.utils import ptime, readfile, writefile
import h5py
import numpy as np
from matplotlib import pyplot as plt, colorbar, ticker, colors
from mintpy.utils import ptime, readfile, writefile
from scipy.optimize import curve_fit
from mpl_toolkits.mplot3d import Axes3D

# %%
######### split

# %%
path_split = '../mintpy_split_ion_upsample/geo/geo_ion-split.h5'

# %%
# !reference_point.py ../mintpy_split_ion_upsample/geo/geo_ion-split.h5 -y 180 -x 190
# !reference_date.py ../mintpy_split_ion_upsample/geo/geo_ion-split.h5 --ref-date 20181211
# Out:
# WARNING: auto turn ON --write-data for file tpye timeseries
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# --------------------------------------------------
# input reference point in y/x: (180, 190)
# --------------------------------------------------
# SAME reference pixel is already selected/saved in file, skip updating.
# input reference date: 20181211
# --------------------------------------------------
# change reference date for file: /panda/eedy/chile/s1_a149/mintpy_split_ion_upsample/geo/geo_ion-split.h5
# input refDate is the same as the existing REF_DATE.
# Nothing to be done.
# time used: 00 mins 1.0 secs.

# %%
timeseries_split = readfile.read(path_split, datasetName='timeseries')[0]
timeseries_split = np.squeeze(timeseries_split)

mask_path_split = '../mintpy_split_ion_upsample/geo/geo_maskTempCoh.h5'
mask_split = readfile.read(mask_path_split, datasetName='mask')[0]
mask_split = np.squeeze(mask_split)

data_out, ramp = ramp.deramp(timeseries_split, mask_in=mask_split, ramp_type='linear', metadata=None, max_num_sample=1e3, coeff_file=None,ignore_zero_value=True)

# %%
def function(data, a, b, c):
    '''
    拟合曲面使用的函数
    '''
    x = data[0]
    y = data[1]
    return a*x+b*y + c



slope_ion_split = np.zeros(timeseries_split.shape[0])
slope_ion_split_dongxifangxiang = np.zeros(timeseries_split.shape[0])
slope_ion_split_nanbeifangxiang = np.zeros(timeseries_split.shape[0])
angle_deg_ion_split = np.zeros(timeseries_split.shape[0])
meta = readfile.read_attribute(path_split)
AZIMUTH_PIXEL_SIZE =  float(meta['AZIMUTH_PIXEL_SIZE'])
RANGE_PIXEL_SIZE = float(meta['RANGE_PIXEL_SIZE'])

for i in range(timeseries_split.shape[0]):
    x_data = ramp.shape[2]
    y_data = ramp.shape[1]
    X_data, Y_data = np.meshgrid(range(x_data), range(y_data))
    Z_data = ramp[i, :,:]
    
    x_data = X_data.flatten()
    y_data = Y_data.flatten()
    z_data = Z_data.flatten()
    
    parameters, covariance = curve_fit(function, [x_data, y_data], z_data)
    print("The equation of the fit plane is: Z = {0} * X + {1} * Y + {2}".format(parameters[0],parameters[1],parameters[2]))
    
    Z_fit = function([X_data, Y_data], *parameters)
    
    # 计算梯度，考虑到横纵坐标的实际长度
    dx = parameters[1]/RANGE_PIXEL_SIZE
    dy = parameters[0]/AZIMUTH_PIXEL_SIZE
    # 计算梯度的大小和方向
    magnitude = np.hypot(dx, dy)  # 梯度的大小
    direction = np.degrees(np.arctan2(dy, dx)) + 90  # 梯度的方向，以x轴正半轴为0°，逆时针旋转为正方向
    direction = (direction + 360) % 360  # 将角度值限制在0°到360°之间

    print('The magnitude of the gradient is( cm(ion)/ 100km(juli)):', magnitude*1e7)
    print('The direction of the gradient is:', direction)

    slope_ion_split[i] = magnitude*1e7
    angle_deg_ion_split[i] = direction
    slope_ion_split_dongxifangxiang[i] = dy*1e7
    slope_ion_split_nanbeifangxiang[i] = dx*1e7

    print(i)
# Out:
# The equation of the fit plane is: Z = 0.001172598008731525 * X + 0.00015836666584717504 * Y + -0.22226303063432218
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.851726400139784
# The direction of the gradient is: 163.2255733807533
# 0
# The equation of the fit plane is: Z = 0.0009233072771048464 * X + 0.0003352785504952258 * Y + -0.20643758098025122
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.619369457878306
# The direction of the gradient is: 140.9765526152725
# 1
# The equation of the fit plane is: Z = 0.0008198183051393653 * X + -0.0002842350160640232 * Y + -0.09849695834378767
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.645736575521865
# The direction of the gradient is: 217.7329792512619
# 2
# The equation of the fit plane is: Z = 0.0004358454710428287 * X + -0.00044414294910374575 * Y + 0.007027089470604374
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.942332467950907
# The direction of the gradient is: 246.26586854729442
# 3
# The equation of the fit plane is: Z = 0.0010339682440709326 * X + 6.438553200937212e-05 * Y + -0.1851001539491143
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.692570027346669
# The direction of the gradient is: 172.08768270366727
# 4
# The equation of the fit plane is: Z = 0.0014080833885947142 * X + 0.0009154946073012775 * Y + -0.40629679548621206
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 15.908931990834818
# The direction of the gradient is: 124.571791401719
# 5
# The equation of the fit plane is: Z = 0.0009579103219337502 * X + -6.405697286150987e-05 * Y + -0.15441400020161333
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.209265581622885
# The direction of the gradient is: 188.4887401787695
# 6
# The equation of the fit plane is: Z = 0.0005076742978400256 * X + -0.0009145830554375625 * Y + 0.058481460328185235
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 13.485290306825531
# The direction of the gradient is: 256.03347384208917
# 7
# The equation of the fit plane is: Z = 0.0004555283280187711 * X + -0.00044830158736830847 * Y + 0.00193628803339417
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.048189763000705
# The direction of the gradient is: 245.52149961013197
# 8
# The equation of the fit plane is: Z = 6.269135842630724e-05 * X + -0.00027966613434582193 * Y + 0.04800341828787824
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.021831375517146
# The direction of the gradient is: 264.26460439364587
# 9
# The equation of the fit plane is: Z = 0.00017292184064877228 * X + -0.00020112343315525032 * Y + 0.010988517020604658
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.0839927570114543
# The direction of the gradient is: 248.93208342823573
# 10
# The equation of the fit plane is: Z = 0.00020582665961945697 * X + -0.00029582235997387276 * Y + 0.024242515706082626
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.433790787495613
# The direction of the gradient is: 252.6854659424048
# 11
# The equation of the fit plane is: Z = 0.0005605153752878507 * X + -0.00017148078684773883 * Y + -0.05736860084042485
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.351312274655234
# The direction of the gradient is: 214.32572141520677
# 12
# The equation of the fit plane is: Z = 0.0009254440299844909 * X + 0.0003229045305613283 * Y + -0.21265101622584878
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.519950456680235
# The direction of the gradient is: 142.0903896536107
# 13
# The equation of the fit plane is: Z = 0.0009499695038021059 * X + 0.00015775129118428998 * Y + -0.18296813590713118
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.495173739178208
# The direction of the gradient is: 159.6639656040802
# 14
# The equation of the fit plane is: Z = 0.0005107038687520538 * X + -0.00026089917262711 * Y + -0.03923341133867076
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.9655487020161715
# The direction of the gradient is: 228.74768188787607
# 15
# The equation of the fit plane is: Z = 0.0005219072824029385 * X + -0.0002584052867152645 * Y + -0.04319942562257786
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.986683625788075
# The direction of the gradient is: 227.8568529203401
# 16
# The equation of the fit plane is: Z = 0.000600361834868833 * X + -0.0001711844986354552 * Y + -0.0652840319916408
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.562277892013155
# The direction of the gradient is: 212.47233169226683
# 17
# The equation of the fit plane is: Z = 0.00030710365132556393 * X + -0.00038059076840507605 * Y + 0.01274320484683796
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.790795540026771
# The direction of the gradient is: 250.1231631880703
# 18
# The equation of the fit plane is: Z = 0.0004309955788293441 * X + -0.0003861074254289495 * Y + -0.004298599167609772
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.177203871645831
# The direction of the gradient is: 243.42853162149868
# 19
# The equation of the fit plane is: Z = 5.884174327537837e-05 * X + -0.00015989857798080051 * Y + 0.02559335083918044
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.318854349896498
# The direction of the gradient is: 260.63731068868185
# 20
# The equation of the fit plane is: Z = 5.963666510290025e-05 * X + -0.0002020150651013542 * Y + 0.029225999137654595
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.9157772457828086
# The direction of the gradient is: 262.4653080283242
# 21
# The equation of the fit plane is: Z = 0.00034358059488817937 * X + -0.0001555836424858526 * Y + -0.022512336126611535
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.1317812705797765
# The direction of the gradient is: 225.30398181381986
# 22
# The equation of the fit plane is: Z = 0.00025014916511751246 * X + -0.00045616144035347635 * Y + 0.0318328460566467
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.721273340459165
# The direction of the gradient is: 256.1958002071816
# 23
# The equation of the fit plane is: Z = -7.884015315376182e-05 * X + -5.1510234458174155e-05 * Y + 0.02033406465181895
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8937145700104945
# The direction of the gradient is: 304.44130738762146
# 24
# The equation of the fit plane is: Z = -0.00017634592708053632 * X + -0.00012130005091921945 * Y + 0.04947614690774899
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0714032003238345
# The direction of the gradient is: 303.079233480853
# 25
# The equation of the fit plane is: Z = -5.2163128526580785e-05 * X + -0.00011198349623160992 * Y + 0.023397179252774618
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6368801285181849
# The direction of the gradient is: 281.78879392707495
# 26
# The equation of the fit plane is: Z = -0.00012298787798008 * X + -3.780241625864514e-05 * Y + 0.029277530538564463
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.956185975197476
# The direction of the gradient is: 325.5494959963263
# 27
# The equation of the fit plane is: Z = -4.932366660140441e-05 * X + -9.13833911481546e-05 * Y + 0.021054015085399443
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3452830656444892
# The direction of the gradient is: 283.5949788035508
# 28
# The equation of the fit plane is: Z = -8.72185179930135e-05 * X + -0.0001194354528827847 * Y + 0.029628920689926615
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7981346242153273
# The direction of the gradient is: 288.11767069413054
# 29
# The equation of the fit plane is: Z = -9.971025767027558e-05 * X + -0.00011392408845082566 * Y + 0.03493158245625366
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.750982022752369
# The direction of the gradient is: 291.41258354838055
# 30
# The equation of the fit plane is: Z = -1.824684600720826e-05 * X + -0.00014874366077743904 * Y + 0.02758050499535845
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.1315618165562453
# The direction of the gradient is: 273.1460248241915
# 31
# The equation of the fit plane is: Z = -7.655506640623613e-05 * X + -0.00019784306731223005 * Y + 0.04531749707886597
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.873135622083858
# The direction of the gradient is: 279.83573871331055
# 32
# The equation of the fit plane is: Z = 5.88071133293539e-06 * X + -0.00038446162121736575 * Y + 0.04383334224246877
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.501329305547614
# The direction of the gradient is: 269.607337309061
# 33
# The equation of the fit plane is: Z = -5.095070816966716e-05 * X + -0.00033390765579173536 * Y + 0.05512893648926519
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.788984579548432
# The direction of the gradient is: 273.91109290956985
# 34
# The equation of the fit plane is: Z = 0.00034138981045048677 * X + -0.00026693844804358166 * Y + -0.019176410934571328
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.402215617098892
# The direction of the gradient is: 240.18662317647897
# 35
# The equation of the fit plane is: Z = 0.00033010516575265176 * X + -0.00037174877346868047 * Y + 0.0029149916643509822
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.724836061186331
# The direction of the gradient is: 248.30439490592755
# 36
# The equation of the fit plane is: Z = 0.0006839799623913145 * X + 0.00044952035372142495 * Y + -0.19009796748123303
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.784650799767225
# The direction of the gradient is: 124.2839527041466
# 37
# The equation of the fit plane is: Z = 0.00030165315941621247 * X + -0.00017565745985380045 * Y + -0.028274197508327933
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.1713583523463402
# The direction of the gradient is: 232.42429440243563
# 38
# The equation of the fit plane is: Z = 0.00041869407566165484 * X + 0.00019469351863588287 * Y + -0.11009664182493198
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.868626167691157
# The direction of the gradient is: 133.93639080079828
# 39
# The equation of the fit plane is: Z = 0.00016953329805265564 * X + -6.597284140117394e-05 * Y + -0.029525917320280207
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.439604316332529
# The direction of the gradient is: 220.97519133537992
# 40
# The equation of the fit plane is: Z = 0.00011962242717514987 * X + -0.00012038585863761166 * Y + -0.0037524126881163062
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8855871445915167
# The direction of the gradient is: 246.00093458433378
# 41
# The equation of the fit plane is: Z = 0.00015850935164806539 * X + 8.854994864074356e-05 * Y + -0.04545689884110581
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.624224285197708
# The direction of the gradient is: 128.73084573527512
# 42
# The equation of the fit plane is: Z = 0.00018357336492656103 * X + 1.8330904661608187e-05 * Y + -0.030777072529730595
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2057782851695045
# The direction of the gradient is: 167.4359498001926
# 43
# The equation of the fit plane is: Z = 2.7227110029233204e-05 * X + -6.37100349672749e-05 * Y + 0.0016619761575464645
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9281781227613364
# The direction of the gradient is: 259.1602796836921
# 44
# The equation of the fit plane is: Z = 7.528343608069868e-05 * X + -0.0001125321962963206 * Y + 0.001955495938158121
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6809849663585574
# The direction of the gradient is: 253.31424686769697
# 45
# The equation of the fit plane is: Z = 8.296194291876493e-05 * X + -0.00028226028803679174 * Y + 0.026395142700841024
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.073688607020912
# The direction of the gradient is: 262.4978319931852
# 46
# The equation of the fit plane is: Z = -1.7549537824279748e-05 * X + -0.0003176220524404493 * Y + 0.051702216605820105
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.546195828665077
# The direction of the gradient is: 271.4181295521564
# 47
# The equation of the fit plane is: Z = 6.875302188677464e-05 * X + -5.138597549860043e-05 * Y + -0.0010194924084320745
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8572722106971895
# The direction of the gradient is: 239.05818922048718
# 48
# The equation of the fit plane is: Z = -8.387823993579866e-05 * X + -0.0002277628638491239 * Y + 0.046103738434148785
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.3030899787132895
# The direction of the gradient is: 279.36958400748165
# 49
# The equation of the fit plane is: Z = -0.0001374306176270587 * X + -0.00014302987576004638 * Y + 0.044018521315497036
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.2281916391890197
# The direction of the gradient is: 293.29238185895076
# 50
# The equation of the fit plane is: Z = -4.9430893028798824e-05 * X + -0.0001653195801019499 * Y + 0.030327474634586717
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.3866647482935517
# The direction of the gradient is: 277.6303693893981
# 51
# The equation of the fit plane is: Z = -7.273543494476955e-05 * X + -5.164189766643476e-05 * Y + 0.019128214845306402
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8737698050576762
# The direction of the gradient is: 302.2543921004327
# 52
# The equation of the fit plane is: Z = -6.0547235980642025e-05 * X + -0.00011613689821694134 * Y + 0.028938303165456317
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.706518643173941
# The direction of the gradient is: 283.1478742933149
# 53
# The equation of the fit plane is: Z = -0.00015166875588508506 * X + -2.7659019547376746e-05 * Y + 0.03084209085594267
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0498183352584898
# The direction of the gradient is: 337.85278728251706
# 54
# The equation of the fit plane is: Z = -5.805388188651948e-05 * X + -0.00014091522081722643 * Y + 0.036168398387915524
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0503962277931285
# The direction of the gradient is: 280.45831716700485
# 55
# The equation of the fit plane is: Z = -0.00013236369636640362 * X + -6.238386196285251e-05 * Y + 0.032222585579789326
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2316331965261218
# The direction of the gradient is: 313.55096033314265
# 56
# The equation of the fit plane is: Z = -9.966651345903232e-05 * X + -5.563277432532e-05 * Y + 0.026196044981811262
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.020766133809311
# The direction of the gradient is: 308.7535115626206
# 57
# The equation of the fit plane is: Z = -0.00013635391188317818 * X + -6.391618853105585e-05 * Y + 0.03833191066209226
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2651545619076654
# The direction of the gradient is: 313.70646414405127
# 58
# The equation of the fit plane is: Z = -0.00013553331445434618 * X + -2.022215331898492e-05 * Y + 0.030303239541696017
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9158277412050999
# The direction of the gradient is: 341.58183945309986
# 59
# The equation of the fit plane is: Z = -0.0001313954055891824 * X + -7.49823597883334e-05 * Y + 0.037482720732060194
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3640941391233217
# The direction of the gradient is: 308.136934623439
# 60
# The equation of the fit plane is: Z = -0.0001371025639087253 * X + -8.047228276347312e-05 * Y + 0.03942092704919818
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4486098327145358
# The direction of the gradient is: 307.35646206404687
# 61
# The equation of the fit plane is: Z = -0.00010216929487456956 * X + -0.00012366560788455876 * Y + 0.043721174188763624
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.886853631580621
# The direction of the gradient is: 290.3129193984993
# 62
# The equation of the fit plane is: Z = -2.010951538333225e-05 * X + -0.0001367863245809716 * Y + 0.025688840508070247
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.961495227091563
# The direction of the gradient is: 273.76861317975397
# 63
# The equation of the fit plane is: Z = -5.7182127078337994e-05 * X + -7.363391857316712e-05 * Y + 0.020045041753091814
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.115572405826522
# The direction of the gradient is: 289.18503369508306
# 64
# The equation of the fit plane is: Z = -0.0001336162873966531 * X + -5.934359784103124e-05 * Y + 0.0367924881780438
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2061683271647132
# The direction of the gradient is: 315.25148293920773
# 65
# The equation of the fit plane is: Z = -3.869198458839119e-05 * X + -0.00010747216519424454 * Y + 0.026454885438346145
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5576802699467729
# The direction of the gradient is: 279.1632520205069
# 66
# The equation of the fit plane is: Z = -0.00012831817655213293 * X + -0.00010969682789699822 * Y + 0.04401975215453957
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.772151014463292
# The direction of the gradient is: 297.6594071617506
# 67
# The equation of the fit plane is: Z = 0.0001198540815782329 * X + 3.950926298903049e-06 * Y + -0.019973926206774188
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7704712973419506
# The direction of the gradient is: 175.79215227302757
# 68
# The equation of the fit plane is: Z = 0.0002098246999314417 * X + 5.9741354487443695e-05 * Y + -0.04573866764693334
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5938337601460109
# The direction of the gradient is: 147.56547706536128
# 69
# The equation of the fit plane is: Z = 7.13446874852758e-05 * X + -0.0001812905774784679 * Y + 0.011814387609469698
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.634074537460131
# The direction of the gradient is: 260.00012243410606
# 70
# The equation of the fit plane is: Z = 0.00018934102466749438 * X + 7.501566604458381e-05 * Y + -0.047732591496481784
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6203910581285879
# The direction of the gradient is: 138.51493507632836
# 71
# The equation of the fit plane is: Z = 0.00020871506047979795 * X + -0.00011689567799208898 * Y + -0.01607097981978432
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.1420115949907097
# The direction of the gradient is: 231.34068834164395
# 72
# The equation of the fit plane is: Z = 0.00028240796381036917 * X + 0.00013411324260002126 * Y + -0.06459665321693975
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.638302192950339
# The direction of the gradient is: 133.33417011048311
# 73
# The equation of the fit plane is: Z = 0.00031164072548433755 * X + 0.00021412619470502083 * Y + -0.08906618367666295
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.6577712919176824
# The direction of the gradient is: 123.10819829381467
# 74
# The equation of the fit plane is: Z = 1.1042739082970083e-05 * X + -0.00010692067212241378 * Y + 0.015274721779835994
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5315480191288329
# The direction of the gradient is: 267.3505544573717
# 75
# The equation of the fit plane is: Z = -7.1933316246344876e-06 * X + -0.00015389730590502785 * Y + 0.023024874800965687
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.2025748905125404
# The direction of the gradient is: 271.19973451983185
# 76
# The equation of the fit plane is: Z = 0.0002276355618169406 * X + -7.84845051352095e-05 * Y + -0.04067709928585912
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8414666731529954
# The direction of the gradient is: 217.57880835113042
# 77
# The equation of the fit plane is: Z = -3.48336213454142e-05 * X + -5.697316708895479e-05 * Y + 0.013794103673941975
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8452549795674497
# The direction of the gradient is: 285.31976406836657
# 78
# The equation of the fit plane is: Z = 0.0001292726420697128 * X + -0.00011801788651009255 * Y + -0.0023565550161755693
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8811106121077947
# The direction of the gradient is: 243.8591779478877
# 79
# The equation of the fit plane is: Z = -0.00012255785107345905 * X + -7.052856790253842e-05 * Y + 0.03475921519390408
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2789909037145952
# The direction of the gradient is: 307.903596575018
# 80
# The equation of the fit plane is: Z = 0.0 * X + 0.0 * Y + 5e-324
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0
# The direction of the gradient is: 90.0
# 81
# The equation of the fit plane is: Z = 5.1383582204789525e-05 * X + -8.16075293467383e-05 * Y + 0.005727329454947314
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2132868895258944
# The direction of the gradient is: 254.24562024993645
# 82
# The equation of the fit plane is: Z = -1.0906181979600294e-05 * X + -3.4487448246173296e-05 * Y + 0.007481925122755825
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4984042965001365
# The direction of the gradient is: 278.06454603264893
# 83
# The equation of the fit plane is: Z = -5.837384922162901e-05 * X + 8.131555458308424e-07 * Y + 0.011488800289135738
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3744204121948379
# The direction of the gradient is: 1.780783478372598
# 84
# The equation of the fit plane is: Z = 0.0001279481179403269 * X + 7.249185488736697e-06 * Y + -0.025035065862437825
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8268182822038406
# The direction of the gradient is: 172.79304091059885
# 85
# The equation of the fit plane is: Z = 1.5397877223189134e-05 * X + -1.9819411057057117e-05 * Y + 0.0017918130765228973
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.30028308891435923
# The direction of the gradient is: 250.80727877380002
# 86
# The equation of the fit plane is: Z = -7.447910585931542e-05 * X + -2.604062862491977e-05 * Y + 0.017171816137838095
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6056710750925933
# The direction of the gradient is: 322.03326239682394
# 87
# The equation of the fit plane is: Z = 5.434721114185678e-05 * X + -4.765087970183757e-05 * Y + -0.004596856909692635
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7656958877457309
# The direction of the gradient is: 242.93230595725277
# 88
# The equation of the fit plane is: Z = 8.888939376306771e-05 * X + -9.795597525764248e-06 * Y + -0.01741244008531872
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5868610948331703
# The direction of the gradient is: 193.8178592451469
# 89
# The equation of the fit plane is: Z = 3.9542355322283195e-05 * X + -9.412021060356573e-05 * Y + 0.007981309997639697
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3704034125018634
# The direction of the gradient is: 259.33951922480924
# 90
# The equation of the fit plane is: Z = 1.7957836640587485e-05 * X + -0.00021503872082764394 * Y + 0.028301098724319976
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.079107930635192
# The direction of the gradient is: 267.85718652136643
# 91
# The equation of the fit plane is: Z = 0.0001040929588806964 * X + -0.00018423430791266926 * Y + 0.013081425655971339
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.719337386004854
# The direction of the gradient is: 255.7940223653768
# 92
# The equation of the fit plane is: Z = 0.00010716088926428968 * X + -0.00013101731490666044 * Y + 0.0020547259407578708
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.996625907423212
# The direction of the gradient is: 249.87379523128072
# 93
# The equation of the fit plane is: Z = 0.00042838565706281235 * X + -0.00018724980192615388 * Y + -0.03187950314245686
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.8368733117594274
# The direction of the gradient is: 224.29158425070216
# 94
# The equation of the fit plane is: Z = 0.00023409635984496154 * X + -9.137189238722667e-05 * Y + -0.026729248315521918
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.9904262062991303
# The direction of the gradient is: 221.06062595359208
# 95
# The equation of the fit plane is: Z = 5.5463359813918936e-05 * X + -0.00025275329795313643 * Y + 0.025664686908337273
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.6340447483438787
# The direction of the gradient is: 264.38479831331995
# 96
# The equation of the fit plane is: Z = -0.00013638677176638935 * X + -0.00026322053328271735 * Y + 0.06634927477905377
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.8665457412992654
# The direction of the gradient is: 283.07001816429863
# 97
# The equation of the fit plane is: Z = -9.384764204341825e-05 * X + -0.0003245359109126344 * Y + 0.07051435543046686
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.682547798147457
# The direction of the gradient is: 277.38239866868184
# 98
# The equation of the fit plane is: Z = -0.00017058665722422 * X + -0.00015315308169401074 * Y + 0.055565603258682164
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.449179958512815
# The direction of the gradient is: 296.5216055789499
# 99
# The equation of the fit plane is: Z = -7.065472276673214e-05 * X + -0.0001229271700900662 * Y + 0.03366724837370335
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.816335146781624
# The direction of the gradient is: 284.4413356350906
# 100
# The equation of the fit plane is: Z = -0.00014498426762793307 * X + -2.4568884184028246e-05 * Y + 0.031979344707186205
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9937658994203233
# The direction of the gradient is: 339.28267951347414
# 101
# The equation of the fit plane is: Z = -0.00013447867228450015 * X + -9.298877390529872e-05 * Y + 0.044306242497499565
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5854663086948502
# The direction of the gradient is: 302.94172156785396
# 102
# The equation of the fit plane is: Z = -0.00012508517494851473 * X + -7.9480712137298e-05 * Y + 0.036743149940319415
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3915791880771444
# The direction of the gradient is: 305.1889258342736
# 103
# The equation of the fit plane is: Z = -0.00010485997914790453 * X + -7.201663692832927e-06 * Y + 0.021012201799771788
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6801179072816023
# The direction of the gradient is: 351.28531839110934
# 104
# The equation of the fit plane is: Z = -0.0001278576340726435 * X + -4.662234955825687e-05 * Y + 0.02950977706671407
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0568613212361533
# The direction of the gradient is: 320.85982652431375
# 105
# The equation of the fit plane is: Z = -0.00013286914208331563 * X + -6.812563391588971e-05 * Y + 0.03329878515818813
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.294548487112401
# The direction of the gradient is: 311.14882224373923
# 106
# The equation of the fit plane is: Z = -0.0001843205068952618 * X + -3.3705485323339036e-05 * Y + 0.04356650322938785
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2763232289320836
# The direction of the gradient is: 337.7980872795363
# 107
# The equation of the fit plane is: Z = -0.00012046992683498266 * X + -4.529517970380546e-05 * Y + 0.026896122148055514
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.008253295783546
# The direction of the gradient is: 319.99786445047926
# 108
# The equation of the fit plane is: Z = -0.0001555887857448109 * X + -3.7497205965319687e-05 * Y + 0.036193494750823375
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1326377632697169
# The direction of the gradient is: 331.7246249760932
# 109
# The equation of the fit plane is: Z = -0.0001675160383353629 * X + 1.4077973997251997e-05 * Y + 0.028290108909130286
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0926876132225105
# The direction of the gradient is: 10.623373144091772
# 110
# The equation of the fit plane is: Z = -0.00012336068958422169 * X + -7.872855422948084e-05 * Y + 0.0356541851626732
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.37641519215456
# The direction of the gradient is: 305.07098533318265
# 111
# The equation of the fit plane is: Z = -0.0001886271809116644 * X + -3.596694683759512e-05 * Y + 0.040629565094560005
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3142591532313563
# The direction of the gradient is: 336.946787045999
# 112
# The equation of the fit plane is: Z = -0.00013082454784847192 * X + -0.00016018692465936434 * Y + 0.044498111755924684
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.440724458573584
# The direction of the gradient is: 290.0987098616007
# 113
# The equation of the fit plane is: Z = -0.00014411130554657515 * X + -0.0001104398951292755 * Y + 0.042203648120376115
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8305333049135026
# The direction of the gradient is: 300.3128666370899
# 114
# The equation of the fit plane is: Z = -0.00014757824305739267 * X + -0.00011961612881098987 * Y + 0.04072370433930679
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.9556685469905282
# The direction of the gradient is: 298.93334243815013
# 115
# The equation of the fit plane is: Z = -0.0001421857855829918 * X + -5.933839345521622e-05 * Y + 0.035224101070747756
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2457365313547506
# The direction of the gradient is: 317.03311105508544
# 116
# The equation of the fit plane is: Z = -0.0001572070276313579 * X + -1.6770060505334522e-06 * Y + 0.031547225518038104
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.008152890193999
# The direction of the gradient is: 358.6361194739141
# 117
# The equation of the fit plane is: Z = -0.00011041552697996321 * X + -0.00015072654722709353 * Y + 0.043077248180126135
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.2699226750607018
# The direction of the gradient is: 288.1709601060086
# 118
# The equation of the fit plane is: Z = -0.00014899562587405722 * X + -5.249792293141575e-05 * Y + 0.03866362176119134
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2152076278982458
# The direction of the gradient is: 321.81860744871113
# 119
# The equation of the fit plane is: Z = -9.567968049219005e-05 * X + -7.862138137080268e-06 * Y + 0.021781295619775407
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.623640988853346
# The direction of the gradient is: 349.60757111800393
# 120
# The equation of the fit plane is: Z = -0.00015719877038141488 * X + -0.00013615563123867797 * Y + 0.05081678222955133
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.1934645948257168
# The direction of the gradient is: 297.3524175602967
# 121
# The equation of the fit plane is: Z = -5.229866604086542e-05 * X + -0.0001642322849440865 * Y + 0.03789677342636917
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.3737725432360706
# The direction of the gradient is: 278.1200801530433
# 122
# The equation of the fit plane is: Z = -3.680425466525533e-06 * X + -0.00020923826945354633 * Y + 0.030176602558791576
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.994050055122853
# The direction of the gradient is: 270.45154130676553
# 123
# The equation of the fit plane is: Z = -0.00011316305034423051 * X + -3.946907891772732e-05 * Y + 0.029843096352580135
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9194004016293696
# The direction of the gradient is: 322.1013658458304
# 124
# The equation of the fit plane is: Z = -0.00018516284678071144 * X + -6.482112265729622e-05 * Y + 0.04672404485005492
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5064784387114019
# The direction of the gradient is: 321.9983404710736
# 125
# The equation of the fit plane is: Z = 1.2287852635897127e-05 * X + -8.74640936123035e-05 * Y + 0.013600829975409012
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2539867586521174
# The direction of the gradient is: 266.39817054135153
# 126
# The equation of the fit plane is: Z = 0.00024271782265092252 * X + 9.389432921175702e-05 * Y + -0.0570182516281606
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0558309573470446
# The direction of the gradient is: 139.19275784731008
# 127
# The equation of the fit plane is: Z = 2.8239054662187796e-05 * X + -0.00011335574403105111 * Y + 0.013263608826393429
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6320618235490056
# The direction of the gradient is: 263.631131291398
# 128
# The equation of the fit plane is: Z = 0.0002902257521161046 * X + -0.00016098314289726568 * Y + -0.021709163310102603
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.961096188811245
# The direction of the gradient is: 231.07010043330877
# 129
# The equation of the fit plane is: Z = 7.989854449235718e-05 * X + -0.00031291834071825637 * Y + 0.036730773938840645
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.506703960115771
# The direction of the gradient is: 263.4736041409435
# 130
# The equation of the fit plane is: Z = 0.0003923389937129938 * X + -0.00010109752876459177 * Y + -0.05709264168476655
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.901627415115056
# The direction of the gradient is: 209.90370713206846
# 131
# The equation of the fit plane is: Z = 0.0001879854475781342 * X + -0.00012004965320732997 * Y + -0.01480435457047313
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0983855880316704
# The direction of the gradient is: 234.94645836226505
# 132
# The equation of the fit plane is: Z = 0.00012149594137194081 * X + -0.00020865969899004313 * Y + 0.015314597838790413
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.085610596102933
# The direction of the gradient is: 255.37826510888397
# 133
# The equation of the fit plane is: Z = 3.46142975907596e-05 * X + -4.967001870303102e-05 * Y + 0.00359393893299919
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7445601347301374
# The direction of the gradient is: 252.65956301276162
# 134
# The equation of the fit plane is: Z = 6.595959210348291e-05 * X + -0.00027722734404630735 * Y + 0.030176782589560115
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.989277947390962
# The direction of the gradient is: 263.9150869103646
# 135
# The equation of the fit plane is: Z = 6.487168148265222e-06 * X + -8.451781374296702e-05 * Y + 0.018814880415461394
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.210066865539248
# The direction of the gradient is: 268.03036684253937
# 136
# The equation of the fit plane is: Z = 0.00010819507582610626 * X + 5.388351536204394e-06 * Y + -0.020504118236326217
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6979194476618743
# The direction of the gradient is: 173.65743312649806
# 137
# The equation of the fit plane is: Z = -0.00011996472442100779 * X + -0.00013452282286637298 * Y + 0.038343543376756856
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.072831011592363
# The direction of the gradient is: 291.7797878939603
# 138
# The equation of the fit plane is: Z = 7.513652892151396e-05 * X + -3.238974590181206e-05 * Y + -0.004290233753594003
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6684579792059993
# The direction of the gradient is: 223.89402058078554
# 139
# The equation of the fit plane is: Z = 0.00022337402134045293 * X + 4.172918713919741e-05 * Y + -0.04765496112839693
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5515626341412658
# The direction of the gradient is: 157.36647525338321
# 140
# The equation of the fit plane is: Z = -5.996203004757029e-05 * X + -2.3928170683185273e-05 * Y + 0.015348562235386434
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5147882935712426
# The direction of the gradient is: 318.31019769160184
# 141
# The equation of the fit plane is: Z = 7.401670985222534e-05 * X + -4.459789915770406e-05 * Y + -0.008227155578594407
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7952384452638924
# The direction of the gradient is: 233.365322583644
# 142
# The equation of the fit plane is: Z = -6.535779012518985e-06 * X + 4.650986353195111e-05 * Y + -0.004471892138701461
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6668200269902698
# The direction of the gradient is: 86.39729281108004
# 143
# The equation of the fit plane is: Z = 0.00014449185632155244 * X + 5.625355545577943e-05 * Y + -0.03505540543275782
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2272017973819935
# The direction of the gradient is: 139.01197872221223
# 144
# The equation of the fit plane is: Z = 7.077133133317534e-05 * X + -8.684556825448661e-05 * Y + -0.0018317155437269819
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.322900232586475
# The direction of the gradient is: 249.94180761861946
# 145
# The equation of the fit plane is: Z = -2.4908329642910824e-05 * X + -0.0001649547949163324 * Y + 0.027701320086840064
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.365707700311857
# The direction of the gradient is: 273.87050740208997
# 146
# The equation of the fit plane is: Z = 0.00023500695844353488 * X + -5.6775374956367575e-05 * Y + -0.02876794299424087
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7117151094914869
# The direction of the gradient is: 208.33368225712024
# 147
# The equation of the fit plane is: Z = 3.1162256880569046e-05 * X + -0.00010556575153141548 * Y + 0.011973551566961721
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5236780826197798
# The direction of the gradient is: 262.4657150261138
# 148
# The equation of the fit plane is: Z = 0.0002235209725323615 * X + -0.00010509642921650737 * Y + -0.016050396646016346
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0772483177864767
# The direction of the gradient is: 226.38093643515333
# 149
# The equation of the fit plane is: Z = 0.00022509275037093464 * X + -0.00023180056397190246 * Y + -0.009124404940862266
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.617132627921812
# The direction of the gradient is: 246.48687214422455
# 150
# The equation of the fit plane is: Z = 0.00019834138316674472 * X + -0.0001789342714782776 * Y + -0.009903737975838892
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.8587190402381464
# The direction of the gradient is: 243.58890138454854
# 151
# The equation of the fit plane is: Z = 0.0002903893875603556 * X + 0.00014248181651387243 * Y + -0.07426355375147792
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.760881324618049
# The direction of the gradient is: 132.40116751804635
# 152
# The equation of the fit plane is: Z = 1.6836834753474185e-05 * X + -0.00019430519253372052 * Y + 0.028752546324776928
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.782376659014245
# The direction of the gradient is: 267.7766514725877
# 153
# The equation of the fit plane is: Z = 1.757466945954315e-05 * X + -0.00017448074898816765 * Y + 0.027459183670412012
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.4991584251306302
# The direction of the gradient is: 267.41598737569745
# 154
# The equation of the fit plane is: Z = 4.05451447827652e-05 * X + -0.00022705891284079626 * Y + 0.03000380269612725
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.2593316621609945
# The direction of the gradient is: 265.425688065264
# 155
# The equation of the fit plane is: Z = -0.00010936709339929954 * X + -0.00013819936179745398 * Y + 0.042067130565199964
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0981004655505586
# The direction of the gradient is: 289.52321153092396
# 156
# The equation of the fit plane is: Z = -0.00013649887992387777 * X + -0.00030307979263282547 * Y + 0.07977212073091382
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.424133187040146
# The direction of the gradient is: 281.4084980109295
# 157
# The equation of the fit plane is: Z = -0.00015609182750646252 * X + -2.1869585745725026e-05 * Y + 0.033008990173318
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0485036850814435
# The direction of the gradient is: 342.63532685070254
# 158
# The equation of the fit plane is: Z = -0.00015751149686194326 * X + -0.00019499252253304286 * Y + 0.057701208230346995
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.967235672413794
# The direction of the gradient is: 289.8965686767341
# 159
# The equation of the fit plane is: Z = -0.00011744394495215223 * X + -0.0002503929589491763 * Y + 0.054427922221189334
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.661094792939582
# The direction of the gradient is: 281.86817116373743
# 160
# The equation of the fit plane is: Z = -0.00010604183180300672 * X + -6.656320736813623e-05 * Y + 0.029478974770669103
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1701849677681948
# The direction of the gradient is: 305.51883263081436
# 161
# The equation of the fit plane is: Z = -0.00019413511647568775 * X + -8.783140504199346e-05 * Y + 0.05393491381533564
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.768764965115812
# The direction of the gradient is: 314.72171505801373
# 162
# The equation of the fit plane is: Z = -0.00014359939556699851 * X + -3.406823214733554e-05 * Y + 0.034046145424026036
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0417240261872407
# The direction of the gradient is: 332.09855747704285
# 163
# The equation of the fit plane is: Z = -0.00013844217415657633 * X + -7.477206208368441e-05 * Y + 0.03930173457196218
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.390129335684597
# The direction of the gradient is: 309.678273709476
# 164
# The equation of the fit plane is: Z = -0.00011989723080065644 * X + -2.8907690507745126e-06 * Y + 0.024242953785697137
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7697831948909062
# The direction of the gradient is: 356.91978332109073
# 165
# The equation of the fit plane is: Z = -0.00014116754537274332 * X + -3.3053042976222404e-05 * Y + 0.03246913734467571
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0211630846358872
# The direction of the gradient is: 332.40950161767927
# 166
# The equation of the fit plane is: Z = -2.293416952903825e-05 * X + -6.246477733597647e-05 * Y + 0.01863875087771144
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9058115219163505
# The direction of the gradient is: 279.3416813829743
# 167
# The equation of the fit plane is: Z = -0.00016284577029012585 * X + 1.0023286628661424e-05 * Y + 0.02938644189667613
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0538229254766398
# The direction of the gradient is: 7.822029966672062
# 168
# The equation of the fit plane is: Z = -0.0001278330395376352 * X + -0.00010048365031425569 * Y + 0.04154355037937818
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6549746779309564
# The direction of the gradient is: 299.68312842616075
# 169
# The equation of the fit plane is: Z = -0.0001483220147122369 * X + -3.6860734246173515e-05 * Y + 0.03327197773332791
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0873853080297318
# The direction of the gradient is: 330.98436417832323
# 170
# The equation of the fit plane is: Z = -8.420511513203899e-05 * X + 3.4195756582239263e-07 * Y + 0.01786643679429709
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5398681408267322
# The direction of the gradient is: 0.5192990720498756
# 171
# The equation of the fit plane is: Z = -0.00015677863223942387 * X + -8.990812832713872e-05 * Y + 0.043080093637722465
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6325750858020092
# The direction of the gradient is: 308.00032108554365
# 172
# The equation of the fit plane is: Z = -0.0001273626513549687 * X + -5.767455187174738e-05 * Y + 0.03408070333153801
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.160936157993334
# The direction of the gradient is: 314.6955676864404
# 173
# The equation of the fit plane is: Z = -0.00018967428689304727 * X + -6.393519343252434e-05 * Y + 0.04703081462930119
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5217188289436256
# The direction of the gradient is: 323.0449988197746
# 174
# The equation of the fit plane is: Z = -0.00012031715920839096 * X + -5.936280361713766e-05 * Y + 0.030498756705990608
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1473898983237543
# The direction of the gradient is: 312.2430107184615
# 175
# The equation of the fit plane is: Z = -0.00015352505624682106 * X + -0.00017738887249527566 * Y + 0.052047873302561845
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.722384708153655
# The direction of the gradient is: 291.1950485127102
# 176
# The equation of the fit plane is: Z = -0.00015007119087641796 * X + -9.04797665292876e-05 * Y + 0.042186472287354136
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.613015388486581
# The direction of the gradient is: 306.61765302380314
# 177
# The equation of the fit plane is: Z = -8.135822982428387e-05 * X + 4.568729139431538e-06 * Y + 0.012569214047878226
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5256751114869362
# The direction of the gradient is: 7.143826755471878
# 178
# The equation of the fit plane is: Z = -1.4993427288199779e-05 * X + -0.00011560885058560524 * Y + 0.03013177684104595
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6570190747550306
# The direction of the gradient is: 273.32560995269637
# 179
# The equation of the fit plane is: Z = -0.00015290548132728977 * X + -0.0001298040859589023 * Y + 0.04972422194010041
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.100167148437273
# The direction of the gradient is: 297.8246696980899
# 180
# The equation of the fit plane is: Z = -7.124178535989876e-06 * X + -0.00015524043448984066 * Y + 0.03006983871467887
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.221780168698946
# The direction of the gradient is: 271.1779268510319
# 181
# The equation of the fit plane is: Z = -1.6301128637130087e-05 * X + -7.916140507498723e-05 * Y + 0.01845689662249715
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1375188675347443
# The direction of the gradient is: 275.271399689527
# 182
# The equation of the fit plane is: Z = -6.996988221886512e-05 * X + -0.0001196085263386723 * Y + 0.03211679750082199
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7692709166832785
# The direction of the gradient is: 284.687149476587
# 183
# The equation of the fit plane is: Z = -3.783553356564996e-05 * X + -0.0002431382510115647 * Y + 0.04295432649538848
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.487472454349549
# The direction of the gradient is: 273.98835571280995
# 184
# The equation of the fit plane is: Z = 6.754453291262969e-06 * X + -0.00033369282508594484 * Y + 0.048475333480106235
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.774953855915708
# The direction of the gradient is: 269.4803858173143
# 185
# The equation of the fit plane is: Z = 2.907257972541307e-05 * X + -0.00021356470633279102 * Y + 0.028900205551231184
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.06154225353594
# The direction of the gradient is: 266.5096741501691
# 186
# The equation of the fit plane is: Z = -2.9113417623789575e-05 * X + -0.00011173419347299417 * Y + 0.02181160464748594
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6096449444253944
# The direction of the gradient is: 276.6587881604553
# 187
# The equation of the fit plane is: Z = 0.00019088535302588206 * X + -1.8562959329493844e-05 * Y + -0.02599762855609861
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2522751039507722
# The direction of the gradient is: 192.24576815109367
# 188
# The equation of the fit plane is: Z = 0.00026868814642838314 * X + -8.435148188239807e-05 * Y + -0.02560936987456725
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.103347290739907
# The direction of the gradient is: 215.01800844050956
# 189
# The equation of the fit plane is: Z = 0.00017225418968832006 * X + -9.246896618879596e-05 * Y + -0.013686937280935318
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7234309050071408
# The direction of the gradient is: 230.15017423380755
# 190
# The equation of the fit plane is: Z = 0.00016434213808116658 * X + -0.00017297695842881876 * Y + 0.006964464588876106
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.690021384170221
# The direction of the gradient is: 246.94130800741993
# 191
# The equation of the fit plane is: Z = 0.00019864500896431207 * X + -0.00027920050408692943 * Y + 0.00626686296080004
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.19311181772175
# The direction of the gradient is: 252.31886062666126
# 192
# ...
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.239983310041663
# The direction of the gradient is: 256.6288400869091
# 255
# The equation of the fit plane is: Z = 8.320968386352913e-05 * X + -0.00021028670686905687 * Y + 0.015289293102836752
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.055882573134679
# The direction of the gradient is: 259.94638798786457
# 256
# The equation of the fit plane is: Z = -1.308826721346403e-06 * X + -7.795921363662253e-05 * Y + 0.009032855357193533
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.115537532173838
# The direction of the gradient is: 270.4309789724576
# 257
# The equation of the fit plane is: Z = 0.0002207349684243893 * X + -0.00018645272072286012 * Y + -0.011655798210450805
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.020009822502995
# The direction of the gradient is: 242.0571099874527
# 258
# The equation of the fit plane is: Z = 6.437300935415668e-05 * X + -0.00021474036549943052 * Y + 0.02044425589147536
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.100277283968376
# The direction of the gradient is: 262.3502306170651
# 259
# The equation of the fit plane is: Z = 0.0005557924488667558 * X + -0.00044867786826034917 * Y + -0.02134938512210092
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.34260108614286
# The direction of the gradient is: 240.96905650334043
# 260
# The equation of the fit plane is: Z = 0.0005550103132906238 * X + -0.0004477146481490113 * Y + -0.021376877899038065
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.328117190939317
# The direction of the gradient is: 240.9510415768425
# 261
# The equation of the fit plane is: Z = 0.000600692901591659 * X + -0.00043453295866153346 * Y + -0.023982068571852377
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.313702289856571
# The direction of the gradient is: 238.22678145842406
# 262
# The equation of the fit plane is: Z = 0.0005122185285647338 * X + -0.00022903206379282183 * Y + -0.042338484587489886
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.639371537646412
# The direction of the gradient is: 224.941560085
# 263
# The equation of the fit plane is: Z = 0.0006715468703291993 * X + -0.00044882480414939433 * Y + -0.035350728811011076
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.731762284703119
# The direction of the gradient is: 236.1625630903775
# 264
# The equation of the fit plane is: Z = 0.0005591054701899711 * X + -0.0006994299829700899 * Y + 0.020746277998076032
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 10.630575958141065
# The direction of the gradient is: 250.29453432077412
# 265
# The equation of the fit plane is: Z = 0.0002047323433148817 * X + -0.0006916455778481915 * Y + 0.07680361873614114
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 9.98330676235565
# The direction of the gradient is: 262.4451604091363
# 266
# The equation of the fit plane is: Z = 0.0002834435327866782 * X + -0.0004948274308101525 * Y + 0.0403740526098571
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.30987722365071
# The direction of the gradient is: 255.60576637756867
# 267
# The equation of the fit plane is: Z = 0.0006078972873372225 * X + -0.00023247678314337381 * Y + -0.0563846950080684
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.123886676509403
# The direction of the gradient is: 220.48198926809835
# 268
# The equation of the fit plane is: Z = 0.00023841041044112048 * X + -0.0002594158738762999 * Y + 0.013630148044883288
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.014314248427619
# The direction of the gradient is: 247.61956368282006
# 269
# The equation of the fit plane is: Z = 0.00015659449477909652 * X + -0.00022178500842807655 * Y + 0.02060577096172452
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.3284999328282128
# The direction of the gradient is: 252.44510376227674
# 270
# The equation of the fit plane is: Z = 0.00015225063345192686 * X + -0.0002186756568669904 * Y + 0.025015185681806554
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.2777072961186433
# The direction of the gradient is: 252.67466584509054
# 271
# The equation of the fit plane is: Z = 0.00029024613476137884 * X + -0.00021107560436731766 * Y + -0.01817069084580731
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.5474554413635473
# The direction of the gradient is: 238.3625339700842
# 272
# The equation of the fit plane is: Z = 0.00017163810347975347 * X + -0.00030304085351973435 * Y + 0.028715970234979522
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.473607253980596
# The direction of the gradient is: 255.76066433343215
# 273
# The equation of the fit plane is: Z = 2.4970508331559164e-05 * X + -0.00022205211958148302 * Y + 0.040886820918520354
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.1813388620871987
# The direction of the gradient is: 267.1156037029933
# 274
# The equation of the fit plane is: Z = 0.0001339740260226179 * X + -0.0003126967845081549 * Y + 0.03901055217303525
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.556024209772072
# The direction of the gradient is: 259.13335800765424
# 275
# The equation of the fit plane is: Z = 0.0003024371509618313 * X + -0.0002882779890643735 * Y + -0.0018883451396099345
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.557907668749706
# The direction of the gradient is: 244.82379719604535
# 276
# The equation of the fit plane is: Z = 0.0007723948545910347 * X + 0.0002793084022606682 * Y + -0.1691542992263487
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.363476717469214
# The direction of the gradient is: 141.09362317088062
# 277
# The equation of the fit plane is: Z = 0.0005845971364833246 * X + -0.00042327026656527577 * Y + -0.022932643520442903
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.122361578629078
# The direction of the gradient is: 238.24985975137042
# 278
# The equation of the fit plane is: Z = 0.0007206963127638638 * X + -0.0002760690057300358 * Y + -0.0659009762081967
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.0788812507554315
# The direction of the gradient is: 220.52863749122332
# 279
# The equation of the fit plane is: Z = 0.001113649997428806 * X + -1.849907711379662e-05 * Y + -0.18612291814103335
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.144607485087911
# The direction of the gradient is: 182.12323554172235
# 280
# The equation of the fit plane is: Z = 0.0012225882216410516 * X + 0.0006208684706849393 * Y + -0.3093433640469147
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 11.847356631983857
# The direction of the gradient is: 131.42138799039367
# 281
# The equation of the fit plane is: Z = 0.0011909718642490704 * X + -0.0001140994499125284 * Y + -0.18000539616561023
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.8080157997630435
# The direction of the gradient is: 192.0694257359504
# 282
# The equation of the fit plane is: Z = 0.0008237109908923498 * X + -0.00014138115214913828 * Y + -0.10698321751994502
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.655105447222894
# The direction of the gradient is: 200.96084763324643
# 283
# The equation of the fit plane is: Z = 0.00034910985247159706 * X + -0.0004053601089295981 * Y + 0.017720743625103563
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.217082951318315
# The direction of the gradient is: 248.89958355169472
# 284
# The equation of the fit plane is: Z = 0.0007537410359224728 * X + -7.239894842137007e-05 * Y + -0.10907527078171382
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.942091531018984
# The direction of the gradient is: 192.09989209647335
# 285
# The equation of the fit plane is: Z = 0.0005921723031735836 * X + -0.0004011626988042909 * Y + -0.03717624894943826
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.882059264695439
# The direction of the gradient is: 236.51993907957967
# 286
# The equation of the fit plane is: Z = 0.0008504563963666758 * X + 3.206014834803452e-05 * Y + -0.14818380643480286
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.4716109884623085
# The direction of the gradient is: 175.1906375462429
# 287
# The equation of the fit plane is: Z = 0.0005813600996162931 * X + -0.000346283156926333 * Y + -0.043741874518302276
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.20022329193517
# The direction of the gradient is: 233.04904218958916
# 288
# The equation of the fit plane is: Z = 0.0007429201653332681 * X + -0.0002264381639337016 * Y + -0.0862328494149273
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.760509608880184
# The direction of the gradient is: 214.22623150496293
# 289
# The equation of the fit plane is: Z = 0.0006188091733292037 * X + -0.0004096492209650467 * Y + -0.03996663467557899
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.077950760491376
# The direction of the gradient is: 235.9091725368346
# 290
# The equation of the fit plane is: Z = 0.0010581511519943854 * X + -0.00041117807167411564 * Y + -0.11356115519677906
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 8.97978741606878
# The direction of the gradient is: 220.93418192115018
# 291
# The equation of the fit plane is: Z = 0.0012114502637714346 * X + 1.1181151726407087e-05 * Y + -0.20827733886604935
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.768355635893149
# The direction of the gradient is: 178.81990972780625
# 292
# The equation of the fit plane is: Z = 0.0013813398479863843 * X + 0.0005647960798231084 * Y + -0.33067251799061637
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 11.989102295103805
# The direction of the gradient is: 137.61749118073084
# 293
# The equation of the fit plane is: Z = 0.0013973314849163349 * X + 0.00025715604877539705 * Y + -0.28022363730088906
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 9.684656123690456
# The direction of the gradient is: 157.66992699514503
# 294
# The equation of the fit plane is: Z = 0.0007720648632438832 * X + -0.0005510103339823219 * Y + -0.034112361634664766
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 9.309281858517497
# The direction of the gradient is: 237.87941749321726
# 295
# The equation of the fit plane is: Z = 0.0010498571385529505 * X + -0.000613159300034527 * Y + -0.0762173497353465
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 11.057967336786975
# The direction of the gradient is: 232.5061580730062
# 296
# The equation of the fit plane is: Z = 0.0004122516429866649 * X + -0.0010239249907251066 * Y + 0.06368339987881212
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 14.887659489359903
# The direction of the gradient is: 259.774182440745
# 297
# The equation of the fit plane is: Z = 0.000306177267590792 * X + -0.0006740396351824784 * Y + 0.05933111269736509
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 9.842449972212517
# The direction of the gradient is: 258.4960857503787
# 298
# The equation of the fit plane is: Z = 0.00026271022181653973 * X + -0.0005305990280222327 * Y + 0.023859900638240887
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.776830197914086
# The direction of the gradient is: 257.4921300391552
# 299
# The equation of the fit plane is: Z = 0.0003006057018252815 * X + -0.00028381167207845086 * Y + -0.00394550669609
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.4951064491078725
# The direction of the gradient is: 244.61271312187205
# 300
# The equation of the fit plane is: Z = 0.0004440928409902119 * X + -0.0002601689075399151 * Y + -0.029285489469918904
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.686649109184839
# The direction of the gradient is: 232.59140401895718
# 301
# The equation of the fit plane is: Z = 0.00022893378987289166 * X + -0.0004356492179014027 * Y + 0.03895077076147373
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.404091797004331
# The direction of the gradient is: 256.7509821636123
# 302
# The equation of the fit plane is: Z = 0.0003609954683287287 * X + -0.0004298003088790131 * Y + 0.011401088968326022
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.571006803796705
# The direction of the gradient is: 249.3774746351255
# 303
# The equation of the fit plane is: Z = 0.0006197836665228216 * X + -0.0003027120227782821 * Y + -0.04975065857175956
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.87793398425598
# The direction of the gradient is: 227.4681320481925
# 304
# The equation of the fit plane is: Z = 0.00016243402106223272 * X + -0.0006981911548544844 * Y + 0.0841718469566612
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 10.04443542905279
# The direction of the gradient is: 264.0490458692889
# 305
# The equation of the fit plane is: Z = 0.0008384452618541006 * X + -1.476574259143249e-06 * Y + -0.1340050585226031
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.375383534333209
# The direction of the gradient is: 180.2252029305257
# 306
# The equation of the fit plane is: Z = 0.0008851692496267935 * X + 8.583561855294918e-05 * Y + -0.158566359674313
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.8062819518712345
# The direction of the gradient is: 167.7879164896483
# 307
# The equation of the fit plane is: Z = 0.0010649180942604458 * X + 2.140406486583915e-05 * Y + -0.17006997101446805
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.834144123512946
# The direction of the gradient is: 177.43146976495927
# 308
# The equation of the fit plane is: Z = 0.0013663579212055438 * X + 4.807947065644578e-05 * Y + -0.23864650502270857
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 8.786807103219346
# The direction of the gradient is: 175.50944129193192
# 309
# The equation of the fit plane is: Z = 0.0010944852303780863 * X + -7.783683592250917e-05 * Y + -0.17024239137293737
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.1046766116885225
# The direction of the gradient is: 189.0190953127683
# 310
# The equation of the fit plane is: Z = 0.0010835501889606286 * X + -0.0004459239319862057 * Y + -0.11347429312832895
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 9.432380926353238
# The direction of the gradient is: 222.5678459925872
# 311
# The equation of the fit plane is: Z = 0.0009033435559943442 * X + -0.0003664940452936337 * Y + -0.10647869056236563
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.812878495865987
# The direction of the gradient is: 222.16074714874708
# 312
# The equation of the fit plane is: Z = 0.0005017110583188016 * X + -9.238871920152006e-05 * Y + -0.06528919383116807
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.4775800630213367
# The direction of the gradient is: 202.34250065895276
# 313
# The equation of the fit plane is: Z = 0.0005769562115122703 * X + -0.00031845209720583566 * Y + -0.04603404323883358
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.869011924688443
# The direction of the gradient is: 230.93181667294198
# 314
# The equation of the fit plane is: Z = 0.0005319627481504874 * X + -5.8786064218319406e-05 * Y + -0.07769274390733358
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.5126584547251714
# The direction of the gradient is: 193.85499452728823
# 315
# The equation of the fit plane is: Z = 0.0008445479134851411 * X + -0.0001660141821197071 * Y + -0.11982622916796536
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.91263975067168
# The direction of the gradient is: 203.68833912559376
# 316
# The equation of the fit plane is: Z = 0.0008212138039571496 * X + -0.0003430590891877453 * Y + -0.0838968889911228
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.198260435435234
# The direction of the gradient is: 222.99538628919993
# 317
# The equation of the fit plane is: Z = 0.0012219749010824498 * X + -0.00020230752124497203 * Y + -0.1709710375558718
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 8.351897915080947
# The direction of the gradient is: 200.27963010142014
# 318
# The equation of the fit plane is: Z = 0.0011834529125286856 * X + -0.00011856933743318439 * Y + -0.17284353755236181
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.774589553949003
# The direction of the gradient is: 192.6046487530473
# 319

# %%
######### GIM

# %%
path_GIM = '../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5'

# %%
# !reference_point.py ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 -y 180 -x 190
# !reference_date.py ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 --ref-date 20181211
# Out:
# WARNING: auto turn ON --write-data for file tpye timeseries
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# --------------------------------------------------
# input reference point in y/x: (180, 190)
# --------------------------------------------------
# SAME reference pixel is already selected/saved in file, skip updating.
# input reference date: 20181211
# --------------------------------------------------
# change reference date for file: /panda/eedy/chile/s1_a149/mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5
# input refDate is the same as the existing REF_DATE.
# Nothing to be done.
# time used: 00 mins 1.0 secs.

# %%
timeseries_GIM = readfile.read(path_GIM, datasetName='timeseries')[0]
timeseries_GIM = np.squeeze(timeseries_GIM)

mask_path_gim = '../mintpy_gim_ion_upsample/geo/geo_maskTempCoh.h5'
mask_gim = readfile.read(mask_path_gim, datasetName='mask')[0]
mask_gim = np.squeeze(mask_gim)

from mintpy.objects import ramp
data_out, ramp = ramp.deramp(timeseries_GIM, mask_in=mask_gim, ramp_type='linear', metadata=None, max_num_sample=1e3, coeff_file=None,ignore_zero_value=True)

# %%
def function(data, a, b, c):
    '''
    拟合曲面使用的函数
    '''
    x = data[0]
    y = data[1]
    return a*x+b*y + c



slope_ion_GIM = np.zeros(timeseries_GIM.shape[0])
slope_ion_GIM_dongxifangxiang = np.zeros(timeseries_GIM.shape[0])
slope_ion_GIM_nanbeifangxiang = np.zeros(timeseries_GIM.shape[0])
angle_deg_ion_GIM = np.zeros(timeseries_GIM.shape[0])
meta = readfile.read_attribute(path_GIM)
AZIMUTH_PIXEL_SIZE =  float(meta['AZIMUTH_PIXEL_SIZE'])
RANGE_PIXEL_SIZE = float(meta['RANGE_PIXEL_SIZE'])

for i in range(timeseries_GIM.shape[0]):
    x_data = ramp.shape[2]
    y_data = ramp.shape[1]
    X_data, Y_data = np.meshgrid(range(x_data), range(y_data))
    Z_data = ramp[i, :,:]
    
    x_data = X_data.flatten()
    y_data = Y_data.flatten()
    z_data = Z_data.flatten()
    
    parameters, covariance = curve_fit(function, [x_data, y_data], z_data)
    print("The equation of the fit plane is: Z = {0} * X + {1} * Y + {2}".format(parameters[0],parameters[1],parameters[2]))
    
    Z_fit = function([X_data, Y_data], *parameters)
    
    # 计算梯度，考虑到横纵坐标的实际长度
    dx = parameters[1]/RANGE_PIXEL_SIZE
    dy = parameters[0]/AZIMUTH_PIXEL_SIZE
    # 计算梯度的大小和方向
    magnitude = np.hypot(dx, dy)  # 梯度的大小
    direction = np.degrees(np.arctan2(dy, dx)) + 90  # 梯度的方向，以x轴正半轴为0°，逆时针旋转为正方向
    direction = (direction + 360) % 360  # 将角度值限制在0°到360°之间

    print('The magnitude of the gradient is( cm(ion)/ 100km(juli)):', magnitude*1e7)
    print('The direction of the gradient is:', direction)

    slope_ion_GIM[i] = magnitude*1e7
    angle_deg_ion_GIM[i] = direction
    slope_ion_GIM_dongxifangxiang[i] = dy*1e7
    slope_ion_GIM_nanbeifangxiang[i] = dx*1e7

    print(i)
# Out:
# The equation of the fit plane is: Z = -3.363108969855387e-05 * X + -0.00011773924036296046 * Y + 0.03140867612327087
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6984531396468994
# The direction of the gradient is: 277.29314429293026
# 0
# The equation of the fit plane is: Z = -2.3917138789091133e-06 * X + -6.15370980764488e-05 * Y + 0.01516893404828033
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8806580356728184
# The direction of the gradient is: 270.9976492642892
# 1
# The equation of the fit plane is: Z = 1.0034009071915283e-05 * X + -7.29718475313111e-05 * Y + 0.012850904138416823
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.046122296468865
# The direction of the gradient is: 266.47450475024243
# 2
# The equation of the fit plane is: Z = -1.8161481821387636e-05 * X + -0.00018681379868574268 * Y + 0.03825181737814366
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.6756235354721714
# The direction of the gradient is: 272.4941206582817
# 3
# The equation of the fit plane is: Z = 3.321986860014049e-06 * X + -0.0001712156258022445 * Y + 0.03391367431623078
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.449989695225296
# The direction of the gradient is: 269.5019268369133
# 4
# The equation of the fit plane is: Z = -2.4006925271599197e-05 * X + -8.964196446827229e-05 * Y + 0.025697958639630876
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2918735976235025
# The direction of the gradient is: 276.8423187402916
# 5
# The equation of the fit plane is: Z = -4.219851459080698e-05 * X + -0.0002525638821193657 * Y + 0.057149662483185225
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.6240085371501283
# The direction of the gradient is: 274.28120649512675
# 6
# The equation of the fit plane is: Z = -7.206865947241159e-05 * X + -0.00034668008563431787 * Y + 0.07747797049961785
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.98206119735697
# The direction of the gradient is: 275.3212776885248
# 7
# The equation of the fit plane is: Z = -7.257342481862654e-05 * X + -0.00025997631511346205 * Y + 0.06216842083621372
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.7489438829390505
# The direction of the gradient is: 277.1292516019049
# 8
# The equation of the fit plane is: Z = -2.9139567751931996e-05 * X + -9.725547401716012e-05 * Y + 0.02389832862642498
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.404096606177894
# The direction of the gradient is: 277.64592238825185
# 9
# The equation of the fit plane is: Z = -2.8380754226717623e-05 * X + -8.321362499464223e-05 * Y + 0.021446730578058494
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2045124272624506
# The direction of the gradient is: 278.68825031170104
# 10
# The equation of the fit plane is: Z = -2.94820009133566e-05 * X + -0.00011320280869218798 * Y + 0.026656879157014493
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.630791379990594
# The direction of the gradient is: 276.65563843321274
# 11
# The equation of the fit plane is: Z = -6.2228680826564465e-06 * X + -0.00012440232646731398 * Y + 0.025749480739548816
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7805000987577626
# The direction of the gradient is: 271.28392294243906
# 12
# The equation of the fit plane is: Z = 2.6942947946885113e-06 * X + -9.943335221283775e-05 * Y + 0.020927722002830905
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4228808532534276
# The direction of the gradient is: 269.3044293251769
# 13
# The equation of the fit plane is: Z = 2.8532635620606232e-05 * X + -5.501145432719257e-05 * Y + 0.007954972209336896
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8081255664244346
# The direction of the gradient is: 256.91729715469296
# 14
# The equation of the fit plane is: Z = -6.905294482822003e-06 * X + -0.00011635427291687202 * Y + 0.02362579696435323
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6654832452161976
# The direction of the gradient is: 271.5231655591823
# 15
# The equation of the fit plane is: Z = 2.6303674898072133e-05 * X + -5.2300335583522204e-05 * Y + 0.005454865767941866
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7671220470680057
# The direction of the gradient is: 257.30105901935974
# 16
# The equation of the fit plane is: Z = 2.72385973579038e-05 * X + -2.9597390283583475e-05 * Y + 0.00030612457750541926
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4580951687808839
# The direction of the gradient is: 247.5915574841954
# 17
# The equation of the fit plane is: Z = -3.414847773220656e-05 * X + -0.00022189632105870403 * Y + 0.046370320078610874
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.1826179819234977
# The direction of the gradient is: 273.9444273244286
# 18
# The equation of the fit plane is: Z = -3.975841761435142e-06 * X + -0.0001413828781530438 * Y + 0.027723444737333087
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0231856622544524
# The direction of the gradient is: 270.7218697810005
# 19
# The equation of the fit plane is: Z = -2.8247089446417205e-05 * X + -0.00011399098638397259 * Y + 0.02746868284706463
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6411013006280808
# The direction of the gradient is: 276.335453326508
# 20
# The equation of the fit plane is: Z = -3.032812005078222e-05 * X + -3.067624687324008e-05 * Y + 0.011872847227739102
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.480078182123746
# The direction of the gradient is: 293.8917048200367
# 21
# The equation of the fit plane is: Z = -3.297245001903287e-05 * X + -6.877543489278306e-05 * Y + 0.019699188313253485
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0065444650623907
# The direction of the gradient is: 282.12321218464785
# 22
# The equation of the fit plane is: Z = -2.921468642647937e-05 * X + -4.506520090855575e-05 * Y + 0.014359479462493583
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6714813441544332
# The direction of the gradient is: 286.19648590836687
# 23
# The equation of the fit plane is: Z = -1.963654734113134e-05 * X + -8.039061796451128e-05 * Y + 0.018955865057974017
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1571649979485752
# The direction of the gradient is: 276.2457459586325
# 24
# The equation of the fit plane is: Z = -9.379116864135667e-06 * X + -8.675002217757488e-05 * Y + 0.018622713152058573
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2427478061839214
# The direction of the gradient is: 272.7733364649047
# 25
# The equation of the fit plane is: Z = -3.562420491415086e-05 * X + -1.9731930058494874e-05 * Y + 0.010988140059139593
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3631505659927086
# The direction of the gradient is: 308.96989320006736
# 26
# The equation of the fit plane is: Z = -3.153014773471868e-05 * X + -3.994729864734705e-05 * Y + 0.01369541819985369
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6062900078520754
# The direction of the gradient is: 289.47580334397543
# 27
# The equation of the fit plane is: Z = -3.188027261831298e-05 * X + -4.065388335462162e-05 * Y + 0.01367489641695412
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6165715947477042
# The direction of the gradient is: 289.3592127794003
# 28
# The equation of the fit plane is: Z = -3.29372807856766e-05 * X + -7.096359840340703e-06 * Y + 0.007943171344133646
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23430875142751176
# The direction of the gradient is: 334.3188417372896
# 29
# The equation of the fit plane is: Z = -2.2963494330293723e-05 * X + -1.6723548652357476e-05 * Y + 0.008272756696470282
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2809553091954715
# The direction of the gradient is: 301.60101561406134
# 30
# The equation of the fit plane is: Z = -2.7848536678809644e-05 * X + -8.18125998669917e-06 * Y + 0.007429420416057252
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21349551260796013
# The direction of the gradient is: 326.74800963396723
# 31
# The equation of the fit plane is: Z = -4.2649421592647164e-05 * X + -4.8400628582532464e-05 * Y + 0.017179301668132745
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7445793748432501
# The direction of the gradient is: 291.5446445747423
# 32
# The equation of the fit plane is: Z = -6.501266185060275e-06 * X + -4.068096481203316e-05 * Y + 0.009187939962065905
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5835877599822106
# The direction of the gradient is: 274.09558270605896
# 33
# The equation of the fit plane is: Z = -2.2404383446538438e-05 * X + -5.5550046824304154e-05 * Y + 0.014838501560225653
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8077305828929796
# The direction of the gradient is: 280.2432179159845
# 34
# The equation of the fit plane is: Z = -9.653018880278697e-06 * X + -3.703327845830362e-05 * Y + 0.008957701551061648
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5335048314102955
# The direction of the gradient is: 276.66127908373477
# 35
# The equation of the fit plane is: Z = -1.7234600416232447e-05 * X + -9.79547738229815e-05 * Y + 0.021100325744906754
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4059676851694745
# The direction of the gradient is: 274.5074192630564
# 36
# The equation of the fit plane is: Z = 9.799774937631157e-06 * X + -0.00012143268564436096 * Y + 0.020832267003042776
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7386964509069645
# The direction of the gradient is: 267.9291868720661
# 37
# The equation of the fit plane is: Z = 9.03310932426241e-07 * X + -0.0001529086211175842 * Y + 0.02812029750796361
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.1879527742239433
# The direction of the gradient is: 269.8483460071402
# 38
# The equation of the fit plane is: Z = 3.0161123893776858e-05 * X + 1.0107127214555748e-05 * Y + -0.005488842181093586
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.24146534986863818
# The direction of the gradient is: 143.20656913005257
# 39
# The equation of the fit plane is: Z = 1.4776863459976319e-05 * X + -3.31638102014665e-05 * Y + 0.004417412498315488
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.48389974447382506
# The direction of the gradient is: 258.709972596017
# 40
# The equation of the fit plane is: Z = 3.873657174048724e-05 * X + 4.241496011986543e-05 * Y + -0.013848026967420005
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6557536536751524
# The direction of the gradient is: 112.2540740480456
# 41
# The equation of the fit plane is: Z = 4.171522406769028e-05 * X + 6.592507731148736e-05 * Y + -0.019015642893388425
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9804899199617882
# The direction of the gradient is: 105.82864968187334
# 42
# The equation of the fit plane is: Z = 8.585560247373177e-06 * X + -4.7788398515626346e-05 * Y + 0.007401479592826996
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6860083613327259
# The direction of the gradient is: 265.3978545325043
# 43
# The equation of the fit plane is: Z = 1.7656795578602738e-05 * X + 4.886978591263847e-05 * Y + -0.011713585440389555
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7083731821832349
# The direction of the gradient is: 99.19538145619322
# 44
# The equation of the fit plane is: Z = -9.81317063660173e-06 * X + -5.360331025403092e-05 * Y + 0.012189485580624156
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7695771172377481
# The direction of the gradient is: 274.6891718822682
# 45
# The equation of the fit plane is: Z = 1.5627683826943287e-05 * X + -5.115987645669268e-05 * Y + 0.006476809485305698
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7388629872497002
# The direction of the gradient is: 262.2066402213509
# 46
# The equation of the fit plane is: Z = 2.2462426584518054e-06 * X + -7.663755140602877e-05 * Y + 0.013436290854706417
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0966890733953163
# The direction of the gradient is: 269.2476158200118
# 47
# The equation of the fit plane is: Z = -2.8660269849932872e-05 * X + -9.773377143846524e-05 * Y + 0.02395900131035658
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4104763473737958
# The direction of the gradient is: 277.4852198411887
# 48
# The equation of the fit plane is: Z = -3.8732140887724875e-05 * X + -6.469049557272384e-05 * Y + 0.019282265431448124
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9583740592752505
# The direction of the gradient is: 285.01668115364436
# 49
# The equation of the fit plane is: Z = -3.2967709204601626e-05 * X + -7.63174610354083e-05 * Y + 0.021358303003300303
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1122805172842891
# The direction of the gradient is: 280.95411770831754
# 50
# The equation of the fit plane is: Z = -4.236809834019477e-05 * X + -6.367601478270276e-05 * Y + 0.019592159699173262
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9507566181570799
# The direction of the gradient is: 286.6003321077443
# 51
# The equation of the fit plane is: Z = -3.28291705940403e-05 * X + -4.289441305505593e-05 * Y + 0.014573687542594775
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6488533192501625
# The direction of the gradient is: 288.92759587400315
# 52
# The equation of the fit plane is: Z = -1.5854729182500318e-05 * X + -2.948879758477318e-05 * Y + 0.009275020462794334
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4340208951974123
# The direction of the gradient is: 283.54423777141085
# 53
# The equation of the fit plane is: Z = -3.292227443284611e-05 * X + -2.405992260072733e-05 * Y + 0.011021992233746591
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4038205262184773
# The direction of the gradient is: 301.5119458023995
# 54
# The equation of the fit plane is: Z = -2.0640048985113206e-05 * X + -2.6892659492613632e-05 * Y + 0.009248069092356185
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4069190381478349
# The direction of the gradient is: 288.97694671993696
# 55
# The equation of the fit plane is: Z = -2.5259961468742787e-05 * X + -9.37688105657656e-06 * Y + 0.0069302528106445285
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21030446757180954
# The direction of the gradient is: 320.35784510054816
# 56
# The equation of the fit plane is: Z = -1.9734199004724186e-05 * X + -4.036696799102038e-05 * Y + 0.011752679931710952
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5912982977884869
# The direction of the gradient is: 282.35485725222
# 57
# The equation of the fit plane is: Z = -2.0849438184485847e-05 * X + 2.1196371342061642e-06 * Y + 0.004103278231338845
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.13706522339500682
# The direction of the gradient is: 12.784120763031638
# 58
# The equation of the fit plane is: Z = -3.240887709949534e-05 * X + -1.691208586485372e-06 * Y + 0.006990197622519102
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20918046536659632
# The direction of the gradient is: 353.3568106295477
# 59
# The equation of the fit plane is: Z = -3.117166900400733e-05 * X + -1.7391836783681815e-05 * Y + 0.009440961440502991
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.31916688865474546
# The direction of the gradient is: 308.7661387137151
# 60
# The equation of the fit plane is: Z = -2.9276985783530687e-05 * X + 5.51659663275465e-06 * Y + 0.005114587525052815
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2036200871460513
# The direction of the gradient is: 22.80920172374192
# 61
# The equation of the fit plane is: Z = -2.567801287127929e-05 * X + -1.0094315499073478e-05 * Y + 0.0071583318611982425
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21900534217094778
# The direction of the gradient is: 318.73688116949154
# 62
# The equation of the fit plane is: Z = -1.9198689534821417e-05 * X + -1.9350037957352686e-06 * Y + 0.00440870880396979
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.12616010977772776
# The direction of the gradient is: 347.32241951143686
# 63
# The equation of the fit plane is: Z = -2.3673898540663334e-05 * X + -1.2033623228348775e-05 * Y + 0.007096176255762366
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.22953034735099487
# The direction of the gradient is: 311.39473630613816
# 64
# The equation of the fit plane is: Z = -1.2697731626683882e-05 * X + -1.659016606028563e-05 * Y + 0.005917249481801815
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.25095638046756685
# The direction of the gradient is: 288.928252854362
# 65
# The equation of the fit plane is: Z = -1.4154438042380575e-05 * X + -1.0096309796882293e-05 * Y + 0.005067279123606238
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17060267092795167
# The direction of the gradient is: 302.1346000024513
# 66
# The equation of the fit plane is: Z = -2.5859965115183603e-05 * X + -2.478366867461797e-05 * Y + 0.009705483641408948
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.39146614571089056
# The direction of the gradient is: 295.05647662470665
# 67
# The equation of the fit plane is: Z = -2.5058020750222276e-05 * X + -3.998970626192221e-05 * Y + 0.0119633326394463
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5943300516251439
# The direction of the gradient is: 285.6822829205517
# 68
# The equation of the fit plane is: Z = -2.1073301648212972e-05 * X + -1.4688510502221361e-05 * Y + 0.007245403432249151
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.249852956323654
# The direction of the gradient is: 302.73326326526563
# 69
# The equation of the fit plane is: Z = -1.6944420102103877e-05 * X + -3.146098698075583e-05 * Y + 0.0097753199213316
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4630919837454692
# The direction of the gradient is: 283.5668618071529
# 70
# The equation of the fit plane is: Z = -9.994111355511847e-06 * X + -3.915357950029622e-05 * Y + 0.010056494068847014
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5638943446962698
# The direction of the gradient is: 276.524382896621
# 71
# The equation of the fit plane is: Z = -1.2545875678149785e-07 * X + -5.442273914954994e-05 * Y + 0.010378179007001559
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7787267234424171
# The direction of the gradient is: 270.0591793237072
# 72
# The equation of the fit plane is: Z = 1.197508234409495e-05 * X + -3.306085974736532e-05 * Y + 0.004696565971052426
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4792518474142954
# The direction of the gradient is: 260.7818462728783
# 73
# The equation of the fit plane is: Z = -5.375224093824187e-06 * X + -8.053389916713042e-05 * Y + 0.016497658664453598
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1528619029455172
# The direction of the gradient is: 271.71292363682863
# 74
# The equation of the fit plane is: Z = 2.1162232554248866e-05 * X + -6.975226277721544e-05 * Y + 0.00996269561450955
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0072531290790763
# The direction of the gradient is: 262.2589667343167
# 75
# The equation of the fit plane is: Z = 1.9317663984479556e-05 * X + 1.0455204503732905e-05 * Y + -0.004305553019982539
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19421336310210535
# The direction of the gradient is: 129.61948634378905
# 76
# The equation of the fit plane is: Z = 1.5681882433578436e-06 * X + -5.9714271632811206e-05 * Y + 0.010111568251628317
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8545011505623586
# The direction of the gradient is: 269.3258607992293
# 77
# The equation of the fit plane is: Z = -2.420930810007442e-06 * X + -2.9329953302545336e-05 * Y + 0.006109675088201712
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4199645330316857
# The direction of the gradient is: 272.1179840984603
# 78
# The equation of the fit plane is: Z = 3.5079795456196504e-05 * X + 9.919827456561951e-06 * Y + -0.00781694591996352
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.26594564583320396
# The direction of the gradient is: 147.74266969188471
# 79
# The equation of the fit plane is: Z = 2.241166916579716e-05 * X + -1.3524504121270652e-05 * Y + -0.0016773956218051494
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2410286389700941
# The direction of the gradient is: 233.40716616221107
# 80
# The equation of the fit plane is: Z = 9.657663558099702e-06 * X + -2.5918827956270443e-05 * Y + 0.003404613638601284
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.37600127356294644
# The direction of the gradient is: 260.52194290206785
# 81
# The equation of the fit plane is: Z = -5.392141320229231e-06 * X + -1.901672884270392e-05 * Y + 0.004560565594609599
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.27429446756677
# The direction of the gradient is: 277.2402688291584
# 82
# The equation of the fit plane is: Z = 0.0 * X + 0.0 * Y + 5e-324
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0
# The direction of the gradient is: 90.0
# 83
# The equation of the fit plane is: Z = 2.9901694911965154e-07 * X + -3.0082383383491418e-05 * Y + 0.005747565177551805
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4304483022270987
# The direction of the gradient is: 269.7448296190447
# 84
# The equation of the fit plane is: Z = 4.047899594790543e-06 * X + -1.8457158790619312e-07 * Y + -0.00062145752196175
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.02608545736637421
# The direction of the gradient is: 185.81083080639326
# 85
# The equation of the fit plane is: Z = 5.451865978029698e-06 * X + -8.192438613191063e-06 * Y + 0.0007058659576357891
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.12232417655549407
# The direction of the gradient is: 253.39717981352953
# 86
# The equation of the fit plane is: Z = 2.9614336075380627e-05 * X + 2.0717235153925742e-05 * Y + -0.008702406614089954
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.35202734612498193
# The direction of the gradient is: 122.63824412769816
# 87
# The equation of the fit plane is: Z = 9.666217419375417e-06 * X + -3.161193198978583e-05 * Y + 0.004448869458836082
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4565554896476226
# The direction of the gradient is: 262.1988307558564
# 88
# The equation of the fit plane is: Z = -5.459119626327058e-06 * X + 1.1469763074984265e-05 * Y + -0.00043021809561206054
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1678093302257853
# The direction of the gradient is: 77.96182864078116
# 89
# The equation of the fit plane is: Z = 1.8633024705238102e-05 * X + 5.2796805599000105e-06 * Y + -0.003917978096334689
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.141341416046879
# The direction of the gradient is: 147.69041235793185
# 90
# The equation of the fit plane is: Z = 2.5917595735328834e-05 * X + -2.9748286388873086e-05 * Y + 0.0012182265979639828
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.45694475125285067
# The direction of the gradient is: 248.67656612209248
# 91
# The equation of the fit plane is: Z = 1.1612948125559997e-05 * X + -4.6850245458296294e-05 * Y + 0.006426420798837837
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6744943259812336
# The direction of the gradient is: 263.6627027018633
# 92
# The equation of the fit plane is: Z = 1.9033154648596097e-06 * X + -6.563916003020046e-05 * Y + 0.011925304170194235
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9392995509461046
# The direction of the gradient is: 269.2556573618947
# 93
# The equation of the fit plane is: Z = -9.434145867734131e-07 * X + -9.666279244615923e-05 * Y + 0.01789888233847737
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3831457285343942
# The direction of the gradient is: 270.25054748671454
# 94
# The equation of the fit plane is: Z = 9.676720108202711e-07 * X + -5.764323467444043e-05 * Y + 0.011078351410639729
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8248311965138185
# The direction of the gradient is: 269.5690556258004
# 95
# The equation of the fit plane is: Z = -5.690642244425835e-06 * X + -9.424809239085344e-05 * Y + 0.019045235037539313
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3490743453917955
# The direction of the gradient is: 271.549645534276
# 96
# The equation of the fit plane is: Z = -1.3596234577719432e-05 * X + -7.888404893095769e-05 * Y + 0.017402971619834368
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1320999993329748
# The direction of the gradient is: 274.4158866701712
# 97
# The equation of the fit plane is: Z = -1.765393494266939e-05 * X + -0.00010547995653481652 * Y + 0.022602029497336116
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5135336201983363
# The direction of the gradient is: 274.2885359864982
# 98
# The equation of the fit plane is: Z = -4.0510436973407616e-05 * X + -9.571792946863166e-05 * Y + 0.025025473846606968
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3940197207408147
# The direction of the gradient is: 280.73734850483237
# 99
# The equation of the fit plane is: Z = -2.260705931980362e-05 * X + -9.915398376813719e-05 * Y + 0.0227391073384454
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4261623259175622
# The direction of the gradient is: 275.8328329797747
# 100
# The equation of the fit plane is: Z = -3.429822121934391e-05 * X + -5.715386372994677e-05 * Y + 0.017404217760341116
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8468511966351442
# The direction of the gradient is: 285.0495632814618
# 101
# The equation of the fit plane is: Z = -3.675519069445534e-05 * X + -4.6072553631604444e-05 * Y + 0.015730578339144954
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7000930145613629
# The direction of the gradient is: 289.6689293394607
# 102
# The equation of the fit plane is: Z = -3.619564733650433e-05 * X + -4.5607875342785735e-05 * Y + 0.015484463756097109
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6926254703589335
# The direction of the gradient is: 289.57462399446865
# 103
# The equation of the fit plane is: Z = -3.0268638098462316e-05 * X + -2.6493364635177276e-05 * Y + 0.011025372671605804
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4258708357395646
# The direction of the gradient is: 297.10777670934635
# 104
# The equation of the fit plane is: Z = -3.877755170507242e-05 * X + -2.9171232407179746e-05 * Y + 0.013176171686296296
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.48583247418393743
# The direction of the gradient is: 300.7779035888819
# 105
# The equation of the fit plane is: Z = -3.138904701136492e-05 * X + -1.629914049363022e-05 * Y + 0.009213231030168332
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.30804067066909013
# The direction of the gradient is: 310.7895972102108
# 106
# The equation of the fit plane is: Z = -3.520803505330312e-05 * X + -3.58262276765408e-06 * Y + 0.007832392553206322
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23146958136515078
# The direction of the gradient is: 347.20471102697513
# 107
# The equation of the fit plane is: Z = -3.87056512649306e-05 * X + -1.1995929437997734e-05 * Y + 0.010075126075346998
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3017266822509448
# The direction of the gradient is: 325.32747608884443
# 108
# The equation of the fit plane is: Z = -3.285759441656171e-05 * X + -3.746676231416176e-06 * Y + 0.007349359698894273
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21736761630225526
# The direction of the gradient is: 345.72148647423796
# 109
# The equation of the fit plane is: Z = -3.519166435603762e-05 * X + -6.621584798549721e-06 * Y + 0.008353585763609339
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.24470373161600376
# The direction of the gradient is: 337.2201418071196
# 110
# The equation of the fit plane is: Z = -2.5181771194994666e-05 * X + 6.416043338060102e-06 * Y + 0.004419507747917068
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.18572028151138548
# The direction of the gradient is: 29.625237233936502
# 111
# The equation of the fit plane is: Z = -3.4909990440953774e-05 * X + 2.7171607185270996e-05 * Y + 0.0022069430375534433
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4486114379521271
# The direction of the gradient is: 60.07295604300401
# 112
# The equation of the fit plane is: Z = -3.468051029674624e-05 * X + -1.1751692928835687e-05 * Y + 0.009184808953375553
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.27876580532865824
# The direction of the gradient is: 322.9001694961395
# 113
# The equation of the fit plane is: Z = -3.73573345037907e-05 * X + -1.253929789258186e-05 * Y + 0.009756716079774552
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.29925450636347767
# The direction of the gradient is: 323.16118153366494
# 114
# The equation of the fit plane is: Z = -3.850015429863646e-05 * X + -3.8560760861826e-05 * Y + 0.014676256264445653
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6044524502748657
# The direction of the gradient is: 294.10117656581724
# 115
# The equation of the fit plane is: Z = -3.8452794213155884e-05 * X + -2.4422564013407377e-05 * Y + 0.011994378971717172
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4276627234873624
# The direction of the gradient is: 305.20089093778364
# 116
# The equation of the fit plane is: Z = -3.0318582613962845e-05 * X + -9.027699648629427e-06 * Y + 0.008087235187244536
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23338388189165832
# The direction of the gradient is: 326.393147265617
# 117
# The equation of the fit plane is: Z = -2.9450620342417003e-05 * X + -3.139790368341796e-06 * Y + 0.006606267711872929
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19408185934902047
# The direction of the gradient is: 346.6155689328425
# 118
# The equation of the fit plane is: Z = -3.600221539093046e-05 * X + 9.354538564948903e-06 * Y + 0.0056086800491206065
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2668168761212565
# The direction of the gradient is: 30.11019556727291
# 119
# The equation of the fit plane is: Z = -2.434237396408439e-05 * X + -1.1574742198324617e-05 * Y + 0.0073716570077270215
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.22756403724283117
# The direction of the gradient is: 313.29771058394135
# 120
# The equation of the fit plane is: Z = -3.617917348018914e-05 * X + -1.1195375503421252e-05 * Y + 0.009458125846793133
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2818891143065612
# The direction of the gradient is: 325.3694060184391
# 121
# The equation of the fit plane is: Z = -3.3781991942235817e-05 * X + 6.558450945033836e-06 * Y + 0.005559038861148883
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23603642060779365
# The direction of the gradient is: 23.427103865423362
# 122
# The equation of the fit plane is: Z = -3.0598142119197176e-05 * X + -8.983959857210382e-06 * Y + 0.007930888625135909
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23453506147471478
# The direction of the gradient is: 326.7628334056178
# 123
# The equation of the fit plane is: Z = -2.4511243494992252e-05 * X + -3.0008847637956483e-05 * Y + 0.01071952096203296
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.45724331786532324
# The direction of the gradient is: 290.1010024980998
# 124
# The equation of the fit plane is: Z = -6.064364909455811e-06 * X + -3.084316760924339e-05 * Y + 0.007275861709957592
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4430392011018486
# The direction of the gradient is: 275.0344982075768
# 125
# The equation of the fit plane is: Z = -2.471745600453422e-05 * X + 3.3025351575705664e-07 * Y + 0.004811310731053149
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.15853610118739514
# The direction of the gradient is: 1.7080897643418211
# 126
# The equation of the fit plane is: Z = -2.1660493801899747e-05 * X + -9.370674956199797e-06 * Y + 0.006408002135436196
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19303494118719602
# The direction of the gradient is: 316.00406086895896
# 127
# The equation of the fit plane is: Z = -2.010409172363397e-05 * X + -5.893450681933786e-05 * Y + 0.015280383593324958
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8530774151602926
# The direction of the gradient is: 278.6899311311339
# 128
# The equation of the fit plane is: Z = -2.323499166790798e-06 * X + -1.4556074033326105e-05 * Y + 0.004213811372863747
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2088125492926877
# The direction of the gradient is: 274.0908069989584
# 129
# The equation of the fit plane is: Z = -1.3023517463781521e-05 * X + -5.620291330641951e-05 * Y + 0.013339893052129728
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8085212898051715
# The direction of the gradient is: 275.92742144997925
# 130
# The equation of the fit plane is: Z = -1.6353253336381128e-06 * X + -4.951368883557104e-05 * Y + 0.010225311791790313
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.708561057741115
# The direction of the gradient is: 270.8478065207902
# 131
# The equation of the fit plane is: Z = 6.6513491180203235e-06 * X + -7.627308440346747e-05 * Y + 0.012876532036963878
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0922121615169793
# The direction of the gradient is: 267.762478850713
# 132
# The equation of the fit plane is: Z = 8.542373963795642e-06 * X + -2.365099792656266e-05 * Y + 0.00434820669507212
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.34282107381387267
# The direction of the gradient is: 260.80758044055005
# 133
# The equation of the fit plane is: Z = 3.702596329602489e-05 * X + -2.742349328597113e-06 * Y + -0.005676017961790521
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.24059795490121555
# The direction of the gradient is: 189.38647025715966
# 134
# The equation of the fit plane is: Z = 1.735337928040242e-05 * X + -7.013668424266225e-05 * Y + 0.010048105788088678
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.009722492567121
# The direction of the gradient is: 263.67415240127616
# 135
# The equation of the fit plane is: Z = -3.6844843109027483e-06 * X + -5.342197802852344e-05 * Y + 0.01085381208611104
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7647714633349437
# The direction of the gradient is: 271.76997908470423
# 136
# The equation of the fit plane is: Z = 1.8919108614398237e-05 * X + -1.7273007420325742e-05 * Y + 0.00031691250840081687
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2753146982687509
# The direction of the gradient is: 243.86053882486635
# 137
# The equation of the fit plane is: Z = -2.9329823410032385e-06 * X + -4.24481075027772e-05 * Y + 0.008735591414144183
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6076742052592801
# The direction of the gradient is: 271.773217450982
# 138
# The equation of the fit plane is: Z = 2.1835968855789728e-05 * X + 1.891975205454522e-05 * Y + -0.007138986029306025
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3047736599737396
# The direction of the gradient is: 117.34399202395724
# 139
# The equation of the fit plane is: Z = -1.0211322574583031e-05 * X + -2.9582383824907163e-06 * Y + 0.0027416891361011224
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.07795826028114422
# The direction of the gradient is: 327.1139809194367
# 140
# The equation of the fit plane is: Z = 2.6994613630892748e-05 * X + 3.382435567041264e-05 * Y + -0.01073298973469032
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5139991406551281
# The direction of the gradient is: 109.67608849505149
# 141
# The equation of the fit plane is: Z = 2.1699096447310174e-05 * X + -6.603384998321098e-07 * Y + -0.003351483440118816
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1394352125672489
# The direction of the gradient is: 183.88556497814704
# 142
# The equation of the fit plane is: Z = -2.7261440813955967e-06 * X + 7.91392793067944e-06 * Y + -0.0006129394608400321
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11457995389282714
# The direction of the gradient is: 81.22609619216303
# 143
# The equation of the fit plane is: Z = 1.2763447680624945e-05 * X + 2.77257805487757e-05 * Y + -0.006931837082760244
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.40507468406086294
# The direction of the gradient is: 101.65428952534984
# 144
# The equation of the fit plane is: Z = 2.915286962448387e-06 * X + 5.6754833201750825e-05 * Y + -0.009958700002356772
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8123109161012337
# The direction of the gradient is: 91.31841266668215
# 145
# The equation of the fit plane is: Z = 3.79346775157486e-05 * X + 5.579676781628788e-05 * Y + -0.016592171065105986
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8346072692014425
# The direction of the gradient is: 106.94163276958591
# 146
# The equation of the fit plane is: Z = 1.3061173164158982e-05 * X + -1.444277637858179e-05 * Y + 0.0007228082889242589
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.22297951491724236
# The direction of the gradient is: 247.9427138790934
# 147
# The equation of the fit plane is: Z = 7.008591220064915e-06 * X + -5.3063546838687196e-05 * Y + 0.008533611098921845
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.760606195580322
# The direction of the gradient is: 266.6132915026765
# 148
# The equation of the fit plane is: Z = 2.1218417976142198e-05 * X + 7.75166907323871e-06 * Y + -0.0045756895538791465
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17552109801405003
# The direction of the gradient is: 140.80719379533411
# 149
# The equation of the fit plane is: Z = 6.483481167400527e-06 * X + -4.51905902046278e-05 * Y + 0.007398570510591655
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6479595520586425
# The direction of the gradient is: 266.32199182545037
# 150
# The equation of the fit plane is: Z = -3.562908256606841e-06 * X + -7.23962428350569e-05 * Y + 0.014768793424219485
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0361581177217123
# The direction of the gradient is: 271.26318746711104
# 151
# The equation of the fit plane is: Z = 2.2419946133814534e-05 * X + -6.772456537689297e-05 * Y + 0.008711368257064561
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9796618806557504
# The direction of the gradient is: 261.5630984126825
# 152
# The equation of the fit plane is: Z = 1.9393725542374406e-05 * X + -6.133436952278068e-05 * Y + 0.00794806832312113
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.88638735487326
# The direction of the gradient is: 261.936449659377
# 153
# The equation of the fit plane is: Z = 6.105918938967954e-06 * X + -5.246035401191686e-05 * Y + 0.009559984404536993
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7516668611079736
# The direction of the gradient is: 267.0147812709347
# 154
# The equation of the fit plane is: Z = -1.3792590846780465e-05 * X + -7.965743422285885e-05 * Y + 0.017286173302946312
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1432303928223277
# The direction of the gradient is: 274.43608742085297
# 155
# The equation of the fit plane is: Z = -1.3067639722746536e-05 * X + -8.731722075209428e-05 * Y + 0.018945456675225403
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2522138692792735
# The direction of the gradient is: 273.8361641856672
# 156
# The equation of the fit plane is: Z = -2.423717103158941e-05 * X + -9.024367054947433e-05 * Y + 0.021358930254295937
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3005979298100885
# The direction of the gradient is: 276.8616966315203
# 157
# The equation of the fit plane is: Z = -3.6475625780127e-05 * X + -7.1473648815371e-05 * Y + 0.020061075481985255
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0490999217476602
# The direction of the gradient is: 282.87963893308984
# 158
# The equation of the fit plane is: Z = -2.8634248128759066e-05 * X + -5.814789019687009e-05 * Y + 0.01684143583451076
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8520401616432474
# The direction of the gradient is: 282.4422378825033
# 159
# The equation of the fit plane is: Z = -3.8087005978012074e-05 * X + -3.74094576437026e-06 * Y + 0.008155965953032963
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.24997733927972257
# The direction of the gradient is: 347.635285855844
# 160
# The equation of the fit plane is: Z = -3.871464204268041e-05 * X + -5.101383199595889e-05 * Y + 0.016929960286595137
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7709927798360569
# The direction of the gradient is: 288.77945340872964
# 161
# The equation of the fit plane is: Z = -2.845378027359633e-05 * X + -4.3609854450695414e-05 * Y + 0.013992525676732747
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6501237996135141
# The direction of the gradient is: 286.2955407114937
# 162
# The equation of the fit plane is: Z = -2.9837602889292328e-05 * X + -2.4375764097052445e-05 * Y + 0.010420351281476071
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.39780157546738354
# The direction of the gradient is: 298.74232058317284
# 163
# The equation of the fit plane is: Z = -3.825286833278918e-05 * X + -3.959542378456514e-05 * Y + 0.014752685364884348
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6173647629478436
# The direction of the gradient is: 293.405783766105
# 164
# The equation of the fit plane is: Z = -4.1194266000413176e-05 * X + -1.6186037003909e-05 * Y + 0.010978876532425241
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.351267530803512
# The direction of the gradient is: 318.75072687283205
# 165
# The equation of the fit plane is: Z = -3.549453137418985e-05 * X + -3.441659239083448e-05 * Y + 0.013206688262029637
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5424953315129635
# The direction of the gradient is: 294.8008823278425
# 166
# The equation of the fit plane is: Z = -3.8609219329752794e-05 * X + -9.180270092372486e-06 * Y + 0.009544036027337237
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2802226979124684
# The direction of the gradient is: 332.0457406585535
# 167
# The equation of the fit plane is: Z = -3.2367266472291705e-05 * X + 4.016949749387895e-06 * Y + 0.006169093996038645
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21532251898843524
# The direction of the gradient is: 15.482177305297796
# 168
# The equation of the fit plane is: Z = -2.3583570119835393e-05 * X + -3.236381346381727e-05 * Y + 0.010669214470344303
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4871461772127877
# The direction of the gradient is: 288.0816117421961
# 169
# The equation of the fit plane is: Z = -3.711437585409414e-05 * X + 1.3256314673630858e-05 * Y + 0.005150538015606245
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.30429669888715655
# The direction of the gradient is: 38.56097900258777
# 170
# The equation of the fit plane is: Z = -4.032727076912116e-05 * X + -1.995012958549985e-05 * Y + 0.011643640189896054
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.38514016574481286
# The direction of the gradient is: 312.1668525479533
# 171
# The equation of the fit plane is: Z = -3.287571004832967e-05 * X + -3.844291294504889e-06 * Y + 0.007195781670827727
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21782868933897953
# The direction of the gradient is: 345.37297678200537
# 172
# The equation of the fit plane is: Z = -2.9647811020112822e-05 * X + 2.386073333606329e-05 * Y + 0.0017483687728258395
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3907628085283185
# The direction of the gradient is: 60.894496998059196
# 173
# The equation of the fit plane is: Z = -4.140204135126165e-05 * X + -1.8826040115799228e-05 * Y + 0.011492171176658086
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.37817858919925373
# The direction of the gradient is: 314.57716578618397
# 174
# The equation of the fit plane is: Z = -4.096870146417269e-05 * X + -7.552065266678172e-06 * Y + 0.009592232770949609
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2840144899540045
# The direction of the gradient is: 337.6366983275584
# 175
# The equation of the fit plane is: Z = -4.235626809637644e-05 * X + -2.209434321020464e-05 * Y + 0.012187082802298974
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4167570757335424
# The direction of the gradient is: 310.66064611971353
# 176
# The equation of the fit plane is: Z = -3.6938652133486295e-05 * X + -3.700754669132784e-05 * Y + 0.014400818765256597
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5800772284589181
# The direction of the gradient is: 294.09497468100636
# 177
# The equation of the fit plane is: Z = -3.212299665243618e-05 * X + -3.502143333801823e-05 * Y + 0.013025055318643798
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5417840498916309
# The direction of the gradient is: 292.34114323999665
# 178
# The equation of the fit plane is: Z = -3.2505778292021835e-05 * X + -2.694484182784208e-05 * Y + 0.011314505202811503
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.43826679931384255
# The direction of the gradient is: 298.39211409968823
# 179
# The equation of the fit plane is: Z = -3.2890563829208615e-05 * X + -5.095173278457227e-05 * Y + 0.01597163408951126
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7589416978631447
# The direction of the gradient is: 286.1313130810172
# 180
# The equation of the fit plane is: Z = -2.2416159755963622e-05 * X + -5.0044178108023525e-05 * Y + 0.01402125650434624
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7303528752421804
# The direction of the gradient is: 281.348166365006
# 181
# The equation of the fit plane is: Z = -3.03062609515526e-05 * X + -4.377228399681195e-05 * Y + 0.013926589292174977
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6557751047107299
# The direction of the gradient is: 287.23457301624336
# 182
# The equation of the fit plane is: Z = -3.5037634052919655e-05 * X + -7.274561869743628e-05 * Y + 0.019916661766259253
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0648673489597016
# The direction of the gradient is: 282.17777762094113
# 183
# The equation of the fit plane is: Z = -2.1086681957032627e-05 * X + -6.666786777693739e-05 * Y + 0.01649886143547901
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9634714633321052
# The direction of the gradient is: 278.066012239265
# 184
# The equation of the fit plane is: Z = -2.3037247716898592e-05 * X + -2.577618776979411e-05 * Y + 0.009484737895980798
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3972997053996036
# The direction of the gradient is: 291.82320233012456
# 185
# The equation of the fit plane is: Z = -1.1316916590720617e-05 * X + -6.983259343445566e-05 * Y + 0.015406088672147255
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0018540607795539
# The direction of the gradient is: 274.1529625863778
# 186
# The equation of the fit plane is: Z = -5.6665747089520805e-06 * X + -6.137459418767617e-05 * Y + 0.012713957565249248
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8789503904265882
# The direction of the gradient is: 272.3688306115363
# 187
# The equation of the fit plane is: Z = 5.894636594516748e-07 * X + -6.510264490395142e-05 * Y + 0.012412625799605956
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.931551044325764
# The direction of the gradient is: 269.7675628243767
# 188
# The equation of the fit plane is: Z = -2.8466233332956575e-06 * X + -6.607104117609472e-05 * Y + 0.012547154881969102
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9455761382256811
# The direction of the gradient is: 271.10589650756106
# 189
# The equation of the fit plane is: Z = -6.58496798378693e-06 * X + -9.03377020821147e-05 * Y + 0.01846692879260776
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2933170023326306
# The direction of the gradient is: 271.87059537009645
# 190
# The equation of the fit plane is: Z = 8.095310912200334e-06 * X + -0.00011438774721097295 * Y + 0.0198751692639361
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.637578693613882
# The direction of the gradient is: 268.1838232807986
# 191
# The equation of the fit plane is: Z = 2.2967816400349444e-06 * X + -0.0001291096825706128 * Y + 0.02391764322109176
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.847468569719748
# ...
# The direction of the gradient is: 264.1621992832786
# 258
# The equation of the fit plane is: Z = 1.4241542718065023e-05 * X + -8.705013275746094e-05 * Y + 0.01301158664595524
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.248928366763222
# The direction of the gradient is: 265.80761527452864
# 259
# The equation of the fit plane is: Z = 2.2528615687124566e-05 * X + 3.5197746722664254e-05 * Y + -0.010170978672201233
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5239399150743633
# The direction of the gradient is: 106.00175287823862
# 260
# The equation of the fit plane is: Z = 1.1563480129051592e-05 * X + -5.2160595859482823e-05 * Y + 0.007643492052155823
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7500304461131015
# The direction of the gradient is: 264.3275145887776
# 261
# The equation of the fit plane is: Z = -9.879754045625908e-06 * X + -0.00013865589767916037 * Y + 0.02635808936709598
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.9850159748152167
# The direction of the gradient is: 271.8285627678014
# 262
# The equation of the fit plane is: Z = -4.191834636239768e-05 * X + -0.00024497198798613493 * Y + 0.053605920936982736
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.5155520393823507
# The direction of the gradient is: 274.38418141635145
# 263
# The equation of the fit plane is: Z = -2.6519478558225807e-05 * X + -0.00014105829508724533 * Y + 0.03189957981768257
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0255287932416217
# The direction of the gradient is: 274.81495105195995
# 264
# The equation of the fit plane is: Z = -2.0393598008664688e-05 * X + -0.0002265679926763624 * Y + 0.04570098078482616
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.2445606942223493
# The direction of the gradient is: 272.3094553887661
# 265
# The equation of the fit plane is: Z = -2.8783251831189943e-05 * X + -0.00020355525561823742 * Y + 0.043375429149520334
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.9184794383858765
# The direction of the gradient is: 273.62515883699473
# 266
# The equation of the fit plane is: Z = -5.5373494260727886e-05 * X + -0.00029346078726200407 * Y + 0.06547841847097108
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.214063546877512
# The direction of the gradient is: 274.83247812442187
# 267
# The equation of the fit plane is: Z = -7.761832465982476e-05 * X + -0.00038430407187732524 * Y + 0.08453290145457379
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.521415373815952
# The direction of the gradient is: 275.17079773539876
# 268
# The equation of the fit plane is: Z = -4.600530486670838e-05 * X + -0.0003114537673895437 * Y + 0.06484331140165442
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.466291713514135
# The direction of the gradient is: 273.786439409223
# 269
# The equation of the fit plane is: Z = -4.0152978919247297e-05 * X + -0.00020258381917186768 * Y + 0.04498668746659406
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.910147499937259
# The direction of the gradient is: 275.0748684866686
# 270
# The equation of the fit plane is: Z = -3.469137332148829e-05 * X + -0.00016015019451682045 * Y + 0.03763975871344166
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.302331373884764
# The direction of the gradient is: 275.543518089416
# 271
# The equation of the fit plane is: Z = -3.348820098290932e-05 * X + -0.00012592591724520615 * Y + 0.02984324891897194
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.814599592156316
# The direction of the gradient is: 276.7949070821082
# 272
# The equation of the fit plane is: Z = -2.1801575984970463e-05 * X + -0.0001004167088063969 * Y + 0.022517380543109023
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4436289542476028
# The direction of the gradient is: 275.5560633038134
# 273
# The equation of the fit plane is: Z = -3.6392589540980215e-05 * X + -0.0001045322580283513 * Y + 0.026149690412111903
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5138232395560773
# The direction of the gradient is: 278.8659721667326
# 274
# The equation of the fit plane is: Z = -2.92648751766677e-05 * X + -0.0001107843066790606 * Y + 0.026164426640470115
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.596259467522692
# The direction of the gradient is: 276.74997668447656
# 275
# The equation of the fit plane is: Z = -3.8160261660623175e-05 * X + -0.000117311989606441 * Y + 0.02928229019635874
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6963331403674584
# The direction of the gradient is: 278.29223089027096
# 276
# The equation of the fit plane is: Z = -3.182341571603313e-05 * X + -6.960546987768381e-05 * Y + 0.019074158152806
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0166555872342518
# The direction of the gradient is: 281.5767327442338
# 277
# The equation of the fit plane is: Z = -2.0280912535357305e-05 * X + -9.387546915709186e-05 * Y + 0.020965385631139154
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3495273724400296
# The direction of the gradient is: 275.5288399343128
# 278
# The equation of the fit plane is: Z = -2.2555911340628234e-05 * X + -0.00011828246839688942 * Y + 0.02646863943179055
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6986514979000469
# The direction of the gradient is: 274.8835550427914
# 279
# The equation of the fit plane is: Z = -3.337458365319627e-05 * X + -0.00015605144000042074 * Y + 0.0369489385111624
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.2431433934053127
# The direction of the gradient is: 275.4736072871098
# 280
# The equation of the fit plane is: Z = -3.410469503399635e-05 * X + -0.00021304966217827734 * Y + 0.046449014240918615
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.056324710055962
# The direction of the gradient is: 274.10241735363616
# 281
# The equation of the fit plane is: Z = -2.9375217047193646e-05 * X + -0.00020671269399156496 * Y + 0.04514004795432867
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.9638084283001738
# The direction of the gradient is: 273.64315509955486
# 282
# The equation of the fit plane is: Z = -4.200493750711549e-05 * X + -0.00017812441198435352 * Y + 0.04313660939680576
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.562941106156798
# The direction of the gradient is: 276.031399893838
# 283
# The equation of the fit plane is: Z = -1.9302286809015962e-05 * X + -0.00010662831386491649 * Y + 0.02625694219865854
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5307378297183185
# The direction of the gradient is: 274.6369900237693
# 284
# The equation of the fit plane is: Z = -2.67504832999899e-05 * X + -0.00020425172924070403 * Y + 0.045045538466567434
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.927632972630128
# The direction of the gradient is: 273.35828632446305
# 285
# The equation of the fit plane is: Z = -1.1033989480214833e-05 * X + -0.00016996713957351852 * Y + 0.03470387091169395
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.4330613107650017
# The direction of the gradient is: 271.6660757284276
# 286
# The equation of the fit plane is: Z = -1.2708542913316001e-05 * X + -0.00012045559341229669 * Y + 0.02540774528530701
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7255045486878273
# The direction of the gradient is: 272.7064199422456
# 287
# The equation of the fit plane is: Z = 4.2219217897632795e-06 * X + -6.774612103192032e-05 * Y + 0.01342180634296282
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9697462731426244
# The direction of the gradient is: 268.4005801193654
# 288
# The equation of the fit plane is: Z = -6.0732404973518266e-06 * X + -0.00016625099493388693 * Y + 0.03094727884059419
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.379177634365438
# The direction of the gradient is: 270.937706697464
# 289
# The equation of the fit plane is: Z = 1.7057066813421145e-05 * X + -4.407270557337234e-05 * Y + 0.006595529309294575
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6400403912758261
# The direction of the gradient is: 260.1624505619187
# 290
# The equation of the fit plane is: Z = -3.052830117962656e-05 * X + -0.0001998305390865306 * Y + 0.04196377410047285
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.8660339448089123
# The direction of the gradient is: 273.9157364724479
# 291
# The equation of the fit plane is: Z = -1.547368904621481e-05 * X + -0.00019233096767031632 * Y + 0.038729459236496996
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.7538206058380004
# The direction of the gradient is: 272.06445877953905
# 292
# The equation of the fit plane is: Z = -2.087796584440106e-05 * X + -0.0002517084205095075 * Y + 0.049836461927696266
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.6041420265827715
# The direction of the gradient is: 272.12833598429575
# 293
# The equation of the fit plane is: Z = -2.1748640653045113e-05 * X + -0.00025666642960565293 * Y + 0.051548276972988694
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.675244930280408
# The direction of the gradient is: 272.1742230004721
# 294
# The equation of the fit plane is: Z = -7.913255710967048e-05 * X + -0.0002353887676299589 * Y + 0.06028727961922697
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.4061339872124123
# The direction of the gradient is: 278.56577146812856
# 295
# The equation of the fit plane is: Z = -7.655514769285495e-05 * X + -1.663706133555607e-05 * Y + 0.020972582277131474
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5454880116244549
# The direction of the gradient is: 334.12487714744606
# 296
# The equation of the fit plane is: Z = -0.00010105564149968284 * X + -0.00028636632894107086 * Y + 0.07428999237397203
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.1484726056556385
# The direction of the gradient is: 278.9847862381149
# 297
# The equation of the fit plane is: Z = -0.0001000325851812475 * X + -0.00039790353921429666 * Y + 0.09286752418407777
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.729543351134461
# The direction of the gradient is: 276.4266782011192
# 298
# The equation of the fit plane is: Z = -0.00010425500459712739 * X + -0.0003945755468299143 * Y + 0.09360075635400596
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.6853442634705225
# The direction of the gradient is: 276.7514907675841
# 299
# The equation of the fit plane is: Z = -4.040641638716868e-05 * X + -0.00022858188788469187 * Y + 0.05088065093405221
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.2809843745364815
# The direction of the gradient is: 274.5284799278045
# 300
# The equation of the fit plane is: Z = -6.415513593952352e-05 * X + -0.00027553648560207293 * Y + 0.06262838864198562
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.96400382548093
# The direction of the gradient is: 275.95571289125644
# 301
# The equation of the fit plane is: Z = -2.41667605215781e-05 * X + -0.00016285841207438646 * Y + 0.0351004393454277
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.3354599714955966
# The direction of the gradient is: 273.8038125127025
# 302
# The equation of the fit plane is: Z = -6.249749086027495e-05 * X + -0.00023264754492919516 * Y + 0.05469620406827013
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.352943176516724
# The direction of the gradient is: 276.8632449855369
# 303
# The equation of the fit plane is: Z = -3.928029550651256e-05 * X + -0.0001449730429891971 * Y + 0.03484758007287108
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.089626162078016
# The direction of the gradient is: 276.9217684585709
# 304
# The equation of the fit plane is: Z = -4.117530727553528e-05 * X + -0.0001497305450723475 * Y + 0.03599013465027589
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.1586719296700543
# The direction of the gradient is: 277.0241314399909
# 305
# The equation of the fit plane is: Z = -2.4954727012360038e-05 * X + -0.00016304224345686728 * Y + 0.03527094488367694
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.338424786297261
# The direction of the gradient is: 273.92304083688424
# 306
# The equation of the fit plane is: Z = -7.510716835232078e-05 * X + -0.0002789700703396223 * Y + 0.06710085294052864
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.02067588921237
# The direction of the gradient is: 276.8782823074122
# 307
# The equation of the fit plane is: Z = -4.8350315544426135e-05 * X + -0.00020970723801085357 * Y + 0.04820786084821406
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.016635804301889
# The direction of the gradient is: 275.89790401626715
# 308
# The equation of the fit plane is: Z = -4.732743677149181e-05 * X + -0.00018906706344202394 * Y + 0.045648290521148514
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.7222925814155063
# The direction of the gradient is: 276.3993449271894
# 309
# The equation of the fit plane is: Z = -4.3245816352798264e-05 * X + -0.00022360022451014034 * Y + 0.0508801390445991
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.21145033948188
# The direction of the gradient is: 274.9526527253725
# 310
# The equation of the fit plane is: Z = -4.297799327398995e-05 * X + -0.00022201193741853878 * Y + 0.050730148400455595
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.1886604186119145
# The direction of the gradient is: 274.95717028888964
# 311
# The equation of the fit plane is: Z = -5.8568207374232436e-05 * X + -0.00019839147060772758 * Y + 0.05060405802029672
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.863477282966008
# The direction of the gradient is: 277.5348522060267
# 312
# The equation of the fit plane is: Z = -3.8028787666775915e-05 * X + -0.0001871765858469172 * Y + 0.044701864614492715
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.68935396868256
# The direction of the gradient is: 275.2013395688266
# 313
# The equation of the fit plane is: Z = -6.023365561475167e-05 * X + -0.0002499058504435387 * Y + 0.059030153177760655
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.596653743821823
# The direction of the gradient is: 276.1635733150065
# 314
# The equation of the fit plane is: Z = -1.9576105803781786e-05 * X + -0.0001799485308536978 * Y + 0.03814942153125364
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.5779117279709607
# The direction of the gradient is: 272.7905126052804
# 315
# The equation of the fit plane is: Z = 6.443493069988581e-06 * X + -7.017979010794094e-05 * Y + 0.011454483126064478
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.00504076889167
# The direction of the gradient is: 267.6443320861499
# 316
# The equation of the fit plane is: Z = 5.586859464559802e-06 * X + -0.00012555787608946892 * Y + 0.021742800224726477
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7969446617542144
# The direction of the gradient is: 268.8578692456856
# 317
# The equation of the fit plane is: Z = 1.757863021746289e-05 * X + -5.4227596267610076e-05 * Y + 0.006456942159144616
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7840755609471337
# The direction of the gradient is: 261.7360445796363
# 318
# The equation of the fit plane is: Z = 4.627453149590909e-06 * X + -9.997119894621692e-05 * Y + 0.01841699485066504
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4307795691846803
# The direction of the gradient is: 268.81189603702853
# 319
# The equation of the fit plane is: Z = -1.782191452419162e-05 * X + -0.00014888079348590738 * Y + 0.031871587774614275
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.1333734331634875
# The direction of the gradient is: 273.0700774580638
# 320
# The equation of the fit plane is: Z = -4.610869011400143e-05 * X + -0.00021186658097997347 * Y + 0.050142648009126024
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.045943311056283
# The direction of the gradient is: 275.56928051343056
# 321
# The equation of the fit plane is: Z = -7.441131211860105e-05 * X + -0.0002669838862527289 * Y + 0.06508220535741278
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.8499013040587102
# The direction of the gradient is: 277.1180512003482
# 322

# %%
with h5py.File(path_GIM, 'r') as file:
    date_GIM = file['date']
    date_GIM = date_GIM[()]
date_GIM = np.char.decode(date_GIM)

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

slope_ion_GIM_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_GIM_correct[i] = slope_ion_GIM[j[0]]
slope_ion_GIM = slope_ion_GIM_correct

angle_deg_ion_GIM_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_GIM == date_split[i])[0]
    if len(j) > 0:
        angle_deg_ion_GIM_correct[i] = angle_deg_ion_GIM[j[0]]
angle_deg_ion_GIM = angle_deg_ion_GIM_correct

slope_ion_GIM_dongxifangxiang_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_GIM_dongxifangxiang_correct[i] = slope_ion_GIM_dongxifangxiang[j[0]]
slope_ion_GIM_dongxifangxiang = slope_ion_GIM_dongxifangxiang_correct

slope_ion_GIM_nanbeifangxiang_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_GIM_nanbeifangxiang_correct[i] = slope_ion_GIM_nanbeifangxiang[j[0]]
slope_ion_GIM_nanbeifangxiang = slope_ion_GIM_nanbeifangxiang_correct

# %%
######### hight_GIM

# %%
path_hight_GIM = '../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5'

# %%
# !reference_point.py ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 -y 180 -x 190
# !reference_date.py ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 --ref-date 20181211
# Out:
# WARNING: auto turn ON --write-data for file tpye timeseries
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# --------------------------------------------------
# input reference point in y/x: (180, 190)
# --------------------------------------------------
# SAME reference pixel is already selected/saved in file, skip updating.
# input reference date: 20181211
# --------------------------------------------------
# change reference date for file: /panda/eedy/chile/s1_a149/mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5
# input refDate is the same as the existing REF_DATE.
# Nothing to be done.
# time used: 00 mins 1.0 secs.

# %%
timeseries_hight_GIM = readfile.read(path_hight_GIM, datasetName='timeseries')[0]
timeseries_hight_GIM = np.squeeze(timeseries_hight_GIM)

mask_path_hight_gim = '../mintpy_hight_gim_ion_upsample/geo/geo_maskTempCoh.h5'
mask_hight_gim = readfile.read(mask_path_hight_gim, datasetName='mask')[0]
mask_hight_gim = np.squeeze(mask_hight_gim)

from mintpy.objects import ramp
data_out, ramp = ramp.deramp(timeseries_hight_GIM, mask_in=mask_hight_gim, ramp_type='linear', metadata=None, max_num_sample=1e3, coeff_file=None,ignore_zero_value=True)

# %%
def function(data, a, b, c):
    '''
    拟合曲面使用的函数
    '''
    x = data[0]
    y = data[1]
    return a*x+b*y + c



slope_ion_hight_GIM = np.zeros(timeseries_hight_GIM.shape[0])
slope_ion_hight_GIM_dongxifangxiang = np.zeros(timeseries_hight_GIM.shape[0])
slope_ion_hight_GIM_nanbeifangxiang = np.zeros(timeseries_hight_GIM.shape[0])
angle_deg_ion_hight_GIM = np.zeros(timeseries_hight_GIM.shape[0])
meta = readfile.read_attribute(path_hight_GIM)
AZIMUTH_PIXEL_SIZE =  float(meta['AZIMUTH_PIXEL_SIZE'])
RANGE_PIXEL_SIZE = float(meta['RANGE_PIXEL_SIZE'])

for i in range(timeseries_hight_GIM.shape[0]):
    x_data = ramp.shape[2]
    y_data = ramp.shape[1]
    X_data, Y_data = np.meshgrid(range(x_data), range(y_data))
    Z_data = ramp[i, :,:]
    
    x_data = X_data.flatten()
    y_data = Y_data.flatten()
    z_data = Z_data.flatten()
    
    parameters, covariance = curve_fit(function, [x_data, y_data], z_data)
    print("The equation of the fit plane is: Z = {0} * X + {1} * Y + {2}".format(parameters[0],parameters[1],parameters[2]))
    
    Z_fit = function([X_data, Y_data], *parameters)
    
    # 计算梯度，考虑到横纵坐标的实际长度
    dx = parameters[1]/RANGE_PIXEL_SIZE
    dy = parameters[0]/AZIMUTH_PIXEL_SIZE
    # 计算梯度的大小和方向
    magnitude = np.hypot(dx, dy)  # 梯度的大小
    direction = np.degrees(np.arctan2(dy, dx)) + 90  # 梯度的方向，以x轴正半轴为0°，逆时针旋转为正方向
    direction = (direction + 360) % 360  # 将角度值限制在0°到360°之间

    print('The magnitude of the gradient is( cm(ion)/ 100km(juli)):', magnitude*1e7)
    print('The direction of the gradient is:', direction)

    slope_ion_hight_GIM[i] = magnitude*1e7
    angle_deg_ion_hight_GIM[i] = direction
    slope_ion_hight_GIM_dongxifangxiang[i] = dy*1e7
    slope_ion_hight_GIM_nanbeifangxiang[i] = dx*1e7
    

    print(i)
# Out:
# The equation of the fit plane is: Z = -3.6715141704345344e-05 * X + -3.882708874154988e-05 * Y + 0.015660807987985376
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6033773816837423
# The direction of the gradient is: 292.96137129690624
# 0
# The equation of the fit plane is: Z = 1.2516403917821823e-05 * X + 2.4776393504994263e-05 * Y + -0.004886467736366874
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.36348937240279794
# The direction of the gradient is: 102.7536411388528
# 1
# The equation of the fit plane is: Z = 2.7486905180043768e-05 * X + -5.598256685360048e-05 * Y + 0.005380203233409665
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8201999070662778
# The direction of the gradient is: 257.59321009354846
# 2
# The equation of the fit plane is: Z = -3.1984466038971294e-05 * X + -0.0002492790672499703 * Y + 0.0503799268968688
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.572783759281679
# The direction of the gradient is: 273.2902213118414
# 3
# The equation of the fit plane is: Z = 4.155086695939932e-05 * X + -0.00015858607902433577 * Y + 0.022060066504996388
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.284765369266842
# The direction of the gradient is: 263.3045250000241
# 4
# The equation of the fit plane is: Z = 5.155160652018314e-06 * X + 0.00010241419438209623 * Y + -0.017648972624928948
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4658010454598192
# The direction of the gradient is: 91.29198657715915
# 5
# The equation of the fit plane is: Z = 2.6264650568664513e-05 * X + -0.00015989217677900872 * Y + 0.0251396276308424
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.2940597974649437
# The direction of the gradient is: 265.7906828010241
# 6
# The equation of the fit plane is: Z = -4.47454581820462e-05 * X + -0.0003329386897045216 * Y + 0.06790310579875428
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.772595859029696
# The direction of the gradient is: 273.4459595380051
# 7
# The equation of the fit plane is: Z = -7.394355084336445e-05 * X + -0.00028446567218503893 * Y + 0.06478830594577747
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.0978867404602175
# The direction of the gradient is: 276.6430547335127
# 8
# The equation of the fit plane is: Z = -6.721978866854031e-05 * X + -0.00016318055949352485 * Y + 0.041515214137409634
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.374361469081057
# The direction of the gradient is: 280.457266081317
# 9
# The equation of the fit plane is: Z = -3.584536435791421e-05 * X + -0.00011974258126271402 * Y + 0.027896443509398395
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7287203600651009
# The direction of the gradient is: 277.6392331480283
# 10
# The equation of the fit plane is: Z = -5.315346010516014e-05 * X + -0.00014905894357449475 * Y + 0.03635658064744101
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.159911976160527
# The direction of the gradient is: 279.0775343157195
# 11
# The equation of the fit plane is: Z = -2.3360390038687214e-05 * X + -0.00019837207958774036 * Y + 0.04030395419723285
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.842422759982418
# The direction of the gradient is: 273.0202756950874
# 12
# The equation of the fit plane is: Z = 8.59289834775343e-05 * X + 3.6199220111269234e-06 * Y + -0.01528287723076847
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5533275125525017
# The direction of the gradient is: 174.62868833686957
# 13
# The equation of the fit plane is: Z = 7.995914100869688e-06 * X + -6.237398732705423e-05 * Y + 0.010404722452716935
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8939704203639914
# The direction of the gradient is: 266.7127155710873
# 14
# The equation of the fit plane is: Z = 2.0578561822949893e-05 * X + -0.00011407322486551342 * Y + 0.0172799805513844
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6375787391296883
# The direction of the gradient is: 265.3789807307676
# 15
# The equation of the fit plane is: Z = 6.108395004316845e-06 * X + -0.00012221535006259876 * Y + 0.020911521556832416
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7491984142415857
# The direction of the gradient is: 268.7171427146021
# 16
# The equation of the fit plane is: Z = 2.9348807917202232e-05 * X + -0.00013059673094692088 * Y + 0.01696300583496244
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8781367068969843
# The direction of the gradient is: 264.2502832443647
# 17
# The equation of the fit plane is: Z = -6.30873927058536e-05 * X + -0.0002715231599293091 * Y + 0.05991798444853939
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.906177567391657
# The direction of the gradient is: 275.94324608841106
# 18
# The equation of the fit plane is: Z = -1.7533968156370265e-05 * X + -0.00018655813249979239 * Y + 0.03666506165050183
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.671796432412502
# The direction of the gradient is: 272.4113434971165
# 19
# The equation of the fit plane is: Z = -4.0226857032410145e-05 * X + -0.00016488490167878043 * Y + 0.03668216032168216
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.373365417702825
# The direction of the gradient is: 276.23826625361886
# 20
# The equation of the fit plane is: Z = -5.310523548127677e-05 * X + -7.733844122080105e-05 * Y + 0.023486430519226647
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1578125296224788
# The direction of the gradient is: 287.10095732134664
# 21
# The equation of the fit plane is: Z = -5.4920943080514055e-05 * X + -0.00012123116356876122 * Y + 0.03166097168011894
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7700514267353664
# The direction of the gradient is: 281.4739455993059
# 22
# The equation of the fit plane is: Z = -5.764516668045694e-05 * X + -9.548658401669542e-05 * Y + 0.027260045424282706
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4154018878781849
# The direction of the gradient is: 285.13561503291976
# 23
# The equation of the fit plane is: Z = -3.0116491523341967e-05 * X + -0.00013461486037363152 * Y + 0.029464586745300073
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.935835487665127
# The direction of the gradient is: 275.7241716485873
# 24
# The equation of the fit plane is: Z = -3.774608317662869e-05 * X + -0.00018384869993634404 * Y + 0.03954863670834758
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.6417687432438646
# The direction of the gradient is: 275.25581847798327
# 25
# The equation of the fit plane is: Z = -6.239355084160387e-05 * X + -7.274996992549332e-05 * Y + 0.024516606063944228
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1151780137243672
# The direction of the gradient is: 291.0201526045375
# 26
# The equation of the fit plane is: Z = -6.26585733336244e-05 * X + -9.500804762367021e-05 * Y + 0.02844716051716656
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4175642230828824
# The direction of the gradient is: 286.4620357356912
# 27
# The equation of the fit plane is: Z = -5.076185303762578e-05 * X + -8.780822550631848e-05 * Y + 0.02493008230507969
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2978969010783157
# The direction of the gradient is: 284.52147802298384
# 28
# The equation of the fit plane is: Z = -7.389840218982409e-05 * X + -7.398994795763353e-05 * Y + 0.026685095967528504
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1598812562535687
# The direction of the gradient is: 294.10833014055777
# 29
# The equation of the fit plane is: Z = -4.675203523074333e-05 * X + -7.483113979318852e-05 * Y + 0.02166672318719079
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1119071987824436
# The direction of the gradient is: 285.6383784198522
# 30
# The equation of the fit plane is: Z = -5.984350089943295e-05 * X + -9.175921868894357e-05 * Y + 0.027286817317714537
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3678747566732425
# The direction of the gradient is: 286.28886030151614
# 31
# The equation of the fit plane is: Z = -6.723217370140897e-05 * X + -8.086261501688325e-05 * Y + 0.026330054066130402
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2347279481033744
# The direction of the gradient is: 290.4316583359033
# 32
# The equation of the fit plane is: Z = -4.006564396744518e-05 * X + -0.00010490230497821451 * Y + 0.025805849013694454
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.522849759554888
# The direction of the gradient is: 279.7106934433213
# 33
# The equation of the fit plane is: Z = -5.077373956934466e-05 * X + -0.00013681471993429265 * Y + 0.03335597030737631
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.9845383902010232
# The direction of the gradient is: 279.4406210835133
# 34
# The equation of the fit plane is: Z = -7.5528748995965135e-06 * X + -0.00012354570564185685 * Y + 0.023208127842988983
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7684588745017904
# The direction of the gradient is: 271.569009696106
# 35
# The equation of the fit plane is: Z = -5.1814123980427286e-05 * X + -0.00018546062488760423 * Y + 0.04218229049148346
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.674436618776347
# The direction of the gradient is: 277.13498258341053
# 36
# The equation of the fit plane is: Z = -1.680369903450682e-06 * X + -0.00017498984179934596 * Y + 0.03124501815663662
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.503924955612518
# The direction of the gradient is: 270.2465124994882
# 37
# The equation of the fit plane is: Z = -1.1938929334213759e-05 * X + -0.0002062129125478468 * Y + 0.03863453995733659
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.9516603183957573
# The direction of the gradient is: 271.4859414932324
# 38
# The equation of the fit plane is: Z = 5.056661206289223e-05 * X + 1.8245035703586527e-05 * Y + -0.012122142137387772
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4162356751622594
# The direction of the gradient is: 141.15574998200145
# 39
# The equation of the fit plane is: Z = 5.7976718638549485e-08 * X + -7.934528768916003e-05 * Y + 0.014127095553162307
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1353391472173733
# The direction of the gradient is: 269.98124219373904
# 40
# The equation of the fit plane is: Z = 4.6600813450265935e-05 * X + 3.745283852255974e-05 * Y + -0.01562757204068583
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.613558906455009
# The direction of the gradient is: 119.13915185841398
# 41
# The equation of the fit plane is: Z = 4.411064183867111e-05 * X + -5.57170657360296e-06 * Y + -0.007328474385056839
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.29381993210346646
# The direction of the gradient is: 195.7439314268264
# 42
# The equation of the fit plane is: Z = 6.094191762539015e-06 * X + -7.128561476219575e-05 * Y + 0.011195139616914497
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0207625062102468
# The direction of the gradient is: 267.80642986339114
# 43
# The equation of the fit plane is: Z = 2.4357259144534042e-05 * X + -2.6464089324509396e-06 * Y + -0.004350570361354715
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16068209616567072
# The direction of the gradient is: 193.63078798070978
# 44
# The equation of the fit plane is: Z = 2.8318023558345865e-06 * X + -7.114778011678493e-05 * Y + 0.012044477079454826
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0182041229185947
# The direction of the gradient is: 268.9783429845454
# 45
# The equation of the fit plane is: Z = -6.429197518216106e-06 * X + -7.580073144559025e-05 * Y + 0.01417911889048699
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.085403505373799
# The direction of the gradient is: 272.17632627631394
# 46
# The equation of the fit plane is: Z = 1.8055821871779116e-06 * X + -0.0001020372026932205 * Y + 0.017416903374507593
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.460079972467504
# The direction of the gradient is: 269.54574555367844
# 47
# The equation of the fit plane is: Z = -1.2251642855357399e-05 * X + -8.962478546653042e-05 * Y + 0.018091805402785353
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2848299400586054
# The direction of the gradient is: 273.50488350200214
# 48
# The equation of the fit plane is: Z = -5.324947371385694e-05 * X + -0.00013392802998453534 * Y + 0.033125562594221315
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.946525330934107
# The direction of the gradient is: 280.10092718864587
# 49
# The equation of the fit plane is: Z = -4.441618023720371e-05 * X + -0.00014576475600484062 * Y + 0.033818274363220234
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.105073233657049
# The direction of the gradient is: 277.7743031143492
# 50
# The equation of the fit plane is: Z = -4.74519499618677e-05 * X + -0.0001285007726375918 * Y + 0.031098528581997926
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8636941333293484
# The direction of the gradient is: 279.39466341976214
# 51
# The equation of the fit plane is: Z = -6.568714405207792e-05 * X + -0.00010984631417012186 * Y + 0.031567560805220045
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6272118938902105
# The direction of the gradient is: 284.998989960397
# 52
# The equation of the fit plane is: Z = -4.105147233000047e-05 * X + -0.00011910155178658528 * Y + 0.02837964439339052
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7244074856185494
# The direction of the gradient is: 278.77896885704394
# 53
# The equation of the fit plane is: Z = -6.478716364460945e-05 * X + -8.0693827037341e-05 * Y + 0.026256712584667944
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2270708060838766
# The direction of the gradient is: 289.78513535011973
# 54
# The equation of the fit plane is: Z = -3.167725669555717e-05 * X + -9.178709241557658e-05 * Y + 0.021872857463403342
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3289756626099016
# The direction of the gradient is: 278.79001246156736
# 55
# The equation of the fit plane is: Z = -6.165304684115505e-05 * X + -7.968432053363207e-05 * Y + 0.025285306414956216
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2067586695084802
# The direction of the gradient is: 289.1195843381631
# 56
# The equation of the fit plane is: Z = -3.927547246488225e-05 * X + -9.643640353206799e-05 * Y + 0.024155603736000474
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4026786762275623
# The direction of the gradient is: 280.34136356253794
# 57
# The equation of the fit plane is: Z = -4.7160062943664836e-05 * X + -6.721611718536104e-05 * Y + 0.020222508478539798
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0081882722755922
# The direction of the gradient is: 287.4510850496987
# 58
# The equation of the fit plane is: Z = -5.6258770613609216e-05 * X + -7.738344469416681e-05 * Y + 0.023928434569880825
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1645303208305835
# The direction of the gradient is: 288.04242482020715
# 59
# The equation of the fit plane is: Z = -5.576496203725632e-05 * X + -8.33596882393695e-05 * Y + 0.024829659790665735
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2452073892008735
# The direction of the gradient is: 286.6851251050009
# 60
# The equation of the fit plane is: Z = -5.170652942236219e-05 * X + -5.4391282469109e-05 * Y + 0.019406178868721504
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8459330192755936
# The direction of the gradient is: 293.0708379471262
# 61
# The equation of the fit plane is: Z = -4.641724574913236e-05 * X + -7.813992325647288e-05 * Y + 0.02170684947682745
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.157015906754391
# The direction of the gradient is: 284.90400085037413
# 62
# The equation of the fit plane is: Z = -4.5227634397394405e-05 * X + -7.750609842063598e-05 * Y + 0.02196163939736712
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1463011966788117
# The direction of the gradient is: 284.65221004825344
# 63
# The equation of the fit plane is: Z = -5.324311566225387e-05 * X + -9.088137732267911e-05 * Y + 0.02573892750763127
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3444611854610733
# The direction of the gradient is: 284.7078564835639
# 64
# The equation of the fit plane is: Z = -3.503611091463708e-05 * X + -7.591788640387422e-05 * Y + 0.019864471448349037
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1092767626679911
# The direction of the gradient is: 281.6827085752892
# 65
# The equation of the fit plane is: Z = -4.046817961967421e-05 * X + -8.512863136131616e-05 * Y + 0.022402892691552063
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2454155227596417
# The direction of the gradient is: 282.0239128937148
# 66
# The equation of the fit plane is: Z = -4.3270107481240404e-05 * X + -8.535134500029152e-05 * Y + 0.02285184588897531
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2523886178835282
# The direction of the gradient is: 282.7973458347443
# 67
# The equation of the fit plane is: Z = -3.8705155237705126e-05 * X + -0.00010691969021408247 * Y + 0.02582266830793988
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.549889903613097
# The direction of the gradient is: 279.21287222888895
# 68
# The equation of the fit plane is: Z = -5.2817849416890265e-05 * X + -0.00010749242358932523 * Y + 0.02881091947566701
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5749254432153947
# The direction of the gradient is: 282.4159235301251
# 69
# The equation of the fit plane is: Z = -6.054376369823918e-06 * X + -8.042104530430662e-05 * Y + 0.015314805743928198
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1513863770062402
# The direction of the gradient is: 271.931900003236
# 70
# The equation of the fit plane is: Z = 6.8985821263309435e-06 * X + -0.00010250734729753657 * Y + 0.016559727311415536
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4674279534605739
# The direction of the gradient is: 268.2728786873515
# 71
# The equation of the fit plane is: Z = -1.609831647771974e-05 * X + -8.235646975207317e-05 * Y + 0.0174020383340799
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1829364892741439
# The direction of the gradient is: 275.0052476906227
# 72
# The equation of the fit plane is: Z = 1.648674102744145e-05 * X + -8.311371256156934e-05 * Y + 0.011635857719436035
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1939486896310874
# The direction of the gradient is: 264.9210716601809
# 73
# The equation of the fit plane is: Z = 1.7715937608865452e-05 * X + -0.00010094591592483762 * Y + 0.014899173068085332
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4488776317398542
# The direction of the gradient is: 265.5039383731954
# 74
# The equation of the fit plane is: Z = 5.038455042796923e-05 * X + -6.280632474994216e-05 * Y + 0.002459951952617255
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9549751830084519
# The direction of the gradient is: 250.22976249399767
# 75
# The equation of the fit plane is: Z = 3.095940251764863e-05 * X + 2.6767498522150433e-05 * Y + -0.010378061013551392
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.43138580563001
# The direction of the gradient is: 117.39396206783306
# 76
# The equation of the fit plane is: Z = -1.1317884433637659e-05 * X + -0.00010623650299972747 * Y + 0.02042042819412707
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5218519682238418
# The direction of the gradient is: 272.7328232595731
# 77
# The equation of the fit plane is: Z = -1.1509865663340826e-05 * X + -0.00010256538361887238 * Y + 0.020175885663931963
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4694456734152659
# The direction of the gradient is: 272.87841518260285
# 78
# The equation of the fit plane is: Z = 4.962338982043758e-05 * X + -2.75963901132705e-05 * Y + -0.004554129874257497
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5070867958226151
# The direction of the gradient is: 231.142398085409
# 79
# The equation of the fit plane is: Z = 8.789331606434362e-06 * X + -7.08875288686604e-05 * Y + 0.010598117811654427
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0158823577401057
# The direction of the gradient is: 266.8202761590006
# 80
# The equation of the fit plane is: Z = 1.719027294160293e-05 * X + -6.339991795797479e-05 * Y + 0.008073498077538297
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9138491113196632
# The direction of the gradient is: 263.07339094731446
# 81
# The equation of the fit plane is: Z = -2.8601671523205992e-05 * X + -8.13884180369892e-05 * Y + 0.01914012860716308
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1789215864856633
# The direction of the gradient is: 278.9480283058185
# 82
# The equation of the fit plane is: Z = 0.0 * X + 0.0 * Y + 5e-324
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0
# The direction of the gradient is: 90.0
# 83
# The equation of the fit plane is: Z = 1.807673582864596e-05 * X + -8.661765098365228e-05 * Y + 0.012008955041851623
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.244804668893935
# The direction of the gradient is: 264.658020589627
# 84
# The equation of the fit plane is: Z = 7.006544726833491e-06 * X + -5.6457191007595765e-05 * Y + 0.008067229909602956
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8090848607978341
# The direction of the gradient is: 266.8173622918006
# 85
# The equation of the fit plane is: Z = 2.3767228594970813e-06 * X + -5.702174115240198e-05 * Y + 0.009450112150736127
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8160572817964248
# The direction of the gradient is: 268.9301148560853
# 86
# The equation of the fit plane is: Z = 3.467812562196339e-05 * X + -2.493936808135776e-05 * Y + -0.002272069556724385
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4204432094002199
# The direction of the gradient is: 238.07655731657906
# 87
# The equation of the fit plane is: Z = 4.352755204700541e-06 * X + -5.331153463364469e-05 * Y + 0.008513849513492492
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7633365182749567
# The direction of the gradient is: 267.90492773465553
# 88
# The equation of the fit plane is: Z = -2.9053938749265424e-06 * X + -5.463031674895766e-05 * Y + 0.010065031785049647
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7819183955694675
# The direction of the gradient is: 271.3650189786081
# 89
# The equation of the fit plane is: Z = 2.529353987177976e-05 * X + -4.952269017203361e-05 * Y + 0.004251159935341103
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7269297823574057
# The direction of the gradient is: 257.1103643261297
# 90
# The equation of the fit plane is: Z = 1.5591576776777476e-05 * X + -6.829185279777256e-05 * Y + 0.009063705591535274
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9822765146032109
# The direction of the gradient is: 264.15932928231314
# 91
# The equation of the fit plane is: Z = -3.2249389954507273e-06 * X + -9.139199119439687e-05 * Y + 0.0166750344499977
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3078768800886844
# The direction of the gradient is: 270.9057883922487
# 92
# The equation of the fit plane is: Z = -1.5142873894640476e-05 * X + -0.00012969741551769728 * Y + 0.025714792873307555
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8583572280714806
# The direction of the gradient is: 272.99454512252646
# 93
# The equation of the fit plane is: Z = -7.830887510839154e-06 * X + -0.00013018270591766038 * Y + 0.024501200615657664
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8634400309876402
# The direction of the gradient is: 271.5438394618883
# 94
# The equation of the fit plane is: Z = 1.2585952585941917e-05 * X + -9.247621266392179e-05 * Y + 0.013918395079215577
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.325685318368444
# The direction of the gradient is: 266.51045996732546
# 95
# The equation of the fit plane is: Z = 4.3916672837010006e-07 * X + -9.316861559110584e-05 * Y + 0.016677685214378183
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.333137857208195
# The direction of the gradient is: 269.87899349673955
# 96
# The equation of the fit plane is: Z = 1.7728566072260196e-06 * X + -0.00012139808422055083 * Y + 0.020937874836160993
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.737103039587515
# The direction of the gradient is: 269.62510888436896
# 97
# The equation of the fit plane is: Z = -2.94793524092243e-05 * X + -0.00012995596949099973 * Y + 0.028260833679402398
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.869098946984428
# The direction of the gradient is: 275.8034001427971
# 98
# The equation of the fit plane is: Z = -4.594797473659957e-05 * X + -0.00014288829678533286 * Y + 0.03350621514117726
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0656778153355626
# The direction of the gradient is: 278.1986225659786
# 99
# The equation of the fit plane is: Z = -5.027174622021154e-05 * X + -0.0001701753120824399 * Y + 0.03884788245734929
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.4562482861032624
# The direction of the gradient is: 277.53980131702156
# 100
# The equation of the fit plane is: Z = -6.209086945034719e-05 * X + -0.0001367191285449113 * Y + 0.035481375170882234
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.99638143015416
# The direction of the gradient is: 281.50161857141444
# 101
# The equation of the fit plane is: Z = -5.0941543212880824e-05 * X + -0.00010226484499211662 * Y + 0.027073501695759686
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4992941647236708
# The direction of the gradient is: 282.58157920330984
# 102
# The equation of the fit plane is: Z = -5.98005854559575e-05 * X + -7.542320532042174e-05 * Y + 0.024242838079665287
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.145293880883246
# The direction of the gradient is: 289.5573033416705
# 103
# The equation of the fit plane is: Z = -5.852371235635689e-05 * X + -8.933969574101793e-05 * Y + 0.02674014621478493
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3322715916503036
# The direction of the gradient is: 286.35718595030517
# 104
# The equation of the fit plane is: Z = -5.849493665775633e-05 * X + -7.14394538119917e-05 * Y + 0.023539909549968294
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0888351527514346
# The direction of the gradient is: 290.14635408453705
# 105
# The equation of the fit plane is: Z = -4.622508323089513e-05 * X + -6.204577165399054e-05 * Y + 0.019510470331208424
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.93595902066145
# The direction of the gradient is: 288.4592520120615
# 106
# The equation of the fit plane is: Z = -5.764097519942669e-05 * X + -6.962110974258304e-05 * Y + 0.02278369140528615
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0625299075803945
# The direction of the gradient is: 290.3524190114382
# 107
# The equation of the fit plane is: Z = -5.767291779181668e-05 * X + -7.579705956662886e-05 * Y + 0.023778286635163928
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1458620604850382
# The direction of the gradient is: 288.8250291294263
# 108
# The equation of the fit plane is: Z = -7.252695427987698e-05 * X + -8.197421886945918e-05 * Y + 0.02750038962583538
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2617562563313518
# The direction of the gradient is: 291.6240725507064
# 109
# The equation of the fit plane is: Z = -5.70561499055776e-05 * X + -7.217060774176426e-05 * Y + 0.023122993204764374
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0955486619936492
# The direction of the gradient is: 289.5049958273005
# 110
# The equation of the fit plane is: Z = -5.113720368533288e-05 * X + -5.21575436939209e-05 * Y + 0.01883646718733669
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8151483371063806
# The direction of the gradient is: 293.7151834921806
# 111
# The equation of the fit plane is: Z = -6.641517118916735e-05 * X + -3.4010258278486944e-05 * Y + 0.018357377031105713
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.646626229041913
# The direction of the gradient is: 311.18437238555
# 112
# The equation of the fit plane is: Z = -5.9077944074099167e-05 * X + -6.583181781597454e-05 * Y + 0.022493879298801943
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0152708742595073
# The direction of the gradient is: 291.90425525955493
# 113
# The equation of the fit plane is: Z = -6.370823417230853e-05 * X + -7.538593665415675e-05 * Y + 0.02511782748354094
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1534228787792198
# The direction of the gradient is: 290.7389182842057
# 114
# The equation of the fit plane is: Z = -4.134257142333617e-05 * X + -8.267017679138021e-05 * Y + 0.021987641991731418
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2122451537391103
# The direction of the gradient is: 282.6294262566063
# 115
# The equation of the fit plane is: Z = -6.41235192334284e-05 * X + -9.6280784426029e-05 * Y + 0.028639609859304287
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4376957028604966
# The direction of the gradient is: 286.61531471647396
# 116
# The equation of the fit plane is: Z = -5.0507865089272735e-05 * X + -7.455389635166e-05 * Y + 0.022376482047647084
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1148417789114533
# The direction of the gradient is: 286.8851303409999
# 117
# The equation of the fit plane is: Z = -5.907659484706043e-05 * X + -8.063334333111018e-05 * Y + 0.02511477998403968
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2143443421597724
# The direction of the gradient is: 288.17332085471753
# 118
# The equation of the fit plane is: Z = -6.127315564892168e-05 * X + -5.415320081530159e-05 * Y + 0.020802199216767413
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8687554616147171
# The direction of the gradient is: 296.8831509955427
# 119
# The equation of the fit plane is: Z = -5.033124644563464e-05 * X + -8.726016770060358e-05 * Y + 0.02441001930506663
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2896133330490436
# The direction of the gradient is: 284.49010615378813
# 120
# The equation of the fit plane is: Z = -6.111805827540648e-05 * X + -9.04161955331408e-05 * Y + 0.027092185147603098
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3517856901340084
# The direction of the gradient is: 286.8497665131636
# 121
# The equation of the fit plane is: Z = -6.407823316959898e-05 * X + -4.756353392687243e-05 * Y + 0.020552634541566854
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7949549561589215
# The direction of the gradient is: 301.1160050785727
# 122
# The equation of the fit plane is: Z = -5.405986993227315e-05 * X + -8.392643572065153e-05 * Y + 0.024526474024565044
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.249902434087986
# The direction of the gradient is: 286.09837987189303
# 123
# The equation of the fit plane is: Z = -5.5621203313955835e-05 * X + -0.00011209250851452762 * Y + 0.030106664544453706
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6430756547646388
# The direction of the gradient is: 282.53448705129364
# 124
# The equation of the fit plane is: Z = -2.1729644962746423e-05 * X + -0.00010691746916471316 * Y + 0.022746944582010535
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5361948028322943
# The direction of the gradient is: 275.20304310855875
# 125
# The equation of the fit plane is: Z = -4.537504920090049e-05 * X + -6.962067381547419e-05 * Y + 0.020413397569415462
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.037796438753837
# The direction of the gradient is: 286.2786198358745
# 126
# The equation of the fit plane is: Z = -7.575602519107078e-05 * X + -8.579305255076085e-05 * Y + 0.029364503248422668
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3201828977282923
# The direction of the gradient is: 291.5853631915482
# 127
# The equation of the fit plane is: Z = -2.4398876540621474e-05 * X + -0.00013117995296907972 * Y + 0.027560217558596074
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.883539572817392
# The direction of the gradient is: 274.7637567844319
# 128
# The equation of the fit plane is: Z = 2.4732872860217877e-05 * X + -5.986375893870218e-05 * Y + 0.005656340925018456
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8711335709099944
# The direction of the gradient is: 259.512507667763
# 129
# The equation of the fit plane is: Z = -1.1175662147529963e-05 * X + -0.00010551767762311962 * Y + 0.020686282849637177
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5115346929703246
# The direction of the gradient is: 272.7168892174253
# 130
# The equation of the fit plane is: Z = 6.897402070191596e-06 * X + -9.818017434488121e-05 * Y + 0.016159688935762462
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4055402540279676
# The direction of the gradient is: 268.1971153357001
# 131
# The equation of the fit plane is: Z = -1.0023300037752005e-05 * X + -0.00016894709250506282 * Y + 0.03154685994883134
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.4182909732302518
# The direction of the gradient is: 271.52267535303304
# 132
# The equation of the fit plane is: Z = 2.910305726181907e-06 * X + -9.60289893767813e-05 * Y + 0.016823182969398182
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.37419018980597
# The direction of the gradient is: 269.2220366564462
# 133
# The equation of the fit plane is: Z = 2.2490257633817637e-05 * X + -7.63735805502554e-05 * Y + 0.009189717434709897
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.10228840953786
# The direction of the gradient is: 262.4837788790612
# 134
# The equation of the fit plane is: Z = 4.84670098775331e-06 * X + -0.0001225179026016426 * Y + 0.02082095258266137
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7533645095212953
# The direction of the gradient is: 268.9845681764036
# 135
# The equation of the fit plane is: Z = 5.11846784970759e-06 * X + -9.822226899800173e-05 * Y + 0.016160669368094883
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.40582984150527
# The direction of the gradient is: 268.6624787616306
# 136
# The equation of the fit plane is: Z = -8.678737105905671e-07 * X + -8.582004337229896e-05 * Y + 0.015273265847675717
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2279979396054381
# The direction of the gradient is: 270.2596058055914
# 137
# The equation of the fit plane is: Z = -9.654479467206343e-06 * X + -9.111509486500254e-05 * Y + 0.01753987450987207
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3052198061278137
# The direction of the gradient is: 272.718079381822
# 138
# The equation of the fit plane is: Z = 3.924175627915788e-05 * X + -1.251823209566632e-05 * Y + -0.005511216942109609
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3088333695178482
# The direction of the gradient is: 215.4500951929823
# 139
# The equation of the fit plane is: Z = -1.651584452765762e-05 * X + -9.08443752821911e-05 * Y + 0.01859961833205699
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3041830968220791
# The direction of the gradient is: 274.6568742160056
# 140
# The equation of the fit plane is: Z = 2.1275837303349697e-05 * X + -3.8329727732309166e-05 * Y + 0.002602658492140347
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5651610679354808
# The direction of the gradient is: 256.03381682006443
# 141
# The equation of the fit plane is: Z = 5.7069867475718704e-05 * X + -2.515436890179784e-05 * Y + -0.006231972831687222
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5132420669716227
# The direction of the gradient is: 224.5303311773257
# 142
# The equation of the fit plane is: Z = -8.833326586802449e-06 * X + -4.219160599507012e-05 * Y + 0.008784888910832369
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6063632932589879
# The direction of the gradient is: 275.35893877459523
# 143
# The equation of the fit plane is: Z = 4.1347454545773466e-05 * X + -2.291081950781382e-05 * Y + -0.004115708644499535
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4215912246393466
# The direction of the gradient is: 231.04090881430932
# 144
# The equation of the fit plane is: Z = 3.820588909359126e-06 * X + 4.810564639823992e-06 * Y + -0.0017971104915788143
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.07306179899934029
# The direction of the gradient is: 109.58786072116959
# 145
# The equation of the fit plane is: Z = 4.21884495772637e-05 * X + 2.706598122289523e-05 * Y + -0.012813157902850382
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.47238117150962206
# The direction of the gradient is: 124.92998348827848
# 146
# The equation of the fit plane is: Z = 1.3574175469895425e-05 * X + -7.972261338480219e-05 * Y + 0.011027517507817042
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1440528718398082
# The direction of the gradient is: 265.63744317197666
# 147
# The equation of the fit plane is: Z = -7.1837781455684366e-06 * X + -9.784159230800822e-05 * Y + 0.018474970550778007
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4007571077575767
# The direction of the gradient is: 271.88417994052656
# 148
# The equation of the fit plane is: Z = 3.420557972667093e-05 * X + -2.2735389785105453e-05 * Y + -0.0024932140535413125
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3923281898992616
# The direction of the gradient is: 236.01626389087005
# 149
# The equation of the fit plane is: Z = 2.29552262447918e-06 * X + -8.759350747455528e-05 * Y + 0.014729634146766217
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2534479479936966
# The direction of the gradient is: 269.3272723596815
# 150
# The equation of the fit plane is: Z = -3.141855548856292e-06 * X + -8.417921919564435e-05 * Y + 0.01525846051788192
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2046754516109783
# The direction of the gradient is: 270.9580549322903
# 151
# The equation of the fit plane is: Z = 3.993536071235792e-05 * X + -9.825642443878094e-05 * Y + 0.009927771947077743
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4290575623510502
# The direction of the gradient is: 259.6792066949565
# 152
# The equation of the fit plane is: Z = 1.5928204123450683e-05 * X + -0.00011568551016911346 * Y + 0.017587924310076556
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6584723519053266
# The direction of the gradient is: 266.46989684112236
# 153
# The equation of the fit plane is: Z = 1.8161933816549593e-05 * X + -9.160962063918226e-05 * Y + 0.012855870354546767
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3159887516622506
# The direction of the gradient is: 264.92387608014724
# 154
# The equation of the fit plane is: Z = -1.310698780110302e-05 * X + -0.00014610124563226473 * Y + 0.027925709689291006
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.092227584282849
# The direction of the gradient is: 272.3017853280521
# 155
# The equation of the fit plane is: Z = -6.181535640382877e-06 * X + -0.0001354369644244753 * Y + 0.025013158384485756
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.9383511276939318
# The direction of the gradient is: 271.17151595401344
# 156
# The equation of the fit plane is: Z = -2.9608766258500195e-05 * X + -0.0001541541229676815 * Y + 0.032724110261990846
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.2139196941811807
# The direction of the gradient is: 274.918651260228
# 157
# The equation of the fit plane is: Z = -4.832086412861127e-05 * X + -0.00012226830068661035 * Y + 0.03045094712705812
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.776733308645986
# The direction of the gradient is: 280.0413455525552
# 158
# The equation of the fit plane is: Z = -5.9394901100218145e-05 * X + -0.00014883903010724184 * Y + 0.036921693986678585
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.1634877706216242
# The direction of the gradient is: 280.1371741516906
# 159
# The equation of the fit plane is: Z = -6.549998245882942e-05 * X + -6.441425402815097e-05 * Y + 0.02340168691121424
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0128456117160118
# The direction of the gradient is: 294.49413044248263
# 160
# The equation of the fit plane is: Z = -7.21481989623474e-05 * X + -0.00012573968103017768 * Y + 0.03529956696072409
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8576953583654863
# The direction of the gradient is: 284.41776993322367
# 161
# The equation of the fit plane is: Z = -5.995511376359068e-05 * X + -0.00011957144271546953 * Y + 0.03197722932040625
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7535743385345084
# The direction of the gradient is: 282.66183868380074
# 162
# The equation of the fit plane is: Z = -6.55705631168421e-05 * X + -8.293672678499928e-05 * Y + 0.026941597526767565
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2589846140760084
# The direction of the gradient is: 289.50582303422686
# 163
# The equation of the fit plane is: Z = -7.8355129855931e-05 * X + -9.682514078802697e-05 * Y + 0.031349782637571315
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4737142559653418
# The direction of the gradient is: 289.9297328745205
# 164
# The equation of the fit plane is: Z = -7.171390743446124e-05 * X + -6.882625399254367e-05 * Y + 0.025384196786232292
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0868582621048055
# The direction of the gradient is: 295.02545928585926
# 165
# The equation of the fit plane is: Z = -5.8149962518113527e-05 * X + -9.18774664249661e-05 * Y + 0.026960953851415066
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3664969818824833
# The direction of the gradient is: 285.8319907171242
# 166
# The equation of the fit plane is: Z = -6.301239512149263e-05 * X + -4.0650474863023474e-05 * Y + 0.018936953663873074
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7081861954031436
# The direction of the gradient is: 304.78090910408355
# 167
# The equation of the fit plane is: Z = -5.237097262887804e-05 * X + -5.448552998222839e-05 * Y + 0.01939594874872743
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8488497896526518
# The direction of the gradient is: 293.29970060476717
# 168
# The equation of the fit plane is: Z = -2.876935209825367e-05 * X + -7.302263409804487e-05 * Y + 0.017973468630431057
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0610234889490442
# The direction of the gradient is: 280.0108519335494
# 169
# The equation of the fit plane is: Z = -6.083854755934325e-05 * X + -4.337358954643748e-05 * Y + 0.018866355408781742
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7330131799523478
# The direction of the gradient is: 302.1478831179878
# 170
# The equation of the fit plane is: Z = -6.050525833321537e-05 * X + -8.008546361654415e-05 * Y + 0.025291913787851946
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2098039447309086
# The direction of the gradient is: 288.7012680465825
# 171
# The equation of the fit plane is: Z = -6.474443331034202e-05 * X + -5.5802091083703383e-05 * Y + 0.021757643533456397
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8999091851997603
# The direction of the gradient is: 297.46771194434154
# 172
# The equation of the fit plane is: Z = -5.097840849108885e-05 * X + -3.162343507468429e-05 * Y + 0.0149850934494398
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5581820553447874
# The direction of the gradient is: 305.83973940782914
# 173
# The equation of the fit plane is: Z = -6.940871726068356e-05 * X + -8.145330491458858e-05 * Y + 0.027051398640107135
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2475606011675164
# The direction of the gradient is: 290.89669454952923
# 174
# The equation of the fit plane is: Z = -6.812131050231266e-05 * X + -7.115362842931689e-05 * Y + 0.024970105840029566
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1078423670836413
# The direction of the gradient is: 293.2172094546172
# 175
# The equation of the fit plane is: Z = -7.5907438502558e-05 * X + -9.051768116432899e-05 * Y + 0.02987833757465675
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.383610552117763
# The direction of the gradient is: 290.5927917495444
# 176
# The equation of the fit plane is: Z = -5.705747706110747e-05 * X + -0.00010000876481655982 * Y + 0.028125995192456593
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4770233427165567
# The direction of the gradient is: 284.33911054646694
# 177
# The equation of the fit plane is: Z = -5.1871647204375635e-05 * X + -0.00010568488707634466 * Y + 0.02827004487082206
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5483623508144426
# The direction of the gradient is: 282.4024752376247
# 178
# The equation of the fit plane is: Z = -5.9284289319920035e-05 * X + -7.592627667651661e-05 * Y + 0.023967207349822384
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1509822066304645
# The direction of the gradient is: 289.28208401005793
# 179
# The equation of the fit plane is: Z = -3.9172730585765276e-05 * X + -6.64522442892095e-05 * Y + 0.018976552359495788
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9834610027175694
# The direction of the gradient is: 284.79509975843666
# 180
# The equation of the fit plane is: Z = -5.029186986457047e-05 * X + -0.00013029517210737054 * Y + 0.03200549003675401
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.89204764652688
# The direction of the gradient is: 279.81170437076213
# 181
# The equation of the fit plane is: Z = -6.3518245087101e-05 * X + -0.00011229854659898634 * Y + 0.03120734229067836
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6576592761366864
# The direction of the gradient is: 284.2208464384558
# 182
# The equation of the fit plane is: Z = -3.8616789913557705e-05 * X + -0.00012834748329157837 * Y + 0.029595233303909698
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8531161425443199
# The direction of the gradient is: 277.677645061886
# 183
# The equation of the fit plane is: Z = -2.734878796558351e-05 * X + -0.0001143980658544684 * Y + 0.024990636079272006
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6462673628049438
# The direction of the gradient is: 276.113870349674
# 184
# The equation of the fit plane is: Z = -4.063600147790223e-05 * X + -9.282152304063805e-05 * Y + 0.023665230762358425
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.353477871862714
# The direction of the gradient is: 281.09769418518505
# 185
# The equation of the fit plane is: Z = -2.4971923006386005e-05 * X + -0.00015095555685893703 * Y + 0.031086291772381158
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.1659240191080227
# The direction of the gradient is: 274.2389574167121
# 186
# The equation of the fit plane is: Z = -1.596080353502053e-05 * X + -0.00014598266291915597 * Y + 0.02838518751927851
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0913474953736517
# The direction of the gradient is: 272.8045036194541
# 187
# The equation of the fit plane is: Z = -2.158765389935522e-05 * X + -0.00015759797997458893 * Y + 0.03178067340626524
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.259287468988517
# The direction of the gradient is: 273.51204416318535
# 188
# The equation of the fit plane is: Z = -2.726841101924513e-05 * X + -0.00012504542244479503 * Y + 0.026921555603893765
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7977751903132344
# The direction of the gradient is: 275.58039972473387
# 189
# The equation of the fit plane is: Z = 1.5657241079670535e-05 * X + -0.00011075072716247542 * Y + 0.016705816424690524
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5878904949489316
# The direction of the gradient is: 266.37558105565176
# 190
# The equation of the fit plane is: Z = 3.685050998838842e-05 * X + -0.00013919230461770647 * Y + 0.017938438626763767
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0056435754014323
# The direction of the gradient is: 263.23522678191364
# 191
# The equation of the fit plane is: Z = 1.6147192282991646e-05 * X + -0.00016513880402289774 * Y + 0.02645926341792682
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.365211397940397
# The direction of the gradient is: 267.49146693200214
# 192
# The equation of the fit plane is: Z = -5.242599920680733e-06 * X + -0.00010882129134864907 * Y + 0.020202540504097113
# ...
# The direction of the gradient is: 268.5028839214042
# 258
# The equation of the fit plane is: Z = 2.037674975228561e-06 * X + -0.0001549332111400775 * Y + 0.027091198806346296
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.216953136368775
# The direction of the gradient is: 269.6623747397018
# 259
# The equation of the fit plane is: Z = 2.8949751633544177e-06 * X + -5.847955244787592e-05 * Y + 0.00926469683861726
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8369804107271843
# The direction of the gradient is: 268.72936981928285
# 260
# The equation of the fit plane is: Z = 1.4215307510490372e-05 * X + -0.00013542717674138027 * Y + 0.021203271028489255
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.9399477858684946
# The direction of the gradient is: 267.3073487208362
# 261
# The equation of the fit plane is: Z = 1.4002052714583133e-05 * X + -0.00018248004221788238 * Y + 0.029180922575492818
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.6126205179194972
# The direction of the gradient is: 268.03095843206813
# 262
# The equation of the fit plane is: Z = 1.3759977628031328e-05 * X + -0.00024309618771473836 * Y + 0.041401033785239336
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.4795430867367854
# The direction of the gradient is: 268.5472326705867
# 263
# The equation of the fit plane is: Z = -5.0589435186650327e-05 * X + -0.0002178225041562656 * Y + 0.04843837392457946
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.133617144896327
# The direction of the gradient is: 275.94081974669723
# 264
# The equation of the fit plane is: Z = -2.8995728327153493e-05 * X + -0.000313858520416734 * Y + 0.06124138460318902
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.494797298993951
# The direction of the gradient is: 272.3702918027897
# 265
# The equation of the fit plane is: Z = 2.621239315975319e-06 * X + -0.00024099048709467266 * Y + 0.04270956063443617
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.4483354524368925
# The direction of the gradient is: 269.7207758968208
# 266
# The equation of the fit plane is: Z = -6.909214395772222e-05 * X + -0.00034274907857432456 * Y + 0.07502995835590795
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.924305011113465
# The direction of the gradient is: 275.1608967768419
# 267
# The equation of the fit plane is: Z = -1.8504273025524143e-05 * X + -0.00037116602294730327 * Y + 0.06948480725523881
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.312280315861186
# The direction of the gradient is: 271.27962043739456
# 268
# The equation of the fit plane is: Z = -6.79750640322313e-05 * X + -0.0003680810268216511 * Y + 0.07775893552475696
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.284811563365605
# The direction of the gradient is: 274.7300699556169
# 269
# The equation of the fit plane is: Z = -6.180784162929181e-05 * X + -0.00024788766949649337 * Y + 0.05546932671813789
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.5690505886163453
# The direction of the gradient is: 276.37442749383547
# 270
# The equation of the fit plane is: Z = -3.348165808773e-05 * X + -0.00022158554999425468 * Y + 0.04564620084870455
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.17789013274411
# The direction of the gradient is: 273.87304812770924
# 271
# The equation of the fit plane is: Z = -5.2253964313540074e-05 * X + -0.00020851714973584216 * Y + 0.046495078395759275
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.0023870248258437
# The direction of the gradient is: 276.40636810980794
# 272
# The equation of the fit plane is: Z = -5.2241869711079715e-05 * X + -0.00015187177792531093 * Y + 0.03620689506360098
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.198767646428631
# The direction of the gradient is: 278.7616791703174
# 273
# The equation of the fit plane is: Z = -6.183613844193757e-05 * X + -0.0001763458259394818 * Y + 0.04266660615371566
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.5542566005878453
# The direction of the gradient is: 278.9287586357033
# 274
# The equation of the fit plane is: Z = -4.686648403110629e-05 * X + -0.00016458349902265398 * Y + 0.037567161420175965
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.374089261895119
# The direction of the gradient is: 277.2708569645186
# 275
# The equation of the fit plane is: Z = -7.96485198661375e-05 * X + -0.00021265851107545855 * Y + 0.05228243768324376
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.0854443893951995
# The direction of the gradient is: 279.526135041659
# 276
# The equation of the fit plane is: Z = -8.205625855910542e-05 * X + -0.00016432270477912078 * Y + 0.04413437711702912
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.4093998309990345
# The direction of the gradient is: 282.61157895335134
# 277
# The equation of the fit plane is: Z = -6.974528394362026e-05 * X + -0.00019719304953701804 * Y + 0.047559055149258095
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.85681387110899
# The direction of the gradient is: 279.00484585390626
# 278
# The equation of the fit plane is: Z = -3.582494012351553e-05 * X + -0.00019720225476361572 * Y + 0.041563345763934084
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.8310675555740663
# The direction of the gradient is: 274.6533616664858
# 279
# The equation of the fit plane is: Z = 2.6383413370158393e-05 * X + -8.920853605632782e-05 * Y + 0.011598030969434047
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2876288264379456
# The direction of the gradient is: 262.45166215427366
# 280
# The equation of the fit plane is: Z = -2.897613125487739e-05 * X + -0.00028441819409922664 * Y + 0.05593001181027604
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.073932303844084
# The direction of the gradient is: 272.6135525144607
# 281
# The equation of the fit plane is: Z = -2.466240455479115e-05 * X + -0.0002433737829547913 * Y + 0.04842425105235519
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.4859842858178
# The direction of the gradient is: 272.59963892814005
# 282
# The equation of the fit plane is: Z = -2.8383233706215512e-05 * X + -0.00014101111044362687 * Y + 0.03199207866974326
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.025894288285675
# The direction of the gradient is: 275.1532927154663
# 283
# The equation of the fit plane is: Z = 6.415162426058083e-05 * X + 0.0001586534149932063 * Y + -0.03806798483495125
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.307101488440886
# The direction of the gradient is: 100.2688668920432
# 284
# The equation of the fit plane is: Z = 4.2831180545287444e-05 * X + -0.00011736832713586848 * Y + 0.014869189717310046
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7017056607824286
# The direction of the gradient is: 260.71391619686005
# 285
# The equation of the fit plane is: Z = 4.984923837682205e-05 * X + -0.00011298447857973494 * Y + 0.012540904562507497
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6479625205588604
# The direction of the gradient is: 258.8178389883353
# 286
# The equation of the fit plane is: Z = -6.328456714147964e-05 * X + -0.00022407593890501587 * Y + 0.05208728685047453
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.2318351502024716
# The direction of the gradient is: 277.21190571083775
# 287
# The equation of the fit plane is: Z = 2.6242992936602518e-05 * X + -6.387943389575807e-05 * Y + 0.006826235378399114
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9293960521495834
# The direction of the gradient is: 259.57040072799896
# 288
# The equation of the fit plane is: Z = 2.0552744694549826e-05 * X + -0.0001600727522781584 * Y + 0.02489346794474477
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.2942424904224037
# The direction of the gradient is: 266.70751674522853
# 289
# The equation of the fit plane is: Z = 2.8662008293383193e-05 * X + 2.2278546028566757e-06 * Y + -0.005769897438571423
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.18649913536227608
# The direction of the gradient is: 170.1581918379551
# 290
# The equation of the fit plane is: Z = -1.373555578692855e-05 * X + -0.00019050594552234913 * Y + 0.037014319442710816
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.727341235836072
# The direction of the gradient is: 271.8502749339617
# 291
# The equation of the fit plane is: Z = -5.743337656383898e-06 * X + -0.00018028040333398655 * Y + 0.033546112477725876
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.579866359356457
# The direction of the gradient is: 270.8177789082414
# 292
# The equation of the fit plane is: Z = 1.4984069313049543e-05 * X + -0.0002386067975919329 * Y + 0.04003100076403129
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.4155378687481677
# The direction of the gradient is: 268.38830832443
# 293
# The equation of the fit plane is: Z = 1.3016110704980934e-05 * X + -0.00023308060077737775 * Y + 0.04014796458828278
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.3361569987046846
# The direction of the gradient is: 268.56671000428105
# 294
# The equation of the fit plane is: Z = -6.300544619518922e-05 * X + -0.00018370416110009 * Y + 0.04584294858903965
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.65944848139017
# The direction of the gradient is: 278.73624194972683
# 295
# The equation of the fit plane is: Z = -2.5191885829847896e-05 * X + 0.0001477034312554585 * Y + -0.02036157722737504
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.119626944513784
# The direction of the gradient is: 85.63005062562968
# 296
# The equation of the fit plane is: Z = -7.691440976894205e-05 * X + -0.00023873288946445886 * Y + 0.05881041219382866
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.451397690459546
# The direction of the gradient is: 278.2140130786972
# 297
# The equation of the fit plane is: Z = -4.962551319784999e-05 * X + -0.0003695242546623837 * Y + 0.07651224261531099
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.297026906953046
# The direction of the gradient is: 273.44340668631787
# 298
# The equation of the fit plane is: Z = -1.9742072795780104e-05 * X + -0.0003423406677593514 * Y + 0.06599048259159983
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.900132968312372
# The direction of the gradient is: 271.48008687069955
# 299
# The equation of the fit plane is: Z = -9.967686696137549e-05 * X + -0.0003321708844986101 * Y + 0.07732945719713974
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.795747020049844
# The direction of the gradient is: 277.657478512068
# 300
# The equation of the fit plane is: Z = -8.220588175895747e-05 * X + -0.00032869335567697395 * Y + 0.07374225858111665
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.73265738821223
# The direction of the gradient is: 276.39371941227955
# 301
# The equation of the fit plane is: Z = -8.675135983315375e-05 * X + -0.0002699442699281269 * Y + 0.06409529670909592
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.902425327654813
# The direction of the gradient is: 278.19364214314805
# 302
# The equation of the fit plane is: Z = -6.484175021617464e-05 * X + -0.00020639340493751437 * Y + 0.049038825445166224
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.982364674806792
# The direction of the gradient is: 278.01243368068106
# 303
# The equation of the fit plane is: Z = -3.814613848454951e-05 * X + -0.00022181230514688494 * Y + 0.046199071479885605
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.1832850249023665
# The direction of the gradient is: 274.40612908531324
# 304
# The equation of the fit plane is: Z = -7.006486097198874e-05 * X + -0.00024158109502864195 * Y + 0.05587297471256519
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.4858086589571697
# The direction of the gradient is: 277.4038921483202
# 305
# The equation of the fit plane is: Z = -5.159280258056722e-05 * X + -0.00021401153922939376 * Y + 0.04776452003329034
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.080068849360005
# The direction of the gradient is: 276.1648286664149
# 306
# The equation of the fit plane is: Z = -2.9280768358305235e-05 * X + -0.00028212561553175836 * Y + 0.055986654453413214
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.041252812471293
# The direction of the gradient is: 272.66242126537816
# 307
# The equation of the fit plane is: Z = -0.0001310742334981853 * X + -0.0003640988974532718 * Y + 0.08939318771503646
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.2771689510513164
# The direction of the gradient is: 279.1626910960783
# 308
# The equation of the fit plane is: Z = -2.3967637352189515e-05 * X + -0.00022315275095289308 * Y + 0.04444615770678058
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.1967522704213582
# The direction of the gradient is: 272.7551017294817
# 309
# The equation of the fit plane is: Z = -3.494951385787283e-05 * X + -0.0002242396783790149 * Y + 0.047194638085764296
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.2164237817134764
# The direction of the gradient is: 273.99460446544083
# 310
# The equation of the fit plane is: Z = -1.8032042814021096e-05 * X + -0.00018067228786422236 * Y + 0.03682104498181121
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.5877945035822107
# The direction of the gradient is: 272.56043480410256
# 311
# The equation of the fit plane is: Z = -5.0781977525028026e-05 * X + -0.00012423117147798105 * Y + 0.032858841358166274
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8071719151835033
# The direction of the gradient is: 280.37867244078166
# 312
# The equation of the fit plane is: Z = -1.3494756286144834e-05 * X + -0.00014286723481840555 * Y + 0.030271929602188472
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0460944296545116
# The direction of the gradient is: 272.4233876429487
# 313
# The equation of the fit plane is: Z = 7.036750424037218e-06 * X + -0.00021004259349872227 * Y + 0.03765423075376427
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.005804586601335
# The direction of the gradient is: 269.14003310932196
# 314
# The equation of the fit plane is: Z = -8.460333953857847e-06 * X + -0.00011839005765735976 * Y + 0.023824338585572476
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.694892596416151
# The direction of the gradient is: 271.8338909177643
# 315
# The equation of the fit plane is: Z = 4.664267009304198e-05 * X + -8.142059635153737e-05 * Y + 0.0055293071958683725
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.202798397200854
# The direction of the gradient is: 255.60461194496474
# 316
# The equation of the fit plane is: Z = -8.940209673826211e-06 * X + -0.00013299545795928143 * Y + 0.02609455698361834
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.9038737849982055
# The direction of the gradient is: 271.72515925905816
# 317
# The equation of the fit plane is: Z = 5.0578236004743894e-05 * X + -4.470668493107635e-05 * Y + -0.0014500562317324077
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7171907162665637
# The direction of the gradient is: 243.11977026354782
# 318
# The equation of the fit plane is: Z = 7.075857533888743e-05 * X + -7.968394445208642e-05 * Y + 0.0015975566253804909
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2271144866532764
# The direction of the gradient is: 248.30414657998767
# 319
# The equation of the fit plane is: Z = 3.037829649866584e-05 * X + -0.00016965139974327114 * Y + 0.025476975438921946
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.4353149696992147
# The direction of the gradient is: 265.4130256239663
# 320
# The equation of the fit plane is: Z = -5.390402845616243e-05 * X + -0.00021187008945014007 * Y + 0.04868551819913357
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.0512488427221913
# The direction of the gradient is: 276.50325098588087
# 321
# The equation of the fit plane is: Z = -6.935837827891828e-05 * X + -0.0002250365070225414 * Y + 0.0546196023893799
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.250569012951151
# The direction of the gradient is: 277.86244166976115
# 322

# %%
with h5py.File(path_hight_GIM, 'r') as file:
    date_hight_GIM = file['date']
    date_hight_GIM = date_hight_GIM[()]
date_hight_GIM = np.char.decode(date_hight_GIM)

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

slope_ion_hight_GIM_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_hight_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_hight_GIM_correct[i] = slope_ion_hight_GIM[j[0]]
slope_ion_hight_GIM = slope_ion_hight_GIM_correct

angle_deg_ion_hight_GIM_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_hight_GIM == date_split[i])[0]
    if len(j) > 0:
        angle_deg_ion_hight_GIM_correct[i] = angle_deg_ion_hight_GIM[j[0]]
angle_deg_ion_hight_GIM = angle_deg_ion_hight_GIM_correct

slope_ion_hight_GIM_dongxifangxiang_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_hight_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_hight_GIM_dongxifangxiang_correct[i] = slope_ion_hight_GIM_dongxifangxiang[j[0]]
slope_ion_hight_GIM_dongxifangxiang = slope_ion_hight_GIM_dongxifangxiang_correct

slope_ion_hight_GIM_nanbeifangxiang_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_hight_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_hight_GIM_nanbeifangxiang_correct[i] = slope_ion_hight_GIM_nanbeifangxiang[j[0]]
slope_ion_hight_GIM_nanbeifangxiang = slope_ion_hight_GIM_nanbeifangxiang_correct

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi
from scipy.stats import binned_statistic

# 假设 angle_deg_ion_split 和 slope_ion_split 是已经定义好的 numpy 数组
# 转换为弧度
ion_split_angle_deg_rad = np.deg2rad(angle_deg_ion_split)

# 计算每个bin中的均值
bin_means, bin_edges, _ = binned_statistic(ion_split_angle_deg_rad, slope_ion_split, statistic='mean', bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12))

# 从蓝色颜色图中取颜色，bin_means / bin_means.max() 使均值在 0-1 之间，以便映射到颜色的深浅
#colors = plt.get_cmap('Blues')(bin_means / np.nanmax(bin_means))
colors = plt.get_cmap('Blues')(bin_means/5)

fig = plt.figure()
ax = fig.add_subplot(111, polar=True)

# 绘制直方图，颜色由均值决定
n, bins, patches = ax.hist(ion_split_angle_deg_rad, bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12), alpha=0.7)

# 清除常规极坐标图的细节
#ax.set_yticklabels([])  # 删除y轴标签
#ax.set_yticks([])  # 删除y轴刻度

# 设置x轴标签为0-360度
ax.set_xticks(np.arange(0, 2*np.pi, np.pi/12))
ax.set_xticklabels(['270°','285°', '300°','315°', '330°','345°' ,'0°','15°', '30°','45°', '60°','75°', '90°','105°', '120°','135°', '150°','165°', '180°','195°', '210°','225°', '240°','255°'])

# 设置直方图的颜色
for i in range(len(patches)):
    patches[i].set_facecolor(colors[i])

ax.grid(True)  # 显示网格线
ax.set_title('ion_split_angle')

# 添加颜色条
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=0, vmax=5))
sm.set_array([])
cax = fig.add_axes([0.85, 0.1, 0.03, 0.8])  # 定义颜色条的位置和大小
cbar = fig.colorbar(sm, cax=cax)
cbar.set_label('Mean Slpoe (cm/100km)')

# 在径向上添加长度刻度
#ax.set_yticks(np.linspace(0, max(n), 5))  # 设置刻度范围和数量
ax.set_yticks(np.linspace(0, 150, 6))

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi
from scipy.stats import binned_statistic

# 假设 angle_deg_ion_GIM 和 slope_ion_GIM 是已经定义好的 numpy 数组
# 转换为弧度
ion_GIM_angle_deg_rad = np.deg2rad(angle_deg_ion_GIM)

# 计算每个bin中的均值
bin_means, bin_edges, _ = binned_statistic(ion_GIM_angle_deg_rad, slope_ion_GIM, statistic='mean', bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12))

# 从蓝色颜色图中取颜色，bin_means / bin_means.max() 使均值在 0-1 之间，以便映射到颜色的深浅
#colors = plt.get_cmap('Blues')(bin_means / np.nanmax(bin_means))
colors = plt.get_cmap('Blues')(bin_means/5)

fig = plt.figure()
ax = fig.add_subplot(111, polar=True)

# 绘制直方图，颜色由均值决定
n, bins, patches = ax.hist(ion_GIM_angle_deg_rad, bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12), alpha=0.7)

# 清除常规极坐标图的细节
#ax.set_yticklabels([])  # 删除y轴标签
#ax.set_yticks([])  # 删除y轴刻度

# 设置x轴标签为0-360度
ax.set_xticks(np.arange(0, 2*np.pi, np.pi/12))
ax.set_xticklabels(['270°','285°', '300°','315°', '330°','345°' ,'0°','15°', '30°','45°', '60°','75°', '90°','105°', '120°','135°', '150°','165°', '180°','195°', '210°','225°', '240°','255°'])

# 设置直方图的颜色
for i in range(len(patches)):
    patches[i].set_facecolor(colors[i])

ax.grid(True)  # 显示网格线
ax.set_title('ion_GIM_angle')

# 添加颜色条
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=0, vmax=5))
sm.set_array([])
cax = fig.add_axes([0.85, 0.1, 0.03, 0.8])  # 定义颜色条的位置和大小
cbar = fig.colorbar(sm, cax=cax)
cbar.set_label('Mean Slpoe (cm/100km)')

# 在径向上添加长度刻度
#ax.set_yticks(np.linspace(0, max(n), 5))  # 设置刻度范围和数量
ax.set_yticks(np.linspace(0, 150, 6))

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi
from scipy.stats import binned_statistic

# 假设 angle_deg_ion_GIM 和 slope_ion_GIM 是已经定义好的 numpy 数组
# 转换为弧度
ion_hight_GIM_angle_deg_rad = np.deg2rad(angle_deg_ion_hight_GIM)

# 计算每个bin中的均值
bin_means, bin_edges, _ = binned_statistic(ion_hight_GIM_angle_deg_rad, slope_ion_hight_GIM, statistic='mean', bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12))

# 从蓝色颜色图中取颜色，bin_means / bin_means.max() 使均值在 0-1 之间，以便映射到颜色的深浅
#colors = plt.get_cmap('Blues')(bin_means / np.nanmax(bin_means))
colors = plt.get_cmap('Blues')(bin_means/5)

fig = plt.figure()
ax = fig.add_subplot(111, polar=True)

# 绘制直方图，颜色由均值决定
n, bins, patches = ax.hist(ion_hight_GIM_angle_deg_rad, bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12), alpha=0.7)

# 清除常规极坐标图的细节
#ax.set_yticklabels([])  # 删除y轴标签
#ax.set_yticks([])  # 删除y轴刻度

# 设置x轴标签为0-360度
ax.set_xticks(np.arange(0, 2*np.pi, np.pi/12))
ax.set_xticklabels(['270°','285°', '300°','315°', '330°','345°' ,'0°','15°', '30°','45°', '60°','75°', '90°','105°', '120°','135°', '150°','165°', '180°','195°', '210°','225°', '240°','255°'])

# 设置直方图的颜色
for i in range(len(patches)):
    patches[i].set_facecolor(colors[i])

ax.grid(True)  # 显示网格线
ax.set_title('ion_hight_GIM_angle')

# 添加颜色条
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=0, vmax=5))
sm.set_array([])
cax = fig.add_axes([0.85, 0.1, 0.03, 0.8])  # 定义颜色条的位置和大小
cbar = fig.colorbar(sm, cax=cax)
cbar.set_label('Mean Slpoe (cm/100km)')

# 在径向上添加长度刻度
#ax.set_yticks(np.linspace(0, max(n), 5))  # 设置刻度范围和数量
ax.set_yticks(np.linspace(0, 150, 6))

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split, slope_ion_GIM)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope')
plt.ylabel('ion_GIM_slope')

# 添加标题
plt.title('ion_split_slope vs ion_GIM_slope')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-2 , 18]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=4))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=4))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_GIM, slope_ion_hight_GIM)

# 为x轴和y轴添加标签
plt.xlabel('ion_GIM_slope')
plt.ylabel('ion_hight_GIM_slope')

# 添加标题
plt.title('ion_GIM_slope vs ion_hight_GIM_slope')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-2 , 18]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=4))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=4))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split, slope_ion_hight_GIM)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope')
plt.ylabel('ion_hight_GIM_slope')

# 添加标题
plt.title('ion_split_slope vs ion_hight_GIM_slope')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-2 , 18]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=4))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=4))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split_dongxifangxiang, slope_ion_GIM_dongxifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope W-E')
plt.ylabel('ion_GIM_slope W-E')

# 添加标题
plt.title('ion_split_slope vs ion_GIM_slope in W-E direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-2 , 10]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=4))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=4))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split_dongxifangxiang, slope_ion_hight_GIM_dongxifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope W-E')
plt.ylabel('ion_hight_GIM_slope W-E')

# 添加标题
plt.title('ion_split_slope vs ion_hight_GIM_slope in W-E direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-2 , 10]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=4))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=4))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_GIM_dongxifangxiang, slope_ion_hight_GIM_dongxifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_GIM_slope W-E')
plt.ylabel('ion_hight_GIM_slope W-E')

# 添加标题
plt.title('ion_GIM_slope vs ion_hight_GIM_slope in W-E direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-1.5 , 1.5]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=1))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split_nanbeifangxiang, slope_ion_GIM_nanbeifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope N-S')
plt.ylabel('ion_GIM_slope N-S')

# 添加标题
plt.title('ion_split_slope vs ion_GIM_slope in N-S direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-12, 10]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=4))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=4))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split_nanbeifangxiang, slope_ion_hight_GIM_nanbeifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope N-S')
plt.ylabel('ion_hight_GIM_slope N-S')

# 添加标题
plt.title('ion_split_slope vs ion_hight_GIM_slope in N-S direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-12, 10]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=4))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=4))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_GIM_nanbeifangxiang, slope_ion_hight_GIM_nanbeifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_GIM_slope N-S')
plt.ylabel('ion_hight_GIM_slope N-S')

# 添加标题
plt.title('ion_GIM_slope vs ion_hight_GIM_slope in N-S direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim =[-8, 6]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=4))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=4))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split, width, label='Ion-Split slope', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM, width, label='Ion-GIM slope', alpha=1)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope(cm(ion)/ 100km(distance))')
ax.set_title('Ion-GIM Slope vs Ion-Split Slope')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split, width, label='Ion-Split slope', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM, width, label='Ion-hight-GIM slope', alpha=1)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope(cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-Split Slope')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]


ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM, width, label='Ion-hight-GIM slope', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM, width, label='Ion-GIM slope', alpha=1)


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope(cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-GIM Slope')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split_dongxifangxiang, width, label='Ion-Split slope W-E', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM_dongxifangxiang, width, label='Ion-GIM slope W-E', alpha=1) 

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope W-E (cm(ion)/ 100km(distance))')
ax.set_title('Ion-GIM Slope vs Ion-Split Slope in W-E direction')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split_dongxifangxiang, width, label='Ion-Split slope W-E', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM_dongxifangxiang, width, label='Ion-hight-GIM slope W-E', alpha=1) 

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope W-E (cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-Split Slope in W-E direction')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM_dongxifangxiang, width, label='Ion-hight-GIM slope W-E', alpha=1) 
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM_dongxifangxiang, width, label='Ion-GIM slope W-E', alpha=1) 

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope W-E (cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-GIM Slope in W-E direction')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split_nanbeifangxiang, width, label='Ion-Split slope N-S', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM_nanbeifangxiang, width, label='Ion-GIM slope N-S', alpha=1)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope N-S (cm(ion)/ 100km(distance))')
ax.set_title('Ion-GIM Slope vs Ion-Split Slope in N-S direction')

ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split_nanbeifangxiang, width, label='Ion-Split slope N-S', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM_nanbeifangxiang, width, label='Ion-hight-GIM slope N-S', alpha=1)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope N-S (cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-Split Slope in N-S direction')

ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM_nanbeifangxiang, width, label='Ion-hight-GIM slope N-S', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM_nanbeifangxiang, width, label='Ion-GIM slope N-S', alpha=1)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope N-S (cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-GIM Slope in N-S direction')

ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, angle_deg_ion_split, width, label='Ion-Split angle', alpha=1)
ax.bar(date_GIM_numeric, angle_deg_ion_GIM, width, label='Ion-GIM angle', alpha=1) 
ax.bar(date_GIM_numeric, angle_deg_ion_hight_GIM, width, label='Ion-hight-GIM angle', alpha=1) 

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('degree')
ax.set_title('Ion-GIM angle , Ion-hight-GIM angle vs Ion-Split angle')
ax.legend()

plt.show()
