# %%
# !pwd
# Out:
# /panda/eedy/chile/s1_a149/notebook

# %%
from mintpy.objects import ramp
from mintpy.utils import ptime, readfile, writefile
import h5py
import numpy as np
from matplotlib import pyplot as plt, colorbar, ticker, colors
from mintpy.utils import ptime, readfile, writefile
from scipy.optimize import curve_fit
from mpl_toolkits.mplot3d import Axes3D

# %%
######### split

# %%
path_split = '../mintpy_split_ion_upsample/geo/geo_ion-split.h5'

# %%
# !reference_point.py ../mintpy_split_ion_upsample/geo/geo_ion-split.h5 -y 180 -x 190
# !reference_date.py ../mintpy_split_ion_upsample/geo/geo_ion-split.h5 --ref-date 20181211
# Out:
# WARNING: auto turn ON --write-data for file tpye timeseries
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# --------------------------------------------------
# input reference point in y/x: (180, 190)
# --------------------------------------------------
# calculating the temporal average of timeseries file: ../mintpy_split_ion_upsample/geo/geo_ion-split.h5
# reading timeseries data from file: ../mintpy_split_ion_upsample/geo/geo_ion-split.h5 ...
# /home/eedy/tools/MintPy/src/mintpy/objects/stack.py:455: RuntimeWarning: Mean of empty slice
#   dmean = np.nanmean(data, axis=0)
# updating dataset values without re-writing to a new file
# update metadata
# input reference date: 20181211
# --------------------------------------------------
# change reference date for file: /panda/eedy/chile/s1_a149/mintpy_split_ion_upsample/geo/geo_ion-split.h5
# reading data ...
# referencing in time ...
# --------------------------------------------------
# open  HDF5 file /panda/eedy/chile/s1_a149/mintpy_split_ion_upsample/geo/geo_ion-split.h5 in r+ mode
# writing dataset /timeseries                block: (0, 320, 0, 788, 0, 343)
# close HDF5 file /panda/eedy/chile/s1_a149/mintpy_split_ion_upsample/geo/geo_ion-split.h5.
# update "REF_DATE" attribute value to 20181211
# time used: 00 mins 2.3 secs.

# %%
timeseries_split = readfile.read(path_split, datasetName='timeseries')[0]
timeseries_split = np.squeeze(timeseries_split)
data_out, ramp = ramp.deramp(timeseries_split, mask_in=None, ramp_type='linear', metadata=None, max_num_sample=1e3, coeff_file=None,ignore_zero_value=True)

# %%
def function(data, a, b, c):
    '''
    拟合曲面使用的函数
    '''
    x = data[0]
    y = data[1]
    return a*x+b*y + c



slope_ion_split = np.zeros(timeseries_split.shape[0])
slope_ion_split_dongxifangxiang = np.zeros(timeseries_split.shape[0])
slope_ion_split_nanbeifangxiang = np.zeros(timeseries_split.shape[0])
angle_deg_ion_split = np.zeros(timeseries_split.shape[0])
meta = readfile.read_attribute(path_split)
AZIMUTH_PIXEL_SIZE =  float(meta['AZIMUTH_PIXEL_SIZE'])
RANGE_PIXEL_SIZE = float(meta['RANGE_PIXEL_SIZE'])

for i in range(timeseries_split.shape[0]):
    x_data = ramp.shape[2]
    y_data = ramp.shape[1]
    X_data, Y_data = np.meshgrid(range(x_data), range(y_data))
    Z_data = ramp[i, :,:]
    
    x_data = X_data.flatten()
    y_data = Y_data.flatten()
    z_data = Z_data.flatten()
    
    parameters, covariance = curve_fit(function, [x_data, y_data], z_data)
    print("The equation of the fit plane is: Z = {0} * X + {1} * Y + {2}".format(parameters[0],parameters[1],parameters[2]))
    
    Z_fit = function([X_data, Y_data], *parameters)
    
    # 计算梯度，考虑到横纵坐标的实际长度
    dx = parameters[1]/RANGE_PIXEL_SIZE
    dy = parameters[0]/AZIMUTH_PIXEL_SIZE
    # 计算梯度的大小和方向
    magnitude = np.hypot(dx, dy)  # 梯度的大小
    direction = np.degrees(np.arctan2(dy, dx)) + 90  # 梯度的方向，以x轴正半轴为0°，逆时针旋转为正方向
    direction = (direction + 360) % 360  # 将角度值限制在0°到360°之间

    print('The magnitude of the gradient is( cm(ion)/ 100km(juli)):', magnitude*1e7)
    print('The direction of the gradient is:', direction)

    slope_ion_split[i] = magnitude*1e7
    angle_deg_ion_split[i] = direction
    slope_ion_split_dongxifangxiang[i] = dy*1e7
    slope_ion_split_nanbeifangxiang[i] = dx*1e7

    print(i)
# Out:
# The equation of the fit plane is: Z = 0.001182967547956297 * X + 0.00018479631810928757 * Y + -0.23881232773838698
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 8.031844263766937
# The direction of the gradient is: 160.77873182879205
# 0
# The equation of the fit plane is: Z = 0.0009218245965480614 * X + 0.000348143799064156 * Y + -0.2133138467444775
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.729329072191959
# The direction of the gradient is: 139.87198090793817
# 1
# The equation of the fit plane is: Z = 0.0008387702006511272 * X + -0.0002588723279793414 * Y + -0.11559167351797173
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.529741567057832
# The direction of the gradient is: 214.56046114876858
# 2
# The equation of the fit plane is: Z = 0.00045200172547511916 * X + -0.0004226841152838168 * Y + -0.007566097378780325
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.706498004572322
# The direction of the gradient is: 244.3996373267712
# 3
# The equation of the fit plane is: Z = 0.001042600959880795 * X + 8.463088546751445e-05 * Y + -0.19792034878925807
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.7930105514630705
# The direction of the gradient is: 169.73116414267167
# 4
# The equation of the fit plane is: Z = 0.0013896533603927582 * X + 0.0009190841572380139 * Y + -0.4049493964816816
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 15.884681224561742
# The direction of the gradient is: 124.11573107994491
# 5
# The equation of the fit plane is: Z = 0.0009674304062590161 * X + -4.617677742961059e-05 * Y + -0.16595243564624493
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.237371681357418
# The direction of the gradient is: 186.08085553328578
# 6
# The equation of the fit plane is: Z = 0.0005422771068024115 * X + -0.0008718648676877841 * Y + 0.029281147158703787
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 12.95073849745598
# The direction of the gradient is: 254.4281406865598
# 7
# The equation of the fit plane is: Z = 0.0004805593731873962 * X + -0.00042200879507753823 * Y + -0.017160821115341028
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.779007308587962
# The direction of the gradient is: 242.96868265655598
# 8
# The equation of the fit plane is: Z = 6.888227458860557e-05 * X + -0.0002735720814697772 * Y + 0.04351519515308441
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.9393304658388653
# The direction of the gradient is: 263.5634531060639
# 9
# The equation of the fit plane is: Z = 0.0001828554883300769 * X + -0.00018905866826715811 * Y + 0.0025384251691098407
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.948296867123689
# The direction of the gradient is: 246.57052530646092
# 10
# The equation of the fit plane is: Z = 0.00021913719292379922 * X + -0.0002812589596366924 * Y + 0.013833803215269018
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.2626611262777665
# The direction of the gradient is: 250.75644661166086
# 11
# The equation of the fit plane is: Z = 0.0005735735628789152 * X + -0.00014888487336307165 * Y + -0.07225764013088823
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.249762231247095
# The direction of the gradient is: 210.08548585946198
# 12
# The equation of the fit plane is: Z = 0.0009256469329098293 * X + 0.00034124231316111814 * Y + -0.2228005565977082
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.68496275207104
# The direction of the gradient is: 140.55269213157243
# 13
# The equation of the fit plane is: Z = 0.0009601318690251634 * X + 0.00018215541541285638 * Y + -0.19821744672814018
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.684570802418254
# The direction of the gradient is: 157.0506181015635
# 14
# The equation of the fit plane is: Z = 0.0005291288113084292 * X + -0.0002361493671918453 * Y + -0.056071722714384827
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.7880500468732
# The direction of the gradient is: 224.88775822141542
# 15
# The equation of the fit plane is: Z = 0.0005378012880788704 * X + -0.00023705724916453313 * Y + -0.05772783215886775
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.83670318133099
# The direction of the gradient is: 224.53196955593012
# 16
# The equation of the fit plane is: Z = 0.0006064543999400628 * X + -0.00016079325194233405 * Y + -0.07217140553704314
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.517775142714381
# The direction of the gradient is: 210.61518299283466
# 17
# The equation of the fit plane is: Z = 0.00032175332432546295 * X + -0.0003642474193095888 * Y + 0.0012259677889009644
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.605318955277542
# The direction of the gradient is: 248.4073471635121
# 18
# The equation of the fit plane is: Z = 0.00046637046769230727 * X + -0.00034925442494543183 * Y + -0.030845181651137452
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.823573258006284
# The direction of the gradient is: 239.10808791036766
# 19
# The equation of the fit plane is: Z = 6.508545966865083e-05 * X + -0.00015086651924080415 * Y + 0.019517339198055483
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.1986828861850727
# The direction of the gradient is: 259.0599951727751
# 20
# The equation of the fit plane is: Z = 6.910529449693314e-05 * X + -0.00019140738595371036 * Y + 0.02173047510637231
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.7744201565961903
# The direction of the gradient is: 260.8112513921442
# 21
# The equation of the fit plane is: Z = 0.0003588925808358857 * X + -0.00013552874258475413 * Y + -0.03643346485040444
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.0091230099613075
# The direction of the gradient is: 220.1251947289694
# 22
# The equation of the fit plane is: Z = 0.0002796315347626905 * X + -0.00042800825266462757 * Y + 0.011117484408234958
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.381300350687515
# The direction of the gradient is: 253.683887161744
# 23
# The equation of the fit plane is: Z = -7.379059871144309e-05 * X + -4.7150354532921305e-05 * Y + 0.0170793956513378
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8240011521490113
# The direction of the gradient is: 305.0382067004839
# 24
# The equation of the fit plane is: Z = -0.00017151560451795134 * X + -0.00011821330193336904 * Y + 0.04695472021434012
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.017493046257687
# The direction of the gradient is: 303.0269342664478
# 25
# The equation of the fit plane is: Z = -4.414592659874035e-05 * X + -0.00010584830979581763 * Y + 0.01862154446951757
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5407836126055674
# The direction of the gradient is: 280.58463938313196
# 26
# The equation of the fit plane is: Z = -0.00012158703634013834 * X + -3.6422188769818276e-05 * Y + 0.02826107300977841
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9376749828398617
# The direction of the gradient is: 326.23419905532614
# 27
# The equation of the fit plane is: Z = -4.11924636245076e-05 * X + -8.502672212157446e-05 * Y + 0.01612225531107054
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2449660625155416
# The direction of the gradient is: 282.2469056771662
# 28
# The equation of the fit plane is: Z = -8.117366141902813e-05 * X + -0.0001137782832841154 * Y + 0.025498287771287476
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7091889118987615
# The direction of the gradient is: 287.72678458198567
# 29
# The equation of the fit plane is: Z = -9.333544698133525e-05 * X + -0.00010897920941601955 * Y + 0.03113933220326282
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6702344018333883
# The direction of the gradient is: 290.9934890950657
# 30
# The equation of the fit plane is: Z = -1.1478368448589465e-05 * X + -0.00014299641544570691 * Y + 0.02329946130545248
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.047435825611783
# The direction of the gradient is: 272.05976385110006
# 31
# The equation of the fit plane is: Z = -7.2472306078281e-05 * X + -0.0001967121266718344 * Y + 0.04401500428285378
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.8528126482777347
# The direction of the gradient is: 279.37328379096954
# 32
# The equation of the fit plane is: Z = 3.5830459195901505e-05 * X + -0.0003642780300838001 * Y + 0.027489250160445587
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.2174556115245645
# The direction of the gradient is: 267.47658872824877
# 33
# The equation of the fit plane is: Z = -4.1532109857557975e-05 * X + -0.00032807914147842923 * Y + 0.050414790603170605
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.701977357603482
# The direction of the gradient is: 273.24630909381676
# 34
# The equation of the fit plane is: Z = 0.00035960673040471674 * X + -0.00024754166483854863 * Y + -0.03315496293778113
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.226250331543593
# The direction of the gradient is: 236.9403692865826
# 35
# The equation of the fit plane is: Z = 0.00035282072388845076 * X + -0.0003461111265806255 * Y + -0.015201816120901044
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.444559405224249
# The direction of the gradient is: 245.45210247680643
# 36
# The equation of the fit plane is: Z = 0.0006799640829114895 * X + 0.00045665488819694386 * Y + -0.19367038140536746
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.85489312459676
# The direction of the gradient is: 123.70931499144899
# 37
# The equation of the fit plane is: Z = 0.0003198115621260482 * X + -0.00015320583866981993 * Y + -0.04373509434971223
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.001602812671572
# The direction of the gradient is: 226.91511043152082
# 38
# The equation of the fit plane is: Z = 0.00042562448764078115 * X + 0.0002047669119798856 * Y + -0.11694093156341909
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.00382882188286
# The direction of the gradient is: 132.96301324019248
# 39
# The equation of the fit plane is: Z = 0.00017361308485629057 * X + -6.096069256170874e-05 * Y + -0.03288197613543376
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4141224982432112
# The direction of the gradient is: 218.0852005110986
# 40
# The equation of the fit plane is: Z = 0.00012671923080100455 * X + -0.00010864936549165026 * Y + -0.011297393811480979
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7541184575285205
# The direction of the gradient is: 242.4099011692564
# 41
# The equation of the fit plane is: Z = 0.00015495099119654872 * X + 9.038695050420425e-05 * Y + -0.04576363743315561
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6308156528876194
# The direction of the gradient is: 127.52772587502494
# 42
# The equation of the fit plane is: Z = 0.00018559468128310586 * X + 2.396822051773757e-05 * Y + -0.03426530246571264
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.238302655947768
# The direction of the gradient is: 163.92128589817776
# 43
# The equation of the fit plane is: Z = 3.262290412492759e-05 * X + -5.843800618257217e-05 * Y + -0.0021501946187902333
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8619397573715146
# The direction of the gradient is: 255.95710720644763
# 44
# The equation of the fit plane is: Z = 8.126217391518798e-05 * X + -0.00010845594069710823 * Y + -0.0012891446963102572
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.636993093332371
# The direction of the gradient is: 251.44267259416984
# 45
# The equation of the fit plane is: Z = 0.00010186005864728354 * X + -0.0002652686093789307 * Y + 0.013717009490614586
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.851452565226472
# The direction of the gradient is: 260.23804966357056
# 46
# The equation of the fit plane is: Z = -5.201573395214289e-06 * X + -0.0003099350781760908 * Y + 0.04540560833014365
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.434937056553162
# The direction of the gradient is: 270.43082945003323
# 47
# The equation of the fit plane is: Z = 7.420714568733946e-05 * X + -4.535782036899207e-05 * Y + -0.0053980852186041985
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8047114082830457
# The direction of the gradient is: 233.75754511820764
# 48
# The equation of the fit plane is: Z = -7.154814561432856e-05 * X + -0.00021823127870384743 * Y + 0.03873381611577529
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.1561473536271127
# The direction of the gradient is: 278.35672301801156
# 49
# The equation of the fit plane is: Z = -0.00012718601177893736 * X + -0.0001363650192624732 * Y + 0.03855328390256863
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.1147476440847304
# The direction of the gradient is: 292.6796245961689
# 50
# The equation of the fit plane is: Z = -3.0743932680500696e-05 * X + -0.00015125051343802914 * Y + 0.019359292735383934
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.17317630466684
# The direction of the gradient is: 275.2037413850451
# 51
# The equation of the fit plane is: Z = -6.747589421206675e-05 * X + -4.6461348849032595e-05 * Y + 0.015386585877509833
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7931625992248158
# The direction of the gradient is: 303.05223209696044
# 52
# The equation of the fit plane is: Z = -5.225019206538568e-05 * X + -0.00011222130806329561 * Y + 0.02529656510952797
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6403252096535552
# The direction of the gradient is: 281.7835960011864
# 53
# The equation of the fit plane is: Z = -0.00014717347283161689 * X + -2.4897398099029882e-05 * Y + 0.028469622319923477
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0085565726012529
# The direction of the gradient is: 339.3149675668797
# 54
# The equation of the fit plane is: Z = -4.9851964109694424e-05 * X + -0.00013786963711140486 * Y + 0.03302342403551131
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.9984765295395042
# The direction of the gradient is: 279.20250556059295
# 55
# The equation of the fit plane is: Z = -0.00012602928431860368 * X + -5.967365576350468e-05 * Y + 0.029543991075864667
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.175549558332262
# The direction of the gradient is: 313.41870242714174
# 56
# The equation of the fit plane is: Z = -9.450285417140674e-05 * X + -5.2982251665229274e-05 * Y + 0.02381105121655894
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9704694250256612
# The direction of the gradient is: 308.6309458335463
# 57
# The equation of the fit plane is: Z = -0.0001314864914059351 * X + -6.071583644863896e-05 * Y + 0.035661360525519444
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2105233083001106
# The direction of the gradient is: 314.136401544617
# 58
# The equation of the fit plane is: Z = -0.00013304801936528905 * X + -1.9187100810267707e-05 * Y + 0.029282065984583987
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8960765159909693
# The direction of the gradient is: 342.1584402585377
# 59
# The equation of the fit plane is: Z = -0.00012798365767748552 * X + -7.182190407045924e-05 * Y + 0.03518035152723769
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3150611983102811
# The direction of the gradient is: 308.6041243472223
# 60
# The equation of the fit plane is: Z = -0.0001317571158793238 * X + -7.840549308986967e-05 * Y + 0.03728102606559101
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4043393030693059
# The direction of the gradient is: 306.97718287200064
# 61
# The equation of the fit plane is: Z = -9.395456969112727e-05 * X + -0.00012004698097712838 * Y + 0.040206321713515715
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.820283845481116
# The direction of the gradient is: 289.32403143147735
# 62
# The equation of the fit plane is: Z = -1.0846045271487223e-05 * X + -0.00012968599123223338 * Y + 0.02020183517380055
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8569585409802005
# The direction of the gradient is: 272.14597554969066
# 63
# The equation of the fit plane is: Z = -5.358405779764591e-05 * X + -7.073593997001616e-05 * Y + 0.01782933986233473
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0688593578957455
# The direction of the gradient is: 288.7476366984702
# 64
# The equation of the fit plane is: Z = -0.0001241009203090213 * X + -5.3475119572721386e-05 * Y + 0.031789460130302455
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.103854025881116
# The direction of the gradient is: 316.11782100807966
# 65
# The equation of the fit plane is: Z = -3.34719230361754e-05 * X + -0.0001056796167862693 * Y + 0.02445535773210327
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5273033515951078
# The direction of the gradient is: 278.07697524157686
# 66
# The equation of the fit plane is: Z = -0.00011959803973434246 * X + -0.00010560736251106014 * Y + 0.040129313835838246
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.694517777078385
# The direction of the gradient is: 296.9035746645023
# 67
# The equation of the fit plane is: Z = 0.00012474574904998423 * X + 1.1017275611581029e-05 * Y + -0.02487170640755515
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8151443770238574
# The direction of the gradient is: 168.84904978719032
# 68
# The equation of the fit plane is: Z = 0.0002116018663524959 * X + 6.463650972996262e-05 * Y + -0.048858641783001935
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.641872924571068
# The direction of the gradient is: 145.71540183789193
# 69
# The equation of the fit plane is: Z = 8.443315710476153e-05 * X + -0.00016517716809501007 * Y + 0.0007697843451623194
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.4246890995558847
# The direction of the gradient is: 257.1001008465021
# 70
# The equation of the fit plane is: Z = 0.000198015591490602 * X + 8.438280663425159e-05 * Y + -0.05443266537037516
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7519929571168487
# The direction of the gradient is: 136.43559503145127
# 71
# The equation of the fit plane is: Z = 0.0002234417930760394 * X + -9.798842049563146e-05 * Y + -0.02909138898676465
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0044833846766816
# The direction of the gradient is: 224.38548586799243
# 72
# The equation of the fit plane is: Z = 0.00029048710486604903 * X + 0.00014634015475590076 * Y + -0.07309194366682092
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.8023130916084886
# The direction of the gradient is: 131.6494459907151
# 73
# The equation of the fit plane is: Z = 0.00030920082804913136 * X + 0.00022166916771670895 * Y + -0.09272304747468331
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.7403287821874343
# The direction of the gradient is: 122.00433235225233
# 74
# The equation of the fit plane is: Z = 1.8070218406053613e-05 * X + -0.00010427203172860216 * Y + 0.012489129768712503
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4965028056608745
# The direction of the gradient is: 265.5600853643472
# 75
# The equation of the fit plane is: Z = -1.8035640970423492e-06 * X + -0.0001545334088075491 * Y + 0.022439140907416878
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.2112241702339714
# The direction of the gradient is: 270.2996089670152
# 76
# The equation of the fit plane is: Z = 0.0002313496300045865 * X + -7.357967658148709e-05 * Y + -0.04393829737526207
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8188894692217759
# The direction of the gradient is: 215.36875987130884
# 77
# The equation of the fit plane is: Z = -3.089977036171627e-05 * X + -5.7452224109695955e-05 * Y + 0.013329971746855542
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.845606797512673
# The direction of the gradient is: 283.54864325022504
# 78
# The equation of the fit plane is: Z = 0.00013925961277555852 * X + -0.00010681102635047438 * Y + -0.010355622193541743
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.770008411596234
# The direction of the gradient is: 239.707993973317
# 79
# The equation of the fit plane is: Z = -0.00011782774462708144 * X + -6.796589489227487e-05 * Y + 0.03249375836661441
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2314285202438844
# The direction of the gradient is: 307.8384146466175
# 80
# The equation of the fit plane is: Z = 0.0 * X + 0.0 * Y + 5e-324
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0
# The direction of the gradient is: 90.0
# 81
# The equation of the fit plane is: Z = 6.044820460959759e-05 * X + -7.2337688889568e-05 * Y + -0.000973657937937414
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1052387917859112
# The direction of the gradient is: 249.4736721383506
# 82
# The equation of the fit plane is: Z = -7.915914544884709e-06 * X + -3.326606484586534e-05 * Y + 0.00623313659725168
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4786965648197533
# The direction of the gradient is: 276.08571649231885
# 83
# The equation of the fit plane is: Z = -5.587591798772965e-05 * X + 2.104769106664869e-06 * Y + 0.010311878474213873
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3594889029082811
# The direction of the gradient is: 4.805685948331984
# 84
# The equation of the fit plane is: Z = 0.00012925606210649433 * X + 8.379876442030153e-06 * Y + -0.025972370858583407
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8373014270405371
# The direction of the gradient is: 171.76661231553646
# 85
# The equation of the fit plane is: Z = 1.7547994074600833e-05 * X + -1.964968560630777e-05 * Y + 0.0012868308624809995
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3028364899233
# The direction of the gradient is: 248.19227458246291
# 86
# The equation of the fit plane is: Z = -7.203553890004e-05 * X + -2.524378638859096e-05 * Y + 0.01628440219572452
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5863064449171381
# The direction of the gradient is: 321.9698551851477
# 87
# The equation of the fit plane is: Z = 5.8363579089327147e-05 * X + -4.356960593847764e-05 * Y + -0.007558991866139231
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7270980963520203
# The direction of the gradient is: 239.02844529422907
# 88
# The equation of the fit plane is: Z = 9.223760108580205e-05 * X + -6.572722930984918e-06 * Y + -0.019755274913505493
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5987749658100108
# The direction of the gradient is: 189.0367202209011
# 89
# The equation of the fit plane is: Z = 4.576062010128245e-05 * X + -8.893654655189787e-05 * Y + 0.003990156441312043
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3059578765394513
# The direction of the gradient is: 257.01807645642907
# 90
# The equation of the fit plane is: Z = 2.6823597899209913e-05 * X + -0.00020934872404940554 * Y + 0.02358371671981003
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.0004696870720244
# The direction of the gradient is: 266.7143608863456
# 91
# The equation of the fit plane is: Z = 0.00011755295765443603 * X + -0.00017177776033764958 * Y + 0.0037583046434449575
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.5708846660001288
# The direction of the gradient is: 252.95366882378835
# 92
# The equation of the fit plane is: Z = 0.00012124600932900608 * X + -0.00011616193482296794 * Y + -0.00859941833182815
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.834922807383918
# The direction of the gradient is: 244.93637194972519
# 93
# The equation of the fit plane is: Z = 0.0004521026219381791 * X + -0.0001576602627187283 * Y + -0.052488120047487194
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.6729223224720395
# The direction of the gradient is: 217.89434168227012
# 94
# The equation of the fit plane is: Z = 0.00024499310084817865 * X + -7.827716198214755e-05 * Y + -0.035899822284503176
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.9291272063197304
# The direction of the gradient is: 215.4929073503257
# 95
# The equation of the fit plane is: Z = 7.030914867523985e-05 * X + -0.00024035048481401027 * Y + 0.01623663679850407
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.468550791179453
# The direction of the gradient is: 262.53297045221666
# 96
# The equation of the fit plane is: Z = -0.00012787639380613385 * X + -0.00025891304258008794 * Y + 0.06252334670966515
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.7943713721645516
# The direction of the gradient is: 282.4779433279051
# 97
# The equation of the fit plane is: Z = -8.29477584104006e-05 * X + -0.00031798563451407964 * Y + 0.06497150014635536
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.580976760293072
# The direction of the gradient is: 276.66623861194455
# 98
# The equation of the fit plane is: Z = -0.00016577425182837113 * X + -0.00015115076679562742 * Y + 0.05362077439858279
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.409812883782973
# The direction of the gradient is: 296.16942378712554
# 99
# The equation of the fit plane is: Z = -6.319357232584887e-05 * X + -0.00011821761677763005 * Y + 0.029698871680195166
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7393973256065813
# The direction of the gradient is: 283.4690049211666
# 100
# The equation of the fit plane is: Z = -0.00014168974076796996 * X + -2.382060692226776e-05 * Y + 0.030942298772965275
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9702258468882724
# The direction of the gradient is: 339.43283941973016
# 101
# The equation of the fit plane is: Z = -0.00012979857887132618 * X + -8.994984242779465e-05 * Y + 0.04170359321086705
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5326586028897653
# The direction of the gradient is: 302.884348745077
# 102
# The equation of the fit plane is: Z = -0.00011949542904787396 * X + -7.588402135460993e-05 * Y + 0.03374478643864101
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.328868017997258
# The direction of the gradient is: 305.2048873248641
# 103
# The equation of the fit plane is: Z = -0.0001010193138984297 * X + -4.3922407117296715e-06 * Y + 0.018749014705758422
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6506854490339334
# The direction of the gradient is: 354.45732129452074
# 104
# The equation of the fit plane is: Z = -0.00012289766939156522 * X + -4.346928516713545e-05 * Y + 0.026881214567268483
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.003830431172305
# The direction of the gradient is: 321.71148857164195
# 105
# The equation of the fit plane is: Z = -0.00012386721650420437 * X + -6.316975311910106e-05 * Y + 0.028948360370427733
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2031795800346408
# The direction of the gradient is: 311.3014232891114
# 106
# The equation of the fit plane is: Z = -0.0001826166904370325 * X + -3.246523288200809e-05 * Y + 0.04256889721859399
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.259563957675529
# The direction of the gradient is: 338.35775124674944
# 107
# The equation of the fit plane is: Z = -0.0001153458216714648 * X + -4.3141140390755505e-05 * Y + 0.02479477427574695
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9632791800449236
# The direction of the gradient is: 320.1461445426055
# 108
# The equation of the fit plane is: Z = -0.0001504697947498075 * X + -3.53523747086508e-05 * Y + 0.0340548308380222
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0892576718001332
# The direction of the gradient is: 332.3285879147939
# 109
# The equation of the fit plane is: Z = -0.00016438009487257155 * X + 1.6283907436739343e-05 * Y + 0.02648946316883143
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.079305280720586
# The direction of the gradient is: 12.467345715463466
# 110
# The equation of the fit plane is: Z = -0.00011693349075688241 * X + -7.453195742153697e-05 * Y + 0.0321732753585137
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3035931444171895
# The direction of the gradient is: 305.10523203923026
# 111
# The equation of the fit plane is: Z = -0.00018581299729125453 * X + -3.468428636189054e-05 * Y + 0.03939133477319945
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2905084494176624
# The direction of the gradient is: 337.3828993547735
# 112
# The equation of the fit plane is: Z = -0.00011845815329556385 * X + -0.00015053956535694872 * Y + 0.03704460927550449
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.2840038977322785
# The direction of the gradient is: 289.42095109054196
# 113
# The equation of the fit plane is: Z = -0.00013602428509016236 * X + -0.00010574350726932047 * Y + 0.038213454744039595
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7463864312950315
# The direction of the gradient is: 299.9571909207564
# 114
# The equation of the fit plane is: Z = -0.00013833122088371144 * X + -0.00011097373389370894 * Y + 0.03439133602088049
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8187775905996015
# The direction of the gradient is: 299.1835701976008
# 115
# The equation of the fit plane is: Z = -0.0001362945202916377 * X + -5.566505939462955e-05 * Y + 0.03209796433836054
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1823428803610685
# The direction of the gradient is: 317.64947039212814
# 116
# The equation of the fit plane is: Z = -0.0001530393828995591 * X + 3.015104275465742e-07 * Y + 0.029658118465673327
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9811576433745165
# The direction of the gradient is: 0.25193704285806007
# 117
# The equation of the fit plane is: Z = -0.00010214877513688732 * X + -0.00014510380008984176 * Y + 0.038522715522417726
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.1770986992450143
# The direction of the gradient is: 287.50601717522636
# 118
# The equation of the fit plane is: Z = -0.0001451035826711003 * X + -5.162936085087633e-05 * Y + 0.03742623969160883
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1879247315306185
# The direction of the gradient is: 321.54585199441544
# 119
# The equation of the fit plane is: Z = -9.313375173895278e-05 * X + -5.844784147337061e-06 * Y + 0.02013977740180911
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6029167761778856
# The direction of the gradient is: 352.0266497135534
# 120
# The equation of the fit plane is: Z = -0.00015096037083144197 * X + -0.00013293644466868585 * Y + 0.047929907824264074
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.134223874828965
# The direction of the gradient is: 296.9669242150514
# 121
# The equation of the fit plane is: Z = -3.679307233338093e-05 * X + -0.00015587609416549582 * Y + 0.030403449954909578
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.242844812435628
# The direction of the gradient is: 276.03704956754086
# 122
# The equation of the fit plane is: Z = 1.4841377179684872e-05 * X + -0.00019246369831500888 * Y + 0.017767645104829012
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.755575640727107
# The direction of the gradient is: 268.0211985292467
# 123
# The equation of the fit plane is: Z = -0.00011113493291668074 * X + -3.887379333106778e-05 * Y + 0.02906614280061928
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9039088606055103
# The direction of the gradient is: 322.0211478863336
# 124
# The equation of the fit plane is: Z = -0.0001824114991345203 * X + -6.37985653049165e-05 * Y + 0.04563566358185124
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4835706372002113
# The direction of the gradient is: 322.02419582335494
# 125
# The equation of the fit plane is: Z = 2.0579376627208337e-05 * X + -7.95771630465332e-05 * Y + 0.007705940647599365
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1462751807663838
# The direction of the gradient is: 263.390616402422
# 126
# The equation of the fit plane is: Z = 0.00024132222562022246 * X + 9.924550504698567e-05 * Y + -0.0597914120698129
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.100067258045732
# The direction of the gradient is: 137.4517547221144
# 127
# The equation of the fit plane is: Z = 3.781429084320279e-05 * X + -0.00010505814497174412 * Y + 0.007013262138938873
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.522683158434259
# The direction of the gradient is: 260.8387964847698
# 128
# The equation of the fit plane is: Z = 0.00029916657322468247 * X + -0.00014672951867795788 * Y + -0.03114420480761357
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.8437083303156747
# The direction of the gradient is: 227.58738353186084
# 129
# The equation of the fit plane is: Z = 9.195143666843545e-05 * X + -0.0003068961186598762 * Y + 0.031378584232217864
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.430719907181476
# The direction of the gradient is: 262.3541111383016
# 130
# The equation of the fit plane is: Z = 0.0004170287766314714 * X + -7.364243103002471e-05 * Y + -0.07677284413920163
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.8737662681798657
# The direction of the gradient is: 201.51069230840085
# 131
# The equation of the fit plane is: Z = 0.0001927086710026834 * X + -0.00011521221163117422 * Y + -0.01820831430283227
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.060125439635378
# The direction of the gradient is: 233.15109786796427
# 132
# The equation of the fit plane is: Z = 0.00013215220963522868 * X + -0.0001965596099393105 * Y + 0.006775318032643115
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.9373790455436857
# The direction of the gradient is: 253.23579990465805
# 133
# The equation of the fit plane is: Z = 3.8400275545555806e-05 * X + -4.422921166216653e-05 * Y + -8.069082458805599e-05
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6790663148631887
# The direction of the gradient is: 248.74385438131162
# 134
# The equation of the fit plane is: Z = 7.883644983801067e-05 * X + -0.00026462572947141876 * Y + 0.02109722909088754
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.820071133870344
# The direction of the gradient is: 262.3970010656053
# 135
# The equation of the fit plane is: Z = 1.6132202173465737e-05 * X + -7.48576371023061e-05 * Y + 0.011696797116327297
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0761076309050799
# The direction of the gradient is: 264.48477989920866
# 136
# The equation of the fit plane is: Z = 0.00010922538950359635 * X + 8.847948419158626e-06 * Y + -0.02257390126681503
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7116058127894779
# The direction of the gradient is: 169.75178177950988
# 137
# The equation of the fit plane is: Z = -0.00011463996280863916 * X + -0.00013360313327552813 * Y + 0.03693461946225637
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0481199009037256
# The direction of the gradient is: 291.0295415017483
# 138
# The equation of the fit plane is: Z = 7.61055676300574e-05 * X + -3.350205633785003e-05 * Y + -0.003930850465341356
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6840073104087986
# The direction of the gradient is: 224.49395544295612
# 139
# The equation of the fit plane is: Z = 0.00022578707922245325 * X + 4.785207973462935e-05 * Y + -0.05139136045583187
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6013106616830848
# The direction of the gradient is: 154.68515445302296
# 140
# The equation of the fit plane is: Z = -5.570106887263889e-05 * X + -2.0954141980128466e-05 * Y + 0.012891116037930746
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4662843581270503
# The direction of the gradient is: 319.9827265624681
# 141
# The equation of the fit plane is: Z = 7.673890438591809e-05 * X + -4.2866873744364565e-05 * Y + -0.00961422637106079
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7863033907470596
# The direction of the gradient is: 231.26740238920934
# 142
# The equation of the fit plane is: Z = -5.069563403882854e-06 * X + 4.752055794099264e-05 * Y + -0.005379906583307266
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.680740415004076
# The direction of the gradient is: 87.2634198166594
# 143
# The equation of the fit plane is: Z = 0.00014632404178093793 * X + 6.096625502282772e-05 * Y + -0.03793602003124716
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2810265454917371
# The direction of the gradient is: 137.0795468855223
# 144
# The equation of the fit plane is: Z = 7.436838463101991e-05 * X + -8.344497194693546e-05 * Y + -0.0043118879395281084
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2856744929864548
# The direction of the gradient is: 248.23245594051514
# 145
# The equation of the fit plane is: Z = -1.5950184640493987e-05 * X + -0.00015684728371152053 * Y + 0.021764041091367866
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.2466312054946154
# The direction of the gradient is: 272.60878337061416
# 146
# The equation of the fit plane is: Z = 0.00024200839648077678 * X + -4.45432366452493e-05 * Y + -0.036688137409859475
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6773473058692667
# The direction of the gradient is: 202.33257863136282
# 147
# The equation of the fit plane is: Z = 3.646591911838738e-05 * X + -0.00010472548185141753 * Y + 0.010545874206772067
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5166274707406155
# The direction of the gradient is: 261.13257780560116
# 148
# The equation of the fit plane is: Z = 0.00023770796369718838 * X + -9.094685985348811e-05 * Y + -0.026524563004668218
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0039878306282546
# The direction of the gradient is: 220.49466670552397
# 149
# The equation of the fit plane is: Z = 0.00023340225388750882 * X + -0.00022259335702310234 * Y + -0.015476024565214096
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.5190423058889024
# The direction of the gradient is: 244.83551826154428
# 150
# The equation of the fit plane is: Z = 0.00020367552426048355 * X + -0.00017305793966360496 * Y + -0.014014201037242833
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.7994498168773023
# The direction of the gradient is: 242.19642154942994
# 151
# The equation of the fit plane is: Z = 0.00029014595027729377 * X + 0.00014866260654711498 * Y + -0.07756750970979194
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.8257905809499584
# The direction of the gradient is: 131.16851203732512
# 152
# The equation of the fit plane is: Z = 2.4668727288711465e-05 * X + -0.00019049166935884704 * Y + 0.02522046334372047
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.7302993440266246
# The direction of the gradient is: 266.67926923908226
# 153
# The equation of the fit plane is: Z = 2.4381144810825212e-05 * X + -0.00016616326488537973 * Y + 0.021618283318630995
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.382736244638439
# The direction of the gradient is: 266.2386466771993
# 154
# The equation of the fit plane is: Z = 5.171381901427622e-05 * X + -0.00021606721965476493 * Y + 0.02204501003395504
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.109397385820077
# The direction of the gradient is: 263.87916359859196
# 155
# The equation of the fit plane is: Z = -0.00010373100988434478 * X + -0.00013437497750803395 * Y + 0.03905999708530752
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0345098981166645
# The direction of the gradient is: 289.0791406949971
# 156
# The equation of the fit plane is: Z = -0.0001292724028006101 * X + -0.00029380168414141073 * Y + 0.07352619874933074
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.284875983101565
# The direction of the gradient is: 281.1523760192465
# 157
# The equation of the fit plane is: Z = -0.00015293910897916084 * X + -2.098491464805676e-05 * Y + 0.03190362499424401
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0254523806988323
# The direction of the gradient is: 342.9733239293623
# 158
# The equation of the fit plane is: Z = -0.000153381809017852 * X + -0.00019213454335653118 * Y + 0.055438374726073165
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.9197926675281103
# The direction of the gradient is: 289.6811425510482
# 159
# The equation of the fit plane is: Z = -0.00010234398645309748 * X + -0.00023898494931270868 * Y + 0.045580381251193534
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.4819767062439766
# The direction of the gradient is: 280.8616257070182
# 160
# The equation of the fit plane is: Z = -0.00010348923503996946 * X + -6.490552266882358e-05 * Y + 0.028059222548833123
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.141371608538021
# The direction of the gradient is: 305.54195205250016
# 161
# The equation of the fit plane is: Z = -0.00019172453131717778 * X + -8.722056350528652e-05 * Y + 0.0530954368047364
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7516865115286648
# The direction of the gradient is: 314.56371202505056
# 162
# The equation of the fit plane is: Z = -0.0001418325423752473 * X + -3.303205150698756e-05 * Y + 0.03308858929085975
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.024804945580775
# The direction of the gradient is: 332.5347810256287
# 163
# The equation of the fit plane is: Z = -0.00013476318493605324 * X + -7.35228961469364e-05 * Y + 0.03793220618469489
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.361330069254325
# The direction of the gradient is: 309.39456477875524
# 164
# The equation of the fit plane is: Z = -0.00011783650050356673 * X + -1.3407795645045124e-06 * Y + 0.02294473828419862
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7557031273295501
# The direction of the gradient is: 358.5452783351282
# 165
# The equation of the fit plane is: Z = -0.00013766800672468632 * X + -3.009270906244656e-05 * Y + 0.03019948934838963
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9820355363201928
# The direction of the gradient is: 333.99378516453237
# 166
# The equation of the fit plane is: Z = -1.9390335119063798e-05 * X + -5.8747409815511264e-05 * Y + 0.015912941575206403
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.849749621656893
# The direction of the gradient is: 278.4122035841136
# 167
# The equation of the fit plane is: Z = -0.00016064343725433503 * X + 1.0920988879249969e-05 * Y + 0.028452550010725424
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0416861103855921
# The direction of the gradient is: 8.627692851958386
# 168
# The equation of the fit plane is: Z = -0.00012452583519130615 * X + -9.856038552066158e-05 * Y + 0.03985541877934606
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.620573613136708
# The direction of the gradient is: 299.51368286590986
# 169
# The equation of the fit plane is: Z = -0.0001455576590392976 * X + -3.645449075555427e-05 * Y + 0.0325217279117853
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.069073441692758
# The direction of the gradient is: 330.79608911209505
# 170
# The equation of the fit plane is: Z = -8.038942846847562e-05 * X + 2.8467383408526585e-06 * Y + 0.01569436630720937
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5169904729439984
# The direction of the gradient is: 4.519001198829756
# 171
# The equation of the fit plane is: Z = -0.000152434155244752 * X + -8.881507453342953e-05 * Y + 0.041659189355629046
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6031497011356242
# The direction of the gradient is: 307.56004205902497
# 172
# The equation of the fit plane is: Z = -0.00012292526427826664 * X + -5.3613086448230684e-05 * Y + 0.031027487751146873
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0998099663086678
# The direction of the gradient is: 315.771508323018
# 173
# The equation of the fit plane is: Z = -0.00018620348814218514 * X + -6.139111863218404e-05 * Y + 0.04495111988407939
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4821358147249961
# The direction of the gradient is: 323.6524120251739
# 174
# The equation of the fit plane is: Z = -0.00010978083168217531 * X + -5.260858940190941e-05 * Y + 0.024859463604274497
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0305404919689358
# The direction of the gradient is: 313.07508397321794
# 175
# The equation of the fit plane is: Z = -0.00014436528527278522 * X + -0.00017339627010392038 * Y + 0.04820842208145689
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.6481079146336093
# The direction of the gradient is: 290.45729209999683
# 176
# The equation of the fit plane is: Z = -0.00014303112331492856 * X + -8.630707959897662e-05 * Y + 0.03855965451723565
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.538171761440317
# The direction of the gradient is: 306.5948087266696
# 177
# The equation of the fit plane is: Z = -7.500360427459508e-05 * X + 1.0399210412617468e-05 * Y + 0.00819463665067431
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5033512768902912
# The direction of the gradient is: 17.194712009150294
# 178
# The equation of the fit plane is: Z = -4.661314800303309e-06 * X + -0.00010585483261546076 * Y + 0.022771806268113023
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5149547193544914
# The direction of the gradient is: 271.13029282374146
# 179
# The equation of the fit plane is: Z = -0.00014817291576745733 * X + -0.00012720393370140582 * Y + 0.04746156249769307
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0531233359483485
# The direction of the gradient is: 297.56048493634984
# 180
# The equation of the fit plane is: Z = -3.6285202538038067e-07 * X + -0.00014891760096802435 * Y + 0.025336978952308045
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.1308395080045184
# The direction of the gradient is: 270.06255080696843
# 181
# The equation of the fit plane is: Z = -1.7694092208405988e-06 * X + -6.708472224716253e-05 * Y + 0.009183573281394034
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9599716343054404
# The direction of the gradient is: 270.6770706886946
# 182
# The equation of the fit plane is: Z = -6.317199539778539e-05 * X + -0.00011514805029284358 * Y + 0.028418282137681963
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6966812302210341
# The direction of the gradient is: 283.80993327983697
# 183
# The equation of the fit plane is: Z = -2.7399161483528633e-05 * X + -0.000234795041163682 * Y + 0.03661430145067195
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.364233848134715
# The direction of the gradient is: 272.9929719403931
# 184
# The equation of the fit plane is: Z = 1.578087538056215e-05 * X + -0.0003232471139240775 * Y + 0.04132216986294324
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.626397857319436
# The direction of the gradient is: 268.746925900714
# 185
# The equation of the fit plane is: Z = 4.17875816108651e-05 * X + -0.00020141545167656462 * Y + 0.019998497276405805
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.89444658015735
# The direction of the gradient is: 264.6892265897786
# 186
# The equation of the fit plane is: Z = -2.2645376519283373e-05 * X + -0.00010830925762279692 * Y + 0.018742681307139575
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5565652682480817
# The direction of the gradient is: 275.3517760102375
# 187
# The equation of the fit plane is: Z = 0.0001974021228524483 * X + -1.3381551724817794e-05 * Y + -0.0301251851758768
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2799640746143879
# The direction of the gradient is: 188.60337849374162
# 188
# The equation of the fit plane is: Z = 0.0002794878821454545 * X + -7.303244124642987e-05 * Y + -0.03389970877845044
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.074286328097837
# The direction of the gradient is: 210.2512182532838
# 189
# The equation of the fit plane is: Z = 0.00017890776974450578 * X + -8.402137908316598e-05 * Y + -0.01955093050247534
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.661623723032515
# The direction of the gradient is: 226.34739354374165
# 190
# The equation of the fit plane is: Z = 0.00018597532974016544 * X + -0.00015435314202129677 * Y + -0.007233139852354415
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.5098934556544235
# The direction of the gradient is: 241.63795594407668
# 191
# The equation of the fit plane is: Z = 0.00020656549152527854 * X + -0.0002679010397949105 * Y + -0.0011368200099850143
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.055661547349558
# The direction of the gradient is: 250.94150571420073
# 192
# ...
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.1855294980409106
# The direction of the gradient is: 255.51554570749477
# 255
# The equation of the fit plane is: Z = 8.914989233688953e-05 * X + -0.00020731001169123226 * Y + 0.012634376505737772
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.020925898271893
# The direction of the gradient is: 259.09412782979723
# 256
# The equation of the fit plane is: Z = 3.36084576829074e-06 * X + -7.463642676372102e-05 * Y + 0.00640832829408118
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0681780806418837
# The direction of the gradient is: 268.844184814026
# 257
# The equation of the fit plane is: Z = 0.00022475129118189118 * X + -0.00018297542726387257 * Y + -0.014195825569728572
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.9884753393581795
# The direction of the gradient is: 241.17395773033957
# 258
# The equation of the fit plane is: Z = 6.98037405527081e-05 * X + -0.00021410572547893116 * Y + 0.019151016830421863
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.0961178782873
# The direction of the gradient is: 261.68926988613816
# 259
# The equation of the fit plane is: Z = 0.0005725156099184933 * X + -0.00042849507857315594 * Y + -0.035264561721098514
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.145950727775816
# The direction of the gradient is: 239.09341672498226
# 260
# The equation of the fit plane is: Z = 0.0005716752767280416 * X + -0.0004275881798756634 * Y + -0.03525065954746334
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.132049755085894
# The direction of the gradient is: 239.07700516480713
# 261
# The equation of the fit plane is: Z = 0.000622382719654359 * X + -0.00041101064618571264 * Y + -0.04082165985550424
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.10692940411794
# The direction of the gradient is: 235.84423932763877
# 262
# The equation of the fit plane is: Z = 0.0005236845398067565 * X + -0.00021596479286773216 * Y + -0.051627600458562926
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.5630478641585634
# The direction of the gradient is: 222.62710079835836
# 263
# The equation of the fit plane is: Z = 0.0006953662204088475 * X + -0.0004244781337020254 * Y + -0.05305695107935312
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.534264318710821
# The direction of the gradient is: 233.72201417453266
# 264
# The equation of the fit plane is: Z = 0.0005879675192848639 * X + -0.000674019466949886 * Y + 0.0016881366611578806
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 10.354919764023563
# The direction of the gradient is: 248.65205886639
# 265
# The equation of the fit plane is: Z = 0.0002232880958790817 * X + -0.0006815967151453899 * Y + 0.06821631606130268
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 9.85735771089061
# The direction of the gradient is: 261.64978709661057
# 266
# The equation of the fit plane is: Z = 0.000308703469924945 * X + -0.00047508100301992516 * Y + 0.025045455034579053
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.080099502079204
# The direction of the gradient is: 253.76764798151294
# 267
# The equation of the fit plane is: Z = 0.0006361922761248691 * X + -0.00020547243396668559 * Y + -0.07638869833811991
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.027888927877242
# The direction of the gradient is: 215.78553132042157
# 268
# The equation of the fit plane is: Z = 0.000254575531995489 * X + -0.00024376178843766132 * Y + 0.00203124851715743
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.850915692433241
# The direction of the gradient is: 244.9238440706563
# 269
# The equation of the fit plane is: Z = 0.00016982224392782214 * X + -0.000211219871605033 * Y + 0.012370947505367264
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.2124338701162234
# The direction of the gradient is: 250.18916985161115
# 270
# The equation of the fit plane is: Z = 0.00016169507855368748 * X + -0.00021027425375136499 * Y + 0.01863982250718172
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.1823553517885976
# The direction of the gradient is: 250.9892034102096
# 271
# The equation of the fit plane is: Z = 0.0003145314685517819 * X + -0.00019115664351348243 * Y + -0.03351088766953348
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.3981912841715554
# The direction of the gradient is: 233.60133214894404
# 272
# The equation of the fit plane is: Z = 0.00018842835119815878 * X + -0.0002899966697810887 * Y + 0.018454959638061354
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.321784393170359
# The direction of the gradient is: 253.76837769973167
# 273
# The equation of the fit plane is: Z = 4.0784609660941917e-05 * X + -0.00020854433405109916 * Y + 0.0305766440439226
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.995461485719881
# The direction of the gradient is: 264.9922843960328
# 274
# The equation of the fit plane is: Z = 0.00014247139378662524 * X + -0.00030898539912131056 * Y + 0.035382310009188206
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.514587884340206
# The direction of the gradient is: 258.32728268563005
# 275
# The equation of the fit plane is: Z = 0.00032180181787239733 * X + -0.00027131874473632794 * Y + -0.014719396730971408
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.396395225265203
# The direction of the gradient is: 242.01305356034118
# 276
# The equation of the fit plane is: Z = 0.0007787218978583284 * X + 0.00029573090039002465 * Y + -0.17957079875310905
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.544518061015521
# The direction of the gradient is: 139.7156216792331
# 277
# The equation of the fit plane is: Z = 0.000606848138992334 * X + -0.00040085832227163416 * Y + -0.03933947405296556
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.930801893733418
# The direction of the gradient is: 235.85130835469386
# 278
# The equation of the fit plane is: Z = 0.0007497809511317904 * X + -0.00024758204518605736 * Y + -0.08703138205105841
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.9713032528664876
# The direction of the gradient is: 216.38960470718428
# 279
# The equation of the fit plane is: Z = 0.0011299028150864212 * X + 9.756712821004986e-06 * Y + -0.20472958319968582
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.245245681212275
# The direction of the gradient is: 178.89591027900508
# 280
# The equation of the fit plane is: Z = 0.0012190151320748688 * X + 0.0006371464384646378 * Y + -0.31784451304353617
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 12.008080328206889
# The direction of the gradient is: 130.60413446939333
# 281
# The equation of the fit plane is: Z = 0.001207579744187425 * X + -8.750780774253463e-05 * Y + -0.19772987191757832
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.842497153201594
# The direction of the gradient is: 189.18717817496542
# 282
# The equation of the fit plane is: Z = 0.0008465157852151398 * X + -0.00011029789033366475 * Y + -0.1284111165518671
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.651907052714223
# The direction of the gradient is: 196.21481301907215
# 283
# The equation of the fit plane is: Z = 0.000365764174847737 * X + -0.0003935388929680645 * Y + 0.008198351480614872
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.099826763970348
# The direction of the gradient is: 247.3917634306573
# 284
# The equation of the fit plane is: Z = 0.0007677353286469424 * X + -4.8363977375121467e-05 * Y + -0.12495490083959464
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.970426375055717
# The direction of the gradient is: 188.003291968957
# 285
# The equation of the fit plane is: Z = 0.0006067771537883141 * X + -0.0003894542035521132 * Y + -0.04611333101263662
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.796113837694734
# The direction of the gradient is: 235.08221371486388
# 286
# The equation of the fit plane is: Z = 0.0008735767320136485 * X + 6.215873308316806e-05 * Y + -0.16896356139282576
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.670756767846422
# The direction of the gradient is: 170.9762908130482
# 287
# The equation of the fit plane is: Z = 0.0005923393148745738 * X + -0.00033504328988886154 * Y + -0.05184165719168685
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.11592152973417
# The direction of the gradient is: 231.61619206163857
# 288
# The equation of the fit plane is: Z = 0.0007625016316697614 * X + -0.00020314799453227583 * Y + -0.10249576436280014
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.6874080026148155
# The direction of the gradient is: 210.73687101200278
# 289
# The equation of the fit plane is: Z = 0.0006342333096191987 * X + -0.00039330581928627705 * Y + -0.051609165009054804
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.942976609609108
# The direction of the gradient is: 234.151402749069
# 290
# The equation of the fit plane is: Z = 0.0010731474761266752 * X + -0.00039020346214669227 * Y + -0.1276932118773445
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 8.860519954201672
# The direction of the gradient is: 219.0603786094922
# 291
# The equation of the fit plane is: Z = 0.0012281629253719224 * X + 4.086376316660297e-05 * Y + -0.22767365600476933
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.895534801137867
# The direction of the gradient is: 175.75300589610674
# 292
# The equation of the fit plane is: Z = 0.0013769594227176546 * X + 0.0005836293547824002 * Y + -0.34012593528996843
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 12.151965413451698
# The direction of the gradient is: 136.5896433333122
# 293
# The equation of the fit plane is: Z = 0.0014091885831863005 * X + 0.00028756093864400184 * Y + -0.2992662120688057
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 9.927300090309389
# The direction of the gradient is: 155.51344934976305
# 294
# The equation of the fit plane is: Z = 0.0007993860636523244 * X + -0.0005170589884556677 * Y + -0.05768829843718998
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 9.000162794246974
# The direction of the gradient is: 235.28976376216247
# 295
# The equation of the fit plane is: Z = 0.0010824954461049103 * X + -0.0005730954789961579 * Y + -0.10388891721943229
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 10.742839441531235
# The direction of the gradient is: 229.75865198885674
# 296
# The equation of the fit plane is: Z = 0.0004697544009805368 * X + -0.000976044924434614 * Y + 0.027588795517871415
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 14.287095288990045
# The direction of the gradient is: 257.83111161947477
# 297
# The equation of the fit plane is: Z = 0.00033861299787477084 * X + -0.0006488068140610032 * Y + 0.039807572349509775
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 9.534112124330555
# The direction of the gradient is: 256.838556397066
# 298
# The equation of the fit plane is: Z = 0.0003053453433165174 * X + -0.0005014439605324648 * Y + 0.0002010279284511523
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.437336480829216
# The direction of the gradient is: 254.7392788009298
# 299
# The equation of the fit plane is: Z = 0.0003260416713187345 * X + -0.0002604796392346699 * Y + -0.021259448921551717
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.273289752688708
# The direction of the gradient is: 240.71526386646792
# 300
# The equation of the fit plane is: Z = 0.00046864405389566955 * X + -0.00023676600718926764 * Y + -0.04648238029940134
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.528203106317143
# The direction of the gradient is: 228.43175016539146
# 301
# The equation of the fit plane is: Z = 0.00024882606239000365 * X + -0.0004186309760414218 * Y + 0.026059342415638065
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.198902337939118
# The direction of the gradient is: 255.0875330902179
# 302
# The equation of the fit plane is: Z = 0.0003813573170294338 * X + -0.000406807315229511 * Y + -0.004719348086531958
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.313553393699668
# The direction of the gradient is: 247.21660625856987
# 303
# The equation of the fit plane is: Z = 0.0006435824738877664 * X + -0.0002720668788712248 * Y + -0.0709683869706894
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.672700058310031
# The direction of the gradient is: 223.3349811432505
# 304
# The equation of the fit plane is: Z = 0.00018687871685557107 * X + -0.0006849764784560577 * Y + 0.07260619554646623
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 9.874175016727445
# The direction of the gradient is: 263.0307749279417
# 305
# The equation of the fit plane is: Z = 0.0008516812212913876 * X + 2.1602555360427077e-05 * Y + -0.14921413937829953
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.468941294181467
# The direction of the gradient is: 176.75988480941737
# 306
# The equation of the fit plane is: Z = 0.0008980622004309918 * X + 0.00011214359253265044 * Y + -0.1755676221794734
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.9769791799431085
# The direction of the gradient is: 164.42670497782524
# 307
# The equation of the fit plane is: Z = 0.0010786604233380009 * X + 5.2139084119560205e-05 * Y + -0.18970972318210272
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 6.955507817135031
# The direction of the gradient is: 173.84259221694788
# 308
# The equation of the fit plane is: Z = 0.0013895293304878975 * X + 8.692877505881584e-05 * Y + -0.2644682026207248
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 8.994805875148096
# The direction of the gradient is: 172.0513602506353
# 309
# The equation of the fit plane is: Z = 0.0011121548366119416 * X + -4.41197608483395e-05 * Y + -0.19204992711797936
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.158010064199886
# The direction of the gradient is: 185.05979079167628
# 310
# The equation of the fit plane is: Z = 0.0011080807280228798 * X + -0.00041328465901420414 * Y + -0.13565557131025288
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 9.243253274503546
# The direction of the gradient is: 219.77522137498408
# 311
# The equation of the fit plane is: Z = 0.0009286499322088534 * X + -0.0003376471795661774 * Y + -0.1266310030093708
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.667320992110593
# The direction of the gradient is: 219.05904788998214
# 312
# The equation of the fit plane is: Z = 0.0005066051752525925 * X + -8.591358213506105e-05 * Y + -0.069738757458482
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.4727527491546226
# The direction of the gradient is: 200.73162742773036
# 313
# The equation of the fit plane is: Z = 0.0005909686431004146 * X + -0.0003013343637353245 * Y + -0.05784281515817459
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.739840323904784
# The direction of the gradient is: 228.69409061289696
# 314
# The equation of the fit plane is: Z = 0.000536684805416991 * X + -5.151924203020849e-05 * Y + -0.08254840636127408
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.5188156060872733
# The direction of the gradient is: 192.0928654253271
# 315
# The equation of the fit plane is: Z = 0.0008559439118122264 * X + -0.000148596579648506 * Y + -0.13130409424667333
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.885055043442979
# The direction of the gradient is: 201.17978774611515
# 316
# The equation of the fit plane is: Z = 0.0008408857307045653 * X + -0.0003171688117359548 * Y + -0.10152409455635608
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.046920087188102
# The direction of the gradient is: 220.09181882047005
# 317
# The equation of the fit plane is: Z = 0.0012575020599346549 * X + -0.00015891642402245145 * Y + -0.2012629532189357
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 8.376496951805162
# The direction of the gradient is: 195.75134821113159
# 318
# The equation of the fit plane is: Z = 0.0012130996985867794 * X + -7.623133657339117e-05 * Y + -0.20157785186968347
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 7.853402489491146
# The direction of the gradient is: 187.9837897550335
# 319

# %%
######### GIM

# %%
path_GIM = '../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5'

# %%
# !reference_point.py ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 -y 180 -x 190
# !reference_date.py ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 --ref-date 20181211
# Out:
# WARNING: auto turn ON --write-data for file tpye timeseries
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# --------------------------------------------------
# input reference point in y/x: (180, 190)
# --------------------------------------------------
# calculating the temporal average of timeseries file: ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5
# reading timeseries data from file: ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 ...
# /home/eedy/tools/MintPy/src/mintpy/objects/stack.py:455: RuntimeWarning: Mean of empty slice
#   dmean = np.nanmean(data, axis=0)
# updating dataset values without re-writing to a new file
# update metadata
# input reference date: 20181211
# --------------------------------------------------
# change reference date for file: /panda/eedy/chile/s1_a149/mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5
# reading data ...
# referencing in time ...
# --------------------------------------------------
# open  HDF5 file /panda/eedy/chile/s1_a149/mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 in r+ mode
# writing dataset /timeseries                block: (0, 323, 0, 788, 0, 343)
# close HDF5 file /panda/eedy/chile/s1_a149/mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5.
# update "REF_DATE" attribute value to 20181211
# time used: 00 mins 2.3 secs.

# %%
timeseries_GIM = readfile.read(path_GIM, datasetName='timeseries')[0]
timeseries_GIM = np.squeeze(timeseries_GIM)
from mintpy.objects import ramp
data_out, ramp = ramp.deramp(timeseries_GIM, mask_in=None, ramp_type='linear', metadata=None, max_num_sample=1e3, coeff_file=None,ignore_zero_value=True)

# %%
def function(data, a, b, c):
    '''
    拟合曲面使用的函数
    '''
    x = data[0]
    y = data[1]
    return a*x+b*y + c



slope_ion_GIM = np.zeros(timeseries_GIM.shape[0])
slope_ion_GIM_dongxifangxiang = np.zeros(timeseries_GIM.shape[0])
slope_ion_GIM_nanbeifangxiang = np.zeros(timeseries_GIM.shape[0])
angle_deg_ion_GIM = np.zeros(timeseries_GIM.shape[0])
meta = readfile.read_attribute(path_GIM)
AZIMUTH_PIXEL_SIZE =  float(meta['AZIMUTH_PIXEL_SIZE'])
RANGE_PIXEL_SIZE = float(meta['RANGE_PIXEL_SIZE'])

for i in range(timeseries_GIM.shape[0]):
    x_data = ramp.shape[2]
    y_data = ramp.shape[1]
    X_data, Y_data = np.meshgrid(range(x_data), range(y_data))
    Z_data = ramp[i, :,:]
    
    x_data = X_data.flatten()
    y_data = Y_data.flatten()
    z_data = Z_data.flatten()
    
    parameters, covariance = curve_fit(function, [x_data, y_data], z_data)
    print("The equation of the fit plane is: Z = {0} * X + {1} * Y + {2}".format(parameters[0],parameters[1],parameters[2]))
    
    Z_fit = function([X_data, Y_data], *parameters)
    
    # 计算梯度，考虑到横纵坐标的实际长度
    dx = parameters[1]/RANGE_PIXEL_SIZE
    dy = parameters[0]/AZIMUTH_PIXEL_SIZE
    # 计算梯度的大小和方向
    magnitude = np.hypot(dx, dy)  # 梯度的大小
    direction = np.degrees(np.arctan2(dy, dx)) + 90  # 梯度的方向，以x轴正半轴为0°，逆时针旋转为正方向
    direction = (direction + 360) % 360  # 将角度值限制在0°到360°之间

    print('The magnitude of the gradient is( cm(ion)/ 100km(juli)):', magnitude*1e7)
    print('The direction of the gradient is:', direction)

    slope_ion_GIM[i] = magnitude*1e7
    angle_deg_ion_GIM[i] = direction
    slope_ion_GIM_dongxifangxiang[i] = dy*1e7
    slope_ion_GIM_nanbeifangxiang[i] = dx*1e7

    print(i)
# Out:
# The equation of the fit plane is: Z = -2.693801217719825e-05 * X + -0.000107640605376532 * Y + 0.024620676033915365
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5498644433081186
# The direction of the gradient is: 276.3977714391009
# 0
# The equation of the fit plane is: Z = 5.16445276977454e-06 * X + -5.073889883617565e-05 * Y + 0.007839626504566979
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7267694123018178
# The direction of the gradient is: 267.388848735373
# 1
# The equation of the fit plane is: Z = 1.277667684630287e-05 * X + -6.875252058672108e-05 * Y + 0.010016962377284598
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9871731446105706
# The direction of the gradient is: 265.2403148769073
# 2
# The equation of the fit plane is: Z = -1.5064216647515183e-05 * X + -0.00018236239657148115 * Y + 0.03524181623214073
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.6111811344242164
# The direction of the gradient is: 272.1196426082738
# 3
# The equation of the fit plane is: Z = 1.0181912707442791e-05 * X + -0.0001608208520941024 * Y + 0.026941819211687697
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.302085635552144
# The direction of the gradient is: 268.3751243534484
# 4
# The equation of the fit plane is: Z = -1.0348237102431393e-05 * X + -7.134184664612354e-05 * Y + 0.013143230656235171
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0229726923233695
# The direction of the gradient is: 273.71844412096004
# 5
# The equation of the fit plane is: Z = -3.394970207152979e-05 * X + -0.00024074441889398012 * Y + 0.0491473814291572
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.451642833360363
# The direction of the gradient is: 273.6153668744731
# 6
# The equation of the fit plane is: Z = -6.786379623456724e-05 * X + -0.00034041651689095334 * Y + 0.07328274098457964
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.890358077437754
# The direction of the gradient is: 275.1041813405841
# 7
# The equation of the fit plane is: Z = -7.038033762377177e-05 * X + -0.0002558898330064963 * Y + 0.059530446135370195
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.689184238143014
# The direction of the gradient is: 277.0252823494435
# 8
# The equation of the fit plane is: Z = -2.9052964373456866e-05 * X + -9.635680825730424e-05 * Y + 0.02339087723411006
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3912786777079442
# The direction of the gradient is: 277.69371822856215
# 9
# The equation of the fit plane is: Z = -2.7112404913453607e-05 * X + -8.077133996445682e-05 * Y + 0.01988062613665789
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1687421014200827
# The direction of the gradient is: 278.55298143988136
# 10
# The equation of the fit plane is: Z = -2.8243115558061896e-05 * X + -0.0001110958956073247 * Y + 0.0252810898502753
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5999325451555961
# The direction of the gradient is: 276.4982500026032
# 11
# The equation of the fit plane is: Z = -2.6066644818952213e-06 * X + -0.00011862611316063738 * Y + 0.021918508543553122
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6974844264658862
# The direction of the gradient is: 270.56407957049566
# 12
# The equation of the fit plane is: Z = 1.0435658617276627e-05 * X + -8.849757583790582e-05 * Y + 0.013496113270677927
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2680638958135122
# The direction of the gradient is: 266.97563334312053
# 13
# The equation of the fit plane is: Z = 3.5261557097726884e-05 * X + -4.5228004249357615e-05 * Y + 0.0013400615837694608
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.685508384027503
# The direction of the gradient is: 250.74477113523596
# 14
# The equation of the fit plane is: Z = -3.125229492744626e-06 * X + -0.00011099819401414513 * Y + 0.019996248967184934
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5883818568378443
# The direction of the gradient is: 270.7227573782046
# 15
# The equation of the fit plane is: Z = 2.8004742340207674e-05 * X + -4.955062586393848e-05 * Y + 0.003626544863559172
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7313910775303291
# The direction of the gradient is: 255.78989167984867
# 16
# The equation of the fit plane is: Z = 2.741548104126452e-05 * X + -2.9296102740291815e-05 * Y + 0.00010496783652953728
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4545498878637537
# The direction of the gradient is: 247.25225591217645
# 17
# The equation of the fit plane is: Z = -3.319355498287026e-05 * X + -0.00022050993819705612 * Y + 0.04544443359835414
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.162409865836082
# The direction of the gradient is: 273.85849502376857
# 18
# The equation of the fit plane is: Z = -1.464967620830156e-06 * X + -0.00013728406285916887 * Y + 0.02501990633691614
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.964398246293861
# The direction of the gradient is: 270.27393918683697
# 19
# The equation of the fit plane is: Z = -2.394484179534576e-05 * X + -0.00010803347855251904 * Y + 0.023414505469375683
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5534375783958916
# The direction of the gradient is: 275.67128650187226
# 20
# The equation of the fit plane is: Z = -3.0382659424855112e-05 * X + -3.022924544362003e-05 * Y + 0.011639261728579263
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4743807132404305
# The direction of the gradient is: 294.2431970476119
# 21
# The equation of the fit plane is: Z = -3.1775432884242686e-05 * X + -6.65592265758358e-05 * Y + 0.018269700612838658
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9739289881867158
# The direction of the gradient is: 282.0736086012462
# 22
# The equation of the fit plane is: Z = -2.819952467653973e-05 * X + -4.333124182516893e-05 * Y + 0.013226617853940107
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6458401039549817
# The direction of the gradient is: 286.25597775748497
# 23
# The equation of the fit plane is: Z = -1.815301695716769e-05 * X + -7.803171474435184e-05 * Y + 0.017395217818476052
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.122592330143321
# The direction of the gradient is: 275.9506141684483
# 24
# The equation of the fit plane is: Z = -7.168608297313402e-06 * X + -8.316487722570015e-05 * Y + 0.016256560734641493
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1908801331082282
# The direction of the gradient is: 272.2117125458908
# 25
# The equation of the fit plane is: Z = -3.5242724481366926e-05 * X + -1.875965160511829e-05 * Y + 0.010386928099573237
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3508628784851875
# The direction of the gradient is: 310.0882496064094
# 26
# The equation of the fit plane is: Z = -3.0789356671779045e-05 * X + -3.8777483023132374e-05 * Y + 0.012920202458745426
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5889266356840231
# The direction of the gradient is: 289.5831417883584
# 27
# The equation of the fit plane is: Z = -3.1159228260934674e-05 * X + -3.9608315118005024e-05 * Y + 0.012975589318329886
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6009245586587223
# The direction of the gradient is: 289.41623627278386
# 28
# The equation of the fit plane is: Z = -3.320412660043818e-05 * X + -7.132130567412656e-06 * Y + 0.008010126833544882
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23607250894650722
# The direction of the gradient is: 334.38682467905835
# 29
# The equation of the fit plane is: Z = -2.206405356220607e-05 * X + -1.501131999383123e-05 * Y + 0.007170381423596397
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2571888083913434
# The direction of the gradient is: 303.36718103829617
# 30
# The equation of the fit plane is: Z = -2.6941019181400644e-05 * X + -6.783660141206354e-06 * Y + 0.006495404559687335
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.1981273560982139
# The direction of the gradient is: 330.6647565974426
# 31
# The equation of the fit plane is: Z = -4.2023519285935196e-05 * X + -4.740987038356292e-05 * Y + 0.01652611598709789
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7299211836945217
# The direction of the gradient is: 291.66032144045334
# 32
# The equation of the fit plane is: Z = -6.227204246268404e-06 * X + -3.9793768196849363e-05 * Y + 0.008653258172764754
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5708005620438559
# The direction of the gradient is: 274.01067493963467
# 33
# The equation of the fit plane is: Z = -2.1484522158161242e-05 * X + -5.399453843956093e-05 * Y + 0.013821513135044476
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7847812757488238
# The direction of the gradient is: 280.1084932449985
# 34
# The equation of the fit plane is: Z = -9.65334546723291e-06 * X + -3.666154104420991e-05 * Y + 0.008753794323949331
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5282222136497752
# The direction of the gradient is: 276.72843191066136
# 35
# The equation of the fit plane is: Z = -1.6520624896165298e-05 * X + -9.695120146407374e-05 * Y + 0.020424824355200995
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3912966545212186
# The direction of the gradient is: 274.3659737636034
# 36
# The equation of the fit plane is: Z = 1.2608471653572203e-05 * X + -0.00011756378247775341 * Y + 0.018202324619162196
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6841424585981384
# The direction of the gradient is: 267.2489116932329
# 37
# The equation of the fit plane is: Z = 4.962521357800211e-06 * X + -0.0001477143873900826 * Y + 0.024537388812863534
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.1138610806424603
# The direction of the gradient is: 269.13762459218503
# 38
# The equation of the fit plane is: Z = 3.6223148165766164e-05 * X + 1.8064367859372797e-05 * Y + -0.01097608773307122
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.34748033488031344
# The direction of the gradient is: 131.9378762070989
# 39
# The equation of the fit plane is: Z = 1.801161206307902e-05 * X + -2.871513074742724e-05 * Y + 0.0013812056985474336
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4267983084092865
# The direction of the gradient is: 254.30249275638016
# 40
# The equation of the fit plane is: Z = 4.088789288972904e-05 * X + 4.551895777998112e-05 * Y + -0.015955067867879782
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7020950318201257
# The direction of the gradient is: 111.92311604275517
# 41
# The equation of the fit plane is: Z = 4.0982873073623314e-05 * X + 6.585477710188152e-05 * Y + -0.018851068918482365
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.978250689664864
# The direction of the gradient is: 105.58015227188741
# 42
# The equation of the fit plane is: Z = 9.710843546558651e-06 * X + -4.600785513596387e-05 * Y + 0.006227574832524723
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6612563332920051
# The direction of the gradient is: 264.59762364239555
# 43
# The equation of the fit plane is: Z = 1.6949911813717446e-05 * X + 4.8557092358814704e-05 * Y + -0.011417783363690358
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7032422394534097
# The direction of the gradient is: 98.88914836257254
# 44
# The equation of the fit plane is: Z = -7.978543083683925e-06 * X + -5.0987139326659745e-05 * Y + 0.010423973635316868
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7313578018535623
# The direction of the gradient is: 274.0105359842049
# 45
# The equation of the fit plane is: Z = 1.7205971023559264e-05 * X + -4.9182074809701644e-05 * Y + 0.005111298712508816
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.712331311928036
# The direction of the gradient is: 261.0915447914148
# 46
# The equation of the fit plane is: Z = 3.4198056787717223e-06 * X + -7.51561598459948e-05 * Y + 0.012418831260755398
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0756209943146937
# The direction of the gradient is: 268.8320446075627
# 47
# The equation of the fit plane is: Z = -2.7366436417183074e-05 * X + -9.542399210422662e-05 * Y + 0.022461308095116973
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.376632721332801
# The direction of the gradient is: 277.32212172351467
# 48
# The equation of the fit plane is: Z = -3.9554089621057647e-05 * X + -6.533964232818496e-05 * Y + 0.019791597180714497
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9687144625665766
# The direction of the gradient is: 285.1753685432021
# 49
# The equation of the fit plane is: Z = -3.144727064518098e-05 * X + -7.357720183028147e-05 * Y + 0.019577655953470892
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0719348199634648
# The direction of the gradient is: 280.84084100904147
# 50
# The equation of the fit plane is: Z = -4.2722118247968466e-05 * X + -6.407841667019362e-05 * Y + 0.019877878895768673
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9569231107980699
# The direction of the gradient is: 286.63206919614424
# 51
# The equation of the fit plane is: Z = -3.269779636628217e-05 * X + -4.2215092184754e-05 * Y + 0.014179830442288616
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6393897470025629
# The direction of the gradient is: 289.13874387773944
# 52
# The equation of the fit plane is: Z = -1.523750170649383e-05 * X + -2.796897074112464e-05 * Y + 0.008330330529778975
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4119538791407304
# The direction of the gradient is: 283.71753616188823
# 53
# The equation of the fit plane is: Z = -3.271249970180787e-05 * X + -2.34998279452526e-05 * Y + 0.01067840854342236
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3962968203219729
# The direction of the gradient is: 301.95180433229115
# 54
# The equation of the fit plane is: Z = -2.0355995527691896e-05 * X + -2.617543233333635e-05 * Y + 0.008804275606527719
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3966252239614527
# The direction of the gradient is: 289.21027445125355
# 55
# The equation of the fit plane is: Z = -2.4897020219545157e-05 * X + -8.582150780654804e-06 * Y + 0.006429966828737421
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20138901654247587
# The direction of the gradient is: 322.42725193586904
# 56
# The equation of the fit plane is: Z = -1.89151678616732e-05 * X + -3.877690833669995e-05 * Y + 0.010735541519423991
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.56794984749382
# The direction of the gradient is: 282.3285127154504
# 57
# The equation of the fit plane is: Z = -2.0058215699624567e-05 * X + 3.337704250781729e-06 * Y + 0.003289693822512588
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.13717702091644077
# The direction of the gradient is: 20.374424762686488
# 58
# The equation of the fit plane is: Z = -3.239642536504605e-05 * X + -1.2440413468426302e-06 * Y + 0.00674357637632299
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20845758678104298
# The direction of the gradient is: 355.1013837711413
# 59
# The equation of the fit plane is: Z = -3.1291532436803464e-05 * X + -1.7282027626152642e-05 * Y + 0.00940169391616636
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.31842687587770635
# The direction of the gradient is: 309.05097382605015
# 60
# The equation of the fit plane is: Z = -2.96207294439367e-05 * X + 5.444011507622586e-06 * Y + 0.0052116884564068445
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20525688828137292
# The direction of the gradient is: 22.3034706331826
# 61
# The equation of the fit plane is: Z = -2.5705786088877397e-05 * X + -9.794466743838147e-06 * Y + 0.006998781376706659
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2163353552307232
# The direction of the gradient is: 319.6221791152813
# 62
# The equation of the fit plane is: Z = -1.9026898764754e-05 * X + -1.4525285119298197e-06 * Y + 0.004112318491021103
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.12374099039669299
# The direction of the gradient is: 350.3305525220494
# 63
# The equation of the fit plane is: Z = -2.315331960625495e-05 * X + -1.1086789473192312e-05 * Y + 0.0064843334411799625
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2172559799546572
# The direction of the gradient is: 313.09730424503755
# 64
# The equation of the fit plane is: Z = -1.1809341508112276e-05 * X + -1.5146979655550763e-05 * Y + 0.0049659534418593065
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.22957891294190522
# The direction of the gradient is: 289.2554579690988
# 65
# The equation of the fit plane is: Z = -1.3964822503402921e-05 * X + -9.431766995279631e-06 * Y + 0.004667481372883031
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16195407721137384
# The direction of the gradient is: 303.55992027636455
# 66
# The equation of the fit plane is: Z = -2.526533823082303e-05 * X + -2.3909982430590555e-05 * Y + 0.0091192056492602
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.37853117510507495
# The direction of the gradient is: 295.33514727359716
# 67
# The equation of the fit plane is: Z = -2.5149655273486553e-05 * X + -4.009668483078347e-05 * Y + 0.012042454979713629
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5959626255974755
# The direction of the gradient is: 285.6968812706897
# 68
# The equation of the fit plane is: Z = -2.092199609378067e-05 * X + -1.4038265941637501e-05 * Y + 0.006863033488881003
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.24153850963907192
# The direction of the gradient is: 303.7331818460366
# 69
# The equation of the fit plane is: Z = -1.518337157208656e-05 * X + -2.8847555738752123e-05 * Y + 0.008020993803578687
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.42409751709871224
# The direction of the gradient is: 283.26922889368143
# 70
# The equation of the fit plane is: Z = -8.515296445584095e-06 * X + -3.6577575543741225e-05 * Y + 0.008376078340037013
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5262221684758603
# The direction of the gradient is: 275.95479451032907
# 71
# The equation of the fit plane is: Z = 2.2031737931862867e-06 * X + -5.1405463674307025e-05 * Y + 0.008300573451503467
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7356881990210024
# The direction of the gradient is: 268.8998911165586
# 72
# The equation of the fit plane is: Z = 1.479779678665732e-05 * X + -2.915430773374532e-05 * Y + 0.002036102889953495
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.42781583684996993
# The direction of the gradient is: 257.18792143742564
# 73
# The equation of the fit plane is: Z = -2.2348466125636287e-06 * X + -7.624919856761331e-05 * Y + 0.013576824873818975
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.091131714196886
# The direction of the gradient is: 270.75237965436395
# 74
# The equation of the fit plane is: Z = 2.5065344091936152e-05 * X + -6.42404656171355e-05 * Y + 0.0062273769121626655
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9331473428267911
# The direction of the gradient is: 260.08374341859144
# 75
# The equation of the fit plane is: Z = 2.205433818055885e-05 * X + 1.4473757943228074e-05 * Y + -0.007014868221837415
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.25076538502732315
# The direction of the gradient is: 124.32195292194854
# 76
# The equation of the fit plane is: Z = 1.535482823746833e-06 * X + -5.9951437444498995e-05 * Y + 0.010252312120131878
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8578920528124271
# The direction of the gradient is: 269.3425301096479
# 77
# The equation of the fit plane is: Z = -1.6091606827183353e-06 * X + -2.8157007961666514e-05 * Y + 0.005316293256760284
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4030262025697615
# The direction of the gradient is: 271.46678881095085
# 78
# The equation of the fit plane is: Z = 3.600788812389136e-05 * X + 1.1542979968406916e-05 * Y + -0.008878090769701297
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.28385126803967275
# The direction of the gradient is: 144.41729636733578
# 79
# The equation of the fit plane is: Z = 2.2881214014452288e-05 * X + -1.2758526328595418e-05 * Y + -0.002176732846584711
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23419434923365676
# The direction of the gradient is: 231.21685989931507
# 80
# The equation of the fit plane is: Z = 1.1702666077252016e-05 * X + -2.3144913569932513e-05 * Y + 0.0015144657262947461
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3395690541011159
# The direction of the gradient is: 257.23533947382566
# 81
# The equation of the fit plane is: Z = -5.288937763258278e-06 * X + -1.8778966985886382e-05 * Y + 0.004414345241634946
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.27083620608181375
# The direction of the gradient is: 277.19211909993487
# 82
# The equation of the fit plane is: Z = 0.0 * X + 0.0 * Y + 5e-324
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0
# The direction of the gradient is: 90.0
# 83
# The equation of the fit plane is: Z = 9.035631806783911e-07 * X + -2.8977505376795578e-05 * Y + 0.0050365143081623695
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4146749734523269
# The direction of the gradient is: 269.19957831537613
# 84
# The equation of the fit plane is: Z = 4.203892118097572e-06 * X + 1.7489222835925003e-07 * Y + -0.0008404207927364949
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.027067432684573314
# The direction of the gradient is: 174.69517343706093
# 85
# The equation of the fit plane is: Z = 6.2878427440105695e-06 * X + -7.028126413497563e-06 * Y + -8.114156040242065e-05
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.10834313329228142
# The direction of the gradient is: 248.15629280312385
# 86
# The equation of the fit plane is: Z = 3.0246485560047703e-05 * X + 2.200867040987732e-05 * Y + -0.00952847081995642
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3698321835929167
# The direction of the gradient is: 121.62289815155947
# 87
# The equation of the fit plane is: Z = 1.0409168396252902e-05 * X + -3.0194086285029434e-05 * Y + 0.003539281069292594
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.43716592248566016
# The direction of the gradient is: 261.21938282795657
# 88
# The equation of the fit plane is: Z = -5.267903524258895e-06 * X + 1.2310132557923616e-05 * Y + -0.0009226585181543431
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17935223888178095
# The direction of the gradient is: 79.14610376181531
# 89
# The equation of the fit plane is: Z = 1.964343595619287e-05 * X + 6.976408803422518e-06 * Y + -0.005031926739727382
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.160700636582054
# The direction of the gradient is: 141.59750734903287
# 90
# The equation of the fit plane is: Z = 2.7316900913717936e-05 * X + -2.753114538508818e-05 * Y + -0.00025305685762684046
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.43111320515194257
# The direction of the gradient is: 246.0318013000891
# 91
# The equation of the fit plane is: Z = 1.2346139963712471e-05 * X + -4.5831133057174615e-05 * Y + 0.0057371427205883474
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6605498373294154
# The direction of the gradient is: 263.11784490053583
# 92
# The equation of the fit plane is: Z = 2.877553253591553e-06 * X + -6.407702129584011e-05 * Y + 0.01089463450761591
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9170534729026192
# The direction of the gradient is: 268.84731132599563
# 93
# The equation of the fit plane is: Z = 1.4082530107624435e-06 * X + -9.369433484680569e-05 * Y + 0.01584834254940026
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3406877170198708
# The direction of the gradient is: 269.6141572360734
# 94
# The equation of the fit plane is: Z = 2.659567955777559e-06 * X + -5.502215174887028e-05 * Y + 0.009331687655032212
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7874878203819196
# The direction of the gradient is: 268.75933307332605
# 95
# The equation of the fit plane is: Z = -2.6360483781723435e-06 * X + -9.000584642584757e-05 * Y + 0.016160562017970444
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2879902017913363
# The direction of the gradient is: 270.7518086170809
# 96
# The equation of the fit plane is: Z = -1.2309056856457109e-05 * X + -7.685722311846069e-05 * Y + 0.01605992323929126
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.102565478872584
# The direction of the gradient is: 274.1043643087894
# 97
# The equation of the fit plane is: Z = -1.5023036879688436e-05 * X + -0.00010236361528603922 * Y + 0.02042187985395472
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4678678910091063
# The direction of the gradient is: 273.76215690273295
# 98
# The equation of the fit plane is: Z = -3.95001577002615e-05 * X + -9.440963326937698e-05 * Y + 0.024135459423634164
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.374423580971021
# The direction of the gradient is: 280.6174614014458
# 99
# The equation of the fit plane is: Z = -2.126361887555625e-05 * X + -9.705317648722152e-05 * Y + 0.021350621044583483
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3953934347165855
# The direction of the gradient is: 275.6064479315957
# 100
# The equation of the fit plane is: Z = -3.375728685106533e-05 * X + -5.600019805824056e-05 * Y + 0.016678279559622033
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8300098173514138
# The direction of the gradient is: 285.1142618002606
# 101
# The equation of the fit plane is: Z = -3.691175799359029e-05 * X + -4.590387240867042e-05 * Y + 0.015668096433894437
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6981602740832915
# The direction of the gradient is: 289.81316937459104
# 102
# The equation of the fit plane is: Z = -3.549363457932824e-05 * X + -4.447077685004949e-05 * Y + 0.01473750371246407
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6757884593277047
# The direction of the gradient is: 289.6772669621495
# 103
# The equation of the fit plane is: Z = -2.9813520647547547e-05 * X + -2.556042441350534e-05 * Y + 0.010433697519501312
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.41267313023214613
# The direction of the gradient is: 297.5917164306821
# 104
# The equation of the fit plane is: Z = -3.871341955195521e-05 * X + -2.8645095139084214e-05 * Y + 0.012877950482985448
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.47916676482246345
# The direction of the gradient is: 301.19631132243774
# 105
# The equation of the fit plane is: Z = -3.1819314052649034e-05 * X + -1.6520319399420718e-05 * Y + 0.009414312649856782
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3122388621133037
# The direction of the gradient is: 310.7934436714763
# 106
# The equation of the fit plane is: Z = -3.529602599424595e-05 * X + -3.2578797129330774e-06 * Y + 0.007672848216496309
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23103751890976285
# The direction of the gradient is: 348.35950647889183
# 107
# The equation of the fit plane is: Z = -3.877565562521711e-05 * X + -1.1706227222373764e-05 * Y + 0.009928008537131092
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.29975998411588844
# The direction of the gradient is: 326.0279190197107
# 108
# The equation of the fit plane is: Z = -3.3049664969026194e-05 * X + -3.696635896483493e-06 * Y + 0.007354905935396975
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.21838663981945672
# The direction of the gradient is: 345.9832176960855
# 109
# The equation of the fit plane is: Z = -3.547266877641386e-05 * X + -6.556516003366988e-06 * Y + 0.008368214439663424
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.24600917528308652
# The direction of the gradient is: 337.58253297823796
# 110
# The equation of the fit plane is: Z = -2.507103835404918e-05 * X + 7.110682344885716e-06 * Y + 0.004015284738361836
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19022909623432718
# The direction of the gradient is: 32.334305860078814
# 111
# The equation of the fit plane is: Z = -3.522025848036585e-05 * X + 2.7136773418006755e-05 * Y + 0.0022787160316170307
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4491761813540253
# The direction of the gradient is: 59.82133681598464
# 112
# The equation of the fit plane is: Z = -3.3923499150430665e-05 * X + -1.0556698524791332e-05 * Y + 0.008393308861397355
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2647974027125891
# The direction of the gradient is: 325.2182725685716
# 113
# The equation of the fit plane is: Z = -3.730093523272603e-05 * X + -1.2209453883583935e-05 * Y + 0.009565213261014727
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.29615676514949557
# The direction of the gradient is: 323.8500265435483
# 114
# The equation of the fit plane is: Z = -3.775528124342879e-05 * X + -3.741194352658184e-05 * Y + 0.013912437974981234
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5875018622036252
# The direction of the gradient is: 294.3306908229101
# 115
# The equation of the fit plane is: Z = -3.8267088885524414e-05 * X + -2.403617090105812e-05 * Y + 0.011752090960129144
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.42246441481667957
# The direction of the gradient is: 305.50118973410974
# 116
# The equation of the fit plane is: Z = -2.993627858240076e-05 * X + -8.120982270997752e-06 * Y + 0.007518837283775696
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.22436059148462856
# The direction of the gradient is: 328.8068677555951
# 117
# The equation of the fit plane is: Z = -2.9141406834321752e-05 * X + -2.5008020691597356e-06 * Y + 0.006198167871365756
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.19022396236502065
# The direction of the gradient is: 349.15732516731214
# 118
# The equation of the fit plane is: Z = -3.627492530826184e-05 * X + 9.30791341812268e-06 * Y + 0.005679709147821503
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.26799858028343776
# The direction of the gradient is: 29.799294124904463
# 119
# The equation of the fit plane is: Z = -2.3229338542215793e-05 * X + -9.788311646449414e-06 * Y + 0.006191454009205281
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2044391170745983
# The direction of the gradient is: 316.75723830742515
# 120
# The equation of the fit plane is: Z = -3.551269695940005e-05 * X + -1.0084869533295206e-05 * Y + 0.008726997820913858
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.26955357389006845
# The direction of the gradient is: 327.6330322265684
# 121
# The equation of the fit plane is: Z = -3.375658428993549e-05 * X + 6.851811753943107e-06 * Y + 0.005393298086050605
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23758814989105145
# The direction of the gradient is: 24.37160684483365
# 122
# The equation of the fit plane is: Z = -3.06338861782497e-05 * X + -8.644659723564253e-06 * Y + 0.007751738046258758
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.23210343882093185
# The direction of the gradient is: 327.79631159332166
# 123
# The equation of the fit plane is: Z = -2.446638742715623e-05 * X + -2.9403813323569164e-05 * Y + 0.010380833395354715
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.44902262839363777
# The direction of the gradient is: 290.4461989501456
# 124
# The equation of the fit plane is: Z = -5.0482650013425325e-06 * X + -2.91651742382537e-05 * Y + 0.006173657927575228
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.41857296484603634
# The direction of the gradient is: 274.4346432901924
# 125
# The equation of the fit plane is: Z = -2.510530153977726e-05 * X + -2.587319031038403e-10 * Y + 0.005062124526405783
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16095216738187448
# The direction of the gradient is: 359.99868210674094
# 126
# The equation of the fit plane is: Z = -2.0589503381970505e-05 * X + -7.693901673199066e-06 * Y + 0.005294968750033041
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.17188442132102705
# The direction of the gradient is: 320.1713892930204
# 127
# The equation of the fit plane is: Z = -1.8653473845016063e-05 * X + -5.664512472412541e-05 * Y + 0.013763207055283722
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8193009397025183
# The direction of the gradient is: 278.39314326447743
# 128
# The equation of the fit plane is: Z = 1.436721538396604e-07 * X + -1.0942100244520968e-05 * Y + 0.0017799765972636304
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.15657147932233328
# The direction of the gradient is: 269.66293281648245
# 129
# The equation of the fit plane is: Z = -1.0731930296829515e-05 * X + -5.307154285341223e-05 * Y + 0.011206970698357747
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7625027808837197
# The direction of the gradient is: 275.17704025577336
# 130
# The equation of the fit plane is: Z = 7.44928590331985e-07 * X + -4.602807499874168e-05 * Y + 0.00787624750691431
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6586257107778124
# The direction of the gradient is: 269.58453562705324
# 131
# The equation of the fit plane is: Z = 7.314798357266626e-06 * X + -7.499381983267154e-05 * Y + 0.012053967005275496
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0740988625078356
# The direction of the gradient is: 267.49763765200464
# 132
# The equation of the fit plane is: Z = 1.2058537860186692e-05 * X + -1.8322628814420257e-05 * Y + 0.0007797776316591016
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.27333606529183235
# The direction of the gradient is: 253.5706781129045
# 133
# The equation of the fit plane is: Z = 3.8947911268320546e-05 * X + 9.903422772029502e-08 * Y + -0.007589163203670906
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.24970230569134935
# The direction of the gradient is: 179.67484369421686
# 134
# The equation of the fit plane is: Z = 1.9522243063198448e-05 * X + -6.703784173533757e-05 * Y + 0.00795688440183287
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9673645597896384
# The direction of the gradient is: 262.5661685064814
# 135
# The equation of the fit plane is: Z = -1.635675513511969e-06 * X + -5.067005385178049e-05 * Y + 0.008978503638564983
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7251055630304569
# The direction of the gradient is: 270.8286384370233
# 136
# The equation of the fit plane is: Z = 2.0255541385161638e-05 * X + -1.5098297507928685e-05 * Y + -0.0011189320368387228
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.25206450607555203
# The direction of the gradient is: 238.99015182788116
# 137
# The equation of the fit plane is: Z = -1.3964161341381747e-06 * X + -4.0227428712649785e-05 * Y + 0.007244590416439349
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5756774875895276
# The direction of the gradient is: 270.89106038878947
# 138
# The equation of the fit plane is: Z = 2.210476245090758e-05 * X + 1.9697459703443394e-05 * Y + -0.007616015716625277
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3154702248375349
# The direction of the gradient is: 116.69363639921852
# 139
# The equation of the fit plane is: Z = -1.0023862983702345e-05 * X + -2.5246479242999853e-06 * Y + 0.002472088255475014
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.07372135452939285
# The direction of the gradient is: 330.65824031179693
# 140
# The equation of the fit plane is: Z = 2.735507051495018e-05 * X + 3.462172383904805e-05 * Y + -0.01123925782032503
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5255231033977181
# The direction of the gradient is: 109.49449535331229
# 141
# The equation of the fit plane is: Z = 2.3459499120239273e-05 * X + 1.847848448793291e-06 * Y + -0.005051690262063387
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.15270724230110255
# The direction of the gradient is: 170.0292453005759
# 142
# The equation of the fit plane is: Z = -2.8404181528932036e-06 * X + 8.040307288231116e-06 * Y + -0.0006615526853296098
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.11647974785375449
# The direction of the gradient is: 81.00562318523805
# 143
# The equation of the fit plane is: Z = 1.3009053578104105e-05 * X + 2.8328898628305046e-05 * Y + -0.0073109005323922956
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4138448201117589
# The direction of the gradient is: 101.62643976339274
# 144
# The equation of the fit plane is: Z = 2.274077128922778e-06 * X + 5.673626358631255e-05 * Y + -0.009836803522154389
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8119610618121552
# The direction of the gradient is: 91.02883882877609
# 145
# The equation of the fit plane is: Z = 3.867384168883819e-05 * X + 5.7106807554827925e-05 * Y + -0.01745137720397887
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8539203107745202
# The direction of the gradient is: 106.87929259258169
# 146
# The equation of the fit plane is: Z = 1.4166112209746087e-05 * X + -1.2645721885137426e-05 * Y + -0.0004639439680716648
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20245891335040142
# The direction of the gradient is: 243.34703726711007
# 147
# The equation of the fit plane is: Z = 8.098725250545464e-06 * X + -5.15299495423679e-05 * Y + 0.007500079384304891
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7391596899593709
# The direction of the gradient is: 265.97199305955576
# 148
# The equation of the fit plane is: Z = 2.251690557505539e-05 * X + 9.910594667141687e-06 * Y + -0.005997975900669414
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.20235855734073907
# The direction of the gradient is: 135.51026741110036
# 149
# The equation of the fit plane is: Z = 6.891905777967275e-06 * X + -4.413331753643343e-05 * Y + 0.0067477600835516936
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6330404796413469
# The direction of the gradient is: 265.99764944674484
# 150
# The equation of the fit plane is: Z = 3.6510722514294767e-07 * X + -6.717035706420876e-05 * Y + 0.011188468800028769
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.961132793134183
# The direction of the gradient is: 269.8604623255047
# 151
# The equation of the fit plane is: Z = 2.5068720895709953e-05 * X + -6.406263799513238e-05 * Y + 0.006217343168159491
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9306446909349398
# The direction of the gradient is: 260.05545327318
# 152
# The equation of the fit plane is: Z = 2.258872047778309e-05 * X + -5.730458958544099e-05 * Y + 0.005155647079672319
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.832652619863811
# The direction of the gradient is: 259.98396049642827
# 153
# The equation of the fit plane is: Z = 8.88775199342429e-06 * X + -4.838629996413909e-05 * Y + 0.006813783082621748
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6946926175309797
# The direction of the gradient is: 265.2951971429719
# 154
# The equation of the fit plane is: Z = -1.2795265822556967e-05 * X + -7.823740004628465e-05 * Y + 0.01632896221954624
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.122487945950583
# The direction of the gradient is: 274.19091621267796
# 155
# The equation of the fit plane is: Z = -1.09482227026234e-05 * X + -8.426547529513628e-05 * Y + 0.016892343036713837
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.207782527839827
# The direction of the gradient is: 273.3316062020208
# 156
# The equation of the fit plane is: Z = -2.2022610717344443e-05 * X + -8.743884469595247e-05 * Y + 0.019417232974612914
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2590896921387182
# The direction of the gradient is: 276.43843838288495
# 157
# The equation of the fit plane is: Z = -3.618398919282673e-05 * X + -7.083694771468315e-05 * Y + 0.01966397634527488
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.039801938219131
# The direction of the gradient is: 282.8911051596071
# 158
# The equation of the fit plane is: Z = -2.7453416375832755e-05 * X + -5.606322972260635e-05 * Y + 0.01548506066605833
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8212811442639947
# The direction of the gradient is: 282.3748614075438
# 159
# The equation of the fit plane is: Z = -3.879987336903528e-05 * X + -4.447103626606397e-06 * Y + 0.008670168433275826
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.25675924696669855
# The direction of the gradient is: 345.65080178554445
# 160
# The equation of the fit plane is: Z = -3.8610205450254585e-05 * X + -5.056106970810711e-05 * Y + 0.01666660783134038
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7646449928260385
# The direction of the gradient is: 288.88823052961163
# 161
# The equation of the fit plane is: Z = -2.6714745701525867e-05 * X + -4.110526051770026e-05 * Y + 0.01230558279980969
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6125976655914103
# The direction of the gradient is: 286.2351775703251
# 162
# The equation of the fit plane is: Z = -2.8884033384489685e-05 * X + -2.296574459234317e-05 * Y + 0.009479183826600757
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3771968840729864
# The direction of the gradient is: 299.40184186567916
# 163
# The equation of the fit plane is: Z = -3.7524789570017815e-05 * X + -3.853847313963894e-05 * Y + 0.01404360193980917
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6016337299901171
# The direction of the gradient is: 293.5699742968957
# 164
# The equation of the fit plane is: Z = -4.149279113696518e-05 * X + -1.6336608560696462e-05 * Y + 0.011117760396956465
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3541271938564717
# The direction of the gradient is: 318.69280825364865
# 165
# The equation of the fit plane is: Z = -3.514393045257356e-05 * X + -3.374172915148979e-05 * Y + 0.012778423480987686
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5327903759679049
# The direction of the gradient is: 295.0170528094012
# 166
# The equation of the fit plane is: Z = -3.836080044643441e-05 * X + -8.52594258291923e-06 * Y + 0.00913803974131132
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2745300986204348
# The direction of the gradient is: 333.6161658576839
# 167
# The equation of the fit plane is: Z = -3.231844693814079e-05 * X + 4.573291746942571e-06 * Y + 0.005850996952692312
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2172843287819159
# The direction of the gradient is: 17.527608091847696
# 168
# The equation of the fit plane is: Z = -2.182174923759783e-05 * X + -3.012182550793264e-05 * Y + 0.009123114481600065
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.45314517121437614
# The direction of the gradient is: 287.9829148310391
# 169
# The equation of the fit plane is: Z = -3.709996484726824e-05 * X + 1.3625338251044876e-05 * Y + 0.004943872183364397
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.30754441081312295
# The direction of the gradient is: 39.34095077500831
# 170
# The equation of the fit plane is: Z = -4.036369352660983e-05 * X + -1.9700809361157692e-05 * Y + 0.011515232985143734
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.38266134084328923
# The direction of the gradient is: 312.55134613706844
# 171
# The equation of the fit plane is: Z = -3.3165054378561155e-05 * X + -4.0754230003429505e-06 * Y + 0.007372179987871727
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.22047566150339076
# The direction of the gradient is: 344.6630876145688
# 172
# The equation of the fit plane is: Z = -2.9945196437808974e-05 * X + 2.385237395917934e-05 * Y + 0.0018048561629104025
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3915894834313338
# The direction of the gradient is: 60.64224833971417
# 173
# The equation of the fit plane is: Z = -4.149764728870076e-05 * X + -1.8777977251043766e-05 * Y + 0.011483648795888462
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.37812003900787305
# The direction of the gradient is: 314.71646430124997
# 174
# The equation of the fit plane is: Z = -4.0767544288436124e-05 * X + -7.053525678580611e-06 * Y + 0.009280822601126762
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.2801742495266981
# The direction of the gradient is: 338.8855454169601
# 175
# The equation of the fit plane is: Z = -4.195129789894097e-05 * X + -2.15819512510415e-05 * Y + 0.01183411404311863
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4095132891974111
# The direction of the gradient is: 311.0534782828428
# 176
# The equation of the fit plane is: Z = -3.5825643423650416e-05 * X + -3.519422009098495e-05 * Y + 0.013207228947498987
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5534932760128981
# The direction of the gradient is: 294.51720678678276
# 177
# The equation of the fit plane is: Z = -3.1872395658029915e-05 * X + -3.4266350865347884e-05 * Y + 0.012566982353024194
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5311864578346938
# The direction of the gradient is: 292.623847848925
# 178
# The equation of the fit plane is: Z = -3.201322677286239e-05 * X + -2.618726944014369e-05 * Y + 0.010811764741249863
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.42723578581508065
# The direction of the gradient is: 298.71082294820826
# 179
# The equation of the fit plane is: Z = -3.12047255845519e-05 * X + -4.8698621041724584e-05 * Y + 0.014431527796995455
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7249701244836195
# The direction of the gradient is: 286.01868316482205
# 180
# The equation of the fit plane is: Z = -2.0707172500960954e-05 * X + -4.7576513655471374e-05 * Y + 0.012358351090559291
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6935882430853806
# The direction of the gradient is: 281.0347173852279
# 181
# The equation of the fit plane is: Z = -3.0334519271735194e-05 * X + -4.351748002824595e-05 * Y + 0.013796974667935622
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6523477399893511
# The direction of the gradient is: 287.34464793986194
# 182
# The equation of the fit plane is: Z = -3.414691084403771e-05 * X + -7.158180579538894e-05 * Y + 0.019124187612536696
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0473866991515917
# The direction of the gradient is: 282.06458701303666
# 183
# The equation of the fit plane is: Z = -1.9169600417191957e-05 * X + -6.417197889668987e-05 * Y + 0.014784736938274073
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9264146110293291
# The direction of the gradient is: 277.62331408606804
# 184
# The equation of the fit plane is: Z = -2.276104877926849e-05 * X + -2.5082547220792647e-05 * Y + 0.009057537675037242
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3874329403715381
# The direction of the gradient is: 292.12574726629873
# 185
# The equation of the fit plane is: Z = -1.0647307317630355e-05 * X + -6.840788693095894e-05 * Y + 0.014507566681621563
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9812148096518609
# The direction of the gradient is: 273.9891525403814
# 186
# The equation of the fit plane is: Z = -5.265977094889536e-06 * X + -6.04246176760106e-05 * Y + 0.012120756457136976
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8652651130111121
# The direction of the gradient is: 272.2361145454141
# 187
# The equation of the fit plane is: Z = 2.2649497809776724e-06 * X + -6.258789553686246e-05 * Y + 0.010729617650451828
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8956779441481892
# The direction of the gradient is: 269.0710769426544
# 188
# The equation of the fit plane is: Z = -2.087946967515775e-06 * X + -6.509527518609232e-05 * Y + 0.0118790419382226
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9315341090261118
# The direction of the gradient is: 270.8233598190842
# 189
# The equation of the fit plane is: Z = -3.545563388747281e-06 * X + -8.612338901913985e-05 * Y + 0.015605761115777026
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2325354828366777
# The direction of the gradient is: 271.0567310410685
# 190
# The equation of the fit plane is: Z = 1.1064724390698379e-05 * X + -0.00011028635353135704 * Y + 0.01709008533105234
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5796634307635948
# The direction of the gradient is: 267.4261921058286
# 191
# The equation of the fit plane is: Z = 5.7950149088411646e-06 * X + -0.00012424973055408182 * Y + 0.020618590829769273
# ...
# The direction of the gradient is: 263.443248332899
# 258
# The equation of the fit plane is: Z = 1.4660996948723952e-05 * X + -8.643587793081085e-05 * Y + 0.012596680594735263
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2403636583329425
# The direction of the gradient is: 265.6540471060496
# 259
# The equation of the fit plane is: Z = 2.2065065648002066e-05 * X + 3.508067681604727e-05 * Y + -0.010027271112817773
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5215159431115612
# The direction of the gradient is: 105.73863569960565
# 260
# The equation of the fit plane is: Z = 1.1569232555892816e-05 * X + -5.163006295606335e-05 * Y + 0.007350396792288956
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7424803711412358
# The direction of the gradient is: 264.26678035438897
# 261
# The equation of the fit plane is: Z = -1.0821181128020584e-05 * X + -0.00013974557833970903 * Y + 0.027135704197011067
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0008003469930067
# The direction of the gradient is: 271.9870646350386
# 262
# The equation of the fit plane is: Z = -3.699155231534035e-05 * X + -0.0002381331500327484 * Y + 0.048956779857015825
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.4156523852261267
# The direction of the gradient is: 273.98136937113827
# 263
# The equation of the fit plane is: Z = -2.076271443765e-05 * X + -0.0001335895842971312 * Y + 0.026744077462987362
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.9161412085602245
# The direction of the gradient is: 273.98346098244554
# 264
# The equation of the fit plane is: Z = -1.8669191511038117e-05 * X + -0.00022345315803400787 * Y + 0.04367775546805498
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.1995951019867777
# The direction of the gradient is: 272.14380780006854
# 265
# The equation of the fit plane is: Z = -2.4340341380877564e-05 * X + -0.00019763105341526137 * Y + 0.03931406394021289
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.8321735278534055
# The direction of the gradient is: 273.1584994862908
# 266
# The equation of the fit plane is: Z = -5.0027325620883156e-05 * X + -0.00028553891423778487 * Y + 0.060156292082704496
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.098300124602116
# The direction of the gradient is: 274.48850642547666
# 267
# The equation of the fit plane is: Z = -7.485448409554877e-05 * X + -0.0003801524029621537 * Y + 0.08176582787318612
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.46066845127576
# The direction of the gradient is: 275.04181212349886
# 268
# The equation of the fit plane is: Z = -4.497699645508868e-05 * X + -0.00030963778548110787 * Y + 0.06367718917076282
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.439931142541912
# The direction of the gradient is: 273.7236941819882
# 269
# The equation of the fit plane is: Z = -3.90393870579466e-05 * X + -0.0002002672546677989 * Y + 0.04351742519744712
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.876501595691078
# The direction of the gradient is: 274.9916245049652
# 270
# The equation of the fit plane is: Z = -3.254548651343254e-05 * X + -0.0001557449774479275 * Y + 0.03483046815113314
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.2382765467213126
# The direction of the gradient is: 275.3488701650858
# 271
# The equation of the fit plane is: Z = -3.267753390715299e-05 * X + -0.00012414526396582276 * Y + 0.028724554616928587
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.788685843100586
# The direction of the gradient is: 276.726160151797
# 272
# The equation of the fit plane is: Z = -2.202142404944858e-05 * X + -0.00010024686725762178 * Y + 0.022467041241816702
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4413475307514159
# The direction of the gradient is: 275.62118178379393
# 273
# The equation of the fit plane is: Z = -3.67438797021632e-05 * X + -0.00010441894286579612 * Y + 0.02615316272705351
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5125703388955072
# The direction of the gradient is: 278.9597298067662
# 274
# The equation of the fit plane is: Z = -2.7880334616610696e-05 * X + -0.00010863268597138405 * Y + 0.024735640621099765
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5646509933480803
# The direction of the gradient is: 276.55969570344604
# 275
# The equation of the fit plane is: Z = -3.763897088650485e-05 * X + -0.00011586683617169485 * Y + 0.028397166752968668
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6753888920396751
# The direction of the gradient is: 278.28112295686594
# 276
# The equation of the fit plane is: Z = -3.153313246827632e-05 * X + -6.880941937045833e-05 * Y + 0.018586605941778734
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0051233822540735
# The direction of the gradient is: 281.60310769292414
# 277
# The equation of the fit plane is: Z = -1.983316479328448e-05 * X + -9.307982056985693e-05 * Y + 0.020453010301529014
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.337920117584553
# The direction of the gradient is: 275.45345575043405
# 278
# The equation of the fit plane is: Z = -2.1181578628490407e-05 * X + -0.00011585777959900147 * Y + 0.02489329116987505
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6633430764151904
# The direction of the gradient is: 274.68289196295825
# 279
# The equation of the fit plane is: Z = -2.8661036448559485e-05 * X + -0.00014870682444440478 * Y + 0.032057811908007716
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.135741333709564
# The direction of the gradient is: 274.93553792134406
# 280
# The equation of the fit plane is: Z = -3.1967790472850466e-05 * X + -0.00020907398466715304 * Y + 0.04387906792026731
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.9986184013293227
# The direction of the gradient is: 273.9190801420028
# 281
# The equation of the fit plane is: Z = -2.6161775135727562e-05 * X + -0.00020109474024470255 * Y + 0.04146381469567776
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.882316817074709
# The direction of the gradient is: 273.3359913758177
# 282
# The equation of the fit plane is: Z = -3.512327348289489e-05 * X + -0.00016834741139201906 * Y + 0.03649773475279891
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.4193581607065537
# The direction of the gradient is: 275.3404501558059
# 283
# The equation of the fit plane is: Z = -9.524791748816839e-06 * X + -9.359480352610691e-05 * Y + 0.01730370180094945
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3406245714464267
# The direction of the gradient is: 272.610673861991
# 284
# The equation of the fit plane is: Z = -1.917435645220564e-05 * X + -0.00019340537617648567 * Y + 0.037700232649606966
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.770135627305575
# The direction of the gradient is: 272.5434103010123
# 285
# The equation of the fit plane is: Z = -6.424301194510217e-06 * X + -0.00016332571266582555 * Y + 0.030208773971320893
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.3373645181493736
# The direction of the gradient is: 271.0096618431056
# 286
# The equation of the fit plane is: Z = -1.0935589020944422e-05 * X + -0.00011731829775939741 * Y + 0.023356700028722723
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6801522224441254
# The direction of the gradient is: 272.391518155438
# 287
# The equation of the fit plane is: Z = 8.3025144822067e-06 * X + -6.182306609660938e-05 * Y + 0.00941530106422356
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8862163508938206
# The direction of the gradient is: 266.5566167220393
# 288
# The equation of the fit plane is: Z = -6.589520175476849e-06 * X + -0.0001666166789677421 * Y + 0.031240373855117576
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.384465795397136
# The direction of the gradient is: 271.01517154914177
# 289
# The equation of the fit plane is: Z = 2.2686015357034454e-05 * X + -3.673931143519638e-05 * Y + 0.001531253044215549
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5454453625129033
# The direction of the gradient is: 254.53509885066205
# 290
# The equation of the fit plane is: Z = -3.0324320748747874e-05 * X + -0.000198981493380763 * Y + 0.041462481977100216
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.8538241809801055
# The direction of the gradient is: 273.9061990603725
# 291
# The equation of the fit plane is: Z = -1.3677756469441307e-05 * X + -0.00018923192648481098 * Y + 0.036693840939282435
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.7091090493925205
# The direction of the gradient is: 271.85489044514895
# 292
# The equation of the fit plane is: Z = -1.840932426101417e-05 * X + -0.0002481286464029914 * Y + 0.04742421824672259
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.552394422302716
# The direction of the gradient is: 271.9039284196841
# 293
# The equation of the fit plane is: Z = -1.8331503504119326e-05 * X + -0.0002518011333915415 * Y + 0.04824472942782485
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.6048985665386386
# The direction of the gradient is: 271.8682544195333
# 294
# The equation of the fit plane is: Z = -7.149409151525974e-05 * X + -0.0002250254030045847 * Y + 0.05319334580895507
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.2523130268325553
# The direction of the gradient is: 278.1017728578526
# 295
# The equation of the fit plane is: Z = -6.785030709937286e-05 * X + -5.035467092759505e-06 * Y + 0.012986906233415087
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4409208241081192
# The direction of the gradient is: 350.59501076873374
# 296
# The equation of the fit plane is: Z = -9.163869874620366e-05 * X + -0.00027345646547875563 * Y + 0.06547320129498468
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.956705226748858
# The direction of the gradient is: 278.53902185083297
# 297
# The equation of the fit plane is: Z = -9.566656619034297e-05 * X + -0.0003907049888863754 * Y + 0.0881263498054108
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.624078231524514
# The direction of the gradient is: 276.26076572655927
# 298
# The equation of the fit plane is: Z = -9.907008279029656e-05 * X + -0.00038623646219472773 * Y + 0.08807512342431947
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.562973556115394
# The direction of the gradient is: 276.5559804052337
# 299
# The equation of the fit plane is: Z = -3.6967802540629384e-05 * X + -0.00022293610439848765 * Y + 0.04715280778921919
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.198749407579193
# The direction of the gradient is: 274.24908674949023
# 300
# The equation of the fit plane is: Z = -6.255477279436565e-05 * X + -0.0002727056811060055 * Y + 0.06078816590624206
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.922656938238861
# The direction of the gradient is: 275.86804777820987
# 301
# The equation of the fit plane is: Z = -2.3524821255442965e-05 * X + -0.00016086366077677598 * Y + 0.033890113473781666
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.306708306819396
# The direction of the gradient is: 273.74884590182273
# 302
# The equation of the fit plane is: Z = -5.9527460514958186e-05 * X + -0.000228215935833228 * Y + 0.051732501056355976
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.2877304794669175
# The direction of the gradient is: 276.6658467013193
# 303
# The equation of the fit plane is: Z = -3.8818308154402264e-05 * X + -0.00014325700320469957 * Y + 0.03382380859736319
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0648936416980015
# The direction of the gradient is: 276.92229327299395
# 304
# The equation of the fit plane is: Z = -4.064097132846833e-05 * X + -0.00014793333559442765 * Y + 0.03490719471512179
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.1327300495693673
# The direction of the gradient is: 277.01727491726103
# 305
# The equation of the fit plane is: Z = -2.3207297824070337e-05 * X + -0.00015994575913680565 * Y + 0.03325412713386767
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.293469503793504
# The direction of the gradient is: 273.71955270649244
# 306
# The equation of the fit plane is: Z = -7.0898625371476e-05 * X + -0.0002719272373721322 * Y + 0.0624729936587267
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.917422761711822
# The direction of the gradient is: 276.6630138054459
# 307
# The equation of the fit plane is: Z = -4.809264723555484e-05 * X + -0.0002079546734370838 * Y + 0.047203572698131024
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.9915217803936276
# The direction of the gradient is: 275.91578585134874
# 308
# The equation of the fit plane is: Z = -4.363296614919947e-05 * X + -0.0001828010407349589 * Y + 0.04152928291180517
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.6305866475949617
# The direction of the gradient is: 276.1043308352423
# 309
# The equation of the fit plane is: Z = -3.65228280478612e-05 * X + -0.00021444340834591072 * Y + 0.04462114797704792
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.0773575818797965
# The direction of the gradient is: 274.3637554083966
# 310
# The equation of the fit plane is: Z = -3.775328219733689e-05 * X + -0.00021424672472251954 * Y + 0.04550223539567185
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.0751622661124673
# The direction of the gradient is: 274.51429694010693
# 311
# The equation of the fit plane is: Z = -4.948626291176774e-05 * X + -0.00018588348554688384 * Y + 0.042064569195017006
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.678631920575649
# The direction of the gradient is: 276.802151585526
# 312
# The equation of the fit plane is: Z = -3.1913450422070055e-05 * X + -0.00017751131601139708 * Y + 0.03826422032548127
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.5482082581684837
# The direction of the gradient is: 274.60532835539857
# 313
# The equation of the fit plane is: Z = -5.559567798144822e-05 * X + -0.00024247990394566838 * Y + 0.054099761767657
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.487866020111722
# The direction of the gradient is: 275.8653516786681
# 314
# The equation of the fit plane is: Z = -1.5760310573994536e-05 * X + -0.00017405854488986738 * Y + 0.03420823161717895
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.4926247275168083
# The direction of the gradient is: 272.32316950983306
# 315
# The equation of the fit plane is: Z = 3.853489364406465e-06 * X + -7.262527878300692e-05 * Y + 0.013260369094109107
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.039477170306635
# The direction of the gradient is: 268.6381347977921
# 316
# The equation of the fit plane is: Z = 5.2626006714970015e-06 * X + -0.00012559144669664702 * Y + 0.021812000420686376
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.797384698677251
# The direction of the gradient is: 268.92442944645495
# 317
# The equation of the fit plane is: Z = 1.6128924750359725e-05 * X + -5.550913982363808e-05 * Y + 0.007417284024072161
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8009740850187219
# The direction of the gradient is: 262.5825478974233
# 318
# The equation of the fit plane is: Z = 6.675268608740316e-06 * X + -9.662122361830604e-05 * Y + 0.01619005147572264
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3831999026903914
# The direction of the gradient is: 268.22700655838855
# 319
# The equation of the fit plane is: Z = -1.4136724399904863e-05 * X + -0.00014349615289504023 * Y + 0.028229353012582937
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.055262884004653
# The direction of the gradient is: 272.5274134090438
# 320
# The equation of the fit plane is: Z = -3.9609742689861975e-05 * X + -0.00020220322644010983 * Y + 0.04363721339092832
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.904416469936358
# The direction of the gradient is: 275.01593655609815
# 321
# The equation of the fit plane is: Z = -6.644621977880219e-05 * X + -0.00025602393955576053 * Y + 0.057603934879919064
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.688090466201082
# The direction of the gradient is: 276.63274302311504
# 322

# %%
with h5py.File(path_GIM, 'r') as file:
    date_GIM = file['date']
    date_GIM = date_GIM[()]
date_GIM = np.char.decode(date_GIM)

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

slope_ion_GIM_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_GIM_correct[i] = slope_ion_GIM[j[0]]
slope_ion_GIM = slope_ion_GIM_correct

angle_deg_ion_GIM_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_GIM == date_split[i])[0]
    if len(j) > 0:
        angle_deg_ion_GIM_correct[i] = angle_deg_ion_GIM[j[0]]
angle_deg_ion_GIM = angle_deg_ion_GIM_correct

slope_ion_GIM_dongxifangxiang_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_GIM_dongxifangxiang_correct[i] = slope_ion_GIM_dongxifangxiang[j[0]]
slope_ion_GIM_dongxifangxiang = slope_ion_GIM_dongxifangxiang_correct

slope_ion_GIM_nanbeifangxiang_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_GIM_nanbeifangxiang_correct[i] = slope_ion_GIM_nanbeifangxiang[j[0]]
slope_ion_GIM_nanbeifangxiang = slope_ion_GIM_nanbeifangxiang_correct

# %%
######### hight_GIM

# %%
path_hight_GIM = '../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5'

# %%
# !reference_point.py ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 -y 180 -x 190
# !reference_date.py ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 --ref-date 20181211
# Out:
# WARNING: auto turn ON --write-data for file tpye timeseries
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# --------------------------------------------------
# input reference point in y/x: (180, 190)
# --------------------------------------------------
# calculating the temporal average of timeseries file: ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5
# reading timeseries data from file: ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 ...
# /home/eedy/tools/MintPy/src/mintpy/objects/stack.py:455: RuntimeWarning: Mean of empty slice
#   dmean = np.nanmean(data, axis=0)
# updating dataset values without re-writing to a new file
# update metadata
# input reference date: 20181211
# --------------------------------------------------
# change reference date for file: /panda/eedy/chile/s1_a149/mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5
# reading data ...
# referencing in time ...
# --------------------------------------------------
# open  HDF5 file /panda/eedy/chile/s1_a149/mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 in r+ mode
# writing dataset /timeseries                block: (0, 323, 0, 788, 0, 343)
# close HDF5 file /panda/eedy/chile/s1_a149/mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5.
# update "REF_DATE" attribute value to 20181211
# time used: 00 mins 2.2 secs.

# %%
timeseries_hight_GIM = readfile.read(path_hight_GIM, datasetName='timeseries')[0]
timeseries_hight_GIM = np.squeeze(timeseries_hight_GIM)
from mintpy.objects import ramp
data_out, ramp = ramp.deramp(timeseries_hight_GIM, mask_in=None, ramp_type='linear', metadata=None, max_num_sample=1e3, coeff_file=None,ignore_zero_value=True)

# %%
def function(data, a, b, c):
    '''
    拟合曲面使用的函数
    '''
    x = data[0]
    y = data[1]
    return a*x+b*y + c



slope_ion_hight_GIM = np.zeros(timeseries_hight_GIM.shape[0])
slope_ion_hight_GIM_dongxifangxiang = np.zeros(timeseries_hight_GIM.shape[0])
slope_ion_hight_GIM_nanbeifangxiang = np.zeros(timeseries_hight_GIM.shape[0])
angle_deg_ion_hight_GIM = np.zeros(timeseries_hight_GIM.shape[0])
meta = readfile.read_attribute(path_hight_GIM)
AZIMUTH_PIXEL_SIZE =  float(meta['AZIMUTH_PIXEL_SIZE'])
RANGE_PIXEL_SIZE = float(meta['RANGE_PIXEL_SIZE'])

for i in range(timeseries_hight_GIM.shape[0]):
    x_data = ramp.shape[2]
    y_data = ramp.shape[1]
    X_data, Y_data = np.meshgrid(range(x_data), range(y_data))
    Z_data = ramp[i, :,:]
    
    x_data = X_data.flatten()
    y_data = Y_data.flatten()
    z_data = Z_data.flatten()
    
    parameters, covariance = curve_fit(function, [x_data, y_data], z_data)
    print("The equation of the fit plane is: Z = {0} * X + {1} * Y + {2}".format(parameters[0],parameters[1],parameters[2]))
    
    Z_fit = function([X_data, Y_data], *parameters)
    
    # 计算梯度，考虑到横纵坐标的实际长度
    dx = parameters[1]/RANGE_PIXEL_SIZE
    dy = parameters[0]/AZIMUTH_PIXEL_SIZE
    # 计算梯度的大小和方向
    magnitude = np.hypot(dx, dy)  # 梯度的大小
    direction = np.degrees(np.arctan2(dy, dx)) + 90  # 梯度的方向，以x轴正半轴为0°，逆时针旋转为正方向
    direction = (direction + 360) % 360  # 将角度值限制在0°到360°之间

    print('The magnitude of the gradient is( cm(ion)/ 100km(juli)):', magnitude*1e7)
    print('The direction of the gradient is:', direction)

    slope_ion_hight_GIM[i] = magnitude*1e7
    angle_deg_ion_hight_GIM[i] = direction
    slope_ion_hight_GIM_dongxifangxiang[i] = dy*1e7
    slope_ion_hight_GIM_nanbeifangxiang[i] = dx*1e7
    

    print(i)
# Out:
# The equation of the fit plane is: Z = -2.4563272813613404e-05 * X + -2.3176362412283566e-05 * Y + 0.0047913434527000155
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.36711775765301624
# The direction of the gradient is: 295.40129093249504
# 0
# The equation of the fit plane is: Z = 2.3185320043959348e-05 * X + 3.875252371542228e-05 * Y + -0.014571445919700974
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.574081080169433
# The direction of the gradient is: 105.00618822467004
# 1
# The equation of the fit plane is: Z = 3.273770872830359e-05 * X + -4.938663474604497e-05 * Y + 0.0007701836085018587
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.737175338144982
# The direction of the gradient is: 253.45824440449337
# 2
# The equation of the fit plane is: Z = -2.758152541339962e-05 * X + -0.0002441435661022982 * Y + 0.046761170672165744
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.497883820116545
# The direction of the gradient is: 272.89769100466106
# 3
# The equation of the fit plane is: Z = 5.375746352309421e-05 * X + -0.00014246438680552543 * Y + 0.010934013975733682
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0674289206136223
# The direction of the gradient is: 260.4039062898046
# 4
# The equation of the fit plane is: Z = 2.7580807767939692e-05 * X + 0.0001297114703646136 * Y + -0.03681725362715272
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8644246915843166
# The direction of the gradient is: 95.44213576019007
# 5
# The equation of the fit plane is: Z = 3.9484410601498904e-05 * X + -0.00014296444811100307 * Y + 0.013383139423626596
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0612581773378564
# The direction of the gradient is: 262.94584460801286
# 6
# The equation of the fit plane is: Z = -3.740591314898396e-05 * X + -0.00032363319167080486 * Y + 0.06146138758635583
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.637021133775607
# The direction of the gradient is: 272.9644831923183
# 7
# The equation of the fit plane is: Z = -6.685106406081881e-05 * X + -0.00027594371436972387 * Y + 0.0588151418526665
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.971627341779713
# The direction of the gradient is: 276.194986627023
# 8
# The equation of the fit plane is: Z = -6.597693285990985e-05 * X + -0.0001617075326139199 * Y + 0.04049271854810424
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.352191444543238
# The direction of the gradient is: 280.35958539316823
# 9
# The equation of the fit plane is: Z = -3.2494707721899975e-05 * X + -0.00011575419902889909 * Y + 0.02510451759315531
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6693583648795045
# The direction of the gradient is: 277.16887196627135
# 10
# The equation of the fit plane is: Z = -5.02999041388468e-05 * X + -0.0001457585141002252 * Y + 0.03403061240009748
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.110418490417054
# The direction of the gradient is: 278.7893604601426
# 11
# The equation of the fit plane is: Z = -1.549411190139809e-05 * X + -0.00018815022517848975 * Y + 0.03324252885905473
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.6940435419896285
# The direction of the gradient is: 272.11307324803516
# 12
# The equation of the fit plane is: Z = 9.905230622627203e-05 * X + 2.057836527802472e-05 * Y + -0.027049631211969325
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6999775926713001
# The direction of the gradient is: 155.12373895548956
# 13
# The equation of the fit plane is: Z = 1.9647809398743633e-05 * X + -4.7968286873692274e-05 * Y + 0.0003312448024734971
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6978333847028404
# The direction of the gradient is: 259.600713965601
# 14
# The equation of the fit plane is: Z = 2.654811263677398e-05 * X + -0.00010607501544597973 * Y + 0.011782362270173439
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.527323639080819
# The direction of the gradient is: 263.60177369151336
# 15
# The equation of the fit plane is: Z = 9.625414227155977e-06 * X + -0.00011749354646349061 * Y + 0.017665509596569012
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.682328604141566
# The direction of the gradient is: 267.89786764625296
# 16
# The equation of the fit plane is: Z = 3.189831066454751e-05 * X + -0.00012815353856286931 * Y + 0.015159417560095497
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8450967043867146
# The direction of the gradient is: 263.6365038017509
# 17
# The equation of the fit plane is: Z = -6.099236432645971e-05 * X + -0.00026904820577327025 * Y + 0.05819590449248827
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.869575600177356
# The direction of the gradient is: 275.7997338506788
# 18
# The equation of the fit plane is: Z = -1.3160563320361689e-05 * X + -0.0001809075406417957 * Y + 0.03277402496320413
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.5899518825192476
# The direction of the gradient is: 271.866868168004
# 19
# The equation of the fit plane is: Z = -3.37406776039199e-05 * X + -0.00015752434892223277 * Y + 0.03145724204028767
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.2643468157929707
# The direction of the gradient is: 275.48185651002956
# 20
# The equation of the fit plane is: Z = -5.1649156496116474e-05 * X + -7.571108898560298e-05 * Y + 0.02233346319158686
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1328133752427405
# The direction of the gradient is: 286.99600383790533
# 21
# The equation of the fit plane is: Z = -5.1440398402008367e-05 * X + -0.00011735685390625788 * Y + 0.02890502114560188
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7113180091907039
# The direction of the gradient is: 281.1109982512307
# 22
# The equation of the fit plane is: Z = -5.514891989357985e-05 * X + -9.285398275866789e-05 * Y + 0.025368902273926356
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3748719820681523
# The direction of the gradient is: 284.90170855091833
# 23
# The equation of the fit plane is: Z = -2.58400040177373e-05 * X + -0.00012974021372310265 * Y + 0.02601487112107935
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8638090080567
# The direction of the gradient is: 275.0993955250957
# 24
# The equation of the fit plane is: Z = -3.308746104121917e-05 * X + -0.00017852711682629326 * Y + 0.0357851359673986
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.5633084213810604
# The direction of the gradient is: 274.74693789664445
# 25
# The equation of the fit plane is: Z = -6.08333011481856e-05 * X + -7.121753296116894e-05 * Y + 0.023398722943216762
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0911227840221889
# The direction of the gradient is: 290.9428584546358
# 26
# The equation of the fit plane is: Z = -5.97608373991494e-05 * X + -9.197579126615167e-05 * Y + 0.02625798315287096
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.370701317350697
# The direction of the gradient is: 286.23126484906385
# 27
# The equation of the fit plane is: Z = -4.8157818160702544e-05 * X + -8.50615623139905e-05 * Y + 0.022956144201412267
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.255680638689676
# The direction of the gradient is: 284.23370396455334
# 28
# The equation of the fit plane is: Z = -7.255881898848756e-05 * X + -7.246963988700645e-05 * Y + 0.025614130334148954
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1365174208245301
# The direction of the gradient is: 294.16109145362054
# 29
# The equation of the fit plane is: Z = -4.426690055396121e-05 * X + -7.207052208494631e-05 * Y + 0.01970434976001763
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0695836928099578
# The direction of the gradient is: 285.38690263400724
# 30
# The equation of the fit plane is: Z = -5.746437919282274e-05 * X + -8.939923995660773e-05 * Y + 0.02556099649220546
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3311936163575144
# The direction of the gradient is: 286.0663774332136
# 31
# The equation of the fit plane is: Z = -6.504762610540754e-05 * X + -7.872574634683706e-05 * Y + 0.024766492085345634
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.201188786419752
# The direction of the gradient is: 290.3147751694962
# 32
# The equation of the fit plane is: Z = -3.8106453164747796e-05 * X + -0.0001030778832494751 * Y + 0.024455421940401973
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4950210928290606
# The direction of the gradient is: 279.40496722010494
# 33
# The equation of the fit plane is: Z = -4.781635647114644e-05 * X + -0.00013368856355632023 * Y + 0.0311122820939397
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.9373359732075135
# The direction of the gradient is: 279.1044720328722
# 34
# The equation of the fit plane is: Z = -3.763694903220305e-06 * X + -0.00011930994660688086 * Y + 0.020195020535331714
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7073575402573418
# The direction of the gradient is: 270.80976389981413
# 35
# The equation of the fit plane is: Z = -4.879805218151025e-05 * X + -0.00018240378951323092 * Y + 0.039969174393676705
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.6286698294017183
# The direction of the gradient is: 276.83519769541977
# 36
# The equation of the fit plane is: Z = 4.408146645216389e-06 * X + -0.00016758211729660211 * Y + 0.026072611684861222
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.398072362120402
# The direction of the gradient is: 269.32476052647337
# 37
# The equation of the fit plane is: Z = -5.8401360218060775e-06 * X + -0.00019912505766348464 * Y + 0.03363481460673116
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.84949473773888
# The direction of the gradient is: 270.75287282295136
# 38
# The equation of the fit plane is: Z = 5.845089505436235e-05 * X + 2.8212588917605956e-05 * Y + -0.01906913865848652
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5508088447499294
# The direction of the gradient is: 132.86968383253247
# 39
# The equation of the fit plane is: Z = 6.306208640869674e-06 * X + -7.19484502646775e-05 * Y + 0.008914202988830267
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0302924710515884
# The direction of the gradient is: 267.75108340256713
# 40
# The equation of the fit plane is: Z = 5.116665034886514e-05 * X + 4.257272301439968e-05 * Y + -0.01929177774252137
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6918740222633902
# The direction of the gradient is: 118.30228711755797
# 41
# The equation of the fit plane is: Z = 4.4667818869054823e-05 * X + -4.662603494816631e-06 * Y + -0.007931027951370264
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.29403798781163865
# The direction of the gradient is: 193.11447643276006
# 42
# The equation of the fit plane is: Z = 8.452139859692168e-06 * X + -6.847717762157638e-05 * Y + 0.009228392058567004
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9813262449958068
# The direction of the gradient is: 266.83460270023227
# 43
# The equation of the fit plane is: Z = 2.4999597412752198e-05 * X + -1.693722748384929e-06 * Y + -0.0049915003493079734
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.16209644450389699
# The direction of the gradient is: 188.5985920748161
# 44
# The equation of the fit plane is: Z = 5.075775499191313e-06 * X + -6.832068142230878e-05 * Y + 0.010086362522403471
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9781312038051803
# The direction of the gradient is: 268.0934883782859
# 45
# The equation of the fit plane is: Z = -4.810563661287267e-06 * X + -7.41617944846706e-05 * Y + 0.012994220710502588
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0616173801080775
# The direction of the gradient is: 271.66472718743194
# 46
# The equation of the fit plane is: Z = 3.788021297822149e-06 * X + -0.00010007650236539395 * Y + 0.01598557825498502
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.43218465174367
# The direction of the gradient is: 269.0283983782714
# 47
# The equation of the fit plane is: Z = -9.491677499055104e-06 * X + -8.61759618893377e-05 * Y + 0.01570069841025912
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2345787123691532
# The direction of the gradient is: 272.8252326499654
# 48
# The equation of the fit plane is: Z = -5.2333386839050845e-05 * X + -0.00013377999398665494 * Y + 0.032891953675983535
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.943417429403186
# The direction of the gradient is: 279.94141247070496
# 49
# The equation of the fit plane is: Z = -3.9621231700299455e-05 * X + -0.0001403319964673401 * Y + 0.029968122499669115
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.023991154283173
# The direction of the gradient is: 277.2097482730935
# 50
# The equation of the fit plane is: Z = -4.515970909043156e-05 * X + -0.00012650052070574446 * Y + 0.029596691214080373
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8330842264789553
# The direction of the gradient is: 279.0875147835952
# 51
# The equation of the fit plane is: Z = -6.363254782183564e-05 * X + -0.00010774101527302447 * Y + 0.030046969327247923
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.594712456623923
# The direction of the gradient is: 284.8219636201993
# 52
# The equation of the fit plane is: Z = -3.7417729677220546e-05 * X + -0.00011507189218276989 * Y + 0.02551347761261655
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6639284907687466
# The direction of the gradient is: 278.2892045370935
# 53
# The equation of the fit plane is: Z = -6.279277760702184e-05 * X + -7.862778793870008e-05 * Y + 0.024764218684943433
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.194926978631674
# The direction of the gradient is: 289.68805626484664
# 54
# The equation of the fit plane is: Z = -2.9504592853998055e-05 * X + -8.951127973839342e-05 * Y + 0.020235382437942047
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2946951616896258
# The direction of the gradient is: 278.4010466916326
# 55
# The equation of the fit plane is: Z = -5.9612806317567115e-05 * X + -7.749995337432321e-05 * Y + 0.023722038485146844
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1729447026628748
# The direction of the gradient is: 289.0159746004166
# 56
# The equation of the fit plane is: Z = -3.61040906691296e-05 * X + -9.277071378783721e-05 * Y + 0.02157472755503826
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3474706851348832
# The direction of the gradient is: 279.8912332543381
# 57
# The equation of the fit plane is: Z = -4.434575649583164e-05 * X + -6.421776457955068e-05 * Y + 0.018070608505888472
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9618589537745156
# The direction of the gradient is: 287.19219824397925
# 58
# The equation of the fit plane is: Z = -5.463538935935403e-05 * X + -7.569385861941201e-05 * Y + 0.02271148916371595
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1383221830274413
# The direction of the gradient is: 287.9212196467655
# 59
# The equation of the fit plane is: Z = -5.390802499932054e-05 * X + -8.137848712587834e-05 * Y + 0.023409721889485903
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2146385879838837
# The direction of the gradient is: 286.5311351326645
# 60
# The equation of the fit plane is: Z = -5.052612639048537e-05 * X + -5.310712284435045e-05 * Y + 0.018489241782782464
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8260622865215974
# The direction of the gradient is: 293.0873538764539
# 61
# The equation of the fit plane is: Z = -4.444434801711518e-05 * X + -7.627839543016267e-05 * Y + 0.020335030472902728
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1280353138121646
# The direction of the gradient is: 284.6311407928017
# 62
# The equation of the fit plane is: Z = -4.321950995729334e-05 * X + -7.550828536486547e-05 * Y + 0.02050708959225836
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.115400144143218
# The direction of the gradient is: 284.3838316456928
# 63
# The equation of the fit plane is: Z = -5.0520525642565625e-05 * X + -8.817968109702547e-05 * Y + 0.02376450405111887
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.302657335502556
# The direction of the gradient is: 284.396983320594
# 64
# The equation of the fit plane is: Z = -3.195396745062891e-05 * X + -7.232114674288428e-05 * Y + 0.01733209396167826
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.054914320837044
# The direction of the gradient is: 281.1977262237919
# 65
# The equation of the fit plane is: Z = -3.8786149841976816e-05 * X + -8.356081848696022e-05 * Y + 0.02124149595792442
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2212417940291913
# The direction of the gradient is: 281.74834203136487
# 66
# The equation of the fit plane is: Z = -4.02819103333927e-05 * X + -8.201291391460877e-05 * Y + 0.02048332390846194
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2015899800953416
# The direction of the gradient is: 282.41107534546154
# 67
# The equation of the fit plane is: Z = -3.702744510701606e-05 * X + -0.00010524399819801102 * Y + 0.024607331735666878
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5245150033684944
# The direction of the gradient is: 278.9581202794511
# 68
# The equation of the fit plane is: Z = -5.083786661918308e-05 * X + -0.00010532195906903234 * Y + 0.027270686202956067
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5418762999905442
# The direction of the gradient is: 282.20338662078206
# 69
# The equation of the fit plane is: Z = -1.4482210417428461e-06 * X + -7.503689752743699e-05 * Y + 0.01151890279170952
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0737311611126976
# The direction of the gradient is: 270.4954487396725
# 70
# The equation of the fit plane is: Z = 1.2148819961331122e-05 * X + -9.646675639651746e-05 * Y + 0.012285640827533638
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3825231584724724
# The direction of the gradient is: 266.7704225845688
# 71
# The equation of the fit plane is: Z = -1.2289446646994127e-05 * X + -7.784468969133639e-05 * Y + 0.01423351886914942
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1166503235130505
# The direction of the gradient is: 274.0460399147015
# 72
# The equation of the fit plane is: Z = 2.279175289130095e-05 * X + -7.542999929452762e-05 * Y + 0.0062586728084427085
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.08916192581727
# The direction of the gradient is: 262.29006448483756
# 73
# The equation of the fit plane is: Z = 2.2665734539101016e-05 * X + -9.476738898647844e-05 * Y + 0.0105970277625511
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3637751563415796
# The direction of the gradient is: 263.8834538835381
# 74
# The equation of the fit plane is: Z = 5.729638404858371e-05 * X + -5.355450818169303e-05 * Y + -0.00389831848768079
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8497957857044826
# The direction of the gradient is: 244.38899338087765
# 75
# The equation of the fit plane is: Z = 3.499631025259443e-05 * X + 3.1976947243607676e-05 * Y + -0.013988356891820972
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5096019069874992
# The direction of the gradient is: 116.12133633787317
# 76
# The equation of the fit plane is: Z = -9.62389851684594e-06 * X + -0.00010447912146908119 * Y + 0.019159057604045553
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4962477823114317
# The direction of the gradient is: 272.3633317653332
# 77
# The equation of the fit plane is: Z = -9.545551465839423e-06 * X + -0.0001001865684036098 * Y + 0.018523215023693855
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4348592923916272
# The direction of the gradient is: 272.4444293185191
# 78
# The equation of the fit plane is: Z = 5.170953100514532e-05 * X + -2.4732249822083237e-05 * Y + -0.006505523349606059
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.48491194744091953
# The direction of the gradient is: 226.86981749517372
# 79
# The equation of the fit plane is: Z = 1.0251190625259871e-05 * X + -6.910390747776472e-05 * Y + 0.00936214045812906
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.990978510086369
# The direction of the gradient is: 266.1973796752384
# 80
# The equation of the fit plane is: Z = 2.114601855359333e-05 * X + -5.8627164050106e-05 * Y + 0.004727702903193893
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8497705025277108
# The direction of the gradient is: 260.82004252182367
# 81
# The equation of the fit plane is: Z = -2.7274279582915152e-05 * X + -8.024409781330216e-05 * Y + 0.01828158299558886
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.161438109773309
# The direction of the gradient is: 278.6589587734694
# 82
# The equation of the fit plane is: Z = 0.0 * X + 0.0 * Y + 5e-324
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.0
# The direction of the gradient is: 90.0
# 83
# The equation of the fit plane is: Z = 2.073626938959621e-05 * X + -8.321022437154418e-05 * Y + 0.009656274517589528
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1980407231160985
# The direction of the gradient is: 263.6289883931021
# 84
# The equation of the fit plane is: Z = 8.322702860563034e-06 * X + -5.513917898249441e-05 * Y + 0.007118485477691033
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7907799236536501
# The direction of the gradient is: 266.1310522049487
# 85
# The equation of the fit plane is: Z = 3.6655672035426223e-06 * X + -5.554012290320494e-05 * Y + 0.008410653197752738
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7950621575693563
# The direction of the gradient is: 268.3062185169297
# 86
# The equation of the fit plane is: Z = 3.67662009106944e-05 * X + -2.2153666629321913e-05 * Y + -0.004178356743699353
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.39502467654002105
# The direction of the gradient is: 233.36609548944693
# 87
# The equation of the fit plane is: Z = 6.318029001195764e-06 * X + -5.083519391984794e-05 * Y + 0.006795383981195539
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7285196086938104
# The direction of the gradient is: 266.81273333929175
# 88
# The equation of the fit plane is: Z = -1.3836655095717908e-06 * X + -5.2826839559819444e-05 * Y + 0.008806496952473458
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7559428849937707
# The direction of the gradient is: 270.67236658061796
# 89
# The equation of the fit plane is: Z = 2.736523929079005e-05 * X + -4.6625280716524395e-05 * Y + 0.0022840987066229837
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6898358948789395
# The direction of the gradient is: 255.26655395048488
# 90
# The equation of the fit plane is: Z = 1.8209293689032384e-05 * X + -6.504083461649077e-05 * Y + 0.006804267263724923
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9379523448021309
# The direction of the gradient is: 262.8501971410692
# 91
# The equation of the fit plane is: Z = -1.0094495707928233e-06 * X + -8.877394742718439e-05 * Y + 0.014837579019101564
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2702687628883989
# The direction of the gradient is: 270.2919072674507
# 92
# The equation of the fit plane is: Z = -1.1646636803623416e-05 * X + -0.00012560015717482653 * Y + 0.02283311091153279
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7987430772131652
# The direction of the gradient is: 272.3790864403712
# 93
# The equation of the fit plane is: Z = -2.4972820209417696e-06 * X + -0.0001237612836031007 * Y + 0.020007616245621248
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7709528708522015
# The direction of the gradient is: 270.517988982221
# 94
# The equation of the fit plane is: Z = 1.802557318248049e-05 * X + -8.595566265785326e-05 * Y + 0.009344938704708178
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2353431110572552
# The direction of the gradient is: 264.6322661012548
# 95
# The equation of the fit plane is: Z = 7.972309363636458e-06 * X + -8.394689258901348e-05 * Y + 0.010225160642588018
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.20226963301662
# The direction of the gradient is: 267.5634956708142
# 96
# The equation of the fit plane is: Z = 7.084377153953903e-06 * X + -0.00011501945618990214 * Y + 0.016463689289300032
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6464216642878702
# The direction of the gradient is: 268.41922623511186
# 97
# The equation of the fit plane is: Z = -2.3948318839563433e-05 * X + -0.00012382441542027581 * Y + 0.02389256066586892
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.778423704724671
# The direction of the gradient is: 274.9526173311539
# 98
# The equation of the fit plane is: Z = -4.336015719431136e-05 * X + -0.00014027378302213574 * Y + 0.03161234506183698
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.026313910225285
# The direction of the gradient is: 277.88514917771727
# 99
# The equation of the fit plane is: Z = -4.633197718888757e-05 * X + -0.00016619631882884111 * Y + 0.03596295227046221
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.396555916675337
# The direction of the gradient is: 277.1197631499585
# 100
# The equation of the fit plane is: Z = -5.928778572194668e-05 * X + -0.0001341241869627718 * Y + 0.03355860421600927
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.9564397640627293
# The direction of the gradient is: 281.202719623087
# 101
# The equation of the fit plane is: Z = -4.9149478137597725e-05 * X + -0.00010057175685505202 * Y + 0.02583073111384116
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4731590817842521
# The direction of the gradient is: 282.3507079820788
# 102
# The equation of the fit plane is: Z = -5.831880271144261e-05 * X + -7.405867062846837e-05 * Y + 0.023230962105118342
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1237179518001823
# The direction of the gradient is: 289.4341268459907
# 103
# The equation of the fit plane is: Z = -5.68903751678624e-05 * X + -8.758225230088007e-05 * Y + 0.02548446770945081
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.305196794331918
# The direction of the gradient is: 286.2270005574002
# 104
# The equation of the fit plane is: Z = -5.683605924635378e-05 * X + -6.982877762777249e-05 * Y + 0.022360184392443964
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.063537348440157
# The direction of the gradient is: 290.03609277935595
# 105
# The equation of the fit plane is: Z = -4.4873021000561386e-05 * X + -6.067620748952808e-05 * Y + 0.018515022899456456
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.914628038985572
# The direction of the gradient is: 288.33288460683605
# 106
# The equation of the fit plane is: Z = -5.627906661078166e-05 * X + -6.830093148419024e-05 * Y + 0.021818083745689804
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0417835429683557
# The direction of the gradient is: 290.26352464222055
# 107
# The equation of the fit plane is: Z = -5.580612424198768e-05 * X + -7.387330698229068e-05 * Y + 0.022390159949500194
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1159486380099235
# The direction of the gradient is: 288.69946089177813
# 108
# The equation of the fit plane is: Z = -7.112569294039972e-05 * X + -8.069612824444969e-05 * Y + 0.02655118740061054
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2414457912132988
# The direction of the gradient is: 291.54967713100723
# 109
# The equation of the fit plane is: Z = -5.5786295217733435e-05 * X + -7.11365319132706e-05 * Y + 0.022330605843829603
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0788865916490304
# The direction of the gradient is: 289.3598251946298
# 110
# The equation of the fit plane is: Z = -4.87389510432541e-05 * X + -4.951679836979277e-05 * Y + 0.01694927474462038
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7743701055800919
# The direction of the gradient is: 293.7980622639901
# 111
# The equation of the fit plane is: Z = -6.568799488470071e-05 * X + -3.300441363066433e-05 * Y + 0.017674398433430615
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6327528399036677
# The direction of the gradient is: 311.72483980471185
# 112
# The equation of the fit plane is: Z = -5.67627718494476e-05 * X + -6.32830786453936e-05 * Y + 0.020675878496900293
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.9758969805072086
# The direction of the gradient is: 291.89450641124824
# 113
# The equation of the fit plane is: Z = -6.245864307321164e-05 * X + -7.411042640624403e-05 * Y + 0.024198424108564716
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1335180160495288
# The direction of the gradient is: 290.6868932476224
# 114
# The equation of the fit plane is: Z = -3.884201434561767e-05 * X + -7.999944928184563e-05 * Y + 0.020075909330815222
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1714722867353107
# The direction of the gradient is: 282.27297878703826
# 115
# The equation of the fit plane is: Z = -6.231280220192213e-05 * X + -9.459298347509065e-05 * Y + 0.0273939095673978
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4112404750564016
# The direction of the gradient is: 286.44405504034955
# 116
# The equation of the fit plane is: Z = -4.847793813296778e-05 * X + -7.252754361170551e-05 * Y + 0.020905218170593275
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0833245389773667
# The direction of the gradient is: 286.6719168338401
# 117
# The equation of the fit plane is: Z = -5.6724187812361144e-05 * X + -7.824831919101405e-05 * Y + 0.02338545901355557
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.177221720397901
# The direction of the gradient is: 287.99395879443074
# 118
# The equation of the fit plane is: Z = -6.0190178314017216e-05 * X + -5.3309776269828095e-05 * Y + 0.020142106414072658
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8548521199655383
# The direction of the gradient is: 296.8338403056642
# 119
# The equation of the fit plane is: Z = -4.7308048634875636e-05 * X + -8.403486226207217e-05 * Y + 0.022100721589190277
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2401023437513679
# The direction of the gradient is: 284.1566135017446
# 120
# The equation of the fit plane is: Z = -5.853110996926141e-05 * X + -8.777586475877024e-05 * Y + 0.025179232206472533
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3108294075373061
# The direction of the gradient is: 286.6346251340771
# 121
# The equation of the fit plane is: Z = -6.29652485445258e-05 * X + -4.6458560165045576e-05 * Y + 0.019741106969431665
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7777342258729608
# The direction of the gradient is: 301.2679001896381
# 122
# The equation of the fit plane is: Z = -5.2159365095900865e-05 * X + -8.220145585302828e-05 * Y + 0.023239304622757816
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2228189604615662
# The direction of the gradient is: 285.8705503992277
# 123
# The equation of the fit plane is: Z = -5.290950884752931e-05 * X + -0.00010934060743364325 * Y + 0.028110109362204316
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6008868299126164
# The direction of the gradient is: 282.23296318395205
# 124
# The equation of the fit plane is: Z = -1.7535991911098272e-05 * X + -0.000102296474857111 * Y + 0.01945205952473764
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.468055080170051
# The direction of the gradient is: 274.39205141783316
# 125
# The equation of the fit plane is: Z = -4.457894519670869e-05 * X + -6.902405590200553e-05 * Y + 0.019946382064440032
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0281741643160596
# The direction of the gradient is: 286.1389539832586
# 126
# The equation of the fit plane is: Z = -7.368621082762997e-05 * X + -8.352628885452159e-05 * Y + 0.027754615647262317
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.28514106575817
# The direction of the gradient is: 291.5672257055294
# 127
# The equation of the fit plane is: Z = -1.9875002296209567e-05 * X + -0.00012598540234634464 * Y + 0.02389065367149068
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8072026621820114
# The direction of the gradient is: 274.04310328840285
# 128
# The equation of the fit plane is: Z = 3.14348456267757e-05 * X + -5.182648574676768e-05 * Y + 1.5707946087147264e-05
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7684733242379816
# The direction of the gradient is: 254.7964452794106
# 129
# The equation of the fit plane is: Z = -6.626197374881952e-06 * X + -0.00010006958333055252 * Y + 0.016869257016857056
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4325097599120102
# The direction of the gradient is: 271.69935640645116
# 130
# The equation of the fit plane is: Z = 1.2724109721067593e-05 * X + -9.123454928112582e-05 * Y + 0.011274864954116151
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.308006883905089
# The direction of the gradient is: 266.424363750369
# 131
# The equation of the fit plane is: Z = -6.587945823436537e-06 * X + -0.00016486979831576527 * Y + 0.028690010307243264
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.3594737425654295
# The direction of the gradient is: 271.0256804697923
# 132
# The equation of the fit plane is: Z = 1.0677495663264938e-05 * X + -8.616587978792708e-05 * Y + 0.009978305461068654
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2348327325056943
# The direction of the gradient is: 266.82211641268634
# 133
# The equation of the fit plane is: Z = 2.638066455130554e-05 * X + -7.153454564354422e-05 * Y + 0.005824300362963347
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0374551479721419
# The direction of the gradient is: 260.61761807978473
# 134
# The equation of the fit plane is: Z = 8.50406726180345e-06 * X + -0.0001180196772589341 * Y + 0.017689962616648278
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6896046292836335
# The direction of the gradient is: 268.1508548162699
# 135
# The equation of the fit plane is: Z = 8.763398619068405e-06 * X + -9.390550560384859e-05 * Y + 0.013134955553217415
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3448529924440384
# The direction of the gradient is: 267.605702130007
# 136
# The equation of the fit plane is: Z = 2.910519012659102e-06 * X + -8.1394203062794e-05 * Y + 0.012157508834522894
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1648061580573823
# The direction of the gradient is: 269.08211266203693
# 137
# The equation of the fit plane is: Z = -6.976416872211874e-06 * X + -8.800198440194608e-05 * Y + 0.015349583836482559
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.260000460273039
# The direction of the gradient is: 272.03426246951693
# 138
# The equation of the fit plane is: Z = 4.070208223192046e-05 * X + -1.0442792856856443e-05 * Y + -0.0069124870170446115
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3006985198595465
# The direction of the gradient is: 209.79669003789297
# 139
# The equation of the fit plane is: Z = -1.4896538097837555e-05 * X + -8.941622880158866e-05 * Y + 0.017535735483350603
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2830019970630095
# The direction of the gradient is: 274.2688797214429
# 140
# The equation of the fit plane is: Z = 2.246544653471378e-05 * X + -3.696688151693118e-05 * Y + 0.001639692625650794
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.548211207577221
# The direction of the gradient is: 254.76828739436746
# 141
# The equation of the fit plane is: Z = 6.0551568625537454e-05 * X + -2.0671075298067778e-05 * Y + -0.009333832384527386
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.4880424173458271
# The direction of the gradient is: 217.30458719457602
# 142
# The equation of the fit plane is: Z = -7.83527995859425e-06 * X + -4.128299085471151e-05 * Y + 0.008114335764558053
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5928437224636248
# The direction of the gradient is: 274.8605940642731
# 143
# The equation of the fit plane is: Z = 4.221746804920498e-05 * X + -2.2201024626112547e-05 * Y + -0.004664151163310349
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.41733856974278205
# The direction of the gradient is: 229.56857898252906
# 144
# The equation of the fit plane is: Z = 4.663690167800474e-06 * X + 5.8584249113779435e-06 * Y + -0.002522124988363959
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.08899988441623782
# The direction of the gradient is: 109.63017563684252
# 145
# The equation of the fit plane is: Z = 4.430837218018702e-05 * X + 2.9823560810421572e-05 * Y + -0.01471699240606268
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5126404650780285
# The direction of the gradient is: 123.65016543363487
# 146
# The equation of the fit plane is: Z = 1.6212954535363335e-05 * X + -7.674854384104115e-05 * Y + 0.008922024814520726
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1030907887693355
# The direction of the gradient is: 264.59308287218005
# 147
# The equation of the fit plane is: Z = -5.0718737148179186e-06 * X + -9.526581352609609e-05 * Y + 0.016686762167293735
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.363531118324859
# The direction of the gradient is: 271.3664651761404
# 148
# The equation of the fit plane is: Z = 3.85449125419507e-05 * X + -1.7548695808825642e-05 * Y + -0.0061364937977863385
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.3523032767913869
# The direction of the gradient is: 225.45848736164294
# 149
# The equation of the fit plane is: Z = 4.181409020622533e-06 * X + -8.545022597376874e-05 * Y + 0.013215887591682697
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.222987514306592
# The direction of the gradient is: 268.7440006010181
# 150
# The equation of the fit plane is: Z = 2.8696036724413704e-06 * X + -7.698277124565428e-05 * Y + 0.010207692388015981
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1016878350038115
# The direction of the gradient is: 269.04316385681284
# 151
# The equation of the fit plane is: Z = 4.4731352370558875e-05 * X + -9.240154684841524e-05 * Y + 0.005834945455871398
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3529025017573009
# The direction of the gradient is: 257.7621036979856
# 152
# The equation of the fit plane is: Z = 1.9734508469434923e-05 * X + -0.00011097608058758366 * Y + 0.014306504295714421
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5929713353407824
# The direction of the gradient is: 265.4445631707714
# 153
# The equation of the fit plane is: Z = 2.5283417581160532e-05 * X + -8.29528780249591e-05 * Y + 0.006798309408661242
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1979763766278226
# The direction of the gradient is: 262.22365182421106
# 154
# The equation of the fit plane is: Z = -9.755831925872284e-06 * X + -0.00014262176706551942 * Y + 0.02541823239148826
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0417103821675893
# The direction of the gradient is: 271.7554648639539
# 155
# The equation of the fit plane is: Z = -2.347331263536974e-06 * X + -0.00013085210657316995 * Y + 0.021807391247399822
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8724024325698634
# The direction of the gradient is: 270.4605045034741
# 156
# The equation of the fit plane is: Z = -2.509982237434493e-05 * X + -0.00014893560577253448 * Y + 0.02904731929320546
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.137162577839864
# The direction of the gradient is: 274.318155916799
# 157
# The equation of the fit plane is: Z = -4.63536454546931e-05 * X + -0.0001205018545971059 * Y + 0.029131302679491218
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7496640124933966
# The direction of the gradient is: 279.77898578731117
# 158
# The equation of the fit plane is: Z = -5.570700167092742e-05 * X + -0.0001447963695386275 * Y + 0.034043799994364014
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.102424401726431
# The direction of the gradient is: 279.78035381342227
# 159
# The equation of the fit plane is: Z = -6.470603687814943e-05 * X + -6.394513276800168e-05 * Y + 0.02300460342453258
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0046285036695808
# The direction of the gradient is: 294.38868262120616
# 160
# The equation of the fit plane is: Z = -7.027158724824881e-05 * X + -0.00012409481418802925 * Y + 0.034068113887347054
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8319139941257072
# The direction of the gradient is: 284.236618404334
# 161
# The equation of the fit plane is: Z = -5.643293086595179e-05 * X + -0.00011602643650654817 * Y + 0.02939839554669825
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6991683715992556
# The direction of the gradient is: 282.29384652614203
# 162
# The equation of the fit plane is: Z = -6.363286674474296e-05 * X + -8.098199847999083e-05 * Y + 0.025519512234291063
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.228474282534131
# The direction of the gradient is: 289.3952615597908
# 163
# The equation of the fit plane is: Z = -7.644421882257658e-05 * X + -9.505742015060431e-05 * Y + 0.030038619913730254
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4457619770482302
# The direction of the gradient is: 289.8149876296363
# 164
# The equation of the fit plane is: Z = -7.092160343322855e-05 * X + -6.833210883512597e-05 * Y + 0.024971415000211935
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.078303868764685
# The direction of the gradient is: 294.93982516350263
# 165
# The equation of the fit plane is: Z = -5.647335084525964e-05 * X + -9.019888900692133e-05 * Y + 0.025746107489793953
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3404624740538542
# The direction of the gradient is: 285.6700583700857
# 166
# The equation of the fit plane is: Z = -6.118712817759191e-05 * X + -3.844973556002101e-05 * Y + 0.017394952931258353
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.6756985629008903
# The direction of the gradient is: 305.48912618856957
# 167
# The equation of the fit plane is: Z = -5.084814426050699e-05 * X + -5.286217946988207e-05 * Y + 0.018233774476438827
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8236542007855416
# The direction of the gradient is: 293.3150692177958
# 168
# The equation of the fit plane is: Z = -2.5613519707994488e-05 * X + -6.940633287748794e-05 * Y + 0.015422716733459626
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.0066084942333655
# The direction of the gradient is: 279.38875527851883
# 169
# The equation of the fit plane is: Z = -5.9992817306189236e-05 * X + -4.242099099752287e-05 * Y + 0.018195272178214365
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7185922993059742
# The direction of the gradient is: 302.3601492461752
# 170
# The equation of the fit plane is: Z = -5.870225059098751e-05 * X + -7.800421798889658e-05 * Y + 0.02383004048917099
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1778905831396749
# The direction of the gradient is: 288.6331490795983
# 171
# The equation of the fit plane is: Z = -6.358761414930865e-05 * X + -5.466036421607597e-05 * Y + 0.020925761730026478
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.88199371156791
# The direction of the gradient is: 297.5297444770834
# 172
# The equation of the fit plane is: Z = -4.942244825625856e-05 * X + -3.0082339271328114e-05 * Y + 0.013859989672821085
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.5344869856299973
# The direction of the gradient is: 306.3569589536023
# 173
# The equation of the fit plane is: Z = -6.744127516171817e-05 * X + -7.959148780969214e-05 * Y + 0.025681185015173576
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.21817555563723
# The direction of the gradient is: 290.7893832356157
# 174
# The equation of the fit plane is: Z = -6.59512105575622e-05 * X + -6.876204385405948e-05 * Y + 0.02326872626739637
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.070908467626384
# The direction of the gradient is: 293.2548993157854
# 175
# The equation of the fit plane is: Z = -7.417481242909086e-05 * X + -8.887855790972878e-05 * Y + 0.028669723259929832
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.3577499656115137
# The direction of the gradient is: 290.50210870685805
# 176
# The equation of the fit plane is: Z = -5.363616730762227e-05 * X + -9.643139215697223e-05 * Y + 0.02554430547152051
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4220235424322343
# The direction of the gradient is: 283.9936583453272
# 177
# The equation of the fit plane is: Z = -4.8887939306332044e-05 * X + -0.00010236376534817153 * Y + 0.025909841440587788
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.497865500959958
# The direction of the gradient is: 282.07825811413704
# 178
# The equation of the fit plane is: Z = -5.674011590684859e-05 * X + -7.335040542546953e-05 * Y + 0.022097055996525033
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1108105425757782
# The direction of the gradient is: 289.1157480270666
# 179
# The equation of the fit plane is: Z = -3.563230785126361e-05 * X + -6.234105255590725e-05 * Y + 0.01607853305413575
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.920814801084108
# The direction of the gradient is: 284.3643070961042
# 180
# The equation of the fit plane is: Z = -4.645979899401359e-05 * X + -0.00012636307754085294 * Y + 0.029155238187159566
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8324786149967194
# The direction of the gradient is: 279.3545651670945
# 181
# The equation of the fit plane is: Z = -6.1882975167752e-05 * X + -0.00011106343807274354 * Y + 0.030244025276090714
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.6379627546143036
# The direction of the gradient is: 284.0172265777285
# 182
# The equation of the fit plane is: Z = -3.560111497076755e-05 * X + -0.0001252517367985488 * Y + 0.027358016976277006
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8066822530505031
# The direction of the gradient is: 277.25768085653124
# 183
# The equation of the fit plane is: Z = -2.3076222110190938e-05 * X + -0.00010944741041855831 * Y + 0.021500387723977017
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5730380352177409
# The direction of the gradient is: 275.39662000277985
# 184
# The equation of the fit plane is: Z = -3.836407249740692e-05 * X + -9.035188613633192e-05 * Y + 0.021906089349600533
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.316018743536055
# The direction of the gradient is: 280.7715430698488
# 185
# The equation of the fit plane is: Z = -2.1974765227120985e-05 * X + -0.00014759335521076592 * Y + 0.02870320394231273
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.1165836497207935
# The direction of the gradient is: 273.8164891303723
# 186
# The equation of the fit plane is: Z = -1.2985250826000471e-05 * X + -0.00014248615543479445 * Y + 0.025938705712633816
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.0405106380201325
# The direction of the gradient is: 272.3382236769377
# 187
# The equation of the fit plane is: Z = -1.742791843401756e-05 * X + -0.0001529241307275213 * Y + 0.028464491539754944
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.1910177937148787
# The direction of the gradient is: 272.92308905006894
# 188
# The equation of the fit plane is: Z = -2.562226532028704e-05 * X + -0.00012356966136135232 * Y + 0.025826741248954732
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7757526867451487
# The direction of the gradient is: 275.30774937949434
# 189
# The equation of the fit plane is: Z = 2.0975732736782306e-05 * X + -0.00010406858225552145 * Y + 0.01206356953473192
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.495160597937707
# The direction of the gradient is: 264.83975171153327
# 190
# The equation of the fit plane is: Z = 4.218031306621131e-05 * X + -0.00013235561679512397 * Y + 0.013209275579617149
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.9130646146786765
# The direction of the gradient is: 261.8737311480319
# 191
# The equation of the fit plane is: Z = 2.2377138767034734e-05 * X + -0.00015711419116172127 * Y + 0.020912626419513605
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.2526947246911457
# The direction of the gradient is: 266.34867717187285
# 192
# ...
# The direction of the gradient is: 267.8325458676459
# 258
# The equation of the fit plane is: Z = 3.0724431595162128e-06 * X + -0.00015362914083236404 * Y + 0.02619094656505495
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.198343161625553
# The direction of the gradient is: 269.48660905873317
# 259
# The equation of the fit plane is: Z = 4.389414689565303e-06 * X + -5.710187704548342e-05 * Y + 0.008240793157336973
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.8175461306074526
# The direction of the gradient is: 268.0274221048952
# 260
# The equation of the fit plane is: Z = 1.614558356109515e-05 * X + -0.00013299217138081185 * Y + 0.019520607127703263
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.9057769261152433
# The direction of the gradient is: 266.8864957480022
# 261
# The equation of the fit plane is: Z = 1.5122452914082834e-05 * X + -0.00018146886022134997 * Y + 0.02844029838065133
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.598418360081688
# The direction of the gradient is: 267.8617031135507
# 262
# The equation of the fit plane is: Z = 1.952189095487942e-05 * X + -0.0002351969835816072 * Y + 0.03600782887829473
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.367722616088854
# The direction of the gradient is: 267.8701961455738
# 263
# The equation of the fit plane is: Z = -4.458350317685998e-05 * X + -0.00021039728355909406 * Y + 0.04326197887861724
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.02407943410539
# The direction of the gradient is: 275.42355160544065
# 264
# The equation of the fit plane is: Z = -2.298946973723532e-05 * X + -0.0003063989515971215 * Y + 0.05605924806653208
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.386690523122653
# The direction of the gradient is: 271.9254299455787
# 265
# The equation of the fit plane is: Z = 1.0151830263140836e-05 * X + -0.00023155643092269426 * Y + 0.03615508293093917
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.313943269170038
# The direction of the gradient is: 268.8746665703777
# 266
# The equation of the fit plane is: Z = -5.8147928150099086e-05 * X + -0.000328490786250772 * Y + 0.0651945509140688
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.7150825513656995
# The direction of the gradient is: 274.53474082032335
# 267
# The equation of the fit plane is: Z = -1.0932121714763371e-05 * X + -0.0003619652824502657 * Y + 0.06306342739839116
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.179777774072089
# The direction of the gradient is: 270.7752836103514
# 268
# The equation of the fit plane is: Z = -6.397135971417888e-05 * X + -0.000363334092536834 * Y + 0.07445113545219494
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.21504140890668
# The direction of the gradient is: 274.51056060013343
# 269
# The equation of the fit plane is: Z = -5.596527512045537e-05 * X + -0.00024109020866873183 * Y + 0.05067888267032667
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.468330113974448
# The direction of the gradient is: 275.93785953677957
# 270
# The equation of the fit plane is: Z = -2.5318386793377943e-05 * X + -0.0002121004455939706 * Y + 0.03894182503129158
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.0392490911834087
# The direction of the gradient is: 273.0614729769618
# 271
# The equation of the fit plane is: Z = -4.760423725953049e-05 * X + -0.00020335293013031393 * Y + 0.04282428524194781
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.925706410090524
# The direction of the gradient is: 275.9876952029223
# 272
# The equation of the fit plane is: Z = -5.0099331838544764e-05 * X + -0.00014981557426369487 * Y + 0.03470102719184895
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.167615839277937
# The direction of the gradient is: 278.52129989012246
# 273
# The equation of the fit plane is: Z = -5.9447412134245454e-05 * X + -0.00017400440992590727 * Y + 0.04096168682817168
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.5188023283223266
# The direction of the gradient is: 278.7029035810715
# 274
# The equation of the fit plane is: Z = -4.175634102900899e-05 * X + -0.0001586555468907633 * Y + 0.03339246628300622
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.2859064940207947
# The direction of the gradient is: 276.7253631096355
# 275
# The equation of the fit plane is: Z = -7.60447061572344e-05 * X + -0.00020896265021735263 * Y + 0.0496138445054984
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.0294989500743776
# The direction of the gradient is: 279.26072071657126
# 276
# The equation of the fit plane is: Z = -8.076528317011354e-05 * X + -0.00016334338076382735 * Y + 0.043378250422425435
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.3939230877540747
# The direction of the gradient is: 282.49149664823153
# 277
# The equation of the fit plane is: Z = -6.823410629318908e-05 * X + -0.00019584033554042882 * Y + 0.04655700331486697
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.8361878075886864
# The direction of the gradient is: 278.87273979753184
# 278
# The equation of the fit plane is: Z = -3.158367416920955e-05 * X + -0.0001924025360640502 * Y + 0.038165046467123015
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.76049354627309
# The direction of the gradient is: 274.2064928104536
# 279
# The equation of the fit plane is: Z = 3.777765611716096e-05 * X + -7.536612744721939e-05 * Y + 0.0018850514685161066
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1052644213475311
# The direction of the gradient is: 257.3421095225972
# 280
# The equation of the fit plane is: Z = -2.0288734693190328e-05 * X + -0.00027424642844200254 * Y + 0.04875993874656881
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.9263036254201844
# The direction of the gradient is: 271.89847364844684
# 281
# The equation of the fit plane is: Z = -1.4678870826374976e-05 * X + -0.00023103764328181913 * Y + 0.03981348370448758
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.3072200388632544
# The direction of the gradient is: 271.63058034349933
# 282
# The equation of the fit plane is: Z = -1.4433515826784041e-05 * X + -0.00012319792201859642 * Y + 0.019613268638816038
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.7652464509878907
# The direction of the gradient is: 273.0048299787536
# 283
# The equation of the fit plane is: Z = 8.002421125004073e-05 * X + 0.00017958269375272477 * Y + -0.052546890639781525
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.6203358070055165
# The direction of the gradient is: 101.29101731260192
# 284
# The equation of the fit plane is: Z = 5.361125965265091e-05 * X + -0.00010287477424387536 * Y + 0.004891179240719331
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5116127833919688
# The direction of the gradient is: 256.85729663952634
# 285
# The equation of the fit plane is: Z = 6.025166389796537e-05 * X + -9.895351360763045e-05 * Y + 0.0028976603814679413
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.4676553853419887
# The direction of the gradient is: 254.74031966624148
# 286
# The equation of the fit plane is: Z = -6.032346494680166e-05 * X + -0.00022024174891006502 * Y + 0.0494429088879023
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.1750456264240285
# The direction of the gradient is: 276.99632748726606
# 287
# The equation of the fit plane is: Z = 3.6202824983974476e-05 * X + -5.1792616542057007e-05 * Y + -0.001657788018070971
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.776587335820123
# The direction of the gradient is: 252.61020423057744
# 288
# The equation of the fit plane is: Z = 2.3706405686328125e-05 * X + -0.00015583923434662998 * Y + 0.021980779405537422
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.2350522283211642
# The direction of the gradient is: 266.1008735334507
# 289
# The equation of the fit plane is: Z = 3.8514931394561693e-05 * X + 1.3157872891137622e-05 * Y + -0.013604613324486562
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.31051206639109935
# The direction of the gradient is: 142.6751300431086
# 290
# The equation of the fit plane is: Z = -1.2396531508695603e-05 * X + -0.0001883948818099979 * Y + 0.03560303711532261
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.6968836555162357
# The direction of the gradient is: 271.68870922768826
# 291
# The equation of the fit plane is: Z = 1.2292368769412045e-06 * X + -0.0001718442232058408 * Y + 0.02762342210990417
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.4589042537264927
# The direction of the gradient is: 269.81636784734746
# 292
# The equation of the fit plane is: Z = 1.8655209911235417e-05 * X + -0.00023363478922770547 * Y + 0.03662409706305779
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.3451817058603357
# The direction of the gradient is: 267.9510705040675
# 293
# The equation of the fit plane is: Z = 2.01857072056986e-05 * X + -0.000223737019215443 * Y + 0.03368071566436403
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.2040319544835323
# The direction of the gradient is: 267.6851689203028
# 294
# The equation of the fit plane is: Z = -4.936434723766694e-05 * X + -0.00016689940251567466 * Y + 0.034081020042339046
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.4090157965188577
# The direction of the gradient is: 277.54892280739296
# 295
# The equation of the fit plane is: Z = -9.079255330447172e-06 * X + 0.00016714249752924616 * Y + -0.03406088774767485
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.392323616248139
# The direction of the gradient is: 88.60579324836772
# 296
# The equation of the fit plane is: Z = -5.6649629212859454e-05 * X + -0.0002137988379158399 * Y + 0.041362315246991126
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.080696524822005
# The direction of the gradient is: 276.77038436749376
# 297
# The equation of the fit plane is: Z = -3.970197828409925e-05 * X + -0.0003562193376073321 * Y + 0.06738304254167106
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.103437105802144
# The direction of the gradient is: 272.8587989578133
# 298
# The equation of the fit plane is: Z = -6.166362081007365e-06 * X + -0.0003248584219642652 * Y + 0.05388387061484432
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.6485155349580465
# The direction of the gradient is: 270.48727484324365
# 299
# The equation of the fit plane is: Z = -8.865945609750736e-05 * X + -0.00031960426636288365 * Y + 0.06842331682293126
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.608354849672239
# The direction of the gradient is: 277.085011070417
# 300
# The equation of the fit plane is: Z = -7.714191793917458e-05 * X + -0.0003226467981511625 * Y + 0.0695112831412441
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 4.643116082922456
# The direction of the gradient is: 276.1144805012067
# 301
# The equation of the fit plane is: Z = -8.046166067898675e-05 * X + -0.0002627128232055241 * Y + 0.058987811750796745
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.7943445045375386
# The direction of the gradient is: 277.81363715199234
# 302
# The equation of the fit plane is: Z = -5.877535082076814e-05 * X + -0.00019906212067998777 * Y + 0.04391169194337032
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.873164789385719
# The direction of the gradient is: 277.53601283204955
# 303
# The equation of the fit plane is: Z = -3.2462945560700067e-05 * X + -0.00021542379461967002 * Y + 0.0416680107322029
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.0894828214343875
# The direction of the gradient is: 273.86264841320894
# 304
# The equation of the fit plane is: Z = -6.58239124473032e-05 * X + -0.00023691622745914084 * Y + 0.05254673698005824
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.4161620146616114
# The direction of the gradient is: 277.09594168412485
# 305
# The equation of the fit plane is: Z = -4.6025655257652554e-05 * X + -0.00020719716531015286 * Y + 0.04300632159382309
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.979399062319022
# The direction of the gradient is: 275.6837878285004
# 306
# The equation of the fit plane is: Z = -1.8816799834409578e-05 * X + -0.0002693796303790802 * Y + 0.04707088087744069
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 3.856397568443547
# The direction of the gradient is: 271.79262249004444
# 307
# The equation of the fit plane is: Z = -0.00012597007485926792 * X + -0.00035805191104346817 * Y + 0.08515784895870282
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 5.18656994061378
# The direction of the gradient is: 278.958018475671
# 308
# The equation of the fit plane is: Z = -1.2480117090609514e-05 * X + -0.00020948999571856328 * Y + 0.03482953191900301
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.998626629416312
# The direction of the gradient is: 271.528980099485
# 309
# The equation of the fit plane is: Z = -2.113393951852784e-05 * X + -0.00020777179595240955 * Y + 0.035600786022483955
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.9760594099324984
# The direction of the gradient is: 272.60941422572796
# 310
# The equation of the fit plane is: Z = -4.421045088557176e-06 * X + -0.00016350762468294238 * Y + 0.02486973881644216
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.3397762459726494
# The direction of the gradient is: 270.6940891545362
# 311
# The equation of the fit plane is: Z = -3.405839751136854e-05 * X + -0.00010390379169094517 * Y + 0.018590123643073077
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5026913957456378
# The direction of the gradient is: 278.35504295961846
# 312
# The equation of the fit plane is: Z = -1.1206642369155175e-06 * X + -0.00012567802770367616 * Y + 0.018521642757130054
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.798321237276565
# The direction of the gradient is: 270.2289092879936
# 313
# The equation of the fit plane is: Z = 1.7827536972808328e-05 * X + -0.00019561448876706031 * Y + 0.027724561651594218
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.8013491094520404
# The direction of the gradient is: 267.66170827785936
# 314
# The equation of the fit plane is: Z = 1.8856470752113868e-07 * X + -0.00010727533019096423 * Y + 0.016105338951219177
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.5349860929187054
# The direction of the gradient is: 269.9548757464181
# 315
# The equation of the fit plane is: Z = 4.611184113787308e-05 * X + -8.186216546817904e-05 * Y + 0.005862099526644676
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.2080820947925988
# The direction of the gradient is: 255.8354473772863
# 316
# The equation of the fit plane is: Z = -7.524758290093604e-06 * X + -0.00013069029102123688 * Y + 0.024555976981833892
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.8706487166918724
# The direction of the gradient is: 271.47775515816915
# 317
# The equation of the fit plane is: Z = 5.01871638765854e-05 * X + -4.46034753300179e-05 * Y + -0.0014411478364041285
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 0.7147416209383745
# The direction of the gradient is: 243.24551367306822
# 318
# The equation of the fit plane is: Z = 7.44744467003434e-05 * X + -7.44111562905056e-05 * Y + -0.0020026135857928564
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 1.1668913895394395
# The direction of the gradient is: 245.8470303912884
# 319
# The equation of the fit plane is: Z = 3.71665978756666e-05 * X + -0.00016034758396457703 * Y + 0.019106430642295117
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.3067277625338605
# The direction of the gradient is: 264.0709397195667
# 320
# The equation of the fit plane is: Z = -4.020671759027504e-05 * X + -0.0001951733673015479 * Y + 0.03698030042736401
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.804575514234256
# The direction of the gradient is: 275.2734987896911
# 321
# The equation of the fit plane is: Z = -5.319753601111574e-05 * X + -0.0002046872514561817 * Y + 0.04045155203037418
# The magnitude of the gradient is( cm(ion)/ 100km(juli)): 2.9486277400097674
# The direction of the gradient is: 276.64199799441565
# 322

# %%
with h5py.File(path_hight_GIM, 'r') as file:
    date_hight_GIM = file['date']
    date_hight_GIM = date_hight_GIM[()]
date_hight_GIM = np.char.decode(date_hight_GIM)

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

slope_ion_hight_GIM_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_hight_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_hight_GIM_correct[i] = slope_ion_hight_GIM[j[0]]
slope_ion_hight_GIM = slope_ion_hight_GIM_correct

angle_deg_ion_hight_GIM_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_hight_GIM == date_split[i])[0]
    if len(j) > 0:
        angle_deg_ion_hight_GIM_correct[i] = angle_deg_ion_hight_GIM[j[0]]
angle_deg_ion_hight_GIM = angle_deg_ion_hight_GIM_correct

slope_ion_hight_GIM_dongxifangxiang_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_hight_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_hight_GIM_dongxifangxiang_correct[i] = slope_ion_hight_GIM_dongxifangxiang[j[0]]
slope_ion_hight_GIM_dongxifangxiang = slope_ion_hight_GIM_dongxifangxiang_correct

slope_ion_hight_GIM_nanbeifangxiang_correct = np.zeros(len(date_split))
for i in range(len(date_split)):
    j = np.where(date_hight_GIM == date_split[i])[0]
    if len(j) > 0:
        slope_ion_hight_GIM_nanbeifangxiang_correct[i] = slope_ion_hight_GIM_nanbeifangxiang[j[0]]
slope_ion_hight_GIM_nanbeifangxiang = slope_ion_hight_GIM_nanbeifangxiang_correct

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi
from scipy.stats import binned_statistic

# 假设 angle_deg_ion_split 和 slope_ion_split 是已经定义好的 numpy 数组
# 转换为弧度
ion_split_angle_deg_rad = np.deg2rad(angle_deg_ion_split)

# 计算每个bin中的均值
bin_means, bin_edges, _ = binned_statistic(ion_split_angle_deg_rad, slope_ion_split, statistic='mean', bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12))

# 从蓝色颜色图中取颜色，bin_means / bin_means.max() 使均值在 0-1 之间，以便映射到颜色的深浅
#colors = plt.get_cmap('Blues')(bin_means / np.nanmax(bin_means))
colors = plt.get_cmap('Blues')(bin_means/5)

fig = plt.figure()
ax = fig.add_subplot(111, polar=True)

# 绘制直方图，颜色由均值决定
n, bins, patches = ax.hist(ion_split_angle_deg_rad, bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12), alpha=0.7)

# 清除常规极坐标图的细节
#ax.set_yticklabels([])  # 删除y轴标签
#ax.set_yticks([])  # 删除y轴刻度

# 设置x轴标签为0-360度
ax.set_xticks(np.arange(0, 2*np.pi, np.pi/12))
ax.set_xticklabels(['270°','285°', '300°','315°', '330°','345°' ,'0°','15°', '30°','45°', '60°','75°', '90°','105°', '120°','135°', '150°','165°', '180°','195°', '210°','225°', '240°','255°'])

# 设置直方图的颜色
for i in range(len(patches)):
    patches[i].set_facecolor(colors[i])

ax.grid(True)  # 显示网格线
ax.set_title('ion_split_angle')

# 添加颜色条
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=0, vmax=5))
sm.set_array([])
cax = fig.add_axes([0.85, 0.1, 0.03, 0.8])  # 定义颜色条的位置和大小
cbar = fig.colorbar(sm, cax=cax)
cbar.set_label('Mean Slpoe (cm/100km)')

# 在径向上添加长度刻度
#ax.set_yticks(np.linspace(0, max(n), 5))  # 设置刻度范围和数量
ax.set_yticks(np.linspace(0, 150, 6))

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi
from scipy.stats import binned_statistic

# 假设 angle_deg_ion_GIM 和 slope_ion_GIM 是已经定义好的 numpy 数组
# 转换为弧度
ion_GIM_angle_deg_rad = np.deg2rad(angle_deg_ion_GIM)

# 计算每个bin中的均值
bin_means, bin_edges, _ = binned_statistic(ion_GIM_angle_deg_rad, slope_ion_GIM, statistic='mean', bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12))

# 从蓝色颜色图中取颜色，bin_means / bin_means.max() 使均值在 0-1 之间，以便映射到颜色的深浅
#colors = plt.get_cmap('Blues')(bin_means / np.nanmax(bin_means))
colors = plt.get_cmap('Blues')(bin_means/5)

fig = plt.figure()
ax = fig.add_subplot(111, polar=True)

# 绘制直方图，颜色由均值决定
n, bins, patches = ax.hist(ion_GIM_angle_deg_rad, bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12), alpha=0.7)

# 清除常规极坐标图的细节
#ax.set_yticklabels([])  # 删除y轴标签
#ax.set_yticks([])  # 删除y轴刻度

# 设置x轴标签为0-360度
ax.set_xticks(np.arange(0, 2*np.pi, np.pi/12))
ax.set_xticklabels(['270°','285°', '300°','315°', '330°','345°' ,'0°','15°', '30°','45°', '60°','75°', '90°','105°', '120°','135°', '150°','165°', '180°','195°', '210°','225°', '240°','255°'])

# 设置直方图的颜色
for i in range(len(patches)):
    patches[i].set_facecolor(colors[i])

ax.grid(True)  # 显示网格线
ax.set_title('ion_GIM_angle')

# 添加颜色条
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=0, vmax=5))
sm.set_array([])
cax = fig.add_axes([0.85, 0.1, 0.03, 0.8])  # 定义颜色条的位置和大小
cbar = fig.colorbar(sm, cax=cax)
cbar.set_label('Mean Slpoe (cm/100km)')

# 在径向上添加长度刻度
#ax.set_yticks(np.linspace(0, max(n), 5))  # 设置刻度范围和数量
ax.set_yticks(np.linspace(0, 150, 6))

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi
from scipy.stats import binned_statistic

# 假设 angle_deg_ion_GIM 和 slope_ion_GIM 是已经定义好的 numpy 数组
# 转换为弧度
ion_hight_GIM_angle_deg_rad = np.deg2rad(angle_deg_ion_hight_GIM)

# 计算每个bin中的均值
bin_means, bin_edges, _ = binned_statistic(ion_hight_GIM_angle_deg_rad, slope_ion_hight_GIM, statistic='mean', bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12))

# 从蓝色颜色图中取颜色，bin_means / bin_means.max() 使均值在 0-1 之间，以便映射到颜色的深浅
#colors = plt.get_cmap('Blues')(bin_means / np.nanmax(bin_means))
colors = plt.get_cmap('Blues')(bin_means/5)

fig = plt.figure()
ax = fig.add_subplot(111, polar=True)

# 绘制直方图，颜色由均值决定
n, bins, patches = ax.hist(ion_hight_GIM_angle_deg_rad, bins=np.arange(0, 2*np.pi+np.pi/12, np.pi/12), alpha=0.7)

# 清除常规极坐标图的细节
#ax.set_yticklabels([])  # 删除y轴标签
#ax.set_yticks([])  # 删除y轴刻度

# 设置x轴标签为0-360度
ax.set_xticks(np.arange(0, 2*np.pi, np.pi/12))
ax.set_xticklabels(['270°','285°', '300°','315°', '330°','345°' ,'0°','15°', '30°','45°', '60°','75°', '90°','105°', '120°','135°', '150°','165°', '180°','195°', '210°','225°', '240°','255°'])

# 设置直方图的颜色
for i in range(len(patches)):
    patches[i].set_facecolor(colors[i])

ax.grid(True)  # 显示网格线
ax.set_title('ion_hight_GIM_angle')

# 添加颜色条
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=0, vmax=5))
sm.set_array([])
cax = fig.add_axes([0.85, 0.1, 0.03, 0.8])  # 定义颜色条的位置和大小
cbar = fig.colorbar(sm, cax=cax)
cbar.set_label('Mean Slpoe (cm/100km)')

# 在径向上添加长度刻度
#ax.set_yticks(np.linspace(0, max(n), 5))  # 设置刻度范围和数量
ax.set_yticks(np.linspace(0, 150, 6))

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split, slope_ion_GIM)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope')
plt.ylabel('ion_GIM_slope')

# 添加标题
plt.title('ion_split_slope vs ion_GIM_slope')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-2 , 18]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=4))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=4))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_GIM, slope_ion_hight_GIM)

# 为x轴和y轴添加标签
plt.xlabel('ion_GIM_slope')
plt.ylabel('ion_hight_GIM_slope')

# 添加标题
plt.title('ion_GIM_slope vs ion_hight_GIM_slope')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-2 , 18]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=4))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=4))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split, slope_ion_hight_GIM)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope')
plt.ylabel('ion_hight_GIM_slope')

# 添加标题
plt.title('ion_split_slope vs ion_hight_GIM_slope')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-2 , 18]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=4))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=4))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split_dongxifangxiang, slope_ion_GIM_dongxifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope W-E')
plt.ylabel('ion_GIM_slope W-E')

# 添加标题
plt.title('ion_split_slope vs ion_GIM_slope in W-E direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-2 , 10]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=4))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=4))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split_dongxifangxiang, slope_ion_hight_GIM_dongxifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope W-E')
plt.ylabel('ion_hight_GIM_slope W-E')

# 添加标题
plt.title('ion_split_slope vs ion_hight_GIM_slope in W-E direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-2 , 10]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=4))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=4))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_GIM_dongxifangxiang, slope_ion_hight_GIM_dongxifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_GIM_slope W-E')
plt.ylabel('ion_hight_GIM_slope W-E')

# 添加标题
plt.title('ion_GIM_slope vs ion_hight_GIM_slope in W-E direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-1.5 , 1.5]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=1))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split_nanbeifangxiang, slope_ion_GIM_nanbeifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope N-S')
plt.ylabel('ion_GIM_slope N-S')

# 添加标题
plt.title('ion_split_slope vs ion_GIM_slope in N-S direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-12, 10]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=4))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=4))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_split_nanbeifangxiang, slope_ion_hight_GIM_nanbeifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_split_slope N-S')
plt.ylabel('ion_hight_GIM_slope N-S')

# 添加标题
plt.title('ion_split_slope vs ion_hight_GIM_slope in N-S direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim = [-12, 10]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=4))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=4))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 创建一个新的图像
plt.figure()

# 绘制散点图
plt.scatter(slope_ion_GIM_nanbeifangxiang, slope_ion_hight_GIM_nanbeifangxiang)

# 为x轴和y轴添加标签
plt.xlabel('ion_GIM_slope N-S')
plt.ylabel('ion_hight_GIM_slope N-S')

# 添加标题
plt.title('ion_GIM_slope vs ion_hight_GIM_slope in N-S direction')

# 设置横轴和纵轴的范围和跨度相同
xlim = ylim =[-8, 6]
plt.xlim(xlim)
plt.ylim(ylim)
plt.gca().set_aspect('equal')

# 添加虚线x=y
plt.plot(xlim, ylim, linestyle='dashed', color='gray')

# 设置横纵坐标的间隔
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=4))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(base=4))

# 调整刻度标签的格式
plt.gca().xaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))

# 显示图像
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split, width, label='Ion-Split slope', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM, width, label='Ion-GIM slope', alpha=1)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope(cm(ion)/ 100km(distance))')
ax.set_title('Ion-GIM Slope vs Ion-Split Slope')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split, width, label='Ion-Split slope', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM, width, label='Ion-hight-GIM slope', alpha=1)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope(cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-Split Slope')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]


ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM, width, label='Ion-hight-GIM slope', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM, width, label='Ion-GIM slope', alpha=1)


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope(cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-GIM Slope')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split_dongxifangxiang, width, label='Ion-Split slope W-E', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM_dongxifangxiang, width, label='Ion-GIM slope W-E', alpha=1) 

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope W-E (cm(ion)/ 100km(distance))')
ax.set_title('Ion-GIM Slope vs Ion-Split Slope in W-E direction')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split_dongxifangxiang, width, label='Ion-Split slope W-E', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM_dongxifangxiang, width, label='Ion-hight-GIM slope W-E', alpha=1) 

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope W-E (cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-Split Slope in W-E direction')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM_dongxifangxiang, width, label='Ion-hight-GIM slope W-E', alpha=1) 
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM_dongxifangxiang, width, label='Ion-GIM slope W-E', alpha=1) 

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope W-E (cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-GIM Slope in W-E direction')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split_nanbeifangxiang, width, label='Ion-Split slope N-S', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM_nanbeifangxiang, width, label='Ion-GIM slope N-S', alpha=1)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope N-S (cm(ion)/ 100km(distance))')
ax.set_title('Ion-GIM Slope vs Ion-Split Slope in N-S direction')

ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, slope_ion_split_nanbeifangxiang, width, label='Ion-Split slope N-S', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM_nanbeifangxiang, width, label='Ion-hight-GIM slope N-S', alpha=1)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope N-S (cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-Split Slope in N-S direction')

ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(np.array(date_GIM_numeric), slope_ion_hight_GIM_nanbeifangxiang, width, label='Ion-hight-GIM slope N-S', alpha=1)
ax.bar(np.array(date_GIM_numeric), slope_ion_GIM_nanbeifangxiang, width, label='Ion-GIM slope N-S', alpha=1)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('slope N-S (cm(ion)/ 100km(distance))')
ax.set_title('Ion-hight-GIM Slope vs Ion-GIM Slope in N-S direction')

ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

with h5py.File(path_split, 'r') as file:
    date_split = file['date']
    date_split = date_split[()]
date_split = np.char.decode(date_split)

# Create figure and axis
fig, ax = plt.subplots(figsize=(14,8))  # 设置图像大小

width = 0.03  # 更改柱状图的宽度
year = [int(date[:4]) for date in date_split]
month = [int(date[4:6]) for date in date_split]
day = [int(date[6:8]) for date in date_split]
date_GIM_numeric = [y + 1/12*m + 1/12/30*d for y, m, d in zip(year, month, day)]

ax.bar(date_GIM_numeric, angle_deg_ion_split, width, label='Ion-Split angle', alpha=1)
ax.bar(date_GIM_numeric, angle_deg_ion_GIM, width, label='Ion-GIM angle', alpha=1) 
ax.bar(date_GIM_numeric, angle_deg_ion_hight_GIM, width, label='Ion-hight-GIM angle', alpha=1) 

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('date')
ax.set_ylabel('degree')
ax.set_title('Ion-GIM angle , Ion-hight-GIM angle vs Ion-Split angle')
ax.legend()

plt.show()
