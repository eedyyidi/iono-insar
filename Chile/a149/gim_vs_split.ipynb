: ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5
# reading data from file ../mintpy_gim_ion_upsample/ion.h5 ...
# skip pixels with zero/nan value in all acquisitions
# /home/eedy/tools/MintPy/src/mintpy/timeseries2velocity.py:276: RuntimeWarning: Mean of empty slice
#   ts_stack = np.nanmean(ts_data, axis=0)
# number of pixels to invert: 139223 out of 142200 (97.9%)
# estimating time functions via linalg.lstsq ...
# estimating time functions STD from time-series fitting residual ...
# --------------------------------------------------
# open  HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5 in a mode
# writing dataset /intercept                 block: [0, 632, 0, 225]
# close HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5.
# --------------------------------------------------
# open  HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5 in a mode
# writing dataset /interceptStd              block: [0, 632, 0, 225]
# close HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5.
# --------------------------------------------------
# open  HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5 in a mode
# writing dataset /velocity                  block: [0, 632, 0, 225]
# close HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5.
# --------------------------------------------------
# open  HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5 in a mode
# writing dataset /velocityStd               block: [0, 632, 0, 225]
# close HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5.
# --------------------------------------------------
# open  HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5 in a mode
# writing dataset /residue                   block: [0, 632, 0, 225]
# close HDF5 file ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5.
# time used: 00 mins 8.2 secs.
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read input option from template file: ../mintpy_split_ion_upsample/smallbaselineApp.cfg
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: ../mintpy_split_ion_upsample/inputs/geometryRadar.h5
# calculate output pixel size using approach 1 (same pixel area before/after resampling)
# output pixel size in (lat, lon) in degree: (-0.010313478791695887, 0.013051604104084269)
# output area extent in (S, N, W, E) in degree: (-26.526033631102113, -18.399012343245754, -70.3930385583997, -65.9163383506988)
# output file row / column number: (788, 343)
# [1/1] preparing geometry for dest_box: (0, 0, 343, 788) --> full src_box: (0, 0, 225, 632)
# --------------------------------------------------
# resampling file: ../mintpy_split_ion_upsample/velocity_ion-split.h5
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: ../mintpy_split_ion_upsample/velocity_ion-split.h5
# create HDF5 file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5 with w mode
# create dataset  : intercept    of float32                   in size of (788, 343)           with compression = None
# create dataset  : interceptStd of float32                   in size of (788, 343)           with compression = None
# create dataset  : residue      of float32                   in size of (788, 343)           with compression = None
# create dataset  : velocity     of float32                   in size of (788, 343)           with compression = None
# create dataset  : velocityStd  of float32                   in size of (788, 343)           with compression = None
# add /intercept    attribute: UNIT = m
# add /interceptStd attribute: UNIT = m
# add /residue      attribute: UNIT = m
# add /velocity     attribute: UNIT = m/year
# add /velocityStd  attribute: UNIT = m/year
# close  HDF5 file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# --------------------------------------------------1/1
# reading velocity     in block (0, 0, 225, 632) from velocity_ion-split.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 788, 0, 343] to file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# --------------------------------------------------1/1
# reading velocityStd  in block (0, 0, 225, 632) from velocity_ion-split.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 788, 0, 343] to file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# --------------------------------------------------1/1
# reading intercept    in block (0, 0, 225, 632) from velocity_ion-split.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 788, 0, 343] to file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# --------------------------------------------------1/1
# reading interceptStd in block (0, 0, 225, 632) from velocity_ion-split.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 788, 0, 343] to file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# --------------------------------------------------1/1
# reading residue      in block (0, 0, 225, 632) from velocity_ion-split.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 788, 0, 343] to file: ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5
# time used: 00 mins 0.8 secs.
#
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read input option from template file: ../mintpy_gim_ion_upsample/smallbaselineApp.cfg
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: ../mintpy_gim_ion_upsample/inputs/geometryRadar.h5
# calculate output pixel size using approach 1 (same pixel area before/after resampling)
# output pixel size in (lat, lon) in degree: (-0.010313478791695887, 0.013051604104084269)
# output area extent in (S, N, W, E) in degree: (-26.526033631102113, -18.399012343245754, -70.3930385583997, -65.9163383506988)
# output file row / column number: (788, 343)
# [1/1] preparing geometry for dest_box: (0, 0, 343, 788) --> full src_box: (0, 0, 225, 632)
# --------------------------------------------------
# resampling file: ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: ../mintpy_gim_ion_upsample/velocity_ion-GIM.h5
# create HDF5 file: ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5 with w mode
# create dataset  : intercept    of float32                   in size of (788, 343)           with compression = None
# create dataset  : interceptStd of float32                   in size of (788, 343)           with compression = None
# create dataset  : residue      of float32                   in size of (788, 343)           with compression = None
# create dataset  : velocity     of float32                   in size of (788, 343)           with compression = None
# create dataset  : velocityStd  of float32                   in size of (788, 343)           with compression = None
# add /intercept    attribute: UNIT = m
# add /interceptStd attribute: UNIT = m
# add /residue      attribute: UNIT = m
# add /velocity     attribute: UNIT = m/year
# add /velocityStd  attribute: UNIT = m/year
# close  HDF5 file: ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5
# --------------------------------------------------1/1
# reading velocity     in block (0, 0, 225, 632) from velocity_ion-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 788, 0, 343] to file: ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5
# --------------------------------------------------1/1
# reading velocityStd  in block (0, 0, 225, 632) from velocity_ion-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 788, 0, 343] to file: ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5
# --------------------------------------------------1/1
# reading intercept    in block (0, 0, 225, 632) from velocity_ion-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 788, 0, 343] to file: ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5
# --------------------------------------------------1/1
# reading interceptStd in block (0, 0, 225, 632) from velocity_ion-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 788, 0, 343] to file: ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5
# --------------------------------------------------1/1
# reading residue      in block (0, 0, 225, 632) from velocity_ion-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 788, 0, 343] to file: ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5
# time used: 00 mins 0.8 secs.

# %%
## 计算高分辨率的电离层的速度以及地理编码的电离层速度
# !timeseries2velocity.py ../mintpy_hight_gim_ion_upsample/ion.h5 -t ../mintpy_hight_gim_ion_upsample/smallbaselineApp.cfg -o ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5
# !geocode.py ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5 -l ../mintpy_hight_gim_ion_upsample/inputs/geometryRadar.h5  -o ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5 -t ../mintpy_hight_gim_ion_upsample/smallbaselineApp.cfg
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read options from template file: smallbaselineApp.cfg
# open timeseries file: ion.h5
# exclude date: []
# --------------------------------------------------
# dates from input file: 323
: ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5 with w mode
# create dataset  : intercept    of <class 'numpy.float32'>   in size of (632, 225)           with compression = None
# create dataset  : interceptStd of <class 'numpy.float32'>   in size of (632, 225)           with compression = None
# create dataset  : velocity     of <class 'numpy.float32'>   in size of (632, 225)           with compression = None
# create dataset  : velocityStd  of <class 'numpy.float32'>   in size of (632, 225)           with compression = None
# create dataset  : residue      of <class 'numpy.float32'>   in size of (632, 225)           with compression = None
# add /intercept    attribute: UNIT = m
# add /interceptStd attribute: UNIT = m
# add /velocity     attribute: UNIT = m/year
# add /velocityStd  attribute: UNIT = m/year
# add /residue      attribute: UNIT = m
# close  HDF5 file: ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5
# reading data from file ../mintpy_hight_gim_ion_upsample/ion.h5 ...
# skip pixels with zero/nan value in all acquisitions
# /home/eedy/tools/MintPy/src/mintpy/timeseries2velocity.py:276: RuntimeWarning: Mean of empty slice
#   ts_stack = np.nanmean(ts_data, axis=0)
# number of pixels to invert: 139223 out of 142200 (97.9%)
# estimating time functions via linalg.lstsq ...
# estimating time functions STD from time-series fitting residual ...
# --------------------------------------------------
# open  HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5 in a mode
# writing dataset /intercept                 block: [0, 632, 0, 225]
# close HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5.
# --------------------------------------------------
# open  HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5 in a mode
# writing dataset /interceptStd              block: [0, 632, 0, 225]
# close HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5.
# --------------------------------------------------
# open  HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5 in a mode
# writing dataset /velocity                  block: [0, 632, 0, 225]
# close HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5.
# --------------------------------------------------
# open  HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5 in a mode
# writing dataset /velocityStd               block: [0, 632, 0, 225]
# close HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5.
# --------------------------------------------------
# open  HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5 in a mode
# writing dataset /residue                   block: [0, 632, 0, 225]
# close HDF5 file ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5.
# time used: 00 mins 8.6 secs.
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read input option from template file: ../mintpy_hight_gim_ion_upsample/smallbaselineApp.cfg
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: ../mintpy_hight_gim_ion_upsample/inputs/geometryRadar.h5
# calculate output pixel size using approach 1 (same pixel area before/after resampling)
# output pixel size in (lat, lon) in degree: (-0.010313478791695887, 0.013051604104084269)
# output area extent in (S, N, W, E) in degree: (-26.526033631102113, -18.399012343245754, -70.3930385583997, -65.9163383506988)
# output file row / column number: (788, 343)
# [1/1] preparing geometry for dest_box: (0, 0, 343, 788) --> full src_box: (0, 0, 225, 632)
# --------------------------------------------------
# resampling file: ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: ../mintpy_hight_gim_ion_upsample/velocity_ion-hight-GIM.h5
# create HDF5 file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5 with w mode
# create dataset  : intercept    of float32                   in size of (788, 343)           with compression = None
# create dataset  : interceptStd of float32                   in size of (788, 343)           with compression = None
# create dataset  : residue      of float32                   in size of (788, 343)           with compression = None
# create dataset  : velocity     of float32                   in size of (788, 343)           with compression = None
# create dataset  : velocityStd  of float32                   in size of (788, 343)           with compression = None
# add /intercept    attribute: UNIT = m
# add /interceptStd attribute: UNIT = m
# add /residue      attribute: UNIT = m
# add /velocity     attribute: UNIT = m/year
# add /velocityStd  attribute: UNIT = m/year
# close  HDF5 file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading velocity     in block (0, 0, 225, 632) from velocity_ion-hight-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 788, 0, 343] to file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading velocityStd  in block (0, 0, 225, 632) from velocity_ion-hight-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 788, 0, 343] to file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading intercept    in block (0, 0, 225, 632) from velocity_ion-hight-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 788, 0, 343] to file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading interceptStd in block (0, 0, 225, 632) from velocity_ion-hight-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 788, 0, 343] to file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading residue      in block (0, 0, 225, 632) from velocity_ion-hight-GIM.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 788, 0, 343] to file: ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5
# time used: 00 mins 0.9 secs.

# %%
## 电离层速度的图像展示
from mintpy.cli import view, tsview, plot_network, plot_transection
view.main('../mintpy_split_ion_upsample/geo_velocity_ion-split.h5  velocity --noverbos --title geo_velocity_ion-split --ref-lalo -22 -68 -c cmy --wrap --wrap-range -0.2 0.2 '.split())
view.main('../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5  velocity --noverbos --title geo_velocity_ion-GIM --ref-lalo -22 -68 -c cmy --wrap --wrap-range -0.2 0.2 '.split())
view.main('../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5  velocity --noverbos --title geo_velocity_ion-hight-GIM --ref-lalo -22 -68 -c cmy --wrap --wrap-range -0.2 0.2 '.split())
# Out:
# view.py ../mintpy_split_ion_upsample/geo_velocity_ion-split.h5 velocity --noverbos --title geo_velocity_ion-split --ref-lalo -22 -68 -c cmy --wrap --wrap-range -0.2 0.2
# view.py ../mintpy_gim_ion_upsample/geo_velocity_ion-GIM.h5 velocity --noverbos --title geo_velocity_ion-GIM --ref-lalo -22 -68 -c cmy --wrap --wrap-range -0.2 0.2
# view.py ../mintpy_hight_gim_ion_upsample/geo_velocity_ion-hight-GIM.h5 velocity --noverbos --title geo_velocity_ion-hight-GIM --ref-lalo -22 -68 -c cmy --wrap --wrap-range -0.2 0.2

# %%
## 将电离层时间序列变为地理坐标的
# !geocode.py ../mintpy_split_ion_upsample/ion.h5 -l ../mintpy_split_ion_upsample/inputs/geometryRadar.h5  -o ../mintpy_split_ion_upsample/geo/geo_ion-split.h5 -t ../mintpy_split_ion_upsample/smallbaselineApp.cfg
# !geocode.py ../mintpy_gim_ion_upsample/ion.h5 -l ../mintpy_gim_ion_upsample/inputs/geometryRadar.h5  -o ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 -t ../mintpy_gim_ion_upsample/smallbaselineApp.cfg
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read input option from template file: ../mintpy_split_ion_upsample/smallbaselineApp.cfg
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: ../mintpy_split_ion_upsample/inputs/geometryRadar.h5
# calculate output pixel size using approach 1 (same pixel area before/after resampling)
# output pixel size in (lat, lon) in degree: (-0.010313478791695887, 0.013051604104084269)
# output area extent in (S, N, W, E) in degree: (-26.526033631102113, -18.399012343245754, -70.3930385583997, -65.9163383506988)
# output file row / column number: (788, 343)
# [1/1] preparing geometry for dest_box: (0, 0, 343, 788) --> full src_box: (0, 0, 225, 632)
# --------------------------------------------------
# resampling file: ../mintpy_split_ion_upsample/ion.h5
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: ../mintpy_split_ion_upsample/ion.h5
# create HDF5 file: ../mintpy_split_ion_upsample/geo/geo_ion-split.h5 with w mode
# create dataset  : bperp      of float32                   in size of (320,)               with compression = None
# create dataset  : date       of |S8                       in size of (320,)               with compression = None
# create dataset  : timeseries of float32                   in size of (320, 788, 343)      with compression = None
# close  HDF5 file: ../mintpy_split_ion_upsample/geo/geo_ion-split.h5
# --------------------------------------------------1/1
# reading timeseries in block (0, 0, 225, 632) from ion.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 320, 0, 788, 0, 343] to file: ../mintpy_split_ion_upsample/geo/geo_ion-split.h5
# time used: 00 mins 3.2 secs.
#
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read input option from template file: ../mintpy_gim_ion_upsample/smallbaselineApp.cfg
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: ../mintpy_gim_ion_upsample/inputs/geometryRadar.h5
# calculate output pixel size using approach 1 (same pixel area before/after resampling)
# output pixel size in (lat, lon) in degree: (-0.010313478791695887, 0.013051604104084269)
# output area extent in (S, N, W, E) in degree: (-26.526033631102113, -18.399012343245754, -70.3930385583997, -65.9163383506988)
# output file row / column number: (788, 343)
# [1/1] preparing geometry for dest_box: (0, 0, 343, 788) --> full src_box: (0, 0, 225, 632)
# --------------------------------------------------
# resampling file: ../mintpy_gim_ion_upsample/ion.h5
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: ../mintpy_gim_ion_upsample/ion.h5
# create HDF5 file: ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 with w mode
# create dataset  : date       of |S8                       in size of (323,)               with compression = None
# create dataset  : timeseries of float32                   in size of (323, 788, 343)      with compression = None
# close  HDF5 file: ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5
# --------------------------------------------------1/1
# reading timeseries in block (0, 0, 225, 632) from ion.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 323, 0, 788, 0, 343] to file: ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5
# time used: 00 mins 3.1 secs.

# %%
## 将高分辨率的电离层时间序列变为地理坐标的
# !geocode.py ../mintpy_hight_gim_ion_upsample/ion.h5 -l ../mintpy_hight_gim_ion_upsample/inputs/geometryRadar.h5  -o ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 -t ../mintpy_hight_gim_ion_upsample/smallbaselineApp.cfg
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /home/eedy/tools/mambaforge/envs/insar/share/proj failed
# read input option from template file: ../mintpy_hight_gim_ion_upsample/smallbaselineApp.cfg
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: ../mintpy_hight_gim_ion_upsample/inputs/geometryRadar.h5
# calculate output pixel size using approach 1 (same pixel area before/after resampling)
# output pixel size in (lat, lon) in degree: (-0.010313478791695887, 0.013051604104084269)
# output area extent in (S, N, W, E) in degree: (-26.526033631102113, -18.399012343245754, -70.3930385583997, -65.9163383506988)
# output file row / column number: (788, 343)
# [1/1] preparing geometry for dest_box: (0, 0, 343, 788) --> full src_box: (0, 0, 225, 632)
# --------------------------------------------------
# resampling file: ../mintpy_hight_gim_ion_upsample/ion.h5
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: ../mintpy_hight_gim_ion_upsample/ion.h5
# create HDF5 file: ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 with w mode
# create dataset  : date       of |S8                       in size of (323,)               with compression = None
# create dataset  : timeseries of float32                   in size of (323, 788, 343)      with compression = None
# close  HDF5 file: ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5
# --------------------------------------------------1/1
# reading timeseries in block (0, 0, 225, 632) from ion.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 1 segments ...
# write data in block [0, 323, 0, 788, 0, 343] to file: ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5
# time used: 00 mins 2.8 secs.

# %%
## 电离层的时间序列展示
from mintpy.cli import view, tsview, plot_network, plot_transection
view.main('../mintpy_split_ion_upsample/geo/geo_ion-split.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20181211 --notitle --ncols 30 --nrows 6 '.split())
view.main('../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20181211 --notitle --ncols 30 --nrows 6 '.split())
view.main('../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20181211 --notitle --ncols 30 --nrows 6 '.split())
# Out:
# view.py ../mintpy_split_ion_upsample/geo/geo_ion-split.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20181211 --notitle --ncols 30 --nrows 6
# view.py ../mintpy_gim_ion_upsample/geo/geo_ion-GIM.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20181211 --notitle --ncols 30 --nrows 6
# view.py ../mintpy_hight_gim_ion_upsample/geo/geo_ion-hight-GIM.h5 --ref-yx 180 190 --wrap -c cmy --noverbos --ref-date 20181211 --notitle --ncols 30 --nrows 6
